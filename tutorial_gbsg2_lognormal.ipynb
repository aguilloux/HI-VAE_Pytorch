# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
from utils import data_processing, visualization, statistic
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
import random
def set_seed(seed=42):
    random.seed(seed)  # Python random module
    np.random.seed(seed)  # NumPy
    torch.manual_seed(seed)  # PyTorch CPU seed
    torch.cuda.manual_seed(seed)  # PyTorch GPU seed
    torch.cuda.manual_seed_all(seed)  # For multi-GPU
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False  # Disable CuDNN auto-tuning

# Set the seed
set_seed(42)

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "gbsg2"
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"

# If the dataset has no missing data, leave the "miss_file" variable empty
m_perc = 10
mask = 1
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data loading and Feature analysis

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = data_processing.read_data(data_file, feat_types_file, miss_file, true_miss_file)

# Feature analysis
data_transformed = data_processing.discrete_variables_transformation(data, feat_types_dict)
# features_df = pd.DataFrame(data_transformed, columns=["feat_" + str(i+1) for i in range(data_transformed.shape[1])])

visualization.plot_data(data_transformed, feat_types_dict)

# %% [markdown]
# ### Experiment setting

# %%
# Train-test split
train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# Adjust batch size if larger than dataset
batch_size = 100
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 500
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

rng = np.random.default_rng(seed=42)
for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = rng.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = data_processing.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau, n_generated_sample=1)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = statistic.samples_concatenation(samples_list)
    
    # Transform discrete variables back to the original values
    data_train_transformed = data_processing.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = data_processing.discrete_variables_transformation(est_data_train[0], feat_types_dict)
    # est_data_train_mean_imputed = statistic.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = statistic.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = statistic.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    visualization.print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

visualization.plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
visualization.plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
visualization.plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 3
# Epoch: [ 0]  time: 0.0905, ELBO_train: -845.24208984, KL_z: 9.70772800, KL_s: 0.43659210, reconstruction loss: -835.09776974
# Clusters: 2
# Epoch: [ 1]  time: 0.1066, ELBO_train: -777.82481689, KL_z: 9.26537685, KL_s: 0.45583546, reconstruction loss: -768.10360458
# Clusters: 2
# Epoch: [ 2]  time: 0.1226, ELBO_train: -809.47102051, KL_z: 8.99897842, KL_s: 0.48797219, reconstruction loss: -799.98406990
# Clusters: 2
# Epoch: [ 3]  time: 0.1379, ELBO_train: -804.78077393, KL_z: 8.88697510, KL_s: 0.53017418, reconstruction loss: -795.36362464
# Clusters: 2
# Epoch: [ 4]  time: 0.1536, ELBO_train: -815.90675049, KL_z: 8.94392891, KL_s: 0.56922717, reconstruction loss: -806.39359441
# Clusters: 2
# Epoch: [ 5]  time: 0.1692, ELBO_train: -772.00187988, KL_z: 9.00335732, KL_s: 0.60484016, reconstruction loss: -762.39368241
# Clusters: 2
# Epoch: [ 6]  time: 0.1849, ELBO_train: -798.44139404, KL_z: 9.31330795, KL_s: 0.65613201, reconstruction loss: -788.47195408
# Clusters: 1
# Epoch: [ 7]  time: 0.2000, ELBO_train: -793.43658447, KL_z: 9.69260540, KL_s: 0.70457623, reconstruction loss: -783.03940284
# Clusters: 2
# Epoch: [ 8]  time: 0.2157, ELBO_train: -777.73078613, KL_z: 10.22051067, KL_s: 0.75320325, reconstruction loss: -766.75707221
# Clusters: 1
# Epoch: [ 9]  time: 0.2316, ELBO_train: -753.45137939, KL_z: 10.91018562, KL_s: 0.80156243, reconstruction loss: -741.73963134
# Clusters: 1
# Epoch: [10]  time: 0.2472, ELBO_train: -738.46466064, KL_z: 11.47437267, KL_s: 0.83827820, reconstruction loss: -726.15200977
# Clusters: 1
# Epoch: [11]  time: 0.2628, ELBO_train: -745.16516113, KL_z: 12.32722874, KL_s: 0.88302178, reconstruction loss: -731.95491061
# Clusters: 1
# Epoch: [12]  time: 0.2780, ELBO_train: -743.09746094, KL_z: 13.17430611, KL_s: 0.92522440, reconstruction loss: -728.99793043
# Clusters: 1
# Epoch: [13]  time: 0.2939, ELBO_train: -702.00501709, KL_z: 14.19401951, KL_s: 0.95916634, reconstruction loss: -686.85183125
# Clusters: 1
# Epoch: [14]  time: 0.3097, ELBO_train: -709.05278320, KL_z: 15.15345497, KL_s: 0.98827910, reconstruction loss: -692.91104913
# Clusters: 1
# Epoch: [15]  time: 0.3253, ELBO_train: -720.64619141, KL_z: 16.36435394, KL_s: 1.02312183, reconstruction loss: -703.25871563
# Clusters: 1
# Epoch: [16]  time: 0.3408, ELBO_train: -709.62408447, KL_z: 17.54896507, KL_s: 1.04910243, reconstruction loss: -691.02601697
# Clusters: 1
# Epoch: [17]  time: 0.3560, ELBO_train: -695.33740234, KL_z: 18.75874214, KL_s: 1.07329948, reconstruction loss: -675.50536072
# Clusters: 1
# Epoch: [18]  time: 0.3713, ELBO_train: -670.05181885, KL_z: 20.11230545, KL_s: 1.09308290, reconstruction loss: -648.84643049
# Clusters: 1
# Epoch: [19]  time: 0.3864, ELBO_train: -670.22401123, KL_z: 21.52655449, KL_s: 1.11639285, reconstruction loss: -647.58106389
# Clusters: 1
# Epoch: [20]  time: 0.4017, ELBO_train: -659.28450928, KL_z: 22.70530739, KL_s: 1.12390382, reconstruction loss: -635.45529807
# Clusters: 1
# Epoch: [21]  time: 0.4172, ELBO_train: -656.00234375, KL_z: 24.14220963, KL_s: 1.14043732, reconstruction loss: -630.71969681
# Clusters: 1
# Epoch: [22]  time: 0.4325, ELBO_train: -655.29398193, KL_z: 25.56372299, KL_s: 1.15395582, reconstruction loss: -628.57630312
# Clusters: 2
# Epoch: [23]  time: 0.4474, ELBO_train: -629.29033203, KL_z: 26.95541039, KL_s: 1.15870235, reconstruction loss: -601.17621930
# Clusters: 2
# Epoch: [24]  time: 0.4630, ELBO_train: -630.68315430, KL_z: 28.63820000, KL_s: 1.17512951, reconstruction loss: -600.86982479
# Clusters: 2
# Epoch: [25]  time: 0.4784, ELBO_train: -592.50498047, KL_z: 29.93041191, KL_s: 1.17747242, reconstruction loss: -561.39709613
# Clusters: 2
# Epoch: [26]  time: 0.4937, ELBO_train: -620.85471191, KL_z: 31.50286102, KL_s: 1.19309144, reconstruction loss: -588.15875945
# Clusters: 2
# Epoch: [27]  time: 0.5100, ELBO_train: -595.37026367, KL_z: 32.58227806, KL_s: 1.18426280, reconstruction loss: -561.60372281
# Clusters: 2
# Epoch: [28]  time: 0.5341, ELBO_train: -580.68815918, KL_z: 33.94738617, KL_s: 1.18954780, reconstruction loss: -545.55122521
# Clusters: 2
# Epoch: [29]  time: 0.5508, ELBO_train: -583.18777466, KL_z: 35.49010315, KL_s: 1.19172130, reconstruction loss: -546.50595021
# Clusters: 2
# Epoch: [30]  time: 0.5677, ELBO_train: -579.44398193, KL_z: 36.80212936, KL_s: 1.19510453, reconstruction loss: -541.44674804
# Clusters: 2
# Epoch: [31]  time: 0.5844, ELBO_train: -562.37155762, KL_z: 38.23771667, KL_s: 1.20071757, reconstruction loss: -522.93312337
# Clusters: 2
# Epoch: [32]  time: 0.6008, ELBO_train: -566.81607666, KL_z: 39.76856003, KL_s: 1.20751734, reconstruction loss: -525.83999929
# Clusters: 2
# Epoch: [33]  time: 0.6192, ELBO_train: -565.74456787, KL_z: 40.95396957, KL_s: 1.21247609, reconstruction loss: -523.57812221
# Clusters: 2
# Epoch: [34]  time: 0.6360, ELBO_train: -559.88264160, KL_z: 42.35798264, KL_s: 1.21503124, reconstruction loss: -516.30962772
# Clusters: 2
# Epoch: [35]  time: 0.6534, ELBO_train: -540.12113037, KL_z: 43.24398575, KL_s: 1.21772501, reconstruction loss: -495.65941961
# Clusters: 2
# Epoch: [36]  time: 0.6708, ELBO_train: -530.64216309, KL_z: 44.47530823, KL_s: 1.22203054, reconstruction loss: -484.94482431
# Clusters: 2
# Epoch: [37]  time: 0.6872, ELBO_train: -536.41781616, KL_z: 45.74688034, KL_s: 1.23260438, reconstruction loss: -489.43833144
# Clusters: 2
# Epoch: [38]  time: 0.7041, ELBO_train: -519.63728027, KL_z: 46.37578049, KL_s: 1.23341897, reconstruction loss: -472.02808082
# Clusters: 2
# Epoch: [39]  time: 0.7209, ELBO_train: -535.20496826, KL_z: 47.60064392, KL_s: 1.24531982, reconstruction loss: -486.35900452
# Clusters: 2
# Epoch: [40]  time: 0.7383, ELBO_train: -520.95062866, KL_z: 48.34930573, KL_s: 1.24830623, reconstruction loss: -471.35301671
# Clusters: 2
# Epoch: [41]  time: 0.7547, ELBO_train: -516.96512451, KL_z: 49.50487366, KL_s: 1.26136124, reconstruction loss: -466.19888961
# Clusters: 2
# Epoch: [42]  time: 0.7711, ELBO_train: -519.78797607, KL_z: 50.43176956, KL_s: 1.27226918, reconstruction loss: -468.08393734
# Clusters: 2
# Epoch: [43]  time: 0.7876, ELBO_train: -486.14646606, KL_z: 50.88444366, KL_s: 1.27734392, reconstruction loss: -433.98467848
# Clusters: 2
# Epoch: [44]  time: 0.8206, ELBO_train: -508.54575806, KL_z: 51.96509857, KL_s: 1.29224007, reconstruction loss: -455.28841941
# Clusters: 2
# Epoch: [45]  time: 0.8372, ELBO_train: -495.62420654, KL_z: 52.64958572, KL_s: 1.30775044, reconstruction loss: -441.66687038
# Clusters: 2
# Epoch: [46]  time: 0.8534, ELBO_train: -490.17442017, KL_z: 52.59096756, KL_s: 1.31043067, reconstruction loss: -436.27302194
# Clusters: 2
# Epoch: [47]  time: 0.8708, ELBO_train: -503.13438110, KL_z: 54.11358032, KL_s: 1.33825338, reconstruction loss: -447.68254740
# Clusters: 2
# Epoch: [48]  time: 0.8884, ELBO_train: -473.25361328, KL_z: 54.10394135, KL_s: 1.34447129, reconstruction loss: -417.80520065
# Clusters: 3
# Epoch: [49]  time: 0.9053, ELBO_train: -477.34765015, KL_z: 54.43486633, KL_s: 1.35803981, reconstruction loss: -421.55474401
# Clusters: 3
# Epoch: [50]  time: 0.9266, ELBO_train: -478.74744263, KL_z: 55.01268158, KL_s: 1.37303400, reconstruction loss: -422.36172705
# Clusters: 3
# Epoch: [51]  time: 0.9443, ELBO_train: -469.43051147, KL_z: 55.64912796, KL_s: 1.38862255, reconstruction loss: -412.39276097
# Clusters: 3
# Epoch: [52]  time: 0.9611, ELBO_train: -479.15801392, KL_z: 55.89013138, KL_s: 1.40089097, reconstruction loss: -421.86699157
# Clusters: 2
# Epoch: [53]  time: 0.9795, ELBO_train: -449.91887207, KL_z: 55.78792419, KL_s: 1.40925841, reconstruction loss: -392.72168946
# Clusters: 2
# Epoch: [54]  time: 0.9961, ELBO_train: -462.09598389, KL_z: 56.23598251, KL_s: 1.42400265, reconstruction loss: -404.43599873
# Clusters: 2
# Epoch: [55]  time: 1.0127, ELBO_train: -459.80136719, KL_z: 56.64945526, KL_s: 1.44156666, reconstruction loss: -401.71034527
# Clusters: 2
# Epoch: [56]  time: 1.0303, ELBO_train: -446.07330322, KL_z: 56.58585281, KL_s: 1.44261849, reconstruction loss: -388.04483192
# Clusters: 2
# Epoch: [57]  time: 1.0472, ELBO_train: -463.90282593, KL_z: 57.14895020, KL_s: 1.46108127, reconstruction loss: -405.29279447
# Clusters: 2
# Epoch: [58]  time: 1.0641, ELBO_train: -446.96873169, KL_z: 57.03942108, KL_s: 1.46504383, reconstruction loss: -388.46426678
# Clusters: 2
# Epoch: [59]  time: 1.0810, ELBO_train: -451.56414185, KL_z: 57.15806885, KL_s: 1.47480247, reconstruction loss: -392.93127053
# Clusters: 2
# Epoch: [60]  time: 1.0986, ELBO_train: -455.32821655, KL_z: 56.85828476, KL_s: 1.48030536, reconstruction loss: -396.98962643
# Clusters: 2
# Epoch: [61]  time: 1.1157, ELBO_train: -432.04018555, KL_z: 56.71522903, KL_s: 1.48311338, reconstruction loss: -373.84184313
# Clusters: 2
# Epoch: [62]  time: 1.1330, ELBO_train: -442.62898560, KL_z: 57.17045670, KL_s: 1.49851227, reconstruction loss: -383.96001663
# Clusters: 2
# Epoch: [63]  time: 1.1508, ELBO_train: -439.84840088, KL_z: 56.75648346, KL_s: 1.49915085, reconstruction loss: -381.59276657
# Clusters: 2
# Epoch: [64]  time: 1.1672, ELBO_train: -441.72346802, KL_z: 57.15232162, KL_s: 1.51021612, reconstruction loss: -383.06093028
# Clusters: 2
# Epoch: [65]  time: 1.1840, ELBO_train: -432.42030029, KL_z: 56.66852264, KL_s: 1.51126640, reconstruction loss: -374.24051125
# Clusters: 2
# Epoch: [66]  time: 1.2012, ELBO_train: -415.01427612, KL_z: 56.29235306, KL_s: 1.50642884, reconstruction loss: -357.21549423
# Clusters: 2
# Epoch: [67]  time: 1.2362, ELBO_train: -424.58110352, KL_z: 56.46253357, KL_s: 1.51237471, reconstruction loss: -366.60619524
# Clusters: 2
# Epoch: [68]  time: 1.2705, ELBO_train: -416.86950684, KL_z: 56.18456955, KL_s: 1.51520004, reconstruction loss: -359.16973724
# Clusters: 2
# Epoch: [69]  time: 1.2871, ELBO_train: -428.12420044, KL_z: 55.92385330, KL_s: 1.51885328, reconstruction loss: -370.68149385
# Clusters: 2
# Epoch: [70]  time: 1.3035, ELBO_train: -409.95036011, KL_z: 55.69040146, KL_s: 1.52191648, reconstruction loss: -352.73804216
# Clusters: 2
# Epoch: [71]  time: 1.3202, ELBO_train: -428.23392944, KL_z: 55.51323395, KL_s: 1.52724485, reconstruction loss: -371.19345064
# Clusters: 2
# Epoch: [72]  time: 1.3386, ELBO_train: -417.71553955, KL_z: 54.88716431, KL_s: 1.53352389, reconstruction loss: -361.29485135
# Clusters: 2
# Epoch: [73]  time: 1.3557, ELBO_train: -407.64588013, KL_z: 54.46273117, KL_s: 1.53944077, reconstruction loss: -351.64370818
# Clusters: 2
# Epoch: [74]  time: 1.3726, ELBO_train: -421.09912109, KL_z: 54.21693573, KL_s: 1.55047014, reconstruction loss: -365.33171523
# Clusters: 2
# Epoch: [75]  time: 1.3906, ELBO_train: -412.86380615, KL_z: 53.88256607, KL_s: 1.56049891, reconstruction loss: -357.42074118
# Clusters: 2
# Epoch: [76]  time: 1.4073, ELBO_train: -406.77315674, KL_z: 53.67165070, KL_s: 1.57836370, reconstruction loss: -351.52314234
# Clusters: 2
# Epoch: [77]  time: 1.4238, ELBO_train: -400.74786377, KL_z: 53.21589279, KL_s: 1.58976886, reconstruction loss: -345.94220212
# Clusters: 2
# Epoch: [78]  time: 1.4403, ELBO_train: -398.01634521, KL_z: 52.99175568, KL_s: 1.60578780, reconstruction loss: -343.41880174
# Clusters: 2
# Epoch: [79]  time: 1.4578, ELBO_train: -402.21670532, KL_z: 52.59629822, KL_s: 1.61709788, reconstruction loss: -348.00330923
# Clusters: 2
# Epoch: [80]  time: 1.4747, ELBO_train: -401.89555054, KL_z: 52.61014938, KL_s: 1.63598156, reconstruction loss: -347.64941959
# Clusters: 2
# Epoch: [81]  time: 1.4908, ELBO_train: -396.49413452, KL_z: 52.34284973, KL_s: 1.65910127, reconstruction loss: -342.49218352
# Clusters: 2
# Epoch: [82]  time: 1.5077, ELBO_train: -392.10895996, KL_z: 51.81994400, KL_s: 1.69047010, reconstruction loss: -338.59854586
# Clusters: 2
# Epoch: [83]  time: 1.5251, ELBO_train: -377.71317139, KL_z: 50.79262543, KL_s: 1.71713803, reconstruction loss: -325.20340793
# Clusters: 2
# Epoch: [84]  time: 1.5417, ELBO_train: -381.58961182, KL_z: 50.96699524, KL_s: 1.74439652, reconstruction loss: -328.87822006
# Clusters: 2
# Epoch: [85]  time: 1.5588, ELBO_train: -391.56204224, KL_z: 50.86306381, KL_s: 1.76465919, reconstruction loss: -338.93431923
# Clusters: 2
# Epoch: [86]  time: 1.5758, ELBO_train: -370.78684082, KL_z: 50.31521683, KL_s: 1.80101635, reconstruction loss: -318.67060764
# Clusters: 2
# Epoch: [87]  time: 1.5919, ELBO_train: -381.20938110, KL_z: 50.31979752, KL_s: 1.83354332, reconstruction loss: -329.05604026
# Clusters: 2
# Epoch: [88]  time: 1.6077, ELBO_train: -380.01437988, KL_z: 51.15143051, KL_s: 1.86446893, reconstruction loss: -326.99848044
# Clusters: 2
# Epoch: [89]  time: 1.6238, ELBO_train: -378.94047241, KL_z: 49.71604233, KL_s: 1.89206254, reconstruction loss: -327.33236754
# Clusters: 2
# Epoch: [90]  time: 1.6400, ELBO_train: -377.40751343, KL_z: 49.80594254, KL_s: 1.91708169, reconstruction loss: -325.68448920
# Clusters: 2
# Epoch: [91]  time: 1.6564, ELBO_train: -370.03774414, KL_z: 49.32101822, KL_s: 1.93583863, reconstruction loss: -318.78088729
# Clusters: 2
# Epoch: [92]  time: 1.6725, ELBO_train: -360.76876831, KL_z: 49.40245056, KL_s: 1.95822251, reconstruction loss: -309.40809524
# Clusters: 2
# Epoch: [93]  time: 1.6884, ELBO_train: -371.81198730, KL_z: 49.79523392, KL_s: 1.96905472, reconstruction loss: -320.04769866
# Clusters: 2
# Epoch: [94]  time: 1.7044, ELBO_train: -380.75172119, KL_z: 49.67932129, KL_s: 1.97455738, reconstruction loss: -329.09784253
# Clusters: 2
# Epoch: [95]  time: 1.7197, ELBO_train: -361.20333862, KL_z: 49.27876587, KL_s: 1.99830525, reconstruction loss: -309.92626750
# Clusters: 1
# Epoch: [96]  time: 1.7352, ELBO_train: -366.11467285, KL_z: 49.92123337, KL_s: 2.01878262, reconstruction loss: -314.17465687
# Clusters: 1
# Epoch: [97]  time: 1.7517, ELBO_train: -357.23403320, KL_z: 48.89930801, KL_s: 2.04555464, reconstruction loss: -306.28917055
# Clusters: 1
# Epoch: [98]  time: 1.7680, ELBO_train: -339.89701538, KL_z: 48.89566345, KL_s: 2.06553884, reconstruction loss: -288.93581309
# Clusters: 1
# Epoch: [99]  time: 1.7835, ELBO_train: -364.78562012, KL_z: 48.87255325, KL_s: 2.08304315, reconstruction loss: -313.83002372
# Clusters: 1
# Epoch: [100]  time: 1.7988, ELBO_train: -358.94632874, KL_z: 48.83755188, KL_s: 2.09603314, reconstruction loss: -308.01274371
# Clusters: 1
# Epoch: [101]  time: 1.8140, ELBO_train: -364.31846313, KL_z: 48.09203186, KL_s: 2.11863031, reconstruction loss: -314.10780096
# Clusters: 1
# Epoch: [102]  time: 1.8293, ELBO_train: -359.70771484, KL_z: 48.37847977, KL_s: 2.13618159, reconstruction loss: -309.19305348
# Clusters: 1
# Epoch: [103]  time: 1.8445, ELBO_train: -340.81901245, KL_z: 47.38503418, KL_s: 2.14810171, reconstruction loss: -291.28587656
# Clusters: 1
# Epoch: [104]  time: 1.8598, ELBO_train: -355.24725037, KL_z: 48.45423355, KL_s: 2.15498242, reconstruction loss: -304.63803439
# Clusters: 1
# Epoch: [105]  time: 1.8749, ELBO_train: -351.07751465, KL_z: 48.10272141, KL_s: 2.15766878, reconstruction loss: -300.81712446
# Clusters: 1
# Epoch: [106]  time: 1.8900, ELBO_train: -340.90647583, KL_z: 47.37244034, KL_s: 2.15716162, reconstruction loss: -291.37687387
# Clusters: 1
# Epoch: [107]  time: 1.9053, ELBO_train: -348.70800171, KL_z: 47.22327957, KL_s: 2.15842524, reconstruction loss: -299.32629690
# Clusters: 1
# Epoch: [108]  time: 1.9204, ELBO_train: -337.17455444, KL_z: 46.91096191, KL_s: 2.16210127, reconstruction loss: -288.10149126
# Clusters: 1
# Epoch: [109]  time: 1.9359, ELBO_train: -336.20211792, KL_z: 47.14555283, KL_s: 2.15771089, reconstruction loss: -286.89885421
# Clusters: 1
# Epoch: [110]  time: 1.9511, ELBO_train: -346.41997986, KL_z: 47.50131454, KL_s: 2.15654507, reconstruction loss: -296.76212025
# Clusters: 1
# Epoch: [111]  time: 1.9672, ELBO_train: -334.80249023, KL_z: 47.07687607, KL_s: 2.16023436, reconstruction loss: -285.56537981
# Clusters: 1
# Epoch: [112]  time: 1.9829, ELBO_train: -336.25137939, KL_z: 46.35943527, KL_s: 2.16552329, reconstruction loss: -287.72642083
# Clusters: 1
# Epoch: [113]  time: 1.9982, ELBO_train: -341.13006592, KL_z: 46.68404312, KL_s: 2.17347822, reconstruction loss: -292.27254457
# Clusters: 1
# Epoch: [114]  time: 2.0138, ELBO_train: -336.86619568, KL_z: 46.16750488, KL_s: 2.18004031, reconstruction loss: -288.51865048
# Clusters: 1
# Epoch: [115]  time: 2.0289, ELBO_train: -320.01637573, KL_z: 45.77291336, KL_s: 2.18255620, reconstruction loss: -272.06090617
# Clusters: 1
# Epoch: [116]  time: 2.0443, ELBO_train: -333.39408569, KL_z: 46.05052109, KL_s: 2.18351188, reconstruction loss: -285.16005273
# Clusters: 1
# Epoch: [117]  time: 2.0596, ELBO_train: -336.22619934, KL_z: 45.73590393, KL_s: 2.18385496, reconstruction loss: -288.30644045
# Clusters: 1
# Epoch: [118]  time: 2.0746, ELBO_train: -328.57247925, KL_z: 45.49701767, KL_s: 2.18322845, reconstruction loss: -280.89223313
# Clusters: 1
# Epoch: [119]  time: 2.0900, ELBO_train: -323.62200317, KL_z: 45.17568817, KL_s: 2.18822989, reconstruction loss: -276.25808511
# Clusters: 1
# Epoch: [120]  time: 2.1053, ELBO_train: -326.66003418, KL_z: 45.04573669, KL_s: 2.19231958, reconstruction loss: -279.42197790
# Clusters: 1
# Epoch: [121]  time: 2.1207, ELBO_train: -328.19318237, KL_z: 44.33101959, KL_s: 2.19384022, reconstruction loss: -281.66832256
# Clusters: 1
# Epoch: [122]  time: 2.1361, ELBO_train: -313.54100342, KL_z: 44.15363159, KL_s: 2.19452825, reconstruction loss: -267.19284358
# Clusters: 1
# Epoch: [123]  time: 2.1515, ELBO_train: -320.08072815, KL_z: 44.60295715, KL_s: 2.19398675, reconstruction loss: -273.28378425
# Clusters: 1
# Epoch: [124]  time: 2.1666, ELBO_train: -324.03900757, KL_z: 44.49511108, KL_s: 2.19366508, reconstruction loss: -277.35023141
# Clusters: 1
# Epoch: [125]  time: 2.1825, ELBO_train: -325.94720764, KL_z: 44.39339600, KL_s: 2.19404106, reconstruction loss: -279.35977058
# Clusters: 1
# Epoch: [126]  time: 2.1978, ELBO_train: -326.94043579, KL_z: 44.39292755, KL_s: 2.19220095, reconstruction loss: -280.35530729
# Clusters: 1
# Epoch: [127]  time: 2.2133, ELBO_train: -322.38952637, KL_z: 44.38144760, KL_s: 2.19309759, reconstruction loss: -275.81498117
# Clusters: 1
# Epoch: [128]  time: 2.2284, ELBO_train: -324.88236694, KL_z: 44.12727051, KL_s: 2.20635390, reconstruction loss: -278.54874253
# Clusters: 1
# Epoch: [129]  time: 2.2440, ELBO_train: -289.70826111, KL_z: 43.16384430, KL_s: 2.21743865, reconstruction loss: -244.32697816
# Clusters: 1
# Epoch: [130]  time: 2.2590, ELBO_train: -311.23648376, KL_z: 43.47531281, KL_s: 2.22252493, reconstruction loss: -265.53864603
# Clusters: 1
# Epoch: [131]  time: 2.2740, ELBO_train: -312.84078979, KL_z: 42.82407150, KL_s: 2.22611871, reconstruction loss: -267.79059958
# Clusters: 1
# Epoch: [132]  time: 2.2893, ELBO_train: -318.03056641, KL_z: 42.75341339, KL_s: 2.22635069, reconstruction loss: -273.05080233
# Clusters: 1
# Epoch: [133]  time: 2.3045, ELBO_train: -317.96419678, KL_z: 42.82802811, KL_s: 2.22788458, reconstruction loss: -272.90828409
# Clusters: 1
# Epoch: [134]  time: 2.3196, ELBO_train: -316.46212158, KL_z: 42.53897705, KL_s: 2.22818789, reconstruction loss: -271.69495664
# Clusters: 1
# Epoch: [135]  time: 2.3348, ELBO_train: -316.12446289, KL_z: 42.37472763, KL_s: 2.22792997, reconstruction loss: -271.52180529
# Clusters: 1
# Epoch: [136]  time: 2.3499, ELBO_train: -303.19080811, KL_z: 41.97738266, KL_s: 2.22804627, reconstruction loss: -258.98537917
# Clusters: 1
# Epoch: [137]  time: 2.3654, ELBO_train: -303.79229126, KL_z: 42.17592545, KL_s: 2.22903957, reconstruction loss: -259.38732624
# Clusters: 1
# Epoch: [138]  time: 2.3804, ELBO_train: -297.44554443, KL_z: 41.79296341, KL_s: 2.22895389, reconstruction loss: -253.42362714
# Clusters: 1
# Epoch: [139]  time: 2.3961, ELBO_train: -300.32070007, KL_z: 41.59884796, KL_s: 2.22802544, reconstruction loss: -256.49382668
# Clusters: 1
# Epoch: [140]  time: 2.4115, ELBO_train: -303.14296265, KL_z: 41.87241669, KL_s: 2.22799673, reconstruction loss: -259.04254923
# Clusters: 1
# Epoch: [141]  time: 2.4267, ELBO_train: -293.02789612, KL_z: 41.02045670, KL_s: 2.22709026, reconstruction loss: -249.78034916
# Clusters: 1
# Epoch: [142]  time: 2.4421, ELBO_train: -305.41640930, KL_z: 41.21014328, KL_s: 2.22718172, reconstruction loss: -261.97908430
# Clusters: 1
# Epoch: [143]  time: 2.4575, ELBO_train: -288.57930908, KL_z: 40.23716431, KL_s: 2.22710381, reconstruction loss: -246.11504097
# Clusters: 1
# Epoch: [144]  time: 2.4733, ELBO_train: -299.85649414, KL_z: 41.12455521, KL_s: 2.22757506, reconstruction loss: -256.50436387
# Clusters: 1
# Epoch: [145]  time: 2.4885, ELBO_train: -285.03793640, KL_z: 40.51781082, KL_s: 2.22767897, reconstruction loss: -242.29244661
# Clusters: 1
# Epoch: [146]  time: 2.5037, ELBO_train: -304.72597046, KL_z: 40.79731827, KL_s: 2.22704668, reconstruction loss: -261.70160551
# Clusters: 1
# Epoch: [147]  time: 2.5188, ELBO_train: -298.25423584, KL_z: 40.22632904, KL_s: 2.22735639, reconstruction loss: -255.80055041
# Clusters: 1
# Epoch: [148]  time: 2.5338, ELBO_train: -302.37664795, KL_z: 40.24828949, KL_s: 2.22545967, reconstruction loss: -259.90289879
# Clusters: 1
# Epoch: [149]  time: 2.5490, ELBO_train: -272.16312561, KL_z: 39.66573257, KL_s: 2.22647719, reconstruction loss: -230.27091584
# Clusters: 1
# Epoch: [150]  time: 2.5644, ELBO_train: -293.28805542, KL_z: 39.73470993, KL_s: 2.22566228, reconstruction loss: -251.32768321
# Clusters: 1
# Epoch: [151]  time: 2.5798, ELBO_train: -293.06606445, KL_z: 39.49481506, KL_s: 2.22491775, reconstruction loss: -251.34633164
# Clusters: 1
# Epoch: [152]  time: 2.5948, ELBO_train: -299.75390320, KL_z: 39.71319122, KL_s: 2.22454610, reconstruction loss: -257.81616588
# Clusters: 1
# Epoch: [153]  time: 2.6108, ELBO_train: -295.45615845, KL_z: 40.05147858, KL_s: 2.22484269, reconstruction loss: -253.17983718
# Clusters: 1
# Epoch: [154]  time: 2.6264, ELBO_train: -283.05876770, KL_z: 39.42040787, KL_s: 2.22486758, reconstruction loss: -241.41349225
# Clusters: 1
# Epoch: [155]  time: 2.6416, ELBO_train: -289.39036560, KL_z: 39.22643433, KL_s: 2.22489014, reconstruction loss: -247.93904114
# Clusters: 1
# Epoch: [156]  time: 2.6568, ELBO_train: -271.97993164, KL_z: 38.90984421, KL_s: 2.22448368, reconstruction loss: -230.84560375
# Clusters: 1
# Epoch: [157]  time: 2.6718, ELBO_train: -285.49080811, KL_z: 38.74698868, KL_s: 2.22369194, reconstruction loss: -244.52012749
# Clusters: 1
# Epoch: [158]  time: 2.6873, ELBO_train: -288.26112061, KL_z: 38.77930756, KL_s: 2.22492771, reconstruction loss: -247.25688534
# Clusters: 1
# Epoch: [159]  time: 2.7028, ELBO_train: -284.97581787, KL_z: 38.31237030, KL_s: 2.22396417, reconstruction loss: -244.43948340
# Clusters: 1
# Epoch: [160]  time: 2.7180, ELBO_train: -291.85036621, KL_z: 38.39158783, KL_s: 2.22384562, reconstruction loss: -251.23493276
# Clusters: 1
# Epoch: [161]  time: 2.7333, ELBO_train: -283.25018616, KL_z: 38.25775604, KL_s: 2.22402134, reconstruction loss: -242.76840878
# Clusters: 1
# Epoch: [162]  time: 2.7485, ELBO_train: -286.09434814, KL_z: 38.07652512, KL_s: 2.22768226, reconstruction loss: -245.79014077
# Clusters: 1
# Epoch: [163]  time: 2.7639, ELBO_train: -283.04613342, KL_z: 37.77826996, KL_s: 2.22831216, reconstruction loss: -243.03955131
# Clusters: 1
# Epoch: [164]  time: 2.7794, ELBO_train: -281.12139282, KL_z: 38.03614120, KL_s: 2.22949080, reconstruction loss: -240.85576081
# Clusters: 1
# Epoch: [165]  time: 2.7947, ELBO_train: -264.31143188, KL_z: 37.30795670, KL_s: 2.23018837, reconstruction loss: -224.77328682
# Clusters: 1
# Epoch: [166]  time: 2.8098, ELBO_train: -275.17293701, KL_z: 37.86273117, KL_s: 2.22995296, reconstruction loss: -235.08025289
# Clusters: 1
# Epoch: [167]  time: 2.8257, ELBO_train: -276.75012512, KL_z: 36.74630356, KL_s: 2.22966681, reconstruction loss: -237.77415476
# Clusters: 1
# Epoch: [168]  time: 2.8410, ELBO_train: -270.69367065, KL_z: 37.05865784, KL_s: 2.22971830, reconstruction loss: -231.40529451
# Clusters: 1
# Epoch: [169]  time: 2.8562, ELBO_train: -276.47268982, KL_z: 36.96280289, KL_s: 2.23018618, reconstruction loss: -237.27970076
# Clusters: 1
# Epoch: [170]  time: 2.8721, ELBO_train: -268.05319214, KL_z: 36.50120544, KL_s: 2.22968802, reconstruction loss: -229.32229867
# Clusters: 1
# Epoch: [171]  time: 2.8873, ELBO_train: -273.44288330, KL_z: 36.93310013, KL_s: 2.23005261, reconstruction loss: -234.27973056
# Clusters: 1
# Epoch: [172]  time: 2.9027, ELBO_train: -271.91028442, KL_z: 37.22131653, KL_s: 2.22957144, reconstruction loss: -232.45939646
# Clusters: 1
# Epoch: [173]  time: 2.9181, ELBO_train: -280.88365784, KL_z: 36.42556305, KL_s: 2.22906499, reconstruction loss: -242.22902980
# Clusters: 1
# Epoch: [174]  time: 2.9336, ELBO_train: -267.54361267, KL_z: 35.89823608, KL_s: 2.23007512, reconstruction loss: -229.41530147
# Clusters: 1
# Epoch: [175]  time: 2.9487, ELBO_train: -266.37816467, KL_z: 35.85917816, KL_s: 2.22939968, reconstruction loss: -228.28958683
# Clusters: 1
# Epoch: [176]  time: 2.9642, ELBO_train: -264.46098328, KL_z: 35.79069366, KL_s: 2.23028054, reconstruction loss: -226.44000907
# Clusters: 1
# Epoch: [177]  time: 2.9792, ELBO_train: -268.59379272, KL_z: 36.12477570, KL_s: 2.23005495, reconstruction loss: -230.23896208
# Clusters: 1
# Epoch: [178]  time: 2.9944, ELBO_train: -277.43841858, KL_z: 36.06087418, KL_s: 2.22975264, reconstruction loss: -239.14779177
# Clusters: 1
# Epoch: [179]  time: 3.0097, ELBO_train: -274.47872620, KL_z: 35.76354828, KL_s: 2.23043609, reconstruction loss: -236.48474183
# Clusters: 1
# Epoch: [180]  time: 3.0249, ELBO_train: -267.64249573, KL_z: 35.13848648, KL_s: 2.22855048, reconstruction loss: -230.27545877
# Clusters: 1
# Epoch: [181]  time: 3.0410, ELBO_train: -266.71798401, KL_z: 35.09545975, KL_s: 2.22932959, reconstruction loss: -229.39319468
# Clusters: 1
# Epoch: [182]  time: 3.0564, ELBO_train: -265.59619141, KL_z: 35.69791260, KL_s: 2.22986426, reconstruction loss: -227.66841455
# Clusters: 1
# Epoch: [183]  time: 3.0718, ELBO_train: -263.47609253, KL_z: 35.16524048, KL_s: 2.22882633, reconstruction loss: -226.08202572
# Clusters: 1
# Epoch: [184]  time: 3.0875, ELBO_train: -261.35811157, KL_z: 34.91305542, KL_s: 2.22881956, reconstruction loss: -224.21623659
# Clusters: 1
# Epoch: [185]  time: 3.1031, ELBO_train: -263.33849487, KL_z: 34.68699417, KL_s: 2.22856078, reconstruction loss: -226.42293992
# Clusters: 1
# Epoch: [186]  time: 3.1182, ELBO_train: -264.82469177, KL_z: 34.92762222, KL_s: 2.22779026, reconstruction loss: -227.66927929
# Clusters: 1
# Epoch: [187]  time: 3.1334, ELBO_train: -262.26723328, KL_z: 34.68948593, KL_s: 2.22729802, reconstruction loss: -225.35044932
# Clusters: 1
# Epoch: [188]  time: 3.1485, ELBO_train: -255.20877075, KL_z: 34.16683426, KL_s: 2.22715626, reconstruction loss: -218.81478024
# Clusters: 1
# Epoch: [189]  time: 3.1639, ELBO_train: -263.39109802, KL_z: 34.41396790, KL_s: 2.22910929, reconstruction loss: -226.74802084
# Clusters: 1
# Epoch: [190]  time: 3.1791, ELBO_train: -257.73580017, KL_z: 34.34098892, KL_s: 2.22773995, reconstruction loss: -221.16707129
# Clusters: 1
# Epoch: [191]  time: 3.1941, ELBO_train: -257.74114685, KL_z: 33.97364807, KL_s: 2.22740331, reconstruction loss: -221.54009547
# Clusters: 1
# Epoch: [192]  time: 3.2091, ELBO_train: -252.72331238, KL_z: 33.70636063, KL_s: 2.22695212, reconstruction loss: -216.78999963
# Clusters: 1
# Epoch: [193]  time: 3.2242, ELBO_train: -264.02285156, KL_z: 33.80584145, KL_s: 2.22736459, reconstruction loss: -227.98964553
# Clusters: 1
# Epoch: [194]  time: 3.2395, ELBO_train: -258.44641724, KL_z: 33.98350906, KL_s: 2.22685637, reconstruction loss: -222.23605180
# Clusters: 1
# Epoch: [195]  time: 3.2549, ELBO_train: -251.94009094, KL_z: 33.97326355, KL_s: 2.22552052, reconstruction loss: -215.74130688
# Clusters: 1
# Epoch: [196]  time: 3.2708, ELBO_train: -242.54431763, KL_z: 32.79980621, KL_s: 2.22633495, reconstruction loss: -207.51817646
# Clusters: 1
# Epoch: [197]  time: 3.2859, ELBO_train: -242.74099121, KL_z: 32.74025230, KL_s: 2.22493277, reconstruction loss: -207.77580614
# Clusters: 1
# Epoch: [198]  time: 3.3013, ELBO_train: -257.74918518, KL_z: 33.07959175, KL_s: 2.22406993, reconstruction loss: -222.44552350
# Clusters: 1
# Epoch: [199]  time: 3.3192, ELBO_train: -252.49041138, KL_z: 32.41532631, KL_s: 2.22383628, reconstruction loss: -217.85124879
# Clusters: 1
# Epoch: [200]  time: 3.3349, ELBO_train: -250.10646667, KL_z: 32.95029945, KL_s: 2.22518945, reconstruction loss: -214.93097777
# Clusters: 1
# Epoch: [201]  time: 3.3506, ELBO_train: -248.93466187, KL_z: 32.34056129, KL_s: 2.22525282, reconstruction loss: -214.36884775
# Clusters: 1
# Epoch: [202]  time: 3.3657, ELBO_train: -255.23287354, KL_z: 32.60604401, KL_s: 2.22390308, reconstruction loss: -220.40292645
# Clusters: 1
# Epoch: [203]  time: 3.3810, ELBO_train: -249.74228821, KL_z: 32.45825348, KL_s: 2.22357917, reconstruction loss: -215.06045556
# Clusters: 1
# Epoch: [204]  time: 3.3960, ELBO_train: -242.10726929, KL_z: 31.97994308, KL_s: 2.22385793, reconstruction loss: -207.90346828
# Clusters: 1
# Epoch: [205]  time: 3.4113, ELBO_train: -252.15551453, KL_z: 32.17425156, KL_s: 2.22266064, reconstruction loss: -217.75860233
# Clusters: 1
# Epoch: [206]  time: 3.4267, ELBO_train: -236.29854736, KL_z: 31.81603966, KL_s: 2.22278776, reconstruction loss: -202.25971994
# Clusters: 1
# Epoch: [207]  time: 3.4420, ELBO_train: -238.18153687, KL_z: 31.57415504, KL_s: 2.22234483, reconstruction loss: -204.38503699
# Clusters: 1
# Epoch: [208]  time: 3.4574, ELBO_train: -254.93193665, KL_z: 31.84293365, KL_s: 2.22227788, reconstruction loss: -220.86672511
# Clusters: 1
# Epoch: [209]  time: 3.4730, ELBO_train: -252.03237915, KL_z: 31.87608261, KL_s: 2.22086096, reconstruction loss: -217.93543558
# Clusters: 1
# Epoch: [210]  time: 3.4881, ELBO_train: -256.30595093, KL_z: 31.97299309, KL_s: 2.22124162, reconstruction loss: -222.11171622
# Clusters: 1
# Epoch: [211]  time: 3.5034, ELBO_train: -247.78601990, KL_z: 31.74301949, KL_s: 2.22149529, reconstruction loss: -213.82150512
# Clusters: 1
# Epoch: [212]  time: 3.5185, ELBO_train: -244.12422485, KL_z: 31.56619110, KL_s: 2.22092423, reconstruction loss: -210.33710952
# Clusters: 1
# Epoch: [213]  time: 3.5353, ELBO_train: -238.67661743, KL_z: 31.68206749, KL_s: 2.21999316, reconstruction loss: -204.77455678
# Clusters: 1
# Epoch: [214]  time: 3.5533, ELBO_train: -251.13103943, KL_z: 31.37963219, KL_s: 2.22205629, reconstruction loss: -217.52935095
# Clusters: 1
# Epoch: [215]  time: 3.5702, ELBO_train: -243.62774658, KL_z: 31.10806923, KL_s: 2.21905799, reconstruction loss: -210.30061936
# Clusters: 1
# Epoch: [216]  time: 3.5860, ELBO_train: -229.16944885, KL_z: 31.37289658, KL_s: 2.21975369, reconstruction loss: -195.57679858
# Clusters: 1
# Epoch: [217]  time: 3.6016, ELBO_train: -246.25959473, KL_z: 31.51864700, KL_s: 2.21822176, reconstruction loss: -212.52272596
# Clusters: 1
# Epoch: [218]  time: 3.6167, ELBO_train: -242.00133362, KL_z: 31.00703049, KL_s: 2.21890941, reconstruction loss: -208.77539372
# Clusters: 1
# Epoch: [219]  time: 3.6321, ELBO_train: -241.99487305, KL_z: 30.55389137, KL_s: 2.21902475, reconstruction loss: -209.22195692
# Clusters: 1
# Epoch: [220]  time: 3.6471, ELBO_train: -244.61352234, KL_z: 30.71343269, KL_s: 2.21871600, reconstruction loss: -211.68137364
# Clusters: 1
# Epoch: [221]  time: 3.6627, ELBO_train: -242.65588379, KL_z: 29.96276169, KL_s: 2.21799955, reconstruction loss: -210.47512255
# Clusters: 1
# Epoch: [222]  time: 3.6787, ELBO_train: -233.12274170, KL_z: 30.21664162, KL_s: 2.21817422, reconstruction loss: -200.68792586
# Clusters: 1
# Epoch: [223]  time: 3.6942, ELBO_train: -239.54891663, KL_z: 30.35208054, KL_s: 2.21805820, reconstruction loss: -206.97877789
# Clusters: 1
# Epoch: [224]  time: 3.7093, ELBO_train: -221.08891907, KL_z: 30.28517456, KL_s: 2.21736460, reconstruction loss: -188.58637991
# Clusters: 1
# Epoch: [225]  time: 3.7248, ELBO_train: -230.28523560, KL_z: 29.90752029, KL_s: 2.21679115, reconstruction loss: -198.16092415
# Clusters: 1
# Epoch: [226]  time: 3.7398, ELBO_train: -235.93983765, KL_z: 29.72003479, KL_s: 2.21539879, reconstruction loss: -204.00440407
# Clusters: 1
# Epoch: [227]  time: 3.7550, ELBO_train: -230.85216064, KL_z: 29.83448601, KL_s: 2.21473408, reconstruction loss: -198.80294056
# Clusters: 1
# Epoch: [228]  time: 3.7704, ELBO_train: -243.90048218, KL_z: 29.68075943, KL_s: 2.21463146, reconstruction loss: -212.00509129
# Clusters: 1
# Epoch: [229]  time: 3.7857, ELBO_train: -224.43157959, KL_z: 29.33743134, KL_s: 2.21457791, reconstruction loss: -192.87957034
# Clusters: 1
# Epoch: [230]  time: 3.8010, ELBO_train: -232.88549805, KL_z: 29.05069008, KL_s: 2.21529160, reconstruction loss: -201.61951637
# Clusters: 1
# Epoch: [231]  time: 3.8167, ELBO_train: -227.05231934, KL_z: 29.75165291, KL_s: 2.21255369, reconstruction loss: -195.08811274
# Clusters: 1
# Epoch: [232]  time: 3.8324, ELBO_train: -230.79154053, KL_z: 29.65700912, KL_s: 2.21330490, reconstruction loss: -198.92122650
# Clusters: 1
# Epoch: [233]  time: 3.8481, ELBO_train: -237.25799866, KL_z: 28.95876541, KL_s: 2.21410851, reconstruction loss: -206.08512473
# Clusters: 1
# Epoch: [234]  time: 3.8636, ELBO_train: -239.97490234, KL_z: 29.33506737, KL_s: 2.21304836, reconstruction loss: -208.42678661
# Clusters: 1
# Epoch: [235]  time: 3.8797, ELBO_train: -224.72707825, KL_z: 28.66799316, KL_s: 2.21313334, reconstruction loss: -193.84595175
# Clusters: 1
# Epoch: [236]  time: 3.8951, ELBO_train: -230.61044922, KL_z: 29.07778320, KL_s: 2.21310172, reconstruction loss: -199.31956429
# Clusters: 1
# Epoch: [237]  time: 3.9107, ELBO_train: -230.75833740, KL_z: 28.90912971, KL_s: 2.21210546, reconstruction loss: -199.63710222
# Clusters: 1
# Epoch: [238]  time: 3.9261, ELBO_train: -233.03247681, KL_z: 29.04469948, KL_s: 2.21320095, reconstruction loss: -201.77457638
# Clusters: 1
# Epoch: [239]  time: 3.9414, ELBO_train: -224.30194092, KL_z: 28.55160942, KL_s: 2.21303244, reconstruction loss: -193.53729906
# Clusters: 1
# Epoch: [240]  time: 3.9567, ELBO_train: -235.22251587, KL_z: 28.69603195, KL_s: 2.21323724, reconstruction loss: -204.31324668
# Clusters: 1
# Epoch: [241]  time: 3.9718, ELBO_train: -234.80241699, KL_z: 28.79963684, KL_s: 2.21257906, reconstruction loss: -203.79020109
# Clusters: 1
# Epoch: [242]  time: 3.9872, ELBO_train: -227.47703247, KL_z: 28.67772598, KL_s: 2.21314387, reconstruction loss: -196.58616261
# Clusters: 1
# Epoch: [243]  time: 4.0022, ELBO_train: -225.05064697, KL_z: 28.21698608, KL_s: 2.21260924, reconstruction loss: -194.62105165
# Clusters: 1
# Epoch: [244]  time: 4.0175, ELBO_train: -225.19464111, KL_z: 27.88962555, KL_s: 2.21391940, reconstruction loss: -195.09109616
# Clusters: 1
# Epoch: [245]  time: 4.0324, ELBO_train: -221.85650635, KL_z: 28.34690132, KL_s: 2.21274548, reconstruction loss: -191.29685955
# Clusters: 1
# Epoch: [246]  time: 4.0478, ELBO_train: -221.31278381, KL_z: 27.84681931, KL_s: 2.21155014, reconstruction loss: -191.25441437
# Clusters: 1
# Epoch: [247]  time: 4.0629, ELBO_train: -214.29295044, KL_z: 27.00436440, KL_s: 2.21103973, reconstruction loss: -185.07754631
# Clusters: 1
# Epoch: [248]  time: 4.0781, ELBO_train: -213.11021423, KL_z: 26.93040276, KL_s: 2.21003804, reconstruction loss: -183.96977344
# Clusters: 1
# Epoch: [249]  time: 4.0938, ELBO_train: -219.00514832, KL_z: 27.27708054, KL_s: 2.21058626, reconstruction loss: -189.51748152
# Clusters: 1
# Epoch: [250]  time: 4.1092, ELBO_train: -228.93526306, KL_z: 27.30214653, KL_s: 2.21019454, reconstruction loss: -199.42292199
# Clusters: 1
# Epoch: [251]  time: 4.1243, ELBO_train: -225.77512207, KL_z: 27.23005142, KL_s: 2.20895915, reconstruction loss: -196.33611150
# Clusters: 1
# Epoch: [252]  time: 4.1395, ELBO_train: -225.06947632, KL_z: 27.39556808, KL_s: 2.20930939, reconstruction loss: -195.46459885
# Clusters: 1
# Epoch: [253]  time: 4.1552, ELBO_train: -217.14881287, KL_z: 26.50507851, KL_s: 2.20970111, reconstruction loss: -188.43403325
# Clusters: 1
# Epoch: [254]  time: 4.1706, ELBO_train: -214.32969666, KL_z: 26.96161308, KL_s: 2.21030121, reconstruction loss: -185.15778236
# Clusters: 1
# Epoch: [255]  time: 4.1860, ELBO_train: -217.64074097, KL_z: 26.83900833, KL_s: 2.21012788, reconstruction loss: -188.59160476
# Clusters: 1
# Epoch: [256]  time: 4.2011, ELBO_train: -221.45208435, KL_z: 27.01272354, KL_s: 2.21163287, reconstruction loss: -192.22772794
# Clusters: 1
# Epoch: [257]  time: 4.2164, ELBO_train: -225.73563843, KL_z: 26.97385674, KL_s: 2.21472640, reconstruction loss: -196.54705529
# Clusters: 1
# Epoch: [258]  time: 4.2318, ELBO_train: -222.75757141, KL_z: 26.69216652, KL_s: 2.21952820, reconstruction loss: -193.84587669
# Clusters: 1
# Epoch: [259]  time: 4.2472, ELBO_train: -218.69369812, KL_z: 26.34707756, KL_s: 2.22316337, reconstruction loss: -190.12345719
# Clusters: 1
# Epoch: [260]  time: 4.2625, ELBO_train: -226.76778870, KL_z: 27.36120796, KL_s: 2.22569060, reconstruction loss: -197.18089013
# Clusters: 1
# Epoch: [261]  time: 4.2779, ELBO_train: -217.18462830, KL_z: 26.02082825, KL_s: 2.22900839, reconstruction loss: -188.93479166
# Clusters: 1
# Epoch: [262]  time: 4.2943, ELBO_train: -219.73851318, KL_z: 26.41788864, KL_s: 2.22973280, reconstruction loss: -191.09089174
# Clusters: 1
# Epoch: [263]  time: 4.3103, ELBO_train: -220.15885315, KL_z: 26.53297462, KL_s: 2.23240376, reconstruction loss: -191.39347477
# Clusters: 1
# Epoch: [264]  time: 4.3257, ELBO_train: -217.46351013, KL_z: 26.13448753, KL_s: 2.24124017, reconstruction loss: -189.08778243
# Clusters: 1
# Epoch: [265]  time: 4.3415, ELBO_train: -201.01471558, KL_z: 25.64731331, KL_s: 2.24752350, reconstruction loss: -173.11987877
# Clusters: 1
# Epoch: [266]  time: 4.3585, ELBO_train: -215.34713135, KL_z: 25.92922325, KL_s: 2.25063066, reconstruction loss: -187.16727743
# Clusters: 1
# Epoch: [267]  time: 4.3741, ELBO_train: -211.87284546, KL_z: 25.49343338, KL_s: 2.25268764, reconstruction loss: -184.12672443
# Clusters: 1
# Epoch: [268]  time: 4.3895, ELBO_train: -215.89735718, KL_z: 25.09202690, KL_s: 2.25333638, reconstruction loss: -188.55199389
# Clusters: 1
# Epoch: [269]  time: 4.4049, ELBO_train: -202.51171265, KL_z: 25.13330688, KL_s: 2.25336256, reconstruction loss: -175.12504320
# Clusters: 1
# Epoch: [270]  time: 4.4200, ELBO_train: -212.34182739, KL_z: 25.10970345, KL_s: 2.25423555, reconstruction loss: -184.97788839
# Clusters: 1
# Epoch: [271]  time: 4.4354, ELBO_train: -215.24523010, KL_z: 24.82316208, KL_s: 2.25425210, reconstruction loss: -188.16781592
# Clusters: 1
# Epoch: [272]  time: 4.4509, ELBO_train: -216.29757996, KL_z: 25.12368927, KL_s: 2.25428338, reconstruction loss: -188.91960731
# Clusters: 1
# Epoch: [273]  time: 4.4660, ELBO_train: -213.02212524, KL_z: 25.30186577, KL_s: 2.25411019, reconstruction loss: -185.46614928
# Clusters: 1
# Epoch: [274]  time: 4.4811, ELBO_train: -216.28956909, KL_z: 25.24334526, KL_s: 2.25442381, reconstruction loss: -188.79180002
# Clusters: 1
# Epoch: [275]  time: 4.4963, ELBO_train: -212.39203186, KL_z: 25.34704437, KL_s: 2.25433640, reconstruction loss: -184.79065108
# Clusters: 1
# Epoch: [276]  time: 4.5118, ELBO_train: -208.51192017, KL_z: 24.74673042, KL_s: 2.25448413, reconstruction loss: -181.51070561
# Clusters: 1
# Epoch: [277]  time: 4.5272, ELBO_train: -210.01446533, KL_z: 24.65464554, KL_s: 2.25353990, reconstruction loss: -183.10627990
# Clusters: 1
# Epoch: [278]  time: 4.5425, ELBO_train: -208.65036926, KL_z: 24.49078979, KL_s: 2.25405579, reconstruction loss: -181.90552368
# Clusters: 1
# Epoch: [279]  time: 4.5578, ELBO_train: -212.84109192, KL_z: 24.91007919, KL_s: 2.25338373, reconstruction loss: -185.67762899
# Clusters: 1
# Epoch: [280]  time: 4.5732, ELBO_train: -209.06533813, KL_z: 24.69749680, KL_s: 2.25276985, reconstruction loss: -182.11507149
# Clusters: 1
# Epoch: [281]  time: 4.5885, ELBO_train: -217.52629089, KL_z: 24.73302078, KL_s: 2.25341249, reconstruction loss: -190.53985763
# Clusters: 1
# Epoch: [282]  time: 4.6040, ELBO_train: -199.56558533, KL_z: 23.99681969, KL_s: 2.25349946, reconstruction loss: -173.31526618
# Clusters: 1
# Epoch: [283]  time: 4.6193, ELBO_train: -213.98775940, KL_z: 24.53932877, KL_s: 2.25669231, reconstruction loss: -187.19173832
# Clusters: 1
# Epoch: [284]  time: 4.6344, ELBO_train: -207.88625183, KL_z: 24.23976593, KL_s: 2.26159582, reconstruction loss: -181.38489008
# Clusters: 1
# Epoch: [285]  time: 4.6497, ELBO_train: -215.55496216, KL_z: 24.64804420, KL_s: 2.26458325, reconstruction loss: -188.64233470
# Clusters: 1
# Epoch: [286]  time: 4.6651, ELBO_train: -209.61685791, KL_z: 24.25674133, KL_s: 2.26577744, reconstruction loss: -183.09433913
# Clusters: 1
# Epoch: [287]  time: 4.6804, ELBO_train: -198.21321411, KL_z: 24.16935043, KL_s: 2.26633325, reconstruction loss: -171.77753043
# Clusters: 1
# Epoch: [288]  time: 4.6957, ELBO_train: -204.94990845, KL_z: 23.73926544, KL_s: 2.26761208, reconstruction loss: -178.94303093
# Clusters: 1
# Epoch: [289]  time: 4.7110, ELBO_train: -206.25368958, KL_z: 23.72791290, KL_s: 2.26732011, reconstruction loss: -180.25845656
# Clusters: 1
# Epoch: [290]  time: 4.7264, ELBO_train: -199.78171997, KL_z: 23.46389656, KL_s: 2.26789837, reconstruction loss: -174.04992504
# Clusters: 1
# Epoch: [291]  time: 4.7418, ELBO_train: -201.92867126, KL_z: 23.57078438, KL_s: 2.26766472, reconstruction loss: -176.09022217
# Clusters: 1
# Epoch: [292]  time: 4.7570, ELBO_train: -203.59541321, KL_z: 23.48067169, KL_s: 2.26788301, reconstruction loss: -177.84685850
# Clusters: 1
# Epoch: [293]  time: 4.7722, ELBO_train: -197.53653259, KL_z: 23.05135727, KL_s: 2.26774931, reconstruction loss: -172.21742601
# Clusters: 1
# Epoch: [294]  time: 4.7872, ELBO_train: -202.99618530, KL_z: 23.20751381, KL_s: 2.26800418, reconstruction loss: -177.52066731
# Clusters: 1
# Epoch: [295]  time: 4.8025, ELBO_train: -208.22952881, KL_z: 23.19226418, KL_s: 2.26762314, reconstruction loss: -182.76964149
# Clusters: 1
# Epoch: [296]  time: 4.8177, ELBO_train: -196.26315613, KL_z: 22.70646095, KL_s: 2.26767459, reconstruction loss: -171.28902059
# Clusters: 1
# Epoch: [297]  time: 4.8329, ELBO_train: -206.97833862, KL_z: 23.21166801, KL_s: 2.26699677, reconstruction loss: -181.49967384
# Clusters: 1
# Epoch: [298]  time: 4.8480, ELBO_train: -199.91416016, KL_z: 22.77587204, KL_s: 2.26772957, reconstruction loss: -174.87055855
# Clusters: 1
# Epoch: [299]  time: 4.8633, ELBO_train: -201.32131958, KL_z: 22.59918861, KL_s: 2.26781240, reconstruction loss: -176.45431857
# Clusters: 1
# Epoch: [300]  time: 4.8784, ELBO_train: -199.13571472, KL_z: 22.75370636, KL_s: 2.26761756, reconstruction loss: -174.11439080
# Clusters: 1
# Epoch: [301]  time: 4.8934, ELBO_train: -198.43973083, KL_z: 22.57045822, KL_s: 2.26740284, reconstruction loss: -173.60186977
# Clusters: 1
# Epoch: [302]  time: 4.9087, ELBO_train: -196.88908997, KL_z: 22.89764328, KL_s: 2.26685362, reconstruction loss: -171.72459307
# Clusters: 1
# Epoch: [303]  time: 4.9241, ELBO_train: -195.70270386, KL_z: 22.79774208, KL_s: 2.26756630, reconstruction loss: -170.63739548
# Clusters: 1
# Epoch: [304]  time: 4.9399, ELBO_train: -199.39325867, KL_z: 22.31352654, KL_s: 2.26769700, reconstruction loss: -174.81203513
# Clusters: 1
# Epoch: [305]  time: 4.9555, ELBO_train: -194.15204773, KL_z: 22.09925575, KL_s: 2.26764731, reconstruction loss: -169.78514466
# Clusters: 1
# Epoch: [306]  time: 4.9707, ELBO_train: -198.79053650, KL_z: 22.54331894, KL_s: 2.26722021, reconstruction loss: -173.97999735
# Clusters: 1
# Epoch: [307]  time: 4.9858, ELBO_train: -202.43030090, KL_z: 22.44584045, KL_s: 2.26756196, reconstruction loss: -177.71689849
# Clusters: 1
# Epoch: [308]  time: 5.0009, ELBO_train: -187.55963440, KL_z: 21.70380135, KL_s: 2.26769967, reconstruction loss: -163.58813338
# Clusters: 1
# Epoch: [309]  time: 5.0162, ELBO_train: -203.44819336, KL_z: 22.31197090, KL_s: 2.26718283, reconstruction loss: -178.86903963
# Clusters: 1
# Epoch: [310]  time: 5.0317, ELBO_train: -200.81273804, KL_z: 21.65358887, KL_s: 2.26716070, reconstruction loss: -176.89198847
# Clusters: 1
# Epoch: [311]  time: 5.0468, ELBO_train: -203.92879944, KL_z: 22.44391937, KL_s: 2.26748486, reconstruction loss: -179.21739521
# Clusters: 1
# Epoch: [312]  time: 5.0622, ELBO_train: -196.29922791, KL_z: 22.26538696, KL_s: 2.26710420, reconstruction loss: -171.76673675
# Clusters: 1
# Epoch: [313]  time: 5.0775, ELBO_train: -203.26481323, KL_z: 22.60804634, KL_s: 2.26675243, reconstruction loss: -178.39001446
# Clusters: 1
# Epoch: [314]  time: 5.0927, ELBO_train: -195.26545715, KL_z: 22.27319336, KL_s: 2.26698275, reconstruction loss: -170.72528105
# Clusters: 1
# Epoch: [315]  time: 5.1080, ELBO_train: -199.16020508, KL_z: 22.10490913, KL_s: 2.26653051, reconstruction loss: -174.78876543
# Clusters: 1
# Epoch: [316]  time: 5.1231, ELBO_train: -189.49107971, KL_z: 21.82404366, KL_s: 2.26706467, reconstruction loss: -165.39997139
# Clusters: 1
# Epoch: [317]  time: 5.1379, ELBO_train: -193.89198303, KL_z: 21.92722321, KL_s: 2.26736846, reconstruction loss: -169.69739137
# Clusters: 1
# Epoch: [318]  time: 5.1549, ELBO_train: -192.64952698, KL_z: 21.82927628, KL_s: 2.26679034, reconstruction loss: -168.55346036
# Clusters: 1
# Epoch: [319]  time: 5.1703, ELBO_train: -189.25711670, KL_z: 21.44790535, KL_s: 2.26692076, reconstruction loss: -165.54229059
# Clusters: 1
# Epoch: [320]  time: 5.1854, ELBO_train: -197.04918823, KL_z: 21.71985054, KL_s: 2.26718936, reconstruction loss: -173.06214833
# Clusters: 1
# Epoch: [321]  time: 5.2007, ELBO_train: -198.87228699, KL_z: 21.56375122, KL_s: 2.26669869, reconstruction loss: -175.04183707
# Clusters: 1
# Epoch: [322]  time: 5.2156, ELBO_train: -195.66690674, KL_z: 21.31722832, KL_s: 2.26661601, reconstruction loss: -172.08306241
# Clusters: 1
# Epoch: [323]  time: 5.2310, ELBO_train: -188.03941956, KL_z: 21.05250702, KL_s: 2.26676006, reconstruction loss: -164.72015247
# Clusters: 1
# Epoch: [324]  time: 5.2463, ELBO_train: -194.54971619, KL_z: 21.29796448, KL_s: 2.26684890, reconstruction loss: -170.98490281
# Clusters: 1
# Epoch: [325]  time: 5.2618, ELBO_train: -191.06134338, KL_z: 20.77144356, KL_s: 2.26634321, reconstruction loss: -168.02355661
# Clusters: 1
# Epoch: [326]  time: 5.2772, ELBO_train: -189.63333130, KL_z: 21.15993423, KL_s: 2.26584287, reconstruction loss: -166.20755420
# Clusters: 1
# Epoch: [327]  time: 5.2922, ELBO_train: -195.44283447, KL_z: 21.43333969, KL_s: 2.26615014, reconstruction loss: -171.74334464
# Clusters: 1
# Epoch: [328]  time: 5.3073, ELBO_train: -191.31459045, KL_z: 20.80252876, KL_s: 2.26636472, reconstruction loss: -168.24569697
# Clusters: 1
# Epoch: [329]  time: 5.3227, ELBO_train: -194.34115906, KL_z: 20.75959816, KL_s: 2.26622901, reconstruction loss: -171.31533189
# Clusters: 1
# Epoch: [330]  time: 5.3379, ELBO_train: -184.56178894, KL_z: 20.56882858, KL_s: 2.26643643, reconstruction loss: -161.72652392
# Clusters: 1
# Epoch: [331]  time: 5.3532, ELBO_train: -188.36859741, KL_z: 20.93922577, KL_s: 2.26605043, reconstruction loss: -165.16332121
# Clusters: 1
# Epoch: [332]  time: 5.3688, ELBO_train: -186.07973633, KL_z: 20.79126205, KL_s: 2.26612439, reconstruction loss: -163.02234988
# Clusters: 1
# Epoch: [333]  time: 5.3845, ELBO_train: -184.72698364, KL_z: 20.31002159, KL_s: 2.26613884, reconstruction loss: -162.15082321
# Clusters: 1
# Epoch: [334]  time: 5.3997, ELBO_train: -192.46907043, KL_z: 20.91903877, KL_s: 2.26593442, reconstruction loss: -169.28409724
# Clusters: 1
# Epoch: [335]  time: 5.4151, ELBO_train: -190.03851166, KL_z: 20.42344894, KL_s: 2.26559286, reconstruction loss: -167.34946985
# Clusters: 1
# Epoch: [336]  time: 5.4303, ELBO_train: -187.54186707, KL_z: 20.32075500, KL_s: 2.26586194, reconstruction loss: -164.95525012
# Clusters: 1
# Epoch: [337]  time: 5.4454, ELBO_train: -189.04192810, KL_z: 20.28576012, KL_s: 2.26543760, reconstruction loss: -166.49073038
# Clusters: 1
# Epoch: [338]  time: 5.4607, ELBO_train: -180.00614624, KL_z: 20.00318565, KL_s: 2.26557717, reconstruction loss: -157.73738341
# Clusters: 1
# Epoch: [339]  time: 5.4757, ELBO_train: -192.89630432, KL_z: 20.20846443, KL_s: 2.26566210, reconstruction loss: -170.42217779
# Clusters: 1
# Epoch: [340]  time: 5.4911, ELBO_train: -184.93322144, KL_z: 20.10637512, KL_s: 2.26650033, reconstruction loss: -162.56034598
# Clusters: 1
# Epoch: [341]  time: 5.5066, ELBO_train: -191.52837372, KL_z: 20.52001686, KL_s: 2.26643038, reconstruction loss: -168.74192648
# Clusters: 1
# Epoch: [342]  time: 5.5221, ELBO_train: -179.97127686, KL_z: 19.77587013, KL_s: 2.26632524, reconstruction loss: -157.92908149
# Clusters: 1
# Epoch: [343]  time: 5.5372, ELBO_train: -184.43703918, KL_z: 19.82769012, KL_s: 2.26638045, reconstruction loss: -162.34296861
# Clusters: 1
# Epoch: [344]  time: 5.5524, ELBO_train: -190.29739075, KL_z: 19.84649277, KL_s: 2.26655107, reconstruction loss: -168.18434691
# Clusters: 1
# Epoch: [345]  time: 5.5674, ELBO_train: -189.15490723, KL_z: 20.15139809, KL_s: 2.26622300, reconstruction loss: -166.73728614
# Clusters: 1
# ...
# Epoch: [385]  time: 6.1793, ELBO_train: -174.30304565, KL_z: 17.58679390, KL_s: 2.27850385, reconstruction loss: -154.43774791
# Clusters: 1
# Epoch: [386]  time: 6.1942, ELBO_train: -178.30733948, KL_z: 17.71957684, KL_s: 2.27926073, reconstruction loss: -158.30850191
# Clusters: 1
# Epoch: [387]  time: 6.2091, ELBO_train: -173.34484711, KL_z: 17.38788452, KL_s: 2.27861032, reconstruction loss: -153.67835226
# Clusters: 1
# Epoch: [388]  time: 6.2252, ELBO_train: -162.19373474, KL_z: 17.11015034, KL_s: 2.27897606, reconstruction loss: -142.80460835
# Clusters: 1
# Epoch: [389]  time: 6.2409, ELBO_train: -164.68475342, KL_z: 16.89944992, KL_s: 2.27866344, reconstruction loss: -145.50664005
# Clusters: 1
# Epoch: [390]  time: 6.2563, ELBO_train: -174.21421204, KL_z: 17.07517948, KL_s: 2.27872872, reconstruction loss: -154.86030383
# Clusters: 1
# Epoch: [391]  time: 6.2716, ELBO_train: -167.64113617, KL_z: 17.03355770, KL_s: 2.27865372, reconstruction loss: -148.32892475
# Clusters: 1
# Epoch: [392]  time: 6.2913, ELBO_train: -171.93349304, KL_z: 17.19854202, KL_s: 2.27900996, reconstruction loss: -152.45594106
# Clusters: 1
# Epoch: [393]  time: 6.3067, ELBO_train: -156.62121887, KL_z: 16.56749687, KL_s: 2.27887254, reconstruction loss: -137.77484946
# Clusters: 1
# Epoch: [394]  time: 6.3220, ELBO_train: -173.12564697, KL_z: 17.11837788, KL_s: 2.27878633, reconstruction loss: -153.72848277
# Clusters: 1
# Epoch: [395]  time: 6.3375, ELBO_train: -159.53244324, KL_z: 16.40901585, KL_s: 2.27882433, reconstruction loss: -140.84460306
# Clusters: 1
# Epoch: [396]  time: 6.3530, ELBO_train: -173.22469788, KL_z: 17.02205963, KL_s: 2.27854710, reconstruction loss: -153.92409115
# Clusters: 1
# Epoch: [397]  time: 6.3679, ELBO_train: -174.09683533, KL_z: 17.03512058, KL_s: 2.27865539, reconstruction loss: -154.78305936
# Clusters: 1
# Epoch: [398]  time: 6.3831, ELBO_train: -158.47308044, KL_z: 16.83210602, KL_s: 2.27836676, reconstruction loss: -139.36260767
# Clusters: 1
# Epoch: [399]  time: 6.3984, ELBO_train: -169.41884460, KL_z: 16.43107262, KL_s: 2.27857223, reconstruction loss: -150.70919976
# Clusters: 1
# Epoch: [400]  time: 6.4137, ELBO_train: -166.17563782, KL_z: 16.14813614, KL_s: 2.27863159, reconstruction loss: -147.74887009
# Clusters: 1
# Epoch: [401]  time: 6.4295, ELBO_train: -168.87427979, KL_z: 16.42122650, KL_s: 2.27864261, reconstruction loss: -150.17441068
# Clusters: 1
# Epoch: [402]  time: 6.4451, ELBO_train: -173.34340210, KL_z: 16.61424599, KL_s: 2.27866626, reconstruction loss: -154.45048985
# Clusters: 1
# Epoch: [403]  time: 6.4603, ELBO_train: -161.88497009, KL_z: 16.73852100, KL_s: 2.27845078, reconstruction loss: -142.86799831
# Clusters: 1
# Epoch: [404]  time: 6.4753, ELBO_train: -155.36020508, KL_z: 16.29450302, KL_s: 2.27833009, reconstruction loss: -136.78737197
# Clusters: 1
# Epoch: [405]  time: 6.4903, ELBO_train: -172.62585144, KL_z: 16.59897919, KL_s: 2.27820458, reconstruction loss: -153.74866767
# Clusters: 1
# Epoch: [406]  time: 6.5057, ELBO_train: -169.50967712, KL_z: 16.26211948, KL_s: 2.27835016, reconstruction loss: -150.96920748
# Clusters: 1
# Epoch: [407]  time: 6.5212, ELBO_train: -169.82592773, KL_z: 16.38959656, KL_s: 2.27867904, reconstruction loss: -151.15765214
# Clusters: 1
# Epoch: [408]  time: 6.5366, ELBO_train: -171.99014587, KL_z: 16.77689438, KL_s: 2.27854290, reconstruction loss: -152.93470860
# Clusters: 1
# Epoch: [409]  time: 6.5518, ELBO_train: -149.76068726, KL_z: 15.79382648, KL_s: 2.27836933, reconstruction loss: -131.68849144
# Clusters: 1
# Epoch: [410]  time: 6.5670, ELBO_train: -170.02303772, KL_z: 16.44502735, KL_s: 2.27806978, reconstruction loss: -151.29994059
# Clusters: 1
# Epoch: [411]  time: 6.5824, ELBO_train: -167.85192871, KL_z: 16.33849316, KL_s: 2.27841506, reconstruction loss: -149.23502049
# Clusters: 1
# Epoch: [412]  time: 6.5977, ELBO_train: -172.17341003, KL_z: 16.33992233, KL_s: 2.27835207, reconstruction loss: -153.55513563
# Clusters: 1
# Epoch: [413]  time: 6.6128, ELBO_train: -168.76252136, KL_z: 16.14685059, KL_s: 2.27781186, reconstruction loss: -150.33785892
# Clusters: 1
# Epoch: [414]  time: 6.6279, ELBO_train: -165.43669739, KL_z: 16.25782127, KL_s: 2.27788353, reconstruction loss: -146.90099258
# Clusters: 1
# Epoch: [415]  time: 6.6437, ELBO_train: -166.07366943, KL_z: 15.81439190, KL_s: 2.27812986, reconstruction loss: -147.98114767
# Clusters: 1
# Epoch: [416]  time: 6.6604, ELBO_train: -157.38943176, KL_z: 15.73073940, KL_s: 2.27841163, reconstruction loss: -139.38028073
# Clusters: 1
# Epoch: [417]  time: 6.6760, ELBO_train: -163.55501709, KL_z: 15.83450489, KL_s: 2.27825427, reconstruction loss: -145.44225793
# Clusters: 1
# Epoch: [418]  time: 6.6914, ELBO_train: -157.75913696, KL_z: 15.99566956, KL_s: 2.27788916, reconstruction loss: -139.48557825
# Clusters: 1
# Epoch: [419]  time: 6.7066, ELBO_train: -163.32869568, KL_z: 15.75088215, KL_s: 2.27791338, reconstruction loss: -145.29990015
# Clusters: 1
# Epoch: [420]  time: 6.7219, ELBO_train: -156.99713898, KL_z: 15.98026333, KL_s: 2.27793512, reconstruction loss: -138.73894053
# Clusters: 1
# Epoch: [421]  time: 6.7371, ELBO_train: -161.96032867, KL_z: 15.74491043, KL_s: 2.27837906, reconstruction loss: -143.93703918
# Clusters: 1
# Epoch: [422]  time: 6.7526, ELBO_train: -165.88887177, KL_z: 16.14906311, KL_s: 2.27822680, reconstruction loss: -147.46158185
# Clusters: 1
# Epoch: [423]  time: 6.7681, ELBO_train: -159.46262512, KL_z: 15.44028339, KL_s: 2.27792649, reconstruction loss: -141.74441524
# Clusters: 1
# Epoch: [424]  time: 6.7833, ELBO_train: -159.95326843, KL_z: 15.13467865, KL_s: 2.27797794, reconstruction loss: -142.54061184
# Clusters: 1
# Epoch: [425]  time: 6.7988, ELBO_train: -156.39197083, KL_z: 15.62001648, KL_s: 2.27816539, reconstruction loss: -138.49378896
# Clusters: 1
# Epoch: [426]  time: 6.8141, ELBO_train: -167.74320679, KL_z: 15.65705013, KL_s: 2.27781429, reconstruction loss: -149.80834236
# Clusters: 1
# Epoch: [427]  time: 6.8294, ELBO_train: -164.74347992, KL_z: 15.41638432, KL_s: 2.27779374, reconstruction loss: -147.04930186
# Clusters: 1
# Epoch: [428]  time: 6.8451, ELBO_train: -155.90784302, KL_z: 15.11373997, KL_s: 2.27796288, reconstruction loss: -138.51614017
# Clusters: 1
# Epoch: [429]  time: 6.8610, ELBO_train: -167.69726868, KL_z: 15.79877625, KL_s: 2.27777352, reconstruction loss: -149.62071891
# Clusters: 1
# Epoch: [430]  time: 6.8764, ELBO_train: -168.50157776, KL_z: 15.83953552, KL_s: 2.27779078, reconstruction loss: -150.38425145
# Clusters: 1
# Epoch: [431]  time: 6.8919, ELBO_train: -158.48333740, KL_z: 15.37598381, KL_s: 2.27748985, reconstruction loss: -140.82986374
# Clusters: 1
# Epoch: [432]  time: 6.9071, ELBO_train: -165.03178406, KL_z: 15.62559414, KL_s: 2.27769394, reconstruction loss: -147.12849598
# Clusters: 1
# Epoch: [433]  time: 6.9222, ELBO_train: -160.80955048, KL_z: 15.41173325, KL_s: 2.27789493, reconstruction loss: -143.11992230
# Clusters: 1
# Epoch: [434]  time: 6.9374, ELBO_train: -156.95843048, KL_z: 15.03711700, KL_s: 2.27763638, reconstruction loss: -139.64367709
# Clusters: 1
# Epoch: [435]  time: 6.9526, ELBO_train: -165.94353027, KL_z: 15.60417786, KL_s: 2.27788796, reconstruction loss: -148.06146445
# Clusters: 1
# Epoch: [436]  time: 6.9678, ELBO_train: -154.46611633, KL_z: 15.09887753, KL_s: 2.27769055, reconstruction loss: -137.08954825
# Clusters: 1
# Epoch: [437]  time: 6.9830, ELBO_train: -158.91436462, KL_z: 15.03903046, KL_s: 2.27775669, reconstruction loss: -141.59757748
# Clusters: 1
# Epoch: [438]  time: 6.9986, ELBO_train: -152.41212463, KL_z: 14.69028950, KL_s: 2.27791009, reconstruction loss: -135.44392505
# Clusters: 1
# Epoch: [439]  time: 7.0139, ELBO_train: -158.72925262, KL_z: 14.97733917, KL_s: 2.27704277, reconstruction loss: -141.47487068
# Clusters: 1
# Epoch: [440]  time: 7.0292, ELBO_train: -160.29041901, KL_z: 15.04593430, KL_s: 2.27769561, reconstruction loss: -142.96678910
# Clusters: 1
# Epoch: [441]  time: 7.0447, ELBO_train: -157.82339783, KL_z: 14.87179184, KL_s: 2.27750120, reconstruction loss: -140.67410479
# Clusters: 1
# Epoch: [442]  time: 7.0606, ELBO_train: -156.17619171, KL_z: 14.96902161, KL_s: 2.27760668, reconstruction loss: -138.92956343
# Clusters: 1
# Epoch: [443]  time: 7.0761, ELBO_train: -162.24914246, KL_z: 14.76883965, KL_s: 2.27720561, reconstruction loss: -145.20309720
# Clusters: 1
# Epoch: [444]  time: 7.0915, ELBO_train: -150.71870422, KL_z: 14.61578407, KL_s: 2.27720156, reconstruction loss: -133.82571859
# Clusters: 1
# Epoch: [445]  time: 7.1067, ELBO_train: -159.85829773, KL_z: 14.92927570, KL_s: 2.27755919, reconstruction loss: -142.65146284
# Clusters: 1
# Epoch: [446]  time: 7.1220, ELBO_train: -157.97038269, KL_z: 14.43979588, KL_s: 2.27723193, reconstruction loss: -141.25335488
# Clusters: 1
# Epoch: [447]  time: 7.1377, ELBO_train: -153.61538696, KL_z: 14.37899914, KL_s: 2.27737846, reconstruction loss: -136.95900936
# Clusters: 1
# Epoch: [448]  time: 7.1530, ELBO_train: -149.91841278, KL_z: 14.82842941, KL_s: 2.27730784, reconstruction loss: -132.81267552
# Clusters: 1
# Epoch: [449]  time: 7.1683, ELBO_train: -150.61358643, KL_z: 14.59105988, KL_s: 2.27734385, reconstruction loss: -133.74518270
# Clusters: 1
# Epoch: [450]  time: 7.1837, ELBO_train: -154.74505615, KL_z: 14.58668518, KL_s: 2.27712607, reconstruction loss: -137.88124490
# Clusters: 1
# Epoch: [451]  time: 7.1990, ELBO_train: -153.97171173, KL_z: 14.57577019, KL_s: 2.27747450, reconstruction loss: -137.11846704
# Clusters: 1
# Epoch: [452]  time: 7.2143, ELBO_train: -154.81301270, KL_z: 14.42560062, KL_s: 2.27861724, reconstruction loss: -138.10879483
# Clusters: 1
# Epoch: [453]  time: 7.2298, ELBO_train: -150.88716431, KL_z: 14.34938984, KL_s: 2.27869225, reconstruction loss: -134.25908222
# Clusters: 1
# Epoch: [454]  time: 7.2450, ELBO_train: -150.76976318, KL_z: 14.16881504, KL_s: 2.27922153, reconstruction loss: -134.32172661
# Clusters: 1
# Epoch: [455]  time: 7.2601, ELBO_train: -154.82459412, KL_z: 14.54714851, KL_s: 2.27908125, reconstruction loss: -137.99836435
# Clusters: 1
# Epoch: [456]  time: 7.2765, ELBO_train: -161.00756683, KL_z: 14.47719021, KL_s: 2.27927728, reconstruction loss: -144.25109935
# Clusters: 1
# Epoch: [457]  time: 7.2919, ELBO_train: -157.68558350, KL_z: 14.35812721, KL_s: 2.27926364, reconstruction loss: -141.04819264
# Clusters: 1
# Epoch: [458]  time: 7.3071, ELBO_train: -152.45968933, KL_z: 14.24976311, KL_s: 2.27943420, reconstruction loss: -135.93049202
# Clusters: 1
# Epoch: [459]  time: 7.3224, ELBO_train: -153.48671570, KL_z: 14.27757282, KL_s: 2.27909894, reconstruction loss: -136.93004394
# Clusters: 1
# Epoch: [460]  time: 7.3375, ELBO_train: -157.29503632, KL_z: 14.27808647, KL_s: 2.27967138, reconstruction loss: -140.73727846
# Clusters: 1
# Epoch: [461]  time: 7.3528, ELBO_train: -157.75643616, KL_z: 14.21989689, KL_s: 2.28085046, reconstruction loss: -141.25568881
# Clusters: 1
# Epoch: [462]  time: 7.3682, ELBO_train: -160.41616821, KL_z: 14.83936768, KL_s: 2.28146162, reconstruction loss: -143.29533892
# Clusters: 1
# Epoch: [463]  time: 7.3834, ELBO_train: -152.15363007, KL_z: 14.40986958, KL_s: 2.28229284, reconstruction loss: -135.46146765
# Clusters: 1
# Epoch: [464]  time: 7.3988, ELBO_train: -145.14247284, KL_z: 13.65241051, KL_s: 2.28239970, reconstruction loss: -129.20766263
# Clusters: 1
# Epoch: [465]  time: 7.4140, ELBO_train: -160.89809570, KL_z: 14.40489750, KL_s: 2.28244991, reconstruction loss: -144.21074829
# Clusters: 1
# Epoch: [466]  time: 7.4293, ELBO_train: -157.86344452, KL_z: 14.34490757, KL_s: 2.28275790, reconstruction loss: -141.23577905
# Clusters: 1
# Epoch: [467]  time: 7.4447, ELBO_train: -156.21831970, KL_z: 13.99601364, KL_s: 2.28271112, reconstruction loss: -139.93959494
# Clusters: 1
# Epoch: [468]  time: 7.4648, ELBO_train: -155.14640198, KL_z: 14.29500465, KL_s: 2.28257670, reconstruction loss: -138.56882062
# Clusters: 1
# Epoch: [469]  time: 7.4803, ELBO_train: -152.70778961, KL_z: 14.19715252, KL_s: 2.28242006, reconstruction loss: -136.22821703
# Clusters: 1
# Epoch: [470]  time: 7.4961, ELBO_train: -150.80477295, KL_z: 14.11881199, KL_s: 2.28266840, reconstruction loss: -134.40329256
# Clusters: 1
# Epoch: [471]  time: 7.5119, ELBO_train: -156.65663452, KL_z: 14.09860935, KL_s: 2.28297420, reconstruction loss: -140.27505097
# Clusters: 1
# Epoch: [472]  time: 7.5272, ELBO_train: -153.32647095, KL_z: 13.80905418, KL_s: 2.28266702, reconstruction loss: -137.23474975
# Clusters: 1
# Epoch: [473]  time: 7.5423, ELBO_train: -152.39527893, KL_z: 13.72576542, KL_s: 2.28265753, reconstruction loss: -136.38685598
# Clusters: 1
# Epoch: [474]  time: 7.5580, ELBO_train: -155.22798615, KL_z: 13.90431919, KL_s: 2.28254232, reconstruction loss: -139.04112463
# Clusters: 1
# Epoch: [475]  time: 7.5732, ELBO_train: -156.61254730, KL_z: 14.17242603, KL_s: 2.28254714, reconstruction loss: -140.15757413
# Clusters: 1
# Epoch: [476]  time: 7.5886, ELBO_train: -151.24142151, KL_z: 13.80075989, KL_s: 2.28228540, reconstruction loss: -135.15837622
# Clusters: 1
# Epoch: [477]  time: 7.6037, ELBO_train: -152.19619598, KL_z: 13.81561871, KL_s: 2.28242183, reconstruction loss: -136.09815545
# Clusters: 1
# Epoch: [478]  time: 7.6190, ELBO_train: -152.68997803, KL_z: 13.99985867, KL_s: 2.28241310, reconstruction loss: -136.40770626
# Clusters: 1
# Epoch: [479]  time: 7.6346, ELBO_train: -154.21656494, KL_z: 13.81549263, KL_s: 2.28230019, reconstruction loss: -138.11877213
# Clusters: 1
# Epoch: [480]  time: 7.6497, ELBO_train: -155.26645966, KL_z: 14.06313515, KL_s: 2.28231821, reconstruction loss: -138.92100630
# Clusters: 1
# Epoch: [481]  time: 7.6650, ELBO_train: -151.63297729, KL_z: 13.87650776, KL_s: 2.28229914, reconstruction loss: -135.47417040
# Clusters: 1
# Epoch: [482]  time: 7.6802, ELBO_train: -156.38763428, KL_z: 14.08259697, KL_s: 2.28229761, reconstruction loss: -140.02273970
# Clusters: 1
# Epoch: [483]  time: 7.6960, ELBO_train: -150.02474518, KL_z: 13.68134232, KL_s: 2.28223467, reconstruction loss: -134.06116819
# Clusters: 1
# Epoch: [484]  time: 7.7114, ELBO_train: -154.95739899, KL_z: 13.70085545, KL_s: 2.28231573, reconstruction loss: -138.97422781
# Clusters: 1
# Epoch: [485]  time: 7.7267, ELBO_train: -153.76775970, KL_z: 13.76663723, KL_s: 2.28232985, reconstruction loss: -137.71879263
# Clusters: 1
# Epoch: [486]  time: 7.7418, ELBO_train: -153.50041962, KL_z: 13.96456738, KL_s: 2.28195138, reconstruction loss: -137.25390086
# Clusters: 1
# Epoch: [487]  time: 7.7573, ELBO_train: -153.42325592, KL_z: 13.48624306, KL_s: 2.28225431, reconstruction loss: -137.65475855
# Clusters: 1
# Epoch: [488]  time: 7.7726, ELBO_train: -146.43652802, KL_z: 13.34758015, KL_s: 2.28230858, reconstruction loss: -130.80663929
# Clusters: 1
# Epoch: [489]  time: 7.7881, ELBO_train: -149.41762390, KL_z: 13.46788502, KL_s: 2.28214955, reconstruction loss: -133.66758933
# Clusters: 1
# Epoch: [490]  time: 7.8038, ELBO_train: -144.06529083, KL_z: 13.36916351, KL_s: 2.28203974, reconstruction loss: -128.41408758
# Clusters: 1
# Epoch: [491]  time: 7.8194, ELBO_train: -154.76372528, KL_z: 13.82744026, KL_s: 2.28210859, reconstruction loss: -138.65417643
# Clusters: 1
# Epoch: [492]  time: 7.8347, ELBO_train: -154.80356903, KL_z: 13.85618820, KL_s: 2.28228297, reconstruction loss: -138.66509786
# Clusters: 1
# Epoch: [493]  time: 7.8498, ELBO_train: -146.63931732, KL_z: 13.35150719, KL_s: 2.28199596, reconstruction loss: -131.00581417
# Clusters: 1
# Epoch: [494]  time: 7.8651, ELBO_train: -150.48873749, KL_z: 13.57209873, KL_s: 2.28208737, reconstruction loss: -134.63455138
# Clusters: 1
# Epoch: [495]  time: 7.8806, ELBO_train: -148.15644836, KL_z: 13.19484577, KL_s: 2.28198786, reconstruction loss: -132.67961473
# Clusters: 1
# Epoch: [496]  time: 7.8959, ELBO_train: -154.55124359, KL_z: 13.43326931, KL_s: 2.28223863, reconstruction loss: -138.83573565
# Clusters: 1
# Epoch: [497]  time: 7.9120, ELBO_train: -150.31807861, KL_z: 13.50407181, KL_s: 2.28181257, reconstruction loss: -134.53219423
# Clusters: 1
# Epoch: [498]  time: 7.9273, ELBO_train: -150.35589752, KL_z: 13.29914093, KL_s: 2.28207860, reconstruction loss: -134.77467799
# Clusters: 1
# Epoch: [499]  time: 7.9428, ELBO_train: -150.34790497, KL_z: 13.31770058, KL_s: 2.28185229, reconstruction loss: -134.74835210
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

# Number of samples generated by one input data
n_generated_sample = 10

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = data_processing.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3, n_generated_sample=n_generated_sample)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = statistic.samples_concatenation(samples_list)[-1]
    data_test_transformed = data_processing.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = []
    for j in range(n_generated_sample):
        est_data_test_transformed.append(data_processing.discrete_variables_transformation(est_data_test[i], feat_types_dict).unsqueeze(0))
    
    est_data_test_transformed = torch.cat(est_data_test_transformed, dim=0)

# %% [markdown]
# ### Visualize the generated samples

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
# Take first generated sample
idx = 0
estimated_values = est_data_test_transformed[idx]

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
# Take second generated sample
idx = 1
estimated_values = est_data_test_transformed[idx]

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
