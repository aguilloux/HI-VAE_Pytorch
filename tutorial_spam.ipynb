# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import utils
import time

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "spam"
m_perc = 10
mask = 1
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data preprocessing

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = utils.read_data(data_file, feat_types_file, miss_file, true_miss_file)

train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# %%
# Adjust batch size if larger than dataset
batch_size = 1000
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 200
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
from utils import print_loss, plot_loss_evolution

start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = np.random.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = utils.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = utils.samples_concatenation(samples_list)
    
    # #Transform discrete variables back to the original values
    data_train_transformed = utils.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = utils.discrete_variables_transformation(est_data_train, feat_types_dict)
    est_data_train_mean_imputed = utils.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = utils.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = utils.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 10
# Epoch: [ 0]  time: 0.1229, ELBO_train: -16.09188366, KL_z: 1.93647651, KL_s: 0.13470642, reconstruction loss: -14.02070073
# Clusters: 10
# Epoch: [ 1]  time: 0.2307, ELBO_train: -15.56597233, KL_z: 1.78531595, KL_s: 0.13018409, reconstruction loss: -13.65047228
# Clusters: 10
# Epoch: [ 2]  time: 0.3388, ELBO_train: -15.45359898, KL_z: 1.68619545, KL_s: 0.12655624, reconstruction loss: -13.64084729
# Clusters: 10
# Epoch: [ 3]  time: 0.4495, ELBO_train: -15.13532988, KL_z: 1.58792750, KL_s: 0.12359635, reconstruction loss: -13.42380603
# Clusters: 10
# Epoch: [ 4]  time: 0.5626, ELBO_train: -14.74022293, KL_z: 1.50236781, KL_s: 0.12019666, reconstruction loss: -13.11765846
# Clusters: 10
# Epoch: [ 5]  time: 0.6785, ELBO_train: -14.02343146, KL_z: 1.45231048, KL_s: 0.11988695, reconstruction loss: -12.45123402
# Clusters: 10
# Epoch: [ 6]  time: 0.8217, ELBO_train: -13.93874486, KL_z: 1.40442920, KL_s: 0.11960618, reconstruction loss: -12.41470949
# Clusters: 10
# Epoch: [ 7]  time: 0.9315, ELBO_train: -14.12681357, KL_z: 1.36689945, KL_s: 0.11979524, reconstruction loss: -12.64011888
# Clusters: 10
# Epoch: [ 8]  time: 1.0426, ELBO_train: -13.59733582, KL_z: 1.35631669, KL_s: 0.12191765, reconstruction loss: -12.11910148
# Clusters: 10
# Epoch: [ 9]  time: 1.1566, ELBO_train: -13.42604542, KL_z: 1.33729768, KL_s: 0.12402391, reconstruction loss: -11.96472383
# Clusters: 10
# Epoch: [10]  time: 1.2662, ELBO_train: -12.92343267, KL_z: 1.34593356, KL_s: 0.12666488, reconstruction loss: -11.45083423
# Clusters: 10
# Epoch: [11]  time: 1.3803, ELBO_train: -12.95849228, KL_z: 1.35148164, KL_s: 0.13144223, reconstruction loss: -11.47556841
# Clusters: 10
# Epoch: [12]  time: 1.4928, ELBO_train: -12.42692439, KL_z: 1.37014329, KL_s: 0.13306093, reconstruction loss: -10.92372016
# Clusters: 10
# Epoch: [13]  time: 1.6066, ELBO_train: -11.96857293, KL_z: 1.39248514, KL_s: 0.13835907, reconstruction loss: -10.43772872
# Clusters: 10
# Epoch: [14]  time: 1.7212, ELBO_train: -12.19179249, KL_z: 1.42204769, KL_s: 0.14050953, reconstruction loss: -10.62923527
# Clusters: 10
# Epoch: [15]  time: 1.8701, ELBO_train: -12.62366867, KL_z: 1.47111110, KL_s: 0.14686553, reconstruction loss: -11.00569204
# Clusters: 10
# Epoch: [16]  time: 1.9857, ELBO_train: -11.98729451, KL_z: 1.50151467, KL_s: 0.15043354, reconstruction loss: -10.33534630
# Clusters: 10
# Epoch: [17]  time: 2.0958, ELBO_train: -11.62093925, KL_z: 1.54689066, KL_s: 0.15494347, reconstruction loss: -9.91910513
# Clusters: 10
# Epoch: [18]  time: 2.2154, ELBO_train: -11.56159051, KL_z: 1.59419088, KL_s: 0.15601683, reconstruction loss: -9.81138281
# Clusters: 10
# Epoch: [19]  time: 2.3291, ELBO_train: -11.70017370, KL_z: 1.65862890, KL_s: 0.16114553, reconstruction loss: -9.88039927
# Clusters: 10
# Epoch: [20]  time: 2.4499, ELBO_train: -11.13745530, KL_z: 1.69011037, KL_s: 0.16406973, reconstruction loss: -9.28327521
# Clusters: 10
# Epoch: [21]  time: 2.5948, ELBO_train: -10.89592806, KL_z: 1.74585243, KL_s: 0.16913080, reconstruction loss: -8.98094483
# Clusters: 10
# Epoch: [22]  time: 2.7093, ELBO_train: -10.84642569, KL_z: 1.83541203, KL_s: 0.17314744, reconstruction loss: -8.83786623
# Clusters: 10
# Epoch: [23]  time: 2.8207, ELBO_train: -10.23142783, KL_z: 1.87382670, KL_s: 0.17604899, reconstruction loss: -8.18155213
# Clusters: 10
# Epoch: [24]  time: 2.9464, ELBO_train: -10.58463637, KL_z: 1.94679177, KL_s: 0.17923331, reconstruction loss: -8.45861129
# Clusters: 10
# Epoch: [25]  time: 3.0701, ELBO_train: -10.70418421, KL_z: 2.00041608, KL_s: 0.18436082, reconstruction loss: -8.51940731
# Clusters: 10
# Epoch: [26]  time: 3.1829, ELBO_train: -10.29877218, KL_z: 2.04471016, KL_s: 0.18881337, reconstruction loss: -8.06524865
# Clusters: 10
# Epoch: [27]  time: 3.2927, ELBO_train: -10.32167466, KL_z: 2.11909215, KL_s: 0.19639929, reconstruction loss: -8.00618323
# Clusters: 10
# Epoch: [28]  time: 3.4204, ELBO_train: -9.08034023, KL_z: 2.15833267, KL_s: 0.19959569, reconstruction loss: -6.72241187
# Clusters: 10
# Epoch: [29]  time: 3.5390, ELBO_train: -9.90458806, KL_z: 2.20057933, KL_s: 0.20424390, reconstruction loss: -7.49976484
# Clusters: 10
# Epoch: [30]  time: 3.6570, ELBO_train: -9.85336145, KL_z: 2.22972751, KL_s: 0.20710921, reconstruction loss: -7.41652473
# Clusters: 10
# Epoch: [31]  time: 3.7671, ELBO_train: -9.70738220, KL_z: 2.24227126, KL_s: 0.21318968, reconstruction loss: -7.25192126
# Clusters: 10
# Epoch: [32]  time: 3.8784, ELBO_train: -9.37324429, KL_z: 2.30439266, KL_s: 0.21950920, reconstruction loss: -6.84934243
# Clusters: 10
# Epoch: [33]  time: 3.9827, ELBO_train: -9.27455870, KL_z: 2.35739883, KL_s: 0.22274264, reconstruction loss: -6.69441724
# Clusters: 10
# Epoch: [34]  time: 4.0912, ELBO_train: -9.10665385, KL_z: 2.38033779, KL_s: 0.22876851, reconstruction loss: -6.49754755
# Clusters: 10
# Epoch: [35]  time: 4.2289, ELBO_train: -8.85678291, KL_z: 2.40701564, KL_s: 0.23303056, reconstruction loss: -6.21673671
# Clusters: 10
# Epoch: [36]  time: 4.3394, ELBO_train: -9.22259267, KL_z: 2.43027838, KL_s: 0.23670268, reconstruction loss: -6.55561161
# Clusters: 10
# Epoch: [37]  time: 4.4582, ELBO_train: -8.30675077, KL_z: 2.42826724, KL_s: 0.24042487, reconstruction loss: -5.63805866
# Clusters: 10
# Epoch: [38]  time: 4.5673, ELBO_train: -8.94422436, KL_z: 2.46603942, KL_s: 0.24680154, reconstruction loss: -6.23138340
# Clusters: 10
# Epoch: [39]  time: 4.6805, ELBO_train: -8.60521046, KL_z: 2.49668002, KL_s: 0.25183924, reconstruction loss: -5.85669120
# Clusters: 10
# Epoch: [40]  time: 4.8020, ELBO_train: -8.12068065, KL_z: 2.52706305, KL_s: 0.25874368, reconstruction loss: -5.33487391
# Clusters: 10
# Epoch: [41]  time: 4.9170, ELBO_train: -8.23287265, KL_z: 2.53520576, KL_s: 0.26328977, reconstruction loss: -5.43437711
# Clusters: 10
# Epoch: [42]  time: 5.0368, ELBO_train: -8.50907612, KL_z: 2.54239877, KL_s: 0.26972159, reconstruction loss: -5.69695576
# Clusters: 10
# Epoch: [43]  time: 5.1540, ELBO_train: -7.82331419, KL_z: 2.54056406, KL_s: 0.27535423, reconstruction loss: -5.00739590
# Clusters: 10
# Epoch: [44]  time: 5.2745, ELBO_train: -8.19286251, KL_z: 2.58614302, KL_s: 0.27902293, reconstruction loss: -5.32769656
# Clusters: 10
# Epoch: [45]  time: 5.3871, ELBO_train: -8.15968211, KL_z: 2.58594330, KL_s: 0.28478177, reconstruction loss: -5.28895704
# Clusters: 10
# Epoch: [46]  time: 5.5076, ELBO_train: -8.07403596, KL_z: 2.60868788, KL_s: 0.29061047, reconstruction loss: -5.17473761
# Clusters: 10
# Epoch: [47]  time: 5.6233, ELBO_train: -8.27740876, KL_z: 2.66919351, KL_s: 0.29628348, reconstruction loss: -5.31193177
# Clusters: 10
# Epoch: [48]  time: 5.7459, ELBO_train: -7.80079651, KL_z: 2.65903401, KL_s: 0.30369723, reconstruction loss: -4.83806527
# Clusters: 10
# Epoch: [49]  time: 5.8704, ELBO_train: -8.06023534, KL_z: 2.68573125, KL_s: 0.30608312, reconstruction loss: -5.06842097
# Clusters: 10
# Epoch: [50]  time: 5.9901, ELBO_train: -7.94181458, KL_z: 2.68849738, KL_s: 0.31407340, reconstruction loss: -4.93924379
# Clusters: 10
# Epoch: [51]  time: 6.1047, ELBO_train: -7.72224315, KL_z: 2.67030112, KL_s: 0.31816467, reconstruction loss: -4.73377736
# Clusters: 10
# Epoch: [52]  time: 6.2280, ELBO_train: -7.78767522, KL_z: 2.68905536, KL_s: 0.32509569, reconstruction loss: -4.77352417
# Clusters: 10
# Epoch: [53]  time: 6.3515, ELBO_train: -7.41367420, KL_z: 2.71439536, KL_s: 0.32773197, reconstruction loss: -4.37154686
# Clusters: 10
# Epoch: [54]  time: 6.4702, ELBO_train: -6.63611809, KL_z: 2.75173982, KL_s: 0.33341289, reconstruction loss: -3.55096539
# Clusters: 10
# Epoch: [55]  time: 6.5860, ELBO_train: -7.19581445, KL_z: 2.73473358, KL_s: 0.33880258, reconstruction loss: -4.12227829
# Clusters: 10
# Epoch: [56]  time: 6.7055, ELBO_train: -8.00389036, KL_z: 2.78974549, KL_s: 0.34417526, reconstruction loss: -4.86996961
# Clusters: 10
# Epoch: [57]  time: 6.8253, ELBO_train: -6.94365676, KL_z: 2.77638197, KL_s: 0.34954484, reconstruction loss: -3.81772995
# Clusters: 10
# Epoch: [58]  time: 6.9438, ELBO_train: -7.12466780, KL_z: 2.80277936, KL_s: 0.35894291, reconstruction loss: -3.96294554
# Clusters: 10
# Epoch: [59]  time: 7.0724, ELBO_train: -7.26784945, KL_z: 2.81893396, KL_s: 0.36347957, reconstruction loss: -4.08543591
# Clusters: 10
# Epoch: [60]  time: 7.1985, ELBO_train: -6.63340712, KL_z: 2.79388269, KL_s: 0.36808821, reconstruction loss: -3.47143622
# Clusters: 10
# Epoch: [61]  time: 7.3215, ELBO_train: -7.00423511, KL_z: 2.83966072, KL_s: 0.37162936, reconstruction loss: -3.79294503
# Clusters: 10
# Epoch: [62]  time: 7.4879, ELBO_train: -6.81740141, KL_z: 2.86442852, KL_s: 0.38115692, reconstruction loss: -3.57181597
# Clusters: 10
# Epoch: [63]  time: 7.6073, ELBO_train: -7.54822969, KL_z: 2.83476480, KL_s: 0.38447992, reconstruction loss: -4.32898498
# Clusters: 10
# Epoch: [64]  time: 7.7328, ELBO_train: -6.65430101, KL_z: 2.87726355, KL_s: 0.39267433, reconstruction loss: -3.38436313
# Clusters: 10
# Epoch: [65]  time: 7.8533, ELBO_train: -6.94161431, KL_z: 2.86583376, KL_s: 0.39400653, reconstruction loss: -3.68177402
# Clusters: 10
# Epoch: [66]  time: 7.9772, ELBO_train: -6.57672628, KL_z: 2.90812723, KL_s: 0.40128744, reconstruction loss: -3.26731161
# Clusters: 10
# Epoch: [67]  time: 8.0983, ELBO_train: -6.76740170, KL_z: 2.87974540, KL_s: 0.40280831, reconstruction loss: -3.48484798
# Clusters: 10
# Epoch: [68]  time: 8.2084, ELBO_train: -6.71388626, KL_z: 2.88422863, KL_s: 0.41032811, reconstruction loss: -3.41932952
# Clusters: 10
# Epoch: [69]  time: 8.3242, ELBO_train: -6.61624161, KL_z: 2.94089031, KL_s: 0.41442053, reconstruction loss: -3.26093078
# Clusters: 10
# Epoch: [70]  time: 8.4456, ELBO_train: -6.35449775, KL_z: 2.92536044, KL_s: 0.42045983, reconstruction loss: -3.00867748
# Clusters: 10
# Epoch: [71]  time: 8.5680, ELBO_train: -6.04974635, KL_z: 2.95979587, KL_s: 0.42343593, reconstruction loss: -2.66651456
# Clusters: 10
# Epoch: [72]  time: 8.6885, ELBO_train: -7.25655444, KL_z: 2.99581051, KL_s: 0.43172797, reconstruction loss: -3.82901597
# Clusters: 10
# Epoch: [73]  time: 8.7975, ELBO_train: -7.58162578, KL_z: 3.00563176, KL_s: 0.43990600, reconstruction loss: -4.13608801
# Clusters: 10
# Epoch: [74]  time: 8.9056, ELBO_train: -7.09721518, KL_z: 2.99703558, KL_s: 0.44113032, reconstruction loss: -3.65904927
# Clusters: 10
# Epoch: [75]  time: 9.0141, ELBO_train: -6.03614648, KL_z: 2.97708829, KL_s: 0.44828041, reconstruction loss: -2.61077778
# Clusters: 10
# Epoch: [76]  time: 9.1214, ELBO_train: -6.17716233, KL_z: 2.95797300, KL_s: 0.45399729, reconstruction loss: -2.76519203
# Clusters: 10
# Epoch: [77]  time: 9.2288, ELBO_train: -6.82375193, KL_z: 3.04941511, KL_s: 0.46089272, reconstruction loss: -3.31344410
# Clusters: 10
# Epoch: [78]  time: 9.3465, ELBO_train: -6.84362141, KL_z: 3.02825276, KL_s: 0.46348838, reconstruction loss: -3.35188027
# Clusters: 10
# Epoch: [79]  time: 9.4611, ELBO_train: -6.49460856, KL_z: 3.06010524, KL_s: 0.46582178, reconstruction loss: -2.96868153
# Clusters: 10
# Epoch: [80]  time: 9.5676, ELBO_train: -6.41651392, KL_z: 3.06324736, KL_s: 0.47171434, reconstruction loss: -2.88155222
# Clusters: 10
# Epoch: [81]  time: 9.6748, ELBO_train: -6.46994956, KL_z: 3.07003101, KL_s: 0.47581963, reconstruction loss: -2.92409893
# Clusters: 10
# Epoch: [82]  time: 9.7852, ELBO_train: -6.76686414, KL_z: 3.11295636, KL_s: 0.48160756, reconstruction loss: -3.17230022
# Clusters: 10
# Epoch: [83]  time: 9.8976, ELBO_train: -6.18930149, KL_z: 3.08401291, KL_s: 0.48695425, reconstruction loss: -2.61833433
# Clusters: 10
# Epoch: [84]  time: 10.0210, ELBO_train: -5.65988970, KL_z: 3.12459731, KL_s: 0.48966130, reconstruction loss: -2.04563109
# Clusters: 10
# Epoch: [85]  time: 10.1506, ELBO_train: -5.36934574, KL_z: 3.12891157, KL_s: 0.49189794, reconstruction loss: -1.74853623
# Clusters: 10
# Epoch: [86]  time: 10.2698, ELBO_train: -6.25573762, KL_z: 3.11596179, KL_s: 0.50208370, reconstruction loss: -2.63769213
# Clusters: 10
# Epoch: [87]  time: 10.3861, ELBO_train: -6.52992344, KL_z: 3.15365593, KL_s: 0.50271829, reconstruction loss: -2.87354922
# Clusters: 10
# Epoch: [88]  time: 10.5036, ELBO_train: -6.04961713, KL_z: 3.14272165, KL_s: 0.51238843, reconstruction loss: -2.39450705
# Clusters: 10
# Epoch: [89]  time: 10.6219, ELBO_train: -6.04146051, KL_z: 3.14724215, KL_s: 0.51887051, reconstruction loss: -2.37534785
# Clusters: 10
# Epoch: [90]  time: 10.7392, ELBO_train: -6.72624397, KL_z: 3.18117364, KL_s: 0.52406490, reconstruction loss: -3.02100543
# Clusters: 10
# Epoch: [91]  time: 10.8594, ELBO_train: -5.92616312, KL_z: 3.19466607, KL_s: 0.52768974, reconstruction loss: -2.20380731
# Clusters: 10
# Epoch: [92]  time: 10.9762, ELBO_train: -6.50757297, KL_z: 3.20633094, KL_s: 0.53774675, reconstruction loss: -2.76349529
# Clusters: 10
# Epoch: [93]  time: 11.0921, ELBO_train: -5.59605710, KL_z: 3.17887227, KL_s: 0.53390984, reconstruction loss: -1.88327499
# Clusters: 10
# Epoch: [94]  time: 11.2072, ELBO_train: -6.30665938, KL_z: 3.22356439, KL_s: 0.53891063, reconstruction loss: -2.54418437
# Clusters: 10
# Epoch: [95]  time: 11.3249, ELBO_train: -6.72576904, KL_z: 3.24917706, KL_s: 0.54773601, reconstruction loss: -2.92885598
# Clusters: 10
# Epoch: [96]  time: 11.4406, ELBO_train: -6.11546882, KL_z: 3.25418758, KL_s: 0.55318550, reconstruction loss: -2.30809573
# Clusters: 10
# Epoch: [97]  time: 11.5627, ELBO_train: -5.88411164, KL_z: 3.25686423, KL_s: 0.55583449, reconstruction loss: -2.07141292
# Clusters: 10
# Epoch: [98]  time: 11.6732, ELBO_train: -6.12308772, KL_z: 3.26835219, KL_s: 0.56399349, reconstruction loss: -2.29074204
# Clusters: 10
# Epoch: [99]  time: 11.7838, ELBO_train: -6.31913932, KL_z: 3.27064919, KL_s: 0.56551552, reconstruction loss: -2.48297461
# Clusters: 10
# Epoch: [100]  time: 11.8933, ELBO_train: -6.72792625, KL_z: 3.29689105, KL_s: 0.57442156, reconstruction loss: -2.85661364
# Clusters: 10
# Epoch: [101]  time: 12.0052, ELBO_train: -6.19245283, KL_z: 3.32269470, KL_s: 0.56775860, reconstruction loss: -2.30199953
# Clusters: 10
# Epoch: [102]  time: 12.1340, ELBO_train: -5.90315557, KL_z: 3.27758408, KL_s: 0.56224283, reconstruction loss: -2.06332866
# Clusters: 10
# Epoch: [103]  time: 12.2535, ELBO_train: -6.12775453, KL_z: 3.34140229, KL_s: 0.55994427, reconstruction loss: -2.22640797
# Clusters: 10
# Epoch: [104]  time: 12.3795, ELBO_train: -6.28876813, KL_z: 3.37512008, KL_s: 0.55840143, reconstruction loss: -2.35524662
# Clusters: 10
# Epoch: [105]  time: 12.5066, ELBO_train: -6.12315369, KL_z: 3.37250471, KL_s: 0.55970033, reconstruction loss: -2.19094865
# Clusters: 10
# Epoch: [106]  time: 12.6259, ELBO_train: -6.37164434, KL_z: 3.33313743, KL_s: 0.55273374, reconstruction loss: -2.48577317
# Clusters: 10
# Epoch: [107]  time: 12.7435, ELBO_train: -5.62569857, KL_z: 3.30040367, KL_s: 0.55414812, reconstruction loss: -1.77114677
# Clusters: 10
# Epoch: [108]  time: 12.8674, ELBO_train: -6.02727556, KL_z: 3.39364258, KL_s: 0.55293496, reconstruction loss: -2.08069801
# Clusters: 10
# Epoch: [109]  time: 12.9894, ELBO_train: -6.24059725, KL_z: 3.42285204, KL_s: 0.55553373, reconstruction loss: -2.26221148
# Clusters: 10
# Epoch: [110]  time: 13.1076, ELBO_train: -5.84208473, KL_z: 3.44118086, KL_s: 0.55025550, reconstruction loss: -1.85064836
# Clusters: 10
# Epoch: [111]  time: 13.2186, ELBO_train: -6.47195323, KL_z: 3.41532437, KL_s: 0.55400697, reconstruction loss: -2.50262189
# Clusters: 10
# Epoch: [112]  time: 13.3316, ELBO_train: -5.22983265, KL_z: 3.42958776, KL_s: 0.55629464, reconstruction loss: -1.24395025
# Clusters: 10
# Epoch: [113]  time: 13.4362, ELBO_train: -5.62929376, KL_z: 3.47877431, KL_s: 0.54952224, reconstruction loss: -1.60099721
# Clusters: 10
# Epoch: [114]  time: 13.5528, ELBO_train: -5.50590769, KL_z: 3.46047076, KL_s: 0.54841995, reconstruction loss: -1.49701699
# Clusters: 10
# Epoch: [115]  time: 13.6659, ELBO_train: -5.53244495, KL_z: 3.45994910, KL_s: 0.55158039, reconstruction loss: -1.52091547
# Clusters: 10
# Epoch: [116]  time: 13.7951, ELBO_train: -6.11122402, KL_z: 3.45691975, KL_s: 0.55273120, reconstruction loss: -2.10157307
# Clusters: 10
# Epoch: [117]  time: 13.9052, ELBO_train: -6.12426202, KL_z: 3.46837004, KL_s: 0.55522327, reconstruction loss: -2.10066871
# Clusters: 10
# Epoch: [118]  time: 14.0185, ELBO_train: -5.63196405, KL_z: 3.51256506, KL_s: 0.55253601, reconstruction loss: -1.56686298
# Clusters: 10
# Epoch: [119]  time: 14.1249, ELBO_train: -5.44927422, KL_z: 3.52652240, KL_s: 0.55333300, reconstruction loss: -1.36941882
# Clusters: 10
# Epoch: [120]  time: 14.2329, ELBO_train: -5.63756720, KL_z: 3.55957898, KL_s: 0.54941241, reconstruction loss: -1.52857582
# Clusters: 10
# Epoch: [121]  time: 14.3409, ELBO_train: -5.87881788, KL_z: 3.55352386, KL_s: 0.54823709, reconstruction loss: -1.77705693
# Clusters: 10
# Epoch: [122]  time: 14.4506, ELBO_train: -6.16324409, KL_z: 3.55061030, KL_s: 0.54866763, reconstruction loss: -2.06396616
# Clusters: 10
# Epoch: [123]  time: 14.5598, ELBO_train: -6.24027761, KL_z: 3.54833817, KL_s: 0.54991531, reconstruction loss: -2.14202412
# Clusters: 10
# Epoch: [124]  time: 14.6666, ELBO_train: -6.16257826, KL_z: 3.58595959, KL_s: 0.54853022, reconstruction loss: -2.02808845
# Clusters: 10
# Epoch: [125]  time: 14.7783, ELBO_train: -5.72506936, KL_z: 3.57855789, KL_s: 0.54275099, reconstruction loss: -1.60376048
# Clusters: 10
# Epoch: [126]  time: 14.9162, ELBO_train: -4.98962021, KL_z: 3.60871212, KL_s: 0.54688549, reconstruction loss: -0.83402260
# Clusters: 10
# Epoch: [127]  time: 15.0244, ELBO_train: -6.24951045, KL_z: 3.63012695, KL_s: 0.54662549, reconstruction loss: -2.07275800
# Clusters: 10
# Epoch: [128]  time: 15.1375, ELBO_train: -5.56187725, KL_z: 3.61921430, KL_s: 0.54453095, reconstruction loss: -1.39813201
# Clusters: 10
# Epoch: [129]  time: 15.2565, ELBO_train: -5.38187106, KL_z: 3.63006194, KL_s: 0.54435968, reconstruction loss: -1.20744944
# Clusters: 10
# Epoch: [130]  time: 15.3839, ELBO_train: -5.70667966, KL_z: 3.64591606, KL_s: 0.55164115, reconstruction loss: -1.50912245
# Clusters: 10
# Epoch: [131]  time: 15.5117, ELBO_train: -5.41276344, KL_z: 3.65752665, KL_s: 0.54452153, reconstruction loss: -1.21071525
# Clusters: 10
# Epoch: [132]  time: 15.6392, ELBO_train: -5.51303212, KL_z: 3.70529620, KL_s: 0.55045180, reconstruction loss: -1.25728412
# Clusters: 10
# Epoch: [133]  time: 15.7649, ELBO_train: -6.14312426, KL_z: 3.70667553, KL_s: 0.55528935, reconstruction loss: -1.88115939
# Clusters: 10
# Epoch: [134]  time: 15.8925, ELBO_train: -5.29743163, KL_z: 3.66962139, KL_s: 0.55826092, reconstruction loss: -1.06954932
# Clusters: 10
# Epoch: [135]  time: 16.0154, ELBO_train: -5.59648530, KL_z: 3.73220007, KL_s: 0.56053702, reconstruction loss: -1.30374821
# Clusters: 10
# Epoch: [136]  time: 16.1403, ELBO_train: -6.03648106, KL_z: 3.68616867, KL_s: 0.56155113, reconstruction loss: -1.78876126
# Clusters: 10
# Epoch: [137]  time: 16.2571, ELBO_train: -5.63249556, KL_z: 3.69741646, KL_s: 0.56071917, reconstruction loss: -1.37435993
# Clusters: 10
# Epoch: [138]  time: 16.3840, ELBO_train: -5.35773627, KL_z: 3.71201547, KL_s: 0.56552529, reconstruction loss: -1.08019551
# Clusters: 10
# Epoch: [139]  time: 16.5142, ELBO_train: -5.74956338, KL_z: 3.72296937, KL_s: 0.56980244, reconstruction loss: -1.45679156
# Clusters: 10
# Epoch: [140]  time: 16.6780, ELBO_train: -5.09340501, KL_z: 3.71869898, KL_s: 0.56530118, reconstruction loss: -0.80940485
# Clusters: 10
# Epoch: [141]  time: 16.8107, ELBO_train: -5.08341853, KL_z: 3.70793867, KL_s: 0.56564895, reconstruction loss: -0.80983090
# Clusters: 10
# Epoch: [142]  time: 16.9316, ELBO_train: -5.33281310, KL_z: 3.76405573, KL_s: 0.57272073, reconstruction loss: -0.99603665
# Clusters: 10
# Epoch: [143]  time: 17.0478, ELBO_train: -5.02829496, KL_z: 3.75493121, KL_s: 0.56816244, reconstruction loss: -0.70520131
# Clusters: 10
# Epoch: [144]  time: 17.1719, ELBO_train: -5.62147586, KL_z: 3.80534053, KL_s: 0.57667998, reconstruction loss: -1.23945534
# Clusters: 10
# Epoch: [145]  time: 17.2908, ELBO_train: -5.43207693, KL_z: 3.80016430, KL_s: 0.57271620, reconstruction loss: -1.05919643
# Clusters: 10
# Epoch: [146]  time: 17.4201, ELBO_train: -5.44551627, KL_z: 3.76664162, KL_s: 0.57257175, reconstruction loss: -1.10630290
# Clusters: 10
# Epoch: [147]  time: 17.5367, ELBO_train: -5.93591770, KL_z: 3.77100420, KL_s: 0.57012308, reconstruction loss: -1.59479042
# Clusters: 10
# Epoch: [148]  time: 17.6588, ELBO_train: -5.35393588, KL_z: 3.78364658, KL_s: 0.57138077, reconstruction loss: -0.99890852
# Clusters: 10
# Epoch: [149]  time: 17.7724, ELBO_train: -5.64587196, KL_z: 3.79817319, KL_s: 0.57319379, reconstruction loss: -1.27450498
# Clusters: 10
# Epoch: [150]  time: 17.8898, ELBO_train: -5.70070442, KL_z: 3.83540328, KL_s: 0.57456903, reconstruction loss: -1.29073211
# Clusters: 10
# Epoch: [151]  time: 18.0125, ELBO_train: -5.21692268, KL_z: 3.83194629, KL_s: 0.58023651, reconstruction loss: -0.80473987
# Clusters: 10
# Epoch: [152]  time: 18.1283, ELBO_train: -5.74264240, KL_z: 3.84198165, KL_s: 0.58247610, reconstruction loss: -1.31818465
# Clusters: 10
# Epoch: [153]  time: 18.2579, ELBO_train: -5.55374114, KL_z: 3.83018653, KL_s: 0.57766187, reconstruction loss: -1.14589274
# Clusters: 10
# Epoch: [154]  time: 18.3933, ELBO_train: -5.62421322, KL_z: 3.86594280, KL_s: 0.57921032, reconstruction loss: -1.17906010
# Clusters: 10
# Epoch: [155]  time: 18.5248, ELBO_train: -5.78121646, KL_z: 3.84655913, KL_s: 0.57969693, reconstruction loss: -1.35496040
# Clusters: 10
# Epoch: [156]  time: 18.6395, ELBO_train: -5.38515393, KL_z: 3.85445690, KL_s: 0.57771587, reconstruction loss: -0.95298115
# Clusters: 10
# Epoch: [157]  time: 18.7550, ELBO_train: -5.44531552, KL_z: 3.83981546, KL_s: 0.57755808, reconstruction loss: -1.02794198
# Clusters: 10
# Epoch: [158]  time: 18.8642, ELBO_train: -5.19709786, KL_z: 3.88402255, KL_s: 0.57776419, reconstruction loss: -0.73531111
# Clusters: 10
# Epoch: [159]  time: 18.9774, ELBO_train: -5.23892673, KL_z: 3.91898322, KL_s: 0.57981821, reconstruction loss: -0.74012530
# Clusters: 10
# Epoch: [160]  time: 19.0866, ELBO_train: -5.58372307, KL_z: 3.89558490, KL_s: 0.58091446, reconstruction loss: -1.10722371
# Clusters: 10
# Epoch: [161]  time: 19.1983, ELBO_train: -5.41829157, KL_z: 3.94066334, KL_s: 0.58150593, reconstruction loss: -0.89612230
# Clusters: 10
# Epoch: [162]  time: 19.3276, ELBO_train: -5.47532638, KL_z: 3.92616479, KL_s: 0.57735165, reconstruction loss: -0.97180994
# Clusters: 10
# Epoch: [163]  time: 19.4488, ELBO_train: -5.28594859, KL_z: 3.93124207, KL_s: 0.57121150, reconstruction loss: -0.78349503
# Clusters: 10
# Epoch: [164]  time: 19.5753, ELBO_train: -5.03118102, KL_z: 3.93085726, KL_s: 0.58195551, reconstruction loss: -0.51836824
# Clusters: 10
# Epoch: [165]  time: 19.6987, ELBO_train: -5.78405348, KL_z: 3.96327567, KL_s: 0.58038723, reconstruction loss: -1.24039058
# Clusters: 10
# Epoch: [166]  time: 19.8211, ELBO_train: -5.37592729, KL_z: 3.97655606, KL_s: 0.57555695, reconstruction loss: -0.82381427
# Clusters: 10
# Epoch: [167]  time: 19.9371, ELBO_train: -4.94549624, KL_z: 3.96700104, KL_s: 0.57952150, reconstruction loss: -0.39897370
# Clusters: 10
# Epoch: [168]  time: 20.0601, ELBO_train: -5.38350677, KL_z: 3.96183530, KL_s: 0.57768798, reconstruction loss: -0.84398349
# Clusters: 10
# Epoch: [169]  time: 20.1745, ELBO_train: -4.95811701, KL_z: 3.92425251, KL_s: 0.57873650, reconstruction loss: -0.45512799
# Clusters: 10
# Epoch: [170]  time: 20.2950, ELBO_train: -5.33982539, KL_z: 3.97287361, KL_s: 0.58621867, reconstruction loss: -0.78073311
# Clusters: 10
# Epoch: [171]  time: 20.4054, ELBO_train: -5.28255049, KL_z: 4.01179345, KL_s: 0.58407156, reconstruction loss: -0.68668548
# Clusters: 10
# Epoch: [172]  time: 20.5152, ELBO_train: -5.81099351, KL_z: 4.01805607, KL_s: 0.58682549, reconstruction loss: -1.20611195
# Clusters: 10
# Epoch: [173]  time: 20.6286, ELBO_train: -4.87151615, KL_z: 3.96356503, KL_s: 0.58561238, reconstruction loss: -0.32233874
# Clusters: 10
# Epoch: [174]  time: 20.7391, ELBO_train: -5.31363487, KL_z: 4.03264356, KL_s: 0.59144668, reconstruction loss: -0.68954464
# Clusters: 10
# Epoch: [175]  time: 20.8533, ELBO_train: -5.77106857, KL_z: 3.99749160, KL_s: 0.59355211, reconstruction loss: -1.18002486
# Clusters: 10
# Epoch: [176]  time: 20.9617, ELBO_train: -5.21761560, KL_z: 3.97376736, KL_s: 0.59494770, reconstruction loss: -0.64890055
# Clusters: 10
# Epoch: [177]  time: 21.0761, ELBO_train: -4.57351510, KL_z: 3.95728890, KL_s: 0.58968540, reconstruction loss: -0.02654080
# Clusters: 10
# Epoch: [178]  time: 21.1877, ELBO_train: -5.62609577, KL_z: 3.98603153, KL_s: 0.59459992, reconstruction loss: -1.04546432
# Clusters: 10
# Epoch: [179]  time: 21.3049, ELBO_train: -5.17746782, KL_z: 4.03962310, KL_s: 0.59491821, reconstruction loss: -0.54292651
# Clusters: 10
# Epoch: [180]  time: 21.4161, ELBO_train: -5.49923229, KL_z: 4.08018017, KL_s: 0.60187006, reconstruction loss: -0.81718206
# Clusters: 10
# Epoch: [181]  time: 21.5345, ELBO_train: -5.46741549, KL_z: 4.06384087, KL_s: 0.59734134, reconstruction loss: -0.80623329
# Clusters: 10
# Epoch: [182]  time: 21.6475, ELBO_train: -5.36401383, KL_z: 4.04666758, KL_s: 0.60059508, reconstruction loss: -0.71675118
# Clusters: 10
# Epoch: [183]  time: 21.7616, ELBO_train: -4.87681580, KL_z: 4.01399589, KL_s: 0.60466901, reconstruction loss: -0.25815090
# Clusters: 10
# Epoch: [184]  time: 21.8804, ELBO_train: -4.99283202, KL_z: 4.00084464, KL_s: 0.60088082, reconstruction loss: -0.39110657
# Clusters: 10
# Epoch: [185]  time: 21.9904, ELBO_train: -4.74940467, KL_z: 4.04254142, KL_s: 0.60383368, reconstruction loss: -0.10302957
# Clusters: 10
# Epoch: [186]  time: 22.1069, ELBO_train: -5.19390535, KL_z: 4.07154608, KL_s: 0.60534445, reconstruction loss: -0.51701482
# Clusters: 10
# Epoch: [187]  time: 22.2203, ELBO_train: -4.76948325, KL_z: 4.07211542, KL_s: 0.60290778, reconstruction loss: -0.09446005
# Clusters: 10
# Epoch: [188]  time: 22.3917, ELBO_train: -4.92669423, KL_z: 4.07808065, KL_s: 0.60585892, reconstruction loss: -0.24275466
# Clusters: 10
# Epoch: [189]  time: 22.5280, ELBO_train: -5.84627930, KL_z: 4.09304349, KL_s: 0.61323849, reconstruction loss: -1.13999732
# Clusters: 10
# Epoch: [190]  time: 22.6613, ELBO_train: -4.88785815, KL_z: 4.06355953, KL_s: 0.61142031, reconstruction loss: -0.21287831
# Clusters: 10
# Epoch: [191]  time: 22.7961, ELBO_train: -4.82726065, KL_z: 4.08024915, KL_s: 0.60529264, reconstruction loss: -0.14171886
# Clusters: 10
# Epoch: [192]  time: 22.9212, ELBO_train: -4.59932319, KL_z: 4.08121856, KL_s: 0.61011096, reconstruction loss: 0.09200633
# Clusters: 10
# Epoch: [193]  time: 23.0434, ELBO_train: -4.93994768, KL_z: 4.08211994, KL_s: 0.61306381, reconstruction loss: -0.24476393
# Clusters: 10
# Epoch: [194]  time: 23.1743, ELBO_train: -5.43763224, KL_z: 4.07355078, KL_s: 0.61852841, reconstruction loss: -0.74555306
# Clusters: 10
# Epoch: [195]  time: 23.3069, ELBO_train: -4.91577609, KL_z: 4.08346732, KL_s: 0.62071371, reconstruction loss: -0.21159506
# Clusters: 10
# Epoch: [196]  time: 23.4644, ELBO_train: -4.56697114, KL_z: 4.09401830, KL_s: 0.62106959, reconstruction loss: 0.14811675
# Clusters: 10
# Epoch: [197]  time: 23.5890, ELBO_train: -4.87276252, KL_z: 4.07458989, KL_s: 0.62388778, reconstruction loss: -0.17428486
# Clusters: 10
# Epoch: [198]  time: 23.7269, ELBO_train: -5.55522490, KL_z: 4.10473712, KL_s: 0.62272127, reconstruction loss: -0.82776650
# Clusters: 10
# Epoch: [199]  time: 23.8788, ELBO_train: -5.29510244, KL_z: 4.11895911, KL_s: 0.62723573, reconstruction loss: -0.54890760
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = utils.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = utils.samples_concatenation(samples_list)[-1]
    data_test_transformed = utils.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = utils.discrete_variables_transformation(est_data_test, feat_types_dict)

# %%
from utils import plot_true_vs_estimation
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
estimated_values = est_data_test_transformed

# Call plotting function
plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
