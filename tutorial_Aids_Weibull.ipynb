# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
from utils import data_processing, visualization, statistic
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
import random
def set_seed(seed=42):
    random.seed(seed)  # Python random module
    np.random.seed(seed)  # NumPy
    torch.manual_seed(seed)  # PyTorch CPU seed
    torch.cuda.manual_seed(seed)  # PyTorch GPU seed
    torch.cuda.manual_seed_all(seed)  # For multi-GPU
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False  # Disable CuDNN auto-tuning

# Set the seed
set_seed(42)

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "Aids"
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"

# If the dataset has no missing data, leave the "miss_file" variable empty
m_perc = 10
mask = 1
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data loading and Feature analysis

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = data_processing.read_data(data_file, feat_types_file, miss_file, true_miss_file)

# Feature analysis
data_transformed = data_processing.discrete_variables_transformation(data, feat_types_dict)
# features_df = pd.DataFrame(data_transformed, columns=["feat_" + str(i+1) for i in range(data_transformed.shape[1])])

visualization.plot_data(data_transformed, feat_types_dict)

# %%
data_cens = data[data[:, 1] == 0]
data_surv = data[data[:, 1] == 1]
miss_mask_cens = miss_mask[data[:, 1] == 0]
miss_mask_surv = miss_mask[data[:, 1] == 1]
true_miss_mask_cens = true_miss_mask[data[:, 1] == 0]
true_miss_mask_surv = true_miss_mask[data[:, 1] == 1]

n_surv_time = data_surv.shape[0]
n_cens_time = data_cens.shape[0]
n_time_aug = int(n_cens_time / n_surv_time)
# n_time_aug = 2

data_surv = data_surv.repeat(n_time_aug, 1)
miss_mask_surv = miss_mask_surv.repeat(n_time_aug, 1)
true_miss_mask_surv = true_miss_mask_surv.repeat(n_time_aug, 1)

data = torch.cat([data_cens, data_surv], dim=0)
miss_mask = torch.cat([miss_mask_cens, miss_mask_surv], dim=0)
true_miss_mask = torch.cat([true_miss_mask_cens, true_miss_mask_surv], dim=0)

# %% [markdown]
# ### Experiment setting

# %%
# Train-test split
train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# Adjust batch size if larger than dataset
batch_size = 100
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 500
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

rng = np.random.default_rng(seed=42)
for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = rng.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = data_processing.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau, n_generated_sample=1)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = statistic.samples_concatenation(samples_list)
    
    # Transform discrete variables back to the original values
    data_train_transformed = data_processing.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = data_processing.discrete_variables_transformation(est_data_train[0], feat_types_dict)
    # est_data_train_mean_imputed = statistic.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = statistic.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = statistic.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    visualization.print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

visualization.plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
visualization.plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
visualization.plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 9
# Epoch: [ 0]  time: 0.0815, ELBO_train: -162.42733574, KL_z: 0.70216284, KL_s: 0.07090285, reconstruction loss: -161.65427004
# Clusters: 7
# Epoch: [ 1]  time: 0.1406, ELBO_train: -129.46014833, KL_z: 0.61634973, KL_s: 0.08563493, reconstruction loss: -128.75816367
# Clusters: 6
# Epoch: [ 2]  time: 0.1980, ELBO_train: -112.82476187, KL_z: 0.67789383, KL_s: 0.11083324, reconstruction loss: -112.03603479
# Clusters: 6
# Epoch: [ 3]  time: 0.2559, ELBO_train: -102.47591162, KL_z: 0.81063555, KL_s: 0.14431341, reconstruction loss: -101.52096266
# Clusters: 5
# Epoch: [ 4]  time: 0.3142, ELBO_train: -91.71341705, KL_z: 0.98390400, KL_s: 0.18213628, reconstruction loss: -90.54737677
# Clusters: 5
# Epoch: [ 5]  time: 0.3729, ELBO_train: -83.26443768, KL_z: 1.19529487, KL_s: 0.22095107, reconstruction loss: -81.84819174
# Clusters: 4
# Epoch: [ 6]  time: 0.4307, ELBO_train: -74.73354816, KL_z: 1.40996829, KL_s: 0.25821660, reconstruction loss: -73.06536327
# Clusters: 4
# Epoch: [ 7]  time: 0.4874, ELBO_train: -68.07102346, KL_z: 1.63489436, KL_s: 0.29292868, reconstruction loss: -66.14320043
# Clusters: 4
# Epoch: [ 8]  time: 0.5479, ELBO_train: -62.76506829, KL_z: 1.83517887, KL_s: 0.32358751, reconstruction loss: -60.60630190
# Clusters: 4
# Epoch: [ 9]  time: 0.6049, ELBO_train: -58.56317902, KL_z: 2.02079506, KL_s: 0.35068598, reconstruction loss: -56.19169797
# Clusters: 4
# Epoch: [10]  time: 0.6622, ELBO_train: -54.24185634, KL_z: 2.19769976, KL_s: 0.37482607, reconstruction loss: -51.66933051
# Clusters: 4
# Epoch: [11]  time: 0.7190, ELBO_train: -50.75111270, KL_z: 2.31147890, KL_s: 0.39545113, reconstruction loss: -48.04418267
# Clusters: 4
# Epoch: [12]  time: 0.7769, ELBO_train: -48.57876611, KL_z: 2.40408108, KL_s: 0.41243161, reconstruction loss: -45.76225342
# Clusters: 4
# Epoch: [13]  time: 0.8334, ELBO_train: -46.64269900, KL_z: 2.45845337, KL_s: 0.42736576, reconstruction loss: -43.75687987
# Epoch: [226]  time: 13.9466, ELBO_train: -27.50937355, KL_z: 0.88778495, KL_s: 0.04507104, reconstruction loss: -26.57651756
# Clusters: 10
# Epoch: [227]  time: 14.0078, ELBO_train: -27.46668386, KL_z: 0.88729250, KL_s: 0.04442351, reconstruction loss: -26.53496785
# Clusters: 10
# Epoch: [228]  time: 14.0690, ELBO_train: -27.51939440, KL_z: 0.89052905, KL_s: 0.04363160, reconstruction loss: -26.58523375
# Clusters: 10
# Epoch: [229]  time: 14.1309, ELBO_train: -27.42348802, KL_z: 0.88191928, KL_s: 0.04307602, reconstruction loss: -26.49849272
# Clusters: 10
# Epoch: [230]  time: 14.1913, ELBO_train: -27.42994034, KL_z: 0.87412861, KL_s: 0.04244150, reconstruction loss: -26.51337023
# Clusters: 10
# Epoch: [231]  time: 14.2513, ELBO_train: -27.49124920, KL_z: 0.87466067, KL_s: 0.04229225, reconstruction loss: -26.57429628
# Clusters: 10
# Epoch: [232]  time: 14.3115, ELBO_train: -27.39809430, KL_z: 0.87997424, KL_s: 0.04215260, reconstruction loss: -26.47596746
# Clusters: 10
# Epoch: [233]  time: 14.3729, ELBO_train: -27.50158548, KL_z: 0.88633602, KL_s: 0.04324144, reconstruction loss: -26.57200802
# Clusters: 10
# Epoch: [234]  time: 14.4332, ELBO_train: -27.47314048, KL_z: 0.89693728, KL_s: 0.04350349, reconstruction loss: -26.53269970
# Clusters: 10
# Epoch: [235]  time: 14.4939, ELBO_train: -27.47185183, KL_z: 0.89399515, KL_s: 0.04334505, reconstruction loss: -26.53451163
# Clusters: 10
# Epoch: [236]  time: 14.5555, ELBO_train: -27.48969924, KL_z: 0.90088194, KL_s: 0.04342707, reconstruction loss: -26.54539024
# Clusters: 10
# Epoch: [237]  time: 14.6170, ELBO_train: -27.44875407, KL_z: 0.89665328, KL_s: 0.04406048, reconstruction loss: -26.50804031
# Clusters: 10
# Epoch: [238]  time: 14.6774, ELBO_train: -27.48350585, KL_z: 0.89277669, KL_s: 0.04433136, reconstruction loss: -26.54639780
# Clusters: 10
# Epoch: [239]  time: 14.7377, ELBO_train: -27.46607244, KL_z: 0.90176198, KL_s: 0.04466274, reconstruction loss: -26.51964772
# Clusters: 10
# Epoch: [240]  time: 14.7973, ELBO_train: -27.42440045, KL_z: 0.90878896, KL_s: 0.04539463, reconstruction loss: -26.47021686
# Clusters: 10
# Epoch: [241]  time: 14.8588, ELBO_train: -27.41721451, KL_z: 0.89398164, KL_s: 0.04643056, reconstruction loss: -26.47680232
# Clusters: 10
# Epoch: [242]  time: 14.9192, ELBO_train: -27.40093160, KL_z: 0.88967739, KL_s: 0.04677287, reconstruction loss: -26.46448134
# Clusters: 10
# Epoch: [243]  time: 14.9789, ELBO_train: -27.42184949, KL_z: 0.88337305, KL_s: 0.04648122, reconstruction loss: -26.49199522
# Clusters: 10
# Epoch: [244]  time: 15.0385, ELBO_train: -27.40271270, KL_z: 0.89360503, KL_s: 0.04593326, reconstruction loss: -26.46317441
# Clusters: 10
# Epoch: [245]  time: 15.1008, ELBO_train: -27.45511103, KL_z: 0.90177566, KL_s: 0.04463221, reconstruction loss: -26.50870316
# Clusters: 10
# Epoch: [246]  time: 15.1613, ELBO_train: -27.42969108, KL_z: 0.91439631, KL_s: 0.04423366, reconstruction loss: -26.47106110
# Clusters: 10
# Epoch: [247]  time: 15.2210, ELBO_train: -27.45384717, KL_z: 0.91074562, KL_s: 0.04409508, reconstruction loss: -26.49900647
# Clusters: 10
# Epoch: [248]  time: 15.2811, ELBO_train: -27.41035962, KL_z: 0.90762892, KL_s: 0.04551126, reconstruction loss: -26.45721944
# Clusters: 10
# Epoch: [249]  time: 15.3422, ELBO_train: -27.46658480, KL_z: 0.91020662, KL_s: 0.04646736, reconstruction loss: -26.50991081
# Clusters: 10
# Epoch: [250]  time: 15.4022, ELBO_train: -27.46956933, KL_z: 0.91718261, KL_s: 0.04568130, reconstruction loss: -26.50670542
# Clusters: 10
# Epoch: [251]  time: 15.4619, ELBO_train: -27.39088905, KL_z: 0.91791262, KL_s: 0.04479650, reconstruction loss: -26.42817993
# Clusters: 9
# Epoch: [252]  time: 15.5218, ELBO_train: -27.42357159, KL_z: 0.91842590, KL_s: 0.04544565, reconstruction loss: -26.45970004
# Clusters: 10
# Epoch: [253]  time: 15.5837, ELBO_train: -27.40772104, KL_z: 0.91912158, KL_s: 0.04591829, reconstruction loss: -26.44268117
# Clusters: 10
# Epoch: [254]  time: 15.6441, ELBO_train: -27.35730863, KL_z: 0.91626904, KL_s: 0.04570656, reconstruction loss: -26.39533303
# Clusters: 10
# Epoch: [255]  time: 15.7045, ELBO_train: -27.30509567, KL_z: 0.90331489, KL_s: 0.04526575, reconstruction loss: -26.35651504
# Clusters: 10
# Epoch: [256]  time: 15.7653, ELBO_train: -27.36921179, KL_z: 0.89126314, KL_s: 0.04594055, reconstruction loss: -26.43200810
# Clusters: 10
# Epoch: [257]  time: 15.8271, ELBO_train: -27.41159356, KL_z: 0.90237393, KL_s: 0.04570907, reconstruction loss: -26.46351055
# Clusters: 10
# Epoch: [258]  time: 15.8889, ELBO_train: -27.47845197, KL_z: 0.92012800, KL_s: 0.04607210, reconstruction loss: -26.51225188
# Clusters: 10
# Epoch: [259]  time: 15.9531, ELBO_train: -27.37639499, KL_z: 0.91708910, KL_s: 0.04614511, reconstruction loss: -26.41316077
# Clusters: 10
# Epoch: [260]  time: 16.0152, ELBO_train: -27.38075805, KL_z: 0.92063825, KL_s: 0.04502642, reconstruction loss: -26.41509337
# Clusters: 10
# Epoch: [261]  time: 16.0781, ELBO_train: -27.35784280, KL_z: 0.92390421, KL_s: 0.04401006, reconstruction loss: -26.38992853
# Clusters: 10
# Epoch: [262]  time: 16.1396, ELBO_train: -27.45811582, KL_z: 0.93307185, KL_s: 0.04380107, reconstruction loss: -26.48124290
# Clusters: 10
# Epoch: [263]  time: 16.2010, ELBO_train: -27.32583785, KL_z: 0.92543004, KL_s: 0.04351437, reconstruction loss: -26.35689344
# Clusters: 10
# Epoch: [264]  time: 16.2620, ELBO_train: -27.32575500, KL_z: 0.91441024, KL_s: 0.04431646, reconstruction loss: -26.36702830
# Clusters: 10
# Epoch: [265]  time: 16.3239, ELBO_train: -27.37321031, KL_z: 0.91177411, KL_s: 0.04565112, reconstruction loss: -26.41578508
# Clusters: 10
# Epoch: [266]  time: 16.3848, ELBO_train: -27.37555075, KL_z: 0.91807777, KL_s: 0.04686989, reconstruction loss: -26.41060309
# Clusters: 10
# Epoch: [267]  time: 16.4463, ELBO_train: -27.36876571, KL_z: 0.92633858, KL_s: 0.04737702, reconstruction loss: -26.39505011
# Clusters: 10
# Epoch: [268]  time: 16.5074, ELBO_train: -27.35436487, KL_z: 0.92417490, KL_s: 0.04810832, reconstruction loss: -26.38208164
# Clusters: 10
# Epoch: [269]  time: 16.5709, ELBO_train: -27.33380651, KL_z: 0.92043578, KL_s: 0.04865989, reconstruction loss: -26.36471085
# Clusters: 9
# Epoch: [270]  time: 16.6317, ELBO_train: -27.39804316, KL_z: 0.91649788, KL_s: 0.04897466, reconstruction loss: -26.43257062
# Clusters: 8
# Epoch: [271]  time: 16.6924, ELBO_train: -27.37382329, KL_z: 0.93532812, KL_s: 0.04876463, reconstruction loss: -26.38973054
# Clusters: 10
# Epoch: [272]  time: 16.7533, ELBO_train: -27.37180543, KL_z: 0.93835767, KL_s: 0.04819030, reconstruction loss: -26.38525746
# Clusters: 10
# Epoch: [273]  time: 16.8159, ELBO_train: -27.26941144, KL_z: 0.92910643, KL_s: 0.04884104, reconstruction loss: -26.29146397
# Clusters: 10
# Epoch: [274]  time: 16.8769, ELBO_train: -27.33793831, KL_z: 0.91663313, KL_s: 0.04848759, reconstruction loss: -26.37281759
# Clusters: 10
# Epoch: [275]  time: 16.9379, ELBO_train: -27.33577752, KL_z: 0.92605717, KL_s: 0.04790010, reconstruction loss: -26.36182025
# Clusters: 10
# Epoch: [276]  time: 16.9998, ELBO_train: -27.34254122, KL_z: 0.93538408, KL_s: 0.04854757, reconstruction loss: -26.35860957
# Clusters: 10
# Epoch: [277]  time: 17.0705, ELBO_train: -27.34820688, KL_z: 0.94093013, KL_s: 0.04951780, reconstruction loss: -26.35775895
# Clusters: 10
# Epoch: [278]  time: 17.1328, ELBO_train: -27.33197367, KL_z: 0.95084335, KL_s: 0.04941009, reconstruction loss: -26.33172024
# Clusters: 9
# Epoch: [279]  time: 17.1947, ELBO_train: -27.28148568, KL_z: 0.94293946, KL_s: 0.04963121, reconstruction loss: -26.28891501
# Clusters: 9
# Epoch: [280]  time: 17.2576, ELBO_train: -27.28058290, KL_z: 0.93074151, KL_s: 0.04908948, reconstruction loss: -26.30075192
# Clusters: 9
# Epoch: [281]  time: 17.3218, ELBO_train: -27.28675020, KL_z: 0.91892427, KL_s: 0.04867193, reconstruction loss: -26.31915400
# Clusters: 9
# Epoch: [282]  time: 17.3846, ELBO_train: -27.36787903, KL_z: 0.92208544, KL_s: 0.04746330, reconstruction loss: -26.39833029
# Clusters: 10
# Epoch: [283]  time: 17.4522, ELBO_train: -27.33876610, KL_z: 0.94513370, KL_s: 0.04665239, reconstruction loss: -26.34698001
# Clusters: 10
# Clusters: 10
# Epoch: [304]  time: 18.7418, ELBO_train: -27.27784657, KL_z: 0.97296311, KL_s: 0.04800075, reconstruction loss: -26.25688271
# Clusters: 10
# Epoch: [305]  time: 18.8035, ELBO_train: -27.22600043, KL_z: 0.96368954, KL_s: 0.04798728, reconstruction loss: -26.21432360
# Clusters: 10
# Epoch: [306]  time: 18.8639, ELBO_train: -27.23471117, KL_z: 0.95521022, KL_s: 0.04798424, reconstruction loss: -26.23151670
# Clusters: 10
# Epoch: [307]  time: 18.9240, ELBO_train: -27.26525557, KL_z: 0.95118394, KL_s: 0.04837795, reconstruction loss: -26.26569369
# Clusters: 10
# Epoch: [308]  time: 18.9839, ELBO_train: -27.28398788, KL_z: 0.96993298, KL_s: 0.04831265, reconstruction loss: -26.26574225
# Clusters: 9
# Epoch: [309]  time: 19.0459, ELBO_train: -27.25144529, KL_z: 0.97568401, KL_s: 0.04944646, reconstruction loss: -26.22631482
# Clusters: 9
# Epoch: [310]  time: 19.1063, ELBO_train: -27.26065159, KL_z: 0.97847242, KL_s: 0.05048719, reconstruction loss: -26.23169198
# Clusters: 10
# Epoch: [311]  time: 19.1667, ELBO_train: -27.25440550, KL_z: 0.98191453, KL_s: 0.05187345, reconstruction loss: -26.22061753
# Clusters: 10
# Epoch: [312]  time: 19.2270, ELBO_train: -27.30849338, KL_z: 0.98918913, KL_s: 0.05192269, reconstruction loss: -26.26738156
# Clusters: 10
# Epoch: [313]  time: 19.2885, ELBO_train: -27.23216844, KL_z: 0.98682982, KL_s: 0.05187859, reconstruction loss: -26.19346002
# Clusters: 10
# Epoch: [314]  time: 19.3488, ELBO_train: -27.25404370, KL_z: 0.97301042, KL_s: 0.05165501, reconstruction loss: -26.22937827
# Clusters: 10
# Epoch: [315]  time: 19.4094, ELBO_train: -27.22975743, KL_z: 0.97237299, KL_s: 0.05167368, reconstruction loss: -26.20571075
# Clusters: 10
# Epoch: [316]  time: 19.4692, ELBO_train: -27.20986164, KL_z: 0.96819243, KL_s: 0.05169657, reconstruction loss: -26.18997264
# Clusters: 10
# Epoch: [317]  time: 19.5305, ELBO_train: -27.23119152, KL_z: 0.97659019, KL_s: 0.05096672, reconstruction loss: -26.20363460
# Clusters: 10
# Epoch: [318]  time: 19.5910, ELBO_train: -27.22954059, KL_z: 0.97282331, KL_s: 0.05109149, reconstruction loss: -26.20562578
# Clusters: 10
# Epoch: [319]  time: 19.6523, ELBO_train: -27.17930532, KL_z: 0.97059405, KL_s: 0.05110051, reconstruction loss: -26.15761076
# Clusters: 9
# Epoch: [320]  time: 19.7132, ELBO_train: -27.21183884, KL_z: 0.96974610, KL_s: 0.05079278, reconstruction loss: -26.19129996
# Clusters: 10
# Epoch: [321]  time: 19.7759, ELBO_train: -27.25063121, KL_z: 0.96436341, KL_s: 0.05084473, reconstruction loss: -26.23542307
# Clusters: 10
# Epoch: [322]  time: 19.8364, ELBO_train: -27.19418454, KL_z: 0.97737865, KL_s: 0.05071941, reconstruction loss: -26.16608648
# Clusters: 10
# Epoch: [323]  time: 19.8967, ELBO_train: -27.28371716, KL_z: 0.98550588, KL_s: 0.05094168, reconstruction loss: -26.24726960
# Clusters: 10
# Epoch: [324]  time: 19.9583, ELBO_train: -27.22482979, KL_z: 0.99386686, KL_s: 0.05062668, reconstruction loss: -26.18033625
# Clusters: 9
# Epoch: [325]  time: 20.0203, ELBO_train: -27.20619714, KL_z: 0.99427255, KL_s: 0.05007228, reconstruction loss: -26.16185231
# Clusters: 9
# Epoch: [326]  time: 20.0814, ELBO_train: -27.27036154, KL_z: 0.99114430, KL_s: 0.04924129, reconstruction loss: -26.22997595
# Clusters: 10
# Epoch: [327]  time: 20.1420, ELBO_train: -27.22418869, KL_z: 0.99684896, KL_s: 0.04925257, reconstruction loss: -26.17808716
# Clusters: 9
# Epoch: [328]  time: 20.2027, ELBO_train: -27.22778404, KL_z: 1.00592969, KL_s: 0.05001694, reconstruction loss: -26.17183741
# Clusters: 9
# Epoch: [329]  time: 20.2641, ELBO_train: -27.20733821, KL_z: 1.00648063, KL_s: 0.05056714, reconstruction loss: -26.15029045
# Clusters: 9
# Epoch: [330]  time: 20.3250, ELBO_train: -27.18586290, KL_z: 0.99722634, KL_s: 0.05085666, reconstruction loss: -26.13777990
# Clusters: 9
# Epoch: [331]  time: 20.3863, ELBO_train: -27.18671513, KL_z: 0.98231659, KL_s: 0.05162913, reconstruction loss: -26.15276941
# Clusters: 9
# Epoch: [332]  time: 20.4472, ELBO_train: -27.17673874, KL_z: 0.97716747, KL_s: 0.05269152, reconstruction loss: -26.14687975
# Clusters: 9
# Epoch: [333]  time: 20.5090, ELBO_train: -27.22993374, KL_z: 0.97792474, KL_s: 0.05349962, reconstruction loss: -26.19850937
# Clusters: 9
# Epoch: [334]  time: 20.5696, ELBO_train: -27.18009603, KL_z: 0.99463156, KL_s: 0.05438840, reconstruction loss: -26.13107607
# Clusters: 8
# Epoch: [335]  time: 20.6302, ELBO_train: -27.15753722, KL_z: 0.99378864, KL_s: 0.05551562, reconstruction loss: -26.10823297
# Clusters: 8
# Epoch: [336]  time: 20.6910, ELBO_train: -27.22662282, KL_z: 0.98950434, KL_s: 0.05605051, reconstruction loss: -26.18106797
# Clusters: 9
# Epoch: [337]  time: 20.7522, ELBO_train: -27.16709459, KL_z: 1.00464427, KL_s: 0.05706704, reconstruction loss: -26.10538328
# Clusters: 9
# Epoch: [338]  time: 20.8133, ELBO_train: -27.19142795, KL_z: 0.99696159, KL_s: 0.05736239, reconstruction loss: -26.13710397
# Clusters: 9
# Epoch: [339]  time: 20.8741, ELBO_train: -27.20887053, KL_z: 0.98358831, KL_s: 0.05713896, reconstruction loss: -26.16814326
# Clusters: 9
# Epoch: [340]  time: 20.9347, ELBO_train: -27.18607056, KL_z: 1.00074636, KL_s: 0.05622871, reconstruction loss: -26.12909549
# Clusters: 9
# Epoch: [341]  time: 20.9963, ELBO_train: -27.16915882, KL_z: 1.01007963, KL_s: 0.05488591, reconstruction loss: -26.10419328
# Clusters: 9
# Epoch: [342]  time: 21.0572, ELBO_train: -27.11421525, KL_z: 0.98020289, KL_s: 0.05450632, reconstruction loss: -26.07950604
# Clusters: 9
# Epoch: [343]  time: 21.1184, ELBO_train: -27.13459206, KL_z: 0.97492450, KL_s: 0.05385022, reconstruction loss: -26.10581733
# Clusters: 9
# Epoch: [344]  time: 21.1795, ELBO_train: -27.14687645, KL_z: 0.97976312, KL_s: 0.05340460, reconstruction loss: -26.11370874
# Clusters: 9
# Epoch: [345]  time: 21.2419, ELBO_train: -27.11618888, KL_z: 0.98543429, KL_s: 0.05370533, reconstruction loss: -26.07704926
# Clusters: 9
# Epoch: [346]  time: 21.3027, ELBO_train: -27.10858643, KL_z: 0.98307871, KL_s: 0.05330901, reconstruction loss: -26.07219871
# Clusters: 9
# Epoch: [347]  time: 21.3639, ELBO_train: -27.11139882, KL_z: 0.97983858, KL_s: 0.05293487, reconstruction loss: -26.07862537
# Clusters: 9
# Epoch: [348]  time: 21.4248, ELBO_train: -27.20244396, KL_z: 0.98807692, KL_s: 0.05265538, reconstruction loss: -26.16171166
# Clusters: 9
# Epoch: [349]  time: 21.4884, ELBO_train: -27.13632834, KL_z: 1.01613595, KL_s: 0.05229978, reconstruction loss: -26.06789261
# Clusters: 9
# Epoch: [350]  time: 21.5500, ELBO_train: -27.14657927, KL_z: 1.00988573, KL_s: 0.05218491, reconstruction loss: -26.08450863
# Clusters: 9
# ...
# Clusters: 10
# Epoch: [385]  time: 23.6996, ELBO_train: -27.07939041, KL_z: 1.04297048, KL_s: 0.06425826, reconstruction loss: -25.97216167
# Clusters: 10
# Epoch: [386]  time: 23.7611, ELBO_train: -27.07041919, KL_z: 1.04404989, KL_s: 0.06475317, reconstruction loss: -25.96161613
# Clusters: 10
# Epoch: [387]  time: 23.8224, ELBO_train: -27.06299698, KL_z: 1.02136745, KL_s: 0.06594546, reconstruction loss: -25.97568407
# Clusters: 10
# Epoch: [388]  time: 23.8837, ELBO_train: -27.08777058, KL_z: 1.02448445, KL_s: 0.06543301, reconstruction loss: -25.99785312
# Clusters: 10
# Epoch: [389]  time: 23.9460, ELBO_train: -27.04921067, KL_z: 1.02265493, KL_s: 0.06554712, reconstruction loss: -25.96100862
# Clusters: 10
# Epoch: [390]  time: 24.0073, ELBO_train: -27.08168149, KL_z: 1.03425071, KL_s: 0.06518026, reconstruction loss: -25.98225053
# Clusters: 10
# Epoch: [391]  time: 24.0683, ELBO_train: -27.01732254, KL_z: 1.02646527, KL_s: 0.06444266, reconstruction loss: -25.92641461
# Clusters: 10
# Epoch: [392]  time: 24.1293, ELBO_train: -27.08511138, KL_z: 1.01690946, KL_s: 0.06347264, reconstruction loss: -26.00472928
# Clusters: 10
# Epoch: [393]  time: 24.1918, ELBO_train: -27.04819000, KL_z: 1.04944174, KL_s: 0.06267568, reconstruction loss: -25.93607258
# Clusters: 10
# Epoch: [394]  time: 24.2530, ELBO_train: -27.03056431, KL_z: 1.04029658, KL_s: 0.06216368, reconstruction loss: -25.92810405
# Clusters: 10
# Epoch: [395]  time: 24.3149, ELBO_train: -27.02529538, KL_z: 1.01365140, KL_s: 0.06148937, reconstruction loss: -25.95015460
# Clusters: 10
# Epoch: [396]  time: 24.3759, ELBO_train: -27.01122832, KL_z: 1.02272089, KL_s: 0.06121273, reconstruction loss: -25.92729470
# Clusters: 10
# Epoch: [397]  time: 24.4388, ELBO_train: -27.03599644, KL_z: 1.02613740, KL_s: 0.06142101, reconstruction loss: -25.94843803
# Clusters: 10
# Epoch: [398]  time: 24.4993, ELBO_train: -27.01845753, KL_z: 1.02542608, KL_s: 0.06183049, reconstruction loss: -25.93120096
# Clusters: 10
# Epoch: [399]  time: 24.5600, ELBO_train: -27.03721011, KL_z: 1.03545741, KL_s: 0.06226783, reconstruction loss: -25.93948487
# Clusters: 10
# Epoch: [400]  time: 24.6211, ELBO_train: -27.00339115, KL_z: 1.02843311, KL_s: 0.06170364, reconstruction loss: -25.91325440
# Clusters: 10
# Epoch: [401]  time: 24.6833, ELBO_train: -26.99587941, KL_z: 1.00935168, KL_s: 0.06185417, reconstruction loss: -25.92467356
# Clusters: 10
# Epoch: [402]  time: 24.7449, ELBO_train: -27.02391481, KL_z: 1.01151043, KL_s: 0.06218426, reconstruction loss: -25.95022012
# Clusters: 10
# Epoch: [403]  time: 24.8058, ELBO_train: -27.04993045, KL_z: 1.04474480, KL_s: 0.06135826, reconstruction loss: -25.94382739
# Clusters: 10
# Epoch: [404]  time: 24.8662, ELBO_train: -27.03226733, KL_z: 1.05324679, KL_s: 0.06062840, reconstruction loss: -25.91839214
# Clusters: 10
# Epoch: [405]  time: 24.9291, ELBO_train: -27.00560093, KL_z: 1.05158424, KL_s: 0.05956748, reconstruction loss: -25.89444921
# Clusters: 10
# Epoch: [406]  time: 24.9900, ELBO_train: -27.00000525, KL_z: 1.03433151, KL_s: 0.05849726, reconstruction loss: -25.90717647
# Clusters: 10
# Epoch: [407]  time: 25.0513, ELBO_train: -27.03253925, KL_z: 1.02753159, KL_s: 0.05763379, reconstruction loss: -25.94737387
# Clusters: 10
# Epoch: [408]  time: 25.1156, ELBO_train: -27.00558627, KL_z: 1.03858132, KL_s: 0.05832087, reconstruction loss: -25.90868408
# Clusters: 10
# Epoch: [409]  time: 25.1818, ELBO_train: -27.00926566, KL_z: 1.04189705, KL_s: 0.05928853, reconstruction loss: -25.90808008
# Clusters: 10
# Epoch: [410]  time: 25.2443, ELBO_train: -27.02985775, KL_z: 1.04393279, KL_s: 0.05867107, reconstruction loss: -25.92725389
# Clusters: 10
# Epoch: [411]  time: 25.3057, ELBO_train: -27.01820505, KL_z: 1.06041489, KL_s: 0.05879168, reconstruction loss: -25.89899848
# Clusters: 10
# Epoch: [412]  time: 25.3677, ELBO_train: -27.01116586, KL_z: 1.05807212, KL_s: 0.05917719, reconstruction loss: -25.89391655
# Clusters: 10
# Epoch: [413]  time: 25.4311, ELBO_train: -26.96952486, KL_z: 1.05648572, KL_s: 0.05823638, reconstruction loss: -25.85480276
# Clusters: 10
# Epoch: [414]  time: 25.4921, ELBO_train: -26.96157694, KL_z: 1.04269564, KL_s: 0.05808131, reconstruction loss: -25.86079998
# Clusters: 10
# Epoch: [415]  time: 25.5533, ELBO_train: -27.03926206, KL_z: 1.04380133, KL_s: 0.05793650, reconstruction loss: -25.93752422
# Clusters: 10
# Epoch: [416]  time: 25.6256, ELBO_train: -27.03797853, KL_z: 1.06512106, KL_s: 0.05755895, reconstruction loss: -25.91529851
# Clusters: 10
# Epoch: [417]  time: 25.6971, ELBO_train: -26.96580327, KL_z: 1.06976391, KL_s: 0.05674075, reconstruction loss: -25.83929861
# Clusters: 10
# Epoch: [418]  time: 25.7584, ELBO_train: -27.05486894, KL_z: 1.05345261, KL_s: 0.05604610, reconstruction loss: -25.94537023
# Clusters: 10
# Epoch: [419]  time: 25.8204, ELBO_train: -26.97416162, KL_z: 1.06135826, KL_s: 0.05561265, reconstruction loss: -25.85719071
# Clusters: 10
# Epoch: [420]  time: 25.8812, ELBO_train: -27.01523817, KL_z: 1.05788696, KL_s: 0.05698061, reconstruction loss: -25.90037060
# Clusters: 10
# Epoch: [421]  time: 25.9445, ELBO_train: -26.91605949, KL_z: 1.05961544, KL_s: 0.05948205, reconstruction loss: -25.79696200
# Clusters: 10
# Epoch: [422]  time: 26.0059, ELBO_train: -26.92397654, KL_z: 1.02839600, KL_s: 0.05956267, reconstruction loss: -25.83601787
# Clusters: 10
# Epoch: [423]  time: 26.0670, ELBO_train: -26.94453597, KL_z: 1.02917082, KL_s: 0.05945224, reconstruction loss: -25.85591292
# Clusters: 10
# Epoch: [424]  time: 26.1282, ELBO_train: -26.93988836, KL_z: 1.03305524, KL_s: 0.06068739, reconstruction loss: -25.84614573
# Clusters: 10
# Epoch: [425]  time: 26.1909, ELBO_train: -26.94804823, KL_z: 1.04340894, KL_s: 0.06099230, reconstruction loss: -25.84364700
# Clusters: 10
# Epoch: [426]  time: 26.2522, ELBO_train: -26.94663453, KL_z: 1.04775466, KL_s: 0.06060398, reconstruction loss: -25.83827589
# Clusters: 10
# Epoch: [427]  time: 26.3139, ELBO_train: -26.96411073, KL_z: 1.03707359, KL_s: 0.05969149, reconstruction loss: -25.86734565
# Clusters: 10
# Epoch: [428]  time: 26.3751, ELBO_train: -26.94921947, KL_z: 1.04444718, KL_s: 0.05860475, reconstruction loss: -25.84616753
# Clusters: 10
# Epoch: [429]  time: 26.4379, ELBO_train: -26.95101428, KL_z: 1.04202070, KL_s: 0.05732015, reconstruction loss: -25.85167343
# Clusters: 10
# Epoch: [430]  time: 26.4995, ELBO_train: -26.95241284, KL_z: 1.05990160, KL_s: 0.05775668, reconstruction loss: -25.83475456
# Clusters: 10
# Epoch: [431]  time: 26.5609, ELBO_train: -26.98723602, KL_z: 1.07060239, KL_s: 0.05764204, reconstruction loss: -25.85899159
# Clusters: 10
# Epoch: [432]  time: 26.6221, ELBO_train: -26.92988312, KL_z: 1.07387266, KL_s: 0.05709326, reconstruction loss: -25.79891720
# Clusters: 10
# Epoch: [433]  time: 26.6844, ELBO_train: -26.95851624, KL_z: 1.06090115, KL_s: 0.05750106, reconstruction loss: -25.84011403
# Clusters: 10
# Epoch: [434]  time: 26.7455, ELBO_train: -26.92210221, KL_z: 1.05641488, KL_s: 0.05758160, reconstruction loss: -25.80810573
# Clusters: 10
# Epoch: [435]  time: 26.8066, ELBO_train: -26.91732848, KL_z: 1.05546574, KL_s: 0.05736086, reconstruction loss: -25.80450188
# Clusters: 10
# Epoch: [436]  time: 26.8678, ELBO_train: -26.89708352, KL_z: 1.06746957, KL_s: 0.05875008, reconstruction loss: -25.77086387
# Clusters: 10
# Epoch: [437]  time: 26.9300, ELBO_train: -26.93614793, KL_z: 1.06099981, KL_s: 0.05969532, reconstruction loss: -25.81545280
# Clusters: 10
# Epoch: [438]  time: 26.9916, ELBO_train: -26.94006157, KL_z: 1.06712282, KL_s: 0.06039852, reconstruction loss: -25.81254023
# Clusters: 10
# Epoch: [439]  time: 27.0529, ELBO_train: -27.00946522, KL_z: 1.06354174, KL_s: 0.06106490, reconstruction loss: -25.88485857
# Clusters: 10
# Epoch: [440]  time: 27.1146, ELBO_train: -26.93565321, KL_z: 1.08646029, KL_s: 0.06167643, reconstruction loss: -25.78751649
# Clusters: 10
# Epoch: [441]  time: 27.1774, ELBO_train: -26.92782485, KL_z: 1.07651334, KL_s: 0.06122027, reconstruction loss: -25.79009124
# Clusters: 10
# Epoch: [442]  time: 27.2393, ELBO_train: -26.88939548, KL_z: 1.05398365, KL_s: 0.06016725, reconstruction loss: -25.77524457
# Clusters: 10
# Epoch: [443]  time: 27.3004, ELBO_train: -26.92627454, KL_z: 1.05756025, KL_s: 0.05988528, reconstruction loss: -25.80882901
# Clusters: 10
# Epoch: [444]  time: 27.3616, ELBO_train: -26.94812095, KL_z: 1.08032908, KL_s: 0.05984218, reconstruction loss: -25.80794968
# Clusters: 10
# Epoch: [445]  time: 27.4243, ELBO_train: -26.98479104, KL_z: 1.07173591, KL_s: 0.05987746, reconstruction loss: -25.85317767
# Clusters: 10
# Epoch: [446]  time: 27.4857, ELBO_train: -26.91682732, KL_z: 1.08777441, KL_s: 0.06025694, reconstruction loss: -25.76879597
# Clusters: 10
# Epoch: [447]  time: 27.5471, ELBO_train: -26.93329728, KL_z: 1.08851624, KL_s: 0.05995744, reconstruction loss: -25.78482360
# Clusters: 10
# Epoch: [448]  time: 27.6080, ELBO_train: -26.85648239, KL_z: 1.07935712, KL_s: 0.05959523, reconstruction loss: -25.71753004
# Clusters: 10
# Epoch: [449]  time: 27.6705, ELBO_train: -26.90396523, KL_z: 1.04384868, KL_s: 0.05931756, reconstruction loss: -25.80079900
# Clusters: 10
# Epoch: [450]  time: 27.7326, ELBO_train: -26.83530331, KL_z: 1.05771129, KL_s: 0.05910160, reconstruction loss: -25.71849042
# Clusters: 10
# Epoch: [451]  time: 27.7938, ELBO_train: -26.89331388, KL_z: 1.04409330, KL_s: 0.05872442, reconstruction loss: -25.79049617
# Clusters: 10
# Epoch: [452]  time: 27.8552, ELBO_train: -26.93086088, KL_z: 1.05890564, KL_s: 0.05944149, reconstruction loss: -25.81251375
# Clusters: 10
# Epoch: [453]  time: 27.9175, ELBO_train: -26.89765441, KL_z: 1.09347749, KL_s: 0.05955985, reconstruction loss: -25.74461707
# Clusters: 10
# Epoch: [454]  time: 27.9786, ELBO_train: -26.87991464, KL_z: 1.09327513, KL_s: 0.05963422, reconstruction loss: -25.72700529
# Clusters: 10
# Epoch: [455]  time: 28.0399, ELBO_train: -26.96223390, KL_z: 1.07756210, KL_s: 0.05999906, reconstruction loss: -25.82467274
# Clusters: 10
# Epoch: [456]  time: 28.1004, ELBO_train: -26.85730636, KL_z: 1.08894526, KL_s: 0.06081444, reconstruction loss: -25.70754666
# Clusters: 10
# Epoch: [457]  time: 28.1633, ELBO_train: -26.87082326, KL_z: 1.08858123, KL_s: 0.06090990, reconstruction loss: -25.72133214
# Clusters: 10
# Epoch: [458]  time: 28.2248, ELBO_train: -26.86609352, KL_z: 1.07208091, KL_s: 0.06119731, reconstruction loss: -25.73281530
# Clusters: 10
# Epoch: [459]  time: 28.2861, ELBO_train: -26.83094776, KL_z: 1.05882457, KL_s: 0.06135385, reconstruction loss: -25.71076934
# Clusters: 10
# Epoch: [460]  time: 28.3476, ELBO_train: -26.87832260, KL_z: 1.05626429, KL_s: 0.06324433, reconstruction loss: -25.75881398
# Clusters: 10
# Epoch: [461]  time: 28.4112, ELBO_train: -26.85303724, KL_z: 1.07234573, KL_s: 0.06470713, reconstruction loss: -25.71598437
# Clusters: 10
# Epoch: [462]  time: 28.4730, ELBO_train: -26.85523117, KL_z: 1.06606440, KL_s: 0.06477773, reconstruction loss: -25.72438904
# Clusters: 10
# Epoch: [463]  time: 28.5340, ELBO_train: -26.86291671, KL_z: 1.07098783, KL_s: 0.06405249, reconstruction loss: -25.72787639
# Clusters: 9
# Epoch: [464]  time: 28.5952, ELBO_train: -26.87667048, KL_z: 1.09141316, KL_s: 0.06482157, reconstruction loss: -25.72043575
# Clusters: 9
# Epoch: [465]  time: 28.6586, ELBO_train: -26.84250331, KL_z: 1.08722816, KL_s: 0.06502126, reconstruction loss: -25.69025389
# Clusters: 9
# Epoch: [466]  time: 28.7201, ELBO_train: -26.82992506, KL_z: 1.08034001, KL_s: 0.06526259, reconstruction loss: -25.68432246
# Clusters: 9
# Epoch: [467]  time: 28.7816, ELBO_train: -26.85436392, KL_z: 1.07684702, KL_s: 0.06458826, reconstruction loss: -25.71292863
# Clusters: 10
# Epoch: [468]  time: 28.8424, ELBO_train: -26.86243653, KL_z: 1.08397090, KL_s: 0.06363937, reconstruction loss: -25.71482626
# Clusters: 10
# Epoch: [469]  time: 28.9048, ELBO_train: -26.85811925, KL_z: 1.06802305, KL_s: 0.06392229, reconstruction loss: -25.72617391
# Clusters: 10
# Epoch: [470]  time: 28.9664, ELBO_train: -26.81114841, KL_z: 1.07047858, KL_s: 0.06478494, reconstruction loss: -25.67588488
# Clusters: 10
# Epoch: [471]  time: 29.0330, ELBO_train: -26.84493375, KL_z: 1.07598626, KL_s: 0.06460851, reconstruction loss: -25.70433898
# Clusters: 10
# Epoch: [472]  time: 29.0942, ELBO_train: -26.88278592, KL_z: 1.08079468, KL_s: 0.06414896, reconstruction loss: -25.73784227
# Clusters: 10
# Epoch: [473]  time: 29.1576, ELBO_train: -26.88844752, KL_z: 1.09032028, KL_s: 0.06374697, reconstruction loss: -25.73438027
# Clusters: 10
# Epoch: [474]  time: 29.2190, ELBO_train: -26.80030751, KL_z: 1.09353441, KL_s: 0.06318066, reconstruction loss: -25.64359245
# Clusters: 10
# Epoch: [475]  time: 29.2803, ELBO_train: -26.86343610, KL_z: 1.08286161, KL_s: 0.06326376, reconstruction loss: -25.71731073
# Clusters: 10
# Epoch: [476]  time: 29.3422, ELBO_train: -26.84214473, KL_z: 1.09710983, KL_s: 0.06306839, reconstruction loss: -25.68196651
# Clusters: 10
# Epoch: [477]  time: 29.4050, ELBO_train: -26.83935142, KL_z: 1.08218379, KL_s: 0.06290236, reconstruction loss: -25.69426526
# Clusters: 10
# Epoch: [478]  time: 29.4674, ELBO_train: -26.86767149, KL_z: 1.09461987, KL_s: 0.06285907, reconstruction loss: -25.71019255
# Clusters: 10
# Epoch: [479]  time: 29.5287, ELBO_train: -26.84206820, KL_z: 1.09673069, KL_s: 0.06406097, reconstruction loss: -25.68127654
# Clusters: 10
# Epoch: [480]  time: 29.5902, ELBO_train: -26.85966992, KL_z: 1.09493203, KL_s: 0.06449407, reconstruction loss: -25.70024382
# Clusters: 10
# Epoch: [481]  time: 29.6524, ELBO_train: -26.86008036, KL_z: 1.11579222, KL_s: 0.06512357, reconstruction loss: -25.67916457
# Clusters: 10
# Epoch: [482]  time: 29.7137, ELBO_train: -26.76396930, KL_z: 1.09142617, KL_s: 0.06601465, reconstruction loss: -25.60652848
# Clusters: 10
# Epoch: [483]  time: 29.7750, ELBO_train: -26.86798203, KL_z: 1.07468733, KL_s: 0.06666088, reconstruction loss: -25.72663382
# Clusters: 10
# Epoch: [484]  time: 29.8372, ELBO_train: -26.78566217, KL_z: 1.08185486, KL_s: 0.06758249, reconstruction loss: -25.63622483
# Clusters: 10
# Epoch: [485]  time: 29.8997, ELBO_train: -26.78512514, KL_z: 1.09521582, KL_s: 0.06806868, reconstruction loss: -25.62184063
# Clusters: 10
# Epoch: [486]  time: 29.9605, ELBO_train: -26.76865876, KL_z: 1.06010120, KL_s: 0.06733641, reconstruction loss: -25.64122115
# Clusters: 10
# Epoch: [487]  time: 30.0214, ELBO_train: -26.81695986, KL_z: 1.06117894, KL_s: 0.06662634, reconstruction loss: -25.68915458
# Clusters: 10
# Epoch: [488]  time: 30.0828, ELBO_train: -26.80410874, KL_z: 1.08035094, KL_s: 0.06641260, reconstruction loss: -25.65734520
# Clusters: 10
# Epoch: [489]  time: 30.1461, ELBO_train: -26.81322789, KL_z: 1.08929215, KL_s: 0.06677844, reconstruction loss: -25.65715730
# Clusters: 10
# Epoch: [490]  time: 30.2071, ELBO_train: -26.83814991, KL_z: 1.09438750, KL_s: 0.06720534, reconstruction loss: -25.67655706
# Clusters: 10
# Epoch: [491]  time: 30.2683, ELBO_train: -26.74546599, KL_z: 1.07703059, KL_s: 0.06712988, reconstruction loss: -25.60130552
# Clusters: 10
# Epoch: [492]  time: 30.3308, ELBO_train: -26.76333594, KL_z: 1.06348297, KL_s: 0.06677300, reconstruction loss: -25.63307998
# Clusters: 10
# Epoch: [493]  time: 30.3939, ELBO_train: -26.77803934, KL_z: 1.06794743, KL_s: 0.06627473, reconstruction loss: -25.64381717
# Clusters: 10
# Epoch: [494]  time: 30.4564, ELBO_train: -26.75678813, KL_z: 1.07250745, KL_s: 0.06607203, reconstruction loss: -25.61820865
# Clusters: 10
# Epoch: [495]  time: 30.5180, ELBO_train: -26.72089267, KL_z: 1.07376560, KL_s: 0.06700841, reconstruction loss: -25.58011866
# Clusters: 10
# Epoch: [496]  time: 30.5835, ELBO_train: -26.79781175, KL_z: 1.09167647, KL_s: 0.06756844, reconstruction loss: -25.63856684
# Clusters: 10
# Epoch: [497]  time: 30.6467, ELBO_train: -26.81784689, KL_z: 1.09955209, KL_s: 0.06860131, reconstruction loss: -25.64969350
# Clusters: 9
# Epoch: [498]  time: 30.7079, ELBO_train: -26.80837834, KL_z: 1.11165044, KL_s: 0.07065903, reconstruction loss: -25.62606887
# Clusters: 10
# Epoch: [499]  time: 30.7694, ELBO_train: -26.72962415, KL_z: 1.09489664, KL_s: 0.07114317, reconstruction loss: -25.56358434
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

# Number of samples generated by one input data
n_generated_sample = 10

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = data_processing.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3, n_generated_sample=n_generated_sample)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = statistic.samples_concatenation(samples_list)[-1]
    data_test_transformed = data_processing.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = []
    for j in range(n_generated_sample):
        est_data_test_transformed.append(data_processing.discrete_variables_transformation(est_data_test[i], feat_types_dict).unsqueeze(0))
    
    est_data_test_transformed = torch.cat(est_data_test_transformed, dim=0)

# %% [markdown]
# ### Visualize the generated samples

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
# Take first generated sample
idx = 0
estimated_values = est_data_test_transformed[idx]

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
# Take second generated sample
idx = 1
estimated_values = est_data_test_transformed[idx]

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
