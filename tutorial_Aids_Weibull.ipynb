# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
from utils import data_processing, visualization, statistic
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
import random
def set_seed(seed=42):
    random.seed(seed)  # Python random module
    np.random.seed(seed)  # NumPy
    torch.manual_seed(seed)  # PyTorch CPU seed
    torch.cuda.manual_seed(seed)  # PyTorch GPU seed
    torch.cuda.manual_seed_all(seed)  # For multi-GPU
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False  # Disable CuDNN auto-tuning

# Set the seed
set_seed(42)

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "Aids"
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"

# If the dataset has no missing data, leave the "miss_file" variable empty
m_perc = 10
mask = 1
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data loading and Feature analysis

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = data_processing.read_data(data_file, feat_types_file, miss_file, true_miss_file)

# Feature analysis
data_transformed = data_processing.discrete_variables_transformation(data, feat_types_dict)
# features_df = pd.DataFrame(data_transformed, columns=["feat_" + str(i+1) for i in range(data_transformed.shape[1])])

visualization.plot_data(data_transformed, feat_types_dict)

# %% [markdown]
# ### Experiment setting

# %%
# Train-test split
train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# Adjust batch size if larger than dataset
batch_size = 100
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 500
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

rng = np.random.default_rng(seed=42)
for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = rng.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = data_processing.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau, n_generated_sample=1)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = statistic.samples_concatenation(samples_list)
    
    # Transform discrete variables back to the original values
    data_train_transformed = data_processing.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = data_processing.discrete_variables_transformation(est_data_train[0], feat_types_dict)
    # est_data_train_mean_imputed = statistic.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = statistic.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = statistic.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    visualization.print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

visualization.plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
visualization.plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
visualization.plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 9
# Epoch: [ 0]  time: 0.1743, ELBO_train: -199.09644572, KL_z: 0.75625534, KL_s: 0.07115401, reconstruction loss: -198.26903637
# Clusters: 8
# Epoch: [ 1]  time: 0.2081, ELBO_train: -176.89502970, KL_z: 0.64868636, KL_s: 0.07629752, reconstruction loss: -176.17004583
# Clusters: 7
# Epoch: [ 2]  time: 0.2415, ELBO_train: -155.90918816, KL_z: 0.61313970, KL_s: 0.08612421, reconstruction loss: -155.20992426
# Clusters: 7
# Epoch: [ 3]  time: 0.2756, ELBO_train: -150.15304226, KL_z: 0.63665717, KL_s: 0.09905333, reconstruction loss: -149.41733177
# Clusters: 6
# Epoch: [ 4]  time: 0.3087, ELBO_train: -135.71627723, KL_z: 0.70181334, KL_s: 0.11464196, reconstruction loss: -134.89982193
# Clusters: 6
# Epoch: [ 5]  time: 0.3421, ELBO_train: -123.20527988, KL_z: 0.78472403, KL_s: 0.13376244, reconstruction loss: -122.28679341
# Clusters: 5
# Epoch: [ 6]  time: 0.3752, ELBO_train: -116.85543399, KL_z: 0.87586754, KL_s: 0.15374639, reconstruction loss: -115.82582006
# Clusters: 5
# Epoch: [ 7]  time: 0.4116, ELBO_train: -110.10524835, KL_z: 0.98204314, KL_s: 0.17512570, reconstruction loss: -108.94807950
# Clusters: 5
# Epoch: [ 8]  time: 0.4455, ELBO_train: -105.05387200, KL_z: 1.09265734, KL_s: 0.19718745, reconstruction loss: -103.76402721
# Clusters: 4
# Epoch: [ 9]  time: 0.4788, ELBO_train: -96.55170695, KL_z: 1.22646201, KL_s: 0.22018223, reconstruction loss: -95.10506271
# Clusters: 4
# Epoch: [10]  time: 0.5124, ELBO_train: -90.14594438, KL_z: 1.36715343, KL_s: 0.24213256, reconstruction loss: -88.53665839
# Clusters: 4
# Epoch: [11]  time: 0.5451, ELBO_train: -86.08395810, KL_z: 1.49037953, KL_s: 0.26303938, reconstruction loss: -84.33053919
# Clusters: 4
# Epoch: [12]  time: 0.5781, ELBO_train: -79.80746714, KL_z: 1.61188678, KL_s: 0.28336398, reconstruction loss: -77.91221639
# Clusters: 4
# Epoch: [13]  time: 0.6111, ELBO_train: -76.16961924, KL_z: 1.75326000, KL_s: 0.30271489, reconstruction loss: -74.11364435
# Clusters: 4
# Epoch: [14]  time: 0.6452, ELBO_train: -72.36445194, KL_z: 1.86695070, KL_s: 0.31998948, reconstruction loss: -70.17751176
# Clusters: 4
# Epoch: [15]  time: 0.6780, ELBO_train: -67.64828746, KL_z: 1.98163046, KL_s: 0.33671012, reconstruction loss: -65.32994688
# Clusters: 4
# Epoch: [16]  time: 0.7108, ELBO_train: -65.22006777, KL_z: 2.09667116, KL_s: 0.35123478, reconstruction loss: -62.77216183
# Clusters: 4
# Epoch: [17]  time: 0.7437, ELBO_train: -62.17087513, KL_z: 2.19549280, KL_s: 0.36583756, reconstruction loss: -59.60954477
# Clusters: 4
# Epoch: [18]  time: 0.7762, ELBO_train: -60.69044367, KL_z: 2.29251756, KL_s: 0.37904206, reconstruction loss: -58.01888406
# Epoch: [57]  time: 2.1678, ELBO_train: -34.38709047, KL_z: 1.50614201, KL_s: 0.55975221, reconstruction loss: -32.32119625
# Clusters: 4
# Epoch: [58]  time: 2.2017, ELBO_train: -34.14773475, KL_z: 1.46156834, KL_s: 0.56123934, reconstruction loss: -32.12492707
# Clusters: 4
# Epoch: [59]  time: 2.2350, ELBO_train: -34.29095756, KL_z: 1.41618885, KL_s: 0.56242882, reconstruction loss: -32.31233989
# Clusters: 4
# Epoch: [60]  time: 2.2679, ELBO_train: -33.99127282, KL_z: 1.37316562, KL_s: 0.56375686, reconstruction loss: -32.05435034
# Clusters: 4
# Epoch: [61]  time: 2.3010, ELBO_train: -34.06337229, KL_z: 1.35070026, KL_s: 0.56455326, reconstruction loss: -32.14811877
# Clusters: 4
# Epoch: [62]  time: 2.3346, ELBO_train: -33.73279826, KL_z: 1.32658545, KL_s: 0.56578912, reconstruction loss: -31.84042369
# Clusters: 4
# Epoch: [63]  time: 2.3685, ELBO_train: -33.74673123, KL_z: 1.29745436, KL_s: 0.56712745, reconstruction loss: -31.88214942
# Clusters: 4
# Epoch: [64]  time: 2.4050, ELBO_train: -33.41867193, KL_z: 1.26910435, KL_s: 0.56817887, reconstruction loss: -31.58138871
# Clusters: 4
# Epoch: [65]  time: 2.4418, ELBO_train: -33.37534714, KL_z: 1.23886881, KL_s: 0.56882307, reconstruction loss: -31.56765526
# Clusters: 4
# Epoch: [66]  time: 2.4779, ELBO_train: -33.27922609, KL_z: 1.22457149, KL_s: 0.56962657, reconstruction loss: -31.48502803
# Clusters: 4
# Epoch: [67]  time: 2.5146, ELBO_train: -33.07129245, KL_z: 1.18533496, KL_s: 0.57046460, reconstruction loss: -31.31549289
# Clusters: 4
# Epoch: [68]  time: 2.5498, ELBO_train: -32.93120702, KL_z: 1.16751079, KL_s: 0.57175218, reconstruction loss: -31.19194406
# Clusters: 4
# Epoch: [69]  time: 2.5855, ELBO_train: -32.88985909, KL_z: 1.15106401, KL_s: 0.57203552, reconstruction loss: -31.16675956
# Clusters: 4
# Epoch: [70]  time: 2.6232, ELBO_train: -32.58436161, KL_z: 1.11819971, KL_s: 0.57268561, reconstruction loss: -30.89347629
# Clusters: 4
# Epoch: [71]  time: 2.6604, ELBO_train: -32.57600064, KL_z: 1.10541991, KL_s: 0.57386601, reconstruction loss: -30.89671471
# Clusters: 4
# Epoch: [72]  time: 2.6957, ELBO_train: -32.44096163, KL_z: 1.07474886, KL_s: 0.57360001, reconstruction loss: -30.79261275
# Clusters: 4
# Epoch: [73]  time: 2.7320, ELBO_train: -32.24418449, KL_z: 1.04421655, KL_s: 0.57379353, reconstruction loss: -30.62617441
# Clusters: 4
# Epoch: [74]  time: 2.7665, ELBO_train: -32.31979434, KL_z: 1.03190737, KL_s: 0.57412174, reconstruction loss: -30.71376522
# Clusters: 4
# Epoch: [75]  time: 2.7994, ELBO_train: -32.29771656, KL_z: 1.01000202, KL_s: 0.57434752, reconstruction loss: -30.71336702
# Clusters: 4
# Epoch: [153]  time: 5.3769, ELBO_train: -29.16090520, KL_z: 0.72095140, KL_s: 0.44555181, reconstruction loss: -27.99440200
# Clusters: 4
# Epoch: [154]  time: 5.4098, ELBO_train: -29.08772892, KL_z: 0.72011679, KL_s: 0.44329308, reconstruction loss: -27.92431905
# Clusters: 4
# Epoch: [155]  time: 5.4423, ELBO_train: -29.12475459, KL_z: 0.72197859, KL_s: 0.43881063, reconstruction loss: -27.96396537
# Clusters: 4
# Epoch: [156]  time: 5.4754, ELBO_train: -29.12513182, KL_z: 0.72311219, KL_s: 0.43358841, reconstruction loss: -27.96843121
# Clusters: 4
# Epoch: [157]  time: 5.5078, ELBO_train: -29.09703255, KL_z: 0.72145515, KL_s: 0.43028547, reconstruction loss: -27.94529193
# Clusters: 4
# Epoch: [158]  time: 5.5403, ELBO_train: -29.12406921, KL_z: 0.72923152, KL_s: 0.42556304, reconstruction loss: -27.96927465
# Clusters: 4
# Epoch: [159]  time: 5.5727, ELBO_train: -29.01320394, KL_z: 0.72528481, KL_s: 0.41996308, reconstruction loss: -27.86795604
# Clusters: 4
# Epoch: [160]  time: 5.6065, ELBO_train: -29.04217784, KL_z: 0.73117845, KL_s: 0.41520041, reconstruction loss: -27.89579898
# Clusters: 4
# Epoch: [161]  time: 5.6392, ELBO_train: -29.04210281, KL_z: 0.72965267, KL_s: 0.40971009, reconstruction loss: -27.90274005
# Clusters: 4
# Epoch: [162]  time: 5.6725, ELBO_train: -29.00161552, KL_z: 0.72200617, KL_s: 0.40878737, reconstruction loss: -27.87082199
# Clusters: 4
# Epoch: [163]  time: 5.7051, ELBO_train: -29.00111601, KL_z: 0.71940737, KL_s: 0.40647390, reconstruction loss: -27.87523474
# Clusters: 4
# Epoch: [164]  time: 5.7376, ELBO_train: -29.01646254, KL_z: 0.72138173, KL_s: 0.40191511, reconstruction loss: -27.89316569
# Clusters: 4
# Epoch: [165]  time: 5.7705, ELBO_train: -29.01641782, KL_z: 0.72268652, KL_s: 0.39621888, reconstruction loss: -27.89751242
# Clusters: 4
# Epoch: [166]  time: 5.8032, ELBO_train: -28.91383468, KL_z: 0.72594326, KL_s: 0.39172971, reconstruction loss: -27.79616170
# Clusters: 4
# Epoch: [167]  time: 5.8371, ELBO_train: -28.92295456, KL_z: 0.72774120, KL_s: 0.38644964, reconstruction loss: -27.80876372
# Clusters: 4
# Epoch: [168]  time: 5.8701, ELBO_train: -28.86980353, KL_z: 0.72550119, KL_s: 0.38223906, reconstruction loss: -27.76206328
# Clusters: 4
# Epoch: [169]  time: 5.9024, ELBO_train: -28.97551918, KL_z: 0.72866980, KL_s: 0.37765029, reconstruction loss: -27.86919909
# Clusters: 4
# Epoch: [170]  time: 5.9347, ELBO_train: -28.76602809, KL_z: 0.72885847, KL_s: 0.37235925, reconstruction loss: -27.66481037
# Clusters: 4
# Epoch: [171]  time: 5.9673, ELBO_train: -28.86681133, KL_z: 0.73053788, KL_s: 0.36792131, reconstruction loss: -27.76835213
# Clusters: 4
# Epoch: [172]  time: 5.9997, ELBO_train: -28.82650354, KL_z: 0.72620487, KL_s: 0.36511947, reconstruction loss: -27.73517921
# Clusters: 5
# Epoch: [250]  time: 8.5799, ELBO_train: -28.15405146, KL_z: 0.75361974, KL_s: 0.17818226, reconstruction loss: -27.22224946
# Clusters: 5
# Epoch: [251]  time: 8.6143, ELBO_train: -28.17645137, KL_z: 0.75523555, KL_s: 0.17656787, reconstruction loss: -27.24464795
# Clusters: 6
# Epoch: [252]  time: 8.6471, ELBO_train: -28.15739610, KL_z: 0.75606125, KL_s: 0.17463748, reconstruction loss: -27.22669738
# Clusters: 5
# Epoch: [253]  time: 8.6803, ELBO_train: -28.18193796, KL_z: 0.76212117, KL_s: 0.17326686, reconstruction loss: -27.24654993
# Clusters: 5
# Epoch: [254]  time: 8.7139, ELBO_train: -28.17219416, KL_z: 0.75851472, KL_s: 0.17238532, reconstruction loss: -27.24129412
# Clusters: 5
# Epoch: [255]  time: 8.7471, ELBO_train: -28.09742504, KL_z: 0.75494462, KL_s: 0.17074649, reconstruction loss: -27.17173394
# Clusters: 4
# Epoch: [256]  time: 8.7803, ELBO_train: -28.15512742, KL_z: 0.75570974, KL_s: 0.16879543, reconstruction loss: -27.23062225
# Clusters: 5
# Epoch: [257]  time: 8.8134, ELBO_train: -28.09176954, KL_z: 0.75958084, KL_s: 0.16739464, reconstruction loss: -27.16479406
# Clusters: 5
# Epoch: [258]  time: 8.8483, ELBO_train: -28.06482315, KL_z: 0.75340234, KL_s: 0.16600291, reconstruction loss: -27.14541790
# Clusters: 5
# Epoch: [259]  time: 8.8806, ELBO_train: -28.11085489, KL_z: 0.74962346, KL_s: 0.16388186, reconstruction loss: -27.19734957
# Clusters: 5
# Epoch: [260]  time: 8.9143, ELBO_train: -28.10383903, KL_z: 0.74617462, KL_s: 0.16182942, reconstruction loss: -27.19583499
# Clusters: 5
# Epoch: [261]  time: 8.9473, ELBO_train: -28.13306639, KL_z: 0.75786258, KL_s: 0.16036810, reconstruction loss: -27.21483571
# Clusters: 5
# Epoch: [262]  time: 8.9809, ELBO_train: -28.10177549, KL_z: 0.75910523, KL_s: 0.15924411, reconstruction loss: -27.18342615
# Clusters: 5
# Epoch: [263]  time: 9.0147, ELBO_train: -28.03065957, KL_z: 0.76388524, KL_s: 0.15878092, reconstruction loss: -27.10799341
# Clusters: 5
# Epoch: [264]  time: 9.0474, ELBO_train: -28.06707255, KL_z: 0.75854293, KL_s: 0.15757057, reconstruction loss: -27.15095905
# Clusters: 6
# Epoch: [265]  time: 9.0819, ELBO_train: -28.15400463, KL_z: 0.75697445, KL_s: 0.15623723, reconstruction loss: -27.24079295
# Clusters: 5
# Epoch: [266]  time: 9.1152, ELBO_train: -27.97119395, KL_z: 0.75658835, KL_s: 0.15619241, reconstruction loss: -27.05841319
# Clusters: 6
# Epoch: [267]  time: 9.1485, ELBO_train: -28.07427131, KL_z: 0.75265963, KL_s: 0.15827582, reconstruction loss: -27.16333587
# Clusters: 6
# Epoch: [268]  time: 9.1814, ELBO_train: -28.05543772, KL_z: 0.75945519, KL_s: 0.15963358, reconstruction loss: -27.13634895
# Epoch: [415]  time: 14.2742, ELBO_train: -27.55195554, KL_z: 0.83322402, KL_s: 0.04723170, reconstruction loss: -26.67149982
# Clusters: 9
# Epoch: [416]  time: 14.3087, ELBO_train: -27.57319620, KL_z: 0.83128115, KL_s: 0.04822222, reconstruction loss: -26.69369282
# Clusters: 9
# Epoch: [417]  time: 14.3432, ELBO_train: -27.65819889, KL_z: 0.83056229, KL_s: 0.04863450, reconstruction loss: -26.77900210
# Clusters: 9
# Epoch: [418]  time: 14.3776, ELBO_train: -27.56596226, KL_z: 0.83052101, KL_s: 0.04851235, reconstruction loss: -26.68692889
# Clusters: 9
# Epoch: [419]  time: 14.4121, ELBO_train: -27.55458260, KL_z: 0.83337465, KL_s: 0.04779495, reconstruction loss: -26.67341300
# Clusters: 9
# Epoch: [420]  time: 14.4471, ELBO_train: -27.70064100, KL_z: 0.83619363, KL_s: 0.04824421, reconstruction loss: -26.81620315
# Clusters: 8
# Epoch: [421]  time: 14.4813, ELBO_train: -27.59822400, KL_z: 0.84003682, KL_s: 0.04890341, reconstruction loss: -26.70928378
# Clusters: 8
# Epoch: [422]  time: 14.5152, ELBO_train: -27.67117691, KL_z: 0.84656241, KL_s: 0.04898561, reconstruction loss: -26.77562889
# Clusters: 8
# Epoch: [423]  time: 14.5497, ELBO_train: -27.56819683, KL_z: 0.84598464, KL_s: 0.04888977, reconstruction loss: -26.67332242
# Clusters: 7
# Epoch: [424]  time: 14.5848, ELBO_train: -27.53039085, KL_z: 0.84582533, KL_s: 0.04911677, reconstruction loss: -26.63544875
# Clusters: 7
# Epoch: [425]  time: 14.6189, ELBO_train: -27.55270449, KL_z: 0.82518773, KL_s: 0.04837979, reconstruction loss: -26.67913697
# Clusters: 7
# Epoch: [426]  time: 14.6541, ELBO_train: -27.66083675, KL_z: 0.82009424, KL_s: 0.04838774, reconstruction loss: -26.79235477
# Clusters: 9
# Epoch: [427]  time: 14.6884, ELBO_train: -27.62941127, KL_z: 0.82534679, KL_s: 0.04817269, reconstruction loss: -26.75589180
# Clusters: 9
# Epoch: [428]  time: 14.7231, ELBO_train: -27.52540207, KL_z: 0.83442558, KL_s: 0.04804656, reconstruction loss: -26.64292993
# Clusters: 7
# Epoch: [429]  time: 14.7570, ELBO_train: -27.59731653, KL_z: 0.83217557, KL_s: 0.04814959, reconstruction loss: -26.71699137
# Clusters: 8
# Epoch: [430]  time: 14.7914, ELBO_train: -27.69511562, KL_z: 0.83617208, KL_s: 0.04797191, reconstruction loss: -26.81097162
# Clusters: 7
# Epoch: [431]  time: 14.8259, ELBO_train: -27.57228745, KL_z: 0.83737030, KL_s: 0.04836914, reconstruction loss: -26.68654801
# Clusters: 8
# Epoch: [432]  time: 14.8610, ELBO_train: -27.62143177, KL_z: 0.84244761, KL_s: 0.04857551, reconstruction loss: -26.73040866
# Clusters: 8
# Epoch: [433]  time: 14.8960, ELBO_train: -27.52980677, KL_z: 0.83980946, KL_s: 0.04780963, reconstruction loss: -26.64218768
# Clusters: 8
# Epoch: [434]  time: 14.9306, ELBO_train: -27.58111000, KL_z: 0.84097129, KL_s: 0.04729308, reconstruction loss: -26.69284563
# Clusters: 8
# Epoch: [435]  time: 14.9644, ELBO_train: -27.58654743, KL_z: 0.83145893, KL_s: 0.04689015, reconstruction loss: -26.70819834
# Clusters: 8
# Epoch: [436]  time: 14.9988, ELBO_train: -27.59184202, KL_z: 0.82781694, KL_s: 0.04627922, reconstruction loss: -26.71774585
# Clusters: 8
# Epoch: [437]  time: 15.0336, ELBO_train: -27.68213696, KL_z: 0.83812379, KL_s: 0.04597762, reconstruction loss: -26.79803555
# Clusters: 8
# Epoch: [438]  time: 15.0687, ELBO_train: -27.61293072, KL_z: 0.84408087, KL_s: 0.04570948, reconstruction loss: -26.72314038
# Clusters: 8
# Epoch: [439]  time: 15.1032, ELBO_train: -27.58086777, KL_z: 0.84148204, KL_s: 0.04560606, reconstruction loss: -26.69377967
# Clusters: 8
# Epoch: [440]  time: 15.1376, ELBO_train: -27.59430970, KL_z: 0.84179824, KL_s: 0.04557318, reconstruction loss: -26.70693828
# Clusters: 8
# Epoch: [441]  time: 15.1720, ELBO_train: -27.57373238, KL_z: 0.84048573, KL_s: 0.04560139, reconstruction loss: -26.68764525
# Clusters: 8
# Epoch: [442]  time: 15.2063, ELBO_train: -27.59789764, KL_z: 0.84361107, KL_s: 0.04552481, reconstruction loss: -26.70876175
# Clusters: 8
# Epoch: [443]  time: 15.2408, ELBO_train: -27.67380630, KL_z: 0.84248329, KL_s: 0.04523918, reconstruction loss: -26.78608382
# Clusters: 8
# Epoch: [444]  time: 15.2756, ELBO_train: -27.63915677, KL_z: 0.84155484, KL_s: 0.04516885, reconstruction loss: -26.75243307
# Clusters: 8
# Epoch: [445]  time: 15.3127, ELBO_train: -27.55298615, KL_z: 0.84047645, KL_s: 0.04522628, reconstruction loss: -26.66728341
# Clusters: 7
# Epoch: [446]  time: 15.3471, ELBO_train: -27.60172378, KL_z: 0.84644205, KL_s: 0.04490760, reconstruction loss: -26.71037413
# Clusters: 8
# Epoch: [447]  time: 15.3810, ELBO_train: -27.55336020, KL_z: 0.84347262, KL_s: 0.04469975, reconstruction loss: -26.66518783
# Clusters: 8
# Epoch: [448]  time: 15.4158, ELBO_train: -27.55448680, KL_z: 0.83992480, KL_s: 0.04407170, reconstruction loss: -26.67049030
# Clusters: 8
# Epoch: [449]  time: 15.4505, ELBO_train: -27.54637697, KL_z: 0.83216373, KL_s: 0.04351828, reconstruction loss: -26.67069496
# Clusters: 8
# Epoch: [450]  time: 15.4855, ELBO_train: -27.55953789, KL_z: 0.82615516, KL_s: 0.04298589, reconstruction loss: -26.69039684
# Clusters: 8
# Epoch: [451]  time: 15.5199, ELBO_train: -27.54077276, KL_z: 0.83338295, KL_s: 0.04252635, reconstruction loss: -26.66486345
# Clusters: 8
# Epoch: [452]  time: 15.5540, ELBO_train: -27.62749820, KL_z: 0.83563177, KL_s: 0.04197333, reconstruction loss: -26.74989310
# Clusters: 7
# Epoch: [453]  time: 15.5882, ELBO_train: -27.52974341, KL_z: 0.83675314, KL_s: 0.04203574, reconstruction loss: -26.65095453
# Clusters: 7
# Epoch: [454]  time: 15.6227, ELBO_train: -27.62720807, KL_z: 0.84470436, KL_s: 0.04260023, reconstruction loss: -26.73990348
# Clusters: 8
# Epoch: [455]  time: 15.6574, ELBO_train: -27.50290765, KL_z: 0.84354075, KL_s: 0.04282244, reconstruction loss: -26.61654445
# Clusters: 7
# Epoch: [456]  time: 15.6940, ELBO_train: -27.56833373, KL_z: 0.84477724, KL_s: 0.04283433, reconstruction loss: -26.68072216
# Clusters: 7
# Epoch: [457]  time: 15.7283, ELBO_train: -27.52430344, KL_z: 0.82706834, KL_s: 0.04365402, reconstruction loss: -26.65358108
# Clusters: 7
# Epoch: [458]  time: 15.7625, ELBO_train: -27.59183884, KL_z: 0.83694866, KL_s: 0.04383024, reconstruction loss: -26.71105994
# Clusters: 7
# Epoch: [459]  time: 15.7973, ELBO_train: -27.58341069, KL_z: 0.84180087, KL_s: 0.04318621, reconstruction loss: -26.69842360
# Clusters: 8
# Epoch: [460]  time: 15.8309, ELBO_train: -27.58306970, KL_z: 0.83508588, KL_s: 0.04280411, reconstruction loss: -26.70517970
# Clusters: 7
# Epoch: [461]  time: 15.8657, ELBO_train: -27.54407798, KL_z: 0.83519659, KL_s: 0.04273038, reconstruction loss: -26.66615100
# Clusters: 7
# Epoch: [462]  time: 15.9005, ELBO_train: -27.55485874, KL_z: 0.84531557, KL_s: 0.04224828, reconstruction loss: -26.66729489
# Clusters: 7
# Epoch: [463]  time: 15.9349, ELBO_train: -27.58695200, KL_z: 0.84208911, KL_s: 0.04258847, reconstruction loss: -26.70227442
# Clusters: 7
# Epoch: [464]  time: 15.9693, ELBO_train: -27.55837780, KL_z: 0.84788536, KL_s: 0.04262365, reconstruction loss: -26.66786878
# Clusters: 7
# Epoch: [465]  time: 16.0039, ELBO_train: -27.51231194, KL_z: 0.84861391, KL_s: 0.04357780, reconstruction loss: -26.62012022
# Clusters: 7
# Epoch: [466]  time: 16.0381, ELBO_train: -27.52120696, KL_z: 0.83735392, KL_s: 0.04438843, reconstruction loss: -26.63946462
# Clusters: 7
# Epoch: [467]  time: 16.0729, ELBO_train: -27.51782650, KL_z: 0.83410373, KL_s: 0.04429462, reconstruction loss: -26.63942815
# Clusters: 8
# Epoch: [468]  time: 16.1086, ELBO_train: -27.55398856, KL_z: 0.82840570, KL_s: 0.04369375, reconstruction loss: -26.68188910
# Clusters: 7
# Epoch: [469]  time: 16.1431, ELBO_train: -27.54344855, KL_z: 0.83188545, KL_s: 0.04310534, reconstruction loss: -26.66845777
# Clusters: 8
# Epoch: [470]  time: 16.1776, ELBO_train: -27.54486826, KL_z: 0.84818265, KL_s: 0.04353245, reconstruction loss: -26.65315315
# Clusters: 8
# Epoch: [471]  time: 16.2121, ELBO_train: -27.49193425, KL_z: 0.84179535, KL_s: 0.04390918, reconstruction loss: -26.60622972
# Clusters: 8
# Epoch: [472]  time: 16.2463, ELBO_train: -27.50206036, KL_z: 0.83885600, KL_s: 0.04381882, reconstruction loss: -26.61938555
# Clusters: 8
# Epoch: [473]  time: 16.2815, ELBO_train: -27.60241042, KL_z: 0.83779727, KL_s: 0.04338254, reconstruction loss: -26.72123061
# Clusters: 8
# Epoch: [474]  time: 16.3189, ELBO_train: -27.55029149, KL_z: 0.84251512, KL_s: 0.04304881, reconstruction loss: -26.66472756
# Clusters: 9
# Epoch: [475]  time: 16.3548, ELBO_train: -27.52646616, KL_z: 0.84622076, KL_s: 0.04342013, reconstruction loss: -26.63682527
# Clusters: 8
# Epoch: [476]  time: 16.3912, ELBO_train: -27.54054239, KL_z: 0.84371910, KL_s: 0.04368311, reconstruction loss: -26.65314018
# Clusters: 8
# Epoch: [477]  time: 16.4275, ELBO_train: -27.52195168, KL_z: 0.84504262, KL_s: 0.04357266, reconstruction loss: -26.63333639
# Clusters: 8
# Epoch: [478]  time: 16.4623, ELBO_train: -27.54406442, KL_z: 0.84212513, KL_s: 0.04315737, reconstruction loss: -26.65878192
# Clusters: 8
# Epoch: [479]  time: 16.4977, ELBO_train: -27.49379434, KL_z: 0.84754978, KL_s: 0.04249660, reconstruction loss: -26.60374795
# Clusters: 8
# Epoch: [480]  time: 16.5325, ELBO_train: -27.52983835, KL_z: 0.85860085, KL_s: 0.04225975, reconstruction loss: -26.62897775
# Clusters: 8
# Epoch: [481]  time: 16.5673, ELBO_train: -27.56195704, KL_z: 0.84597870, KL_s: 0.04211850, reconstruction loss: -26.67385985
# Clusters: 8
# Epoch: [482]  time: 16.6019, ELBO_train: -27.53178321, KL_z: 0.84757805, KL_s: 0.04212856, reconstruction loss: -26.64207660
# Clusters: 8
# Epoch: [483]  time: 16.6364, ELBO_train: -27.52193493, KL_z: 0.84192421, KL_s: 0.04225874, reconstruction loss: -26.63775198
# Clusters: 8
# Epoch: [484]  time: 16.6709, ELBO_train: -27.50520473, KL_z: 0.85219295, KL_s: 0.04237665, reconstruction loss: -26.61063513
# Clusters: 8
# Epoch: [485]  time: 16.7070, ELBO_train: -27.46285333, KL_z: 0.85409176, KL_s: 0.04193115, reconstruction loss: -26.56683041
# Clusters: 8
# Epoch: [486]  time: 16.7423, ELBO_train: -27.61759440, KL_z: 0.85798321, KL_s: 0.04258373, reconstruction loss: -26.71702746
# Clusters: 8
# Epoch: [487]  time: 16.7774, ELBO_train: -27.57287301, KL_z: 0.85669878, KL_s: 0.04262119, reconstruction loss: -26.67355304
# Clusters: 8
# Epoch: [488]  time: 16.8119, ELBO_train: -27.58275562, KL_z: 0.87799685, KL_s: 0.04281526, reconstruction loss: -26.66194351
# Clusters: 9
# Epoch: [489]  time: 16.8460, ELBO_train: -27.52582550, KL_z: 0.86678119, KL_s: 0.04292385, reconstruction loss: -26.61612046
# Clusters: 8
# Epoch: [490]  time: 16.8834, ELBO_train: -27.56862534, KL_z: 0.85757112, KL_s: 0.04308952, reconstruction loss: -26.66796470
# Clusters: 8
# Epoch: [491]  time: 16.9215, ELBO_train: -27.60629781, KL_z: 0.85275012, KL_s: 0.04275746, reconstruction loss: -26.71079024
# Clusters: 9
# Epoch: [492]  time: 16.9601, ELBO_train: -27.52800369, KL_z: 0.86818994, KL_s: 0.04307267, reconstruction loss: -26.61674108
# Clusters: 10
# Epoch: [493]  time: 16.9962, ELBO_train: -27.44589806, KL_z: 0.85595912, KL_s: 0.04250977, reconstruction loss: -26.54742916
# Clusters: 9
# Epoch: [494]  time: 17.0317, ELBO_train: -27.50585132, KL_z: 0.84559641, KL_s: 0.04207153, reconstruction loss: -26.61818338
# Clusters: 10
# Epoch: [495]  time: 17.0667, ELBO_train: -27.54033428, KL_z: 0.85207348, KL_s: 0.04189030, reconstruction loss: -26.64637049
# Clusters: 9
# Epoch: [496]  time: 17.1017, ELBO_train: -27.56945525, KL_z: 0.84247526, KL_s: 0.04154849, reconstruction loss: -26.68543151
# Clusters: 10
# Epoch: [497]  time: 17.1387, ELBO_train: -27.49438180, KL_z: 0.85030203, KL_s: 0.04102222, reconstruction loss: -26.60305754
# Clusters: 8
# Epoch: [498]  time: 17.1735, ELBO_train: -27.54014418, KL_z: 0.84836437, KL_s: 0.04109208, reconstruction loss: -26.65068773
# Clusters: 9
# Epoch: [499]  time: 17.2085, ELBO_train: -27.50590939, KL_z: 0.84350316, KL_s: 0.04072417, reconstruction loss: -26.62168205
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

# Number of samples generated by one input data
n_generated_sample = 10

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = data_processing.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3, n_generated_sample=n_generated_sample)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = statistic.samples_concatenation(samples_list)[-1]
    data_test_transformed = data_processing.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = []
    for j in range(n_generated_sample):
        est_data_test_transformed.append(data_processing.discrete_variables_transformation(est_data_test[i], feat_types_dict).unsqueeze(0))
    
    est_data_test_transformed = torch.cat(est_data_test_transformed, dim=0)

# %% [markdown]
# ### Visualize the generated samples

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
# Take first generated sample
idx = 0
estimated_values = est_data_test_transformed[idx]

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
# Take second generated sample
idx = 1
estimated_values = est_data_test_transformed[idx]

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
