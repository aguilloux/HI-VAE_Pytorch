# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
from utils import data_processing, visualization, statistic
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "letter"
m_perc = 10
mask = 1
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data loading and Feature analysis

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = data_processing.read_data(data_file, feat_types_file, miss_file, true_miss_file)

# Feature analysis
data_transformed = data_processing.discrete_variables_transformation(data, feat_types_dict)
features_df = pd.DataFrame(data_transformed, columns=["feat_" + str(i+1) for i in range(data_transformed.shape[1])])

visualization.plot_data(features_df, feat_types_dict)

# %% [markdown]
# ### Experiment setting

# %%
# Train-test split
train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# Adjust batch size if larger than dataset
batch_size = 1000
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 200
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = np.random.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = data_processing.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = statistic.samples_concatenation(samples_list)
    
    # #Transform discrete variables back to the original values
    data_train_transformed = data_processing.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = data_processing.discrete_variables_transformation(est_data_train, feat_types_dict)
    est_data_train_mean_imputed = statistic.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = statistic.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = statistic.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    visualization.print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

visualization.plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
visualization.plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
visualization.plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 9
# Epoch: [ 0]  time: 0.3793, ELBO_train: -73.85906076, KL_z: 0.44939447, KL_s: 0.15125847, reconstruction loss: -73.25840783
# Clusters: 6
# Epoch: [ 1]  time: 0.6790, ELBO_train: -73.22220612, KL_z: 0.39451274, KL_s: 0.23377956, reconstruction loss: -72.59391381
# Clusters: 7
# Epoch: [ 2]  time: 0.9913, ELBO_train: -72.44315815, KL_z: 0.72149904, KL_s: 0.21966532, reconstruction loss: -71.50199379
# Clusters: 7
# Epoch: [ 3]  time: 1.2932, ELBO_train: -71.09529495, KL_z: 1.43077813, KL_s: 0.22198530, reconstruction loss: -69.44253153
# Clusters: 7
# Epoch: [ 4]  time: 1.5939, ELBO_train: -69.08293486, KL_z: 2.60808875, KL_s: 0.24069774, reconstruction loss: -66.23414836
# Clusters: 7
# Epoch: [ 5]  time: 1.8957, ELBO_train: -66.36546421, KL_z: 4.08180660, KL_s: 0.27826878, reconstruction loss: -62.00538883
# Clusters: 8
# Epoch: [ 6]  time: 2.2015, ELBO_train: -63.20342469, KL_z: 5.54468441, KL_s: 0.30012389, reconstruction loss: -57.35861639
# Clusters: 8
# Epoch: [ 7]  time: 2.5064, ELBO_train: -59.91788363, KL_z: 6.63114330, KL_s: 0.32264186, reconstruction loss: -52.96409847
# Clusters: 8
# Epoch: [ 8]  time: 2.8108, ELBO_train: -56.83666897, KL_z: 7.16660959, KL_s: 0.34197032, reconstruction loss: -49.32808907
# Clusters: 8
# Epoch: [ 9]  time: 3.1211, ELBO_train: -54.10342479, KL_z: 7.22226277, KL_s: 0.35594123, reconstruction loss: -46.52522079
# Clusters: 8
# Epoch: [10]  time: 3.4406, ELBO_train: -51.81180716, KL_z: 6.94735619, KL_s: 0.37198880, reconstruction loss: -44.49246216
# Clusters: 8
# Epoch: [11]  time: 3.7643, ELBO_train: -49.84308434, KL_z: 6.54287356, KL_s: 0.38095163, reconstruction loss: -42.91925915
# Clusters: 8
# Epoch: [12]  time: 4.0758, ELBO_train: -48.18733144, KL_z: 6.05789608, KL_s: 0.38894195, reconstruction loss: -41.74049341
# Clusters: 8
# Epoch: [13]  time: 4.3773, ELBO_train: -46.80271554, KL_z: 5.64348042, KL_s: 0.39616258, reconstruction loss: -40.76307254
# Clusters: 8
# Epoch: [14]  time: 4.6737, ELBO_train: -45.65933943, KL_z: 5.20289460, KL_s: 0.40204508, reconstruction loss: -40.05439975
# Clusters: 8
# Epoch: [15]  time: 4.9938, ELBO_train: -44.59758186, KL_z: 4.77133909, KL_s: 0.40266748, reconstruction loss: -39.42357530
# Clusters: 8
# Epoch: [16]  time: 5.2970, ELBO_train: -43.74731922, KL_z: 4.42243621, KL_s: 0.40758034, reconstruction loss: -38.91730268
# Clusters: 8
# Epoch: [17]  time: 5.5943, ELBO_train: -42.96556354, KL_z: 4.06782326, KL_s: 0.40946542, reconstruction loss: -38.48827485
# Clusters: 8
# Epoch: [18]  time: 5.8915, ELBO_train: -42.27818751, KL_z: 3.70897415, KL_s: 0.40538824, reconstruction loss: -38.16382512
# Clusters: 8
# Epoch: [19]  time: 6.2052, ELBO_train: -41.63512278, KL_z: 3.46034411, KL_s: 0.40916096, reconstruction loss: -37.76561771
# Clusters: 8
# Epoch: [20]  time: 6.5169, ELBO_train: -41.15239429, KL_z: 3.16300799, KL_s: 0.40523849, reconstruction loss: -37.58414782
# Clusters: 8
# Epoch: [21]  time: 6.8326, ELBO_train: -40.66564989, KL_z: 2.95881344, KL_s: 0.39822143, reconstruction loss: -37.30861502
# Clusters: 8
# Epoch: [22]  time: 7.2090, ELBO_train: -40.21194315, KL_z: 2.71781534, KL_s: 0.39809383, reconstruction loss: -37.09603398
# Clusters: 8
# Epoch: [23]  time: 7.5335, ELBO_train: -39.86252475, KL_z: 2.49942647, KL_s: 0.39454746, reconstruction loss: -36.96855082
# Clusters: 8
# Epoch: [24]  time: 7.8443, ELBO_train: -39.51700902, KL_z: 2.34333959, KL_s: 0.39117281, reconstruction loss: -36.78249662
# Clusters: 8
# Epoch: [25]  time: 8.1531, ELBO_train: -39.19417834, KL_z: 2.15799281, KL_s: 0.38773730, reconstruction loss: -36.64844823
# Clusters: 8
# Epoch: [26]  time: 8.4619, ELBO_train: -38.94341612, KL_z: 2.00152507, KL_s: 0.38038613, reconstruction loss: -36.56150492
# Clusters: 8
# Epoch: [27]  time: 8.7670, ELBO_train: -38.67345405, KL_z: 1.88714582, KL_s: 0.37297704, reconstruction loss: -36.41333119
# Clusters: 8
# Epoch: [28]  time: 9.0687, ELBO_train: -38.45242214, KL_z: 1.75236522, KL_s: 0.36266914, reconstruction loss: -36.33738779
# Clusters: 8
# Epoch: [29]  time: 9.3745, ELBO_train: -38.25927401, KL_z: 1.64220332, KL_s: 0.35635250, reconstruction loss: -36.26071818
# Clusters: 8
# Epoch: [30]  time: 9.6767, ELBO_train: -38.07891917, KL_z: 1.51637614, KL_s: 0.34705375, reconstruction loss: -36.21548928
# Clusters: 8
# Epoch: [31]  time: 9.9871, ELBO_train: -37.91678715, KL_z: 1.45494719, KL_s: 0.33630114, reconstruction loss: -36.12553882
# Clusters: 8
# Epoch: [32]  time: 10.2915, ELBO_train: -37.74247742, KL_z: 1.34576759, KL_s: 0.32803740, reconstruction loss: -36.06867243
# Clusters: 8
# Epoch: [33]  time: 10.6011, ELBO_train: -37.66166306, KL_z: 1.27986705, KL_s: 0.32046358, reconstruction loss: -36.06133243
# Clusters: 9
# Epoch: [34]  time: 10.9104, ELBO_train: -37.53287983, KL_z: 1.22137749, KL_s: 0.31112821, reconstruction loss: -36.00037413
# Clusters: 9
# Epoch: [35]  time: 11.2185, ELBO_train: -37.37218261, KL_z: 1.15126079, KL_s: 0.30054437, reconstruction loss: -35.92037745
# Clusters: 9
# Epoch: [36]  time: 11.5271, ELBO_train: -37.31644034, KL_z: 1.10245276, KL_s: 0.29287760, reconstruction loss: -35.92110998
# Clusters: 9
# Epoch: [37]  time: 11.8352, ELBO_train: -37.21093321, KL_z: 1.04040011, KL_s: 0.28436095, reconstruction loss: -35.88617215
# Clusters: 9
# Epoch: [38]  time: 12.1459, ELBO_train: -37.13087153, KL_z: 1.00505247, KL_s: 0.27878991, reconstruction loss: -35.84702916
# Clusters: 9
# Epoch: [39]  time: 12.4608, ELBO_train: -37.08481860, KL_z: 0.95344728, KL_s: 0.26810895, reconstruction loss: -35.86326237
# Clusters: 9
# Epoch: [40]  time: 12.7712, ELBO_train: -36.95113945, KL_z: 0.90921910, KL_s: 0.25794323, reconstruction loss: -35.78397712
# Clusters: 9
# Epoch: [41]  time: 13.0852, ELBO_train: -36.88899636, KL_z: 0.87700947, KL_s: 0.24418350, reconstruction loss: -35.76780340
# Clusters: 9
# Epoch: [42]  time: 13.3968, ELBO_train: -36.87614751, KL_z: 0.86228996, KL_s: 0.24060339, reconstruction loss: -35.77325416
# Clusters: 9
# Epoch: [43]  time: 13.7237, ELBO_train: -36.77090764, KL_z: 0.81385209, KL_s: 0.22598897, reconstruction loss: -35.73106658
# Clusters: 9
# Epoch: [44]  time: 14.0442, ELBO_train: -36.75570059, KL_z: 0.79660120, KL_s: 0.21773295, reconstruction loss: -35.74136644
# Clusters: 9
# Epoch: [45]  time: 14.3649, ELBO_train: -36.66753793, KL_z: 0.76965142, KL_s: 0.21496183, reconstruction loss: -35.68292468
# Clusters: 10
# Epoch: [46]  time: 14.7195, ELBO_train: -36.67053628, KL_z: 0.74800068, KL_s: 0.20030725, reconstruction loss: -35.72222835
# Clusters: 10
# Epoch: [47]  time: 15.0365, ELBO_train: -36.59655261, KL_z: 0.73214259, KL_s: 0.19332534, reconstruction loss: -35.67108468
# Clusters: 10
# Epoch: [48]  time: 15.3460, ELBO_train: -36.56995010, KL_z: 0.72035198, KL_s: 0.18888727, reconstruction loss: -35.66071086
# Clusters: 10
# Epoch: [49]  time: 15.6610, ELBO_train: -36.54422402, KL_z: 0.70801904, KL_s: 0.18375996, reconstruction loss: -35.65244503
# Clusters: 10
# Epoch: [50]  time: 15.9715, ELBO_train: -36.49635673, KL_z: 0.68661054, KL_s: 0.18082857, reconstruction loss: -35.62891762
# Clusters: 10
# Epoch: [51]  time: 16.2878, ELBO_train: -36.43563294, KL_z: 0.66717312, KL_s: 0.17300923, reconstruction loss: -35.59545059
# Clusters: 10
# Epoch: [52]  time: 16.6439, ELBO_train: -36.43837690, KL_z: 0.65980340, KL_s: 0.16706015, reconstruction loss: -35.61151335
# Clusters: 10
# Epoch: [53]  time: 17.0214, ELBO_train: -36.41569233, KL_z: 0.64007647, KL_s: 0.16676782, reconstruction loss: -35.60884804
# Clusters: 10
# Epoch: [54]  time: 17.3487, ELBO_train: -36.39376760, KL_z: 0.63909085, KL_s: 0.16558845, reconstruction loss: -35.58908829
# Clusters: 10
# Epoch: [55]  time: 17.6782, ELBO_train: -36.31826639, KL_z: 0.62534838, KL_s: 0.16088560, reconstruction loss: -35.53203241
# Clusters: 10
# Epoch: [56]  time: 17.9934, ELBO_train: -36.31212664, KL_z: 0.61664411, KL_s: 0.15954040, reconstruction loss: -35.53594213
# Clusters: 10
# Epoch: [57]  time: 18.3045, ELBO_train: -36.29402280, KL_z: 0.60611756, KL_s: 0.15998657, reconstruction loss: -35.52791867
# Clusters: 10
# Epoch: [58]  time: 18.6229, ELBO_train: -36.32249618, KL_z: 0.62587483, KL_s: 0.16090968, reconstruction loss: -35.53571166
# Clusters: 10
# Epoch: [59]  time: 18.9361, ELBO_train: -36.26453161, KL_z: 0.59841903, KL_s: 0.16249420, reconstruction loss: -35.50361838
# Clusters: 10
# Epoch: [60]  time: 19.2880, ELBO_train: -36.27118301, KL_z: 0.60000528, KL_s: 0.16446900, reconstruction loss: -35.50670873
# Clusters: 10
# Epoch: [61]  time: 19.6706, ELBO_train: -36.24015045, KL_z: 0.60205207, KL_s: 0.16612247, reconstruction loss: -35.47197592
# Clusters: 10
# Epoch: [62]  time: 19.9945, ELBO_train: -36.25732136, KL_z: 0.60504081, KL_s: 0.16732018, reconstruction loss: -35.48496037
# Clusters: 10
# Epoch: [63]  time: 20.4031, ELBO_train: -36.19443130, KL_z: 0.59217631, KL_s: 0.16565874, reconstruction loss: -35.43659626
# Clusters: 10
# Epoch: [64]  time: 20.7743, ELBO_train: -36.18474913, KL_z: 0.59153334, KL_s: 0.16618158, reconstruction loss: -35.42703421
# Clusters: 10
# Epoch: [65]  time: 21.1008, ELBO_train: -36.15428543, KL_z: 0.58708452, KL_s: 0.16904044, reconstruction loss: -35.39816047
# Clusters: 10
# Epoch: [66]  time: 21.4812, ELBO_train: -36.17746663, KL_z: 0.60188982, KL_s: 0.17179719, reconstruction loss: -35.40377963
# Clusters: 10
# Epoch: [67]  time: 21.8025, ELBO_train: -36.10195923, KL_z: 0.58811400, KL_s: 0.17352179, reconstruction loss: -35.34032344
# Clusters: 10
# Epoch: [68]  time: 22.1197, ELBO_train: -36.11684299, KL_z: 0.58786567, KL_s: 0.17746353, reconstruction loss: -35.35151378
# Clusters: 10
# Epoch: [69]  time: 22.4362, ELBO_train: -36.12471604, KL_z: 0.59948126, KL_s: 0.17787476, reconstruction loss: -35.34736003
# Clusters: 10
# Epoch: [70]  time: 22.7615, ELBO_train: -36.07724667, KL_z: 0.59565131, KL_s: 0.18142425, reconstruction loss: -35.30017111
# Clusters: 10
# Epoch: [71]  time: 23.3424, ELBO_train: -36.10191655, KL_z: 0.60133815, KL_s: 0.18458599, reconstruction loss: -35.31599241
# Clusters: 10
# Epoch: [72]  time: 23.6779, ELBO_train: -36.10749555, KL_z: 0.61632309, KL_s: 0.18613040, reconstruction loss: -35.30504205
# Clusters: 10
# Epoch: [73]  time: 24.0061, ELBO_train: -36.04579592, KL_z: 0.60482411, KL_s: 0.18820222, reconstruction loss: -35.25276959
# Clusters: 10
# Epoch: [74]  time: 24.5351, ELBO_train: -36.07466125, KL_z: 0.61449006, KL_s: 0.18463768, reconstruction loss: -35.27553352
# Clusters: 10
# Epoch: [75]  time: 24.8883, ELBO_train: -36.04792857, KL_z: 0.62243714, KL_s: 0.18750738, reconstruction loss: -35.23798406
# Clusters: 10
# Epoch: [76]  time: 25.2186, ELBO_train: -36.03222013, KL_z: 0.62620534, KL_s: 0.19159487, reconstruction loss: -35.21441992
# Clusters: 10
# Epoch: [77]  time: 25.5472, ELBO_train: -36.01101041, KL_z: 0.63545942, KL_s: 0.19491193, reconstruction loss: -35.18063906
# Clusters: 10
# Epoch: [78]  time: 25.8720, ELBO_train: -35.99875188, KL_z: 0.63030398, KL_s: 0.19764580, reconstruction loss: -35.17080211
# Clusters: 10
# Epoch: [79]  time: 26.1958, ELBO_train: -36.01054144, KL_z: 0.64638254, KL_s: 0.19699514, reconstruction loss: -35.16716376
# Clusters: 10
# Epoch: [80]  time: 26.5096, ELBO_train: -35.97262406, KL_z: 0.64459863, KL_s: 0.20063250, reconstruction loss: -35.12739293
# Clusters: 10
# Epoch: [81]  time: 26.8625, ELBO_train: -35.95050907, KL_z: 0.64580030, KL_s: 0.19964287, reconstruction loss: -35.10506591
# Clusters: 10
# Epoch: [82]  time: 27.2028, ELBO_train: -35.94809079, KL_z: 0.65318818, KL_s: 0.20588107, reconstruction loss: -35.08902154
# Clusters: 10
# Epoch: [83]  time: 27.5317, ELBO_train: -35.91741943, KL_z: 0.65660492, KL_s: 0.20849781, reconstruction loss: -35.05231670
# Clusters: 10
# Epoch: [84]  time: 27.8532, ELBO_train: -35.88471174, KL_z: 0.64842707, KL_s: 0.21489596, reconstruction loss: -35.02138871
# Clusters: 10
# Epoch: [85]  time: 28.1730, ELBO_train: -35.89340448, KL_z: 0.66649687, KL_s: 0.21921040, reconstruction loss: -35.00769722
# Clusters: 10
# Epoch: [86]  time: 28.5109, ELBO_train: -35.89444733, KL_z: 0.66773898, KL_s: 0.21717134, reconstruction loss: -35.00953701
# Clusters: 10
# Epoch: [87]  time: 28.8919, ELBO_train: -35.88329029, KL_z: 0.68378602, KL_s: 0.21687621, reconstruction loss: -34.98262807
# Clusters: 10
# Epoch: [88]  time: 29.2376, ELBO_train: -35.86246276, KL_z: 0.67888672, KL_s: 0.21923573, reconstruction loss: -34.96434031
# Clusters: 10
# Epoch: [89]  time: 29.5647, ELBO_train: -35.84944463, KL_z: 0.69293283, KL_s: 0.22555245, reconstruction loss: -34.93095935
# Clusters: 10
# Epoch: [90]  time: 29.9216, ELBO_train: -35.83435535, KL_z: 0.69462094, KL_s: 0.22397028, reconstruction loss: -34.91576414
# Clusters: 10
# Epoch: [91]  time: 30.2419, ELBO_train: -35.80354404, KL_z: 0.69228656, KL_s: 0.23115395, reconstruction loss: -34.88010353
# Clusters: 10
# Epoch: [92]  time: 30.5675, ELBO_train: -35.78711724, KL_z: 0.69368213, KL_s: 0.23947668, reconstruction loss: -34.85395843
# Clusters: 10
# Epoch: [93]  time: 30.9002, ELBO_train: -35.79785490, KL_z: 0.70891364, KL_s: 0.24230586, reconstruction loss: -34.84663540
# Clusters: 10
# Epoch: [94]  time: 31.2184, ELBO_train: -35.79494834, KL_z: 0.71041872, KL_s: 0.24572231, reconstruction loss: -34.83880731
# Clusters: 10
# Epoch: [95]  time: 31.5985, ELBO_train: -35.75835323, KL_z: 0.72365423, KL_s: 0.24777800, reconstruction loss: -34.78692101
# Clusters: 10
# Epoch: [96]  time: 31.9619, ELBO_train: -35.76982284, KL_z: 0.72320146, KL_s: 0.24718489, reconstruction loss: -34.79943648
# Clusters: 10
# Epoch: [97]  time: 32.3282, ELBO_train: -35.75898218, KL_z: 0.73642091, KL_s: 0.24887516, reconstruction loss: -34.77368611
# Clusters: 10
# Epoch: [98]  time: 32.6523, ELBO_train: -35.72593498, KL_z: 0.74006078, KL_s: 0.24672006, reconstruction loss: -34.73915414
# Clusters: 10
# Epoch: [99]  time: 32.9910, ELBO_train: -35.72492266, KL_z: 0.74085333, KL_s: 0.25049576, reconstruction loss: -34.73357356
# Clusters: 10
# Epoch: [100]  time: 33.3135, ELBO_train: -35.86975288, KL_z: 0.74235196, KL_s: 0.40399049, reconstruction loss: -34.72341043
# Clusters: 9
# Epoch: [101]  time: 33.6382, ELBO_train: -35.94755721, KL_z: 0.74843203, KL_s: 0.49423338, reconstruction loss: -34.70489179
# Clusters: 10
# Epoch: [102]  time: 33.9628, ELBO_train: -35.89491701, KL_z: 0.75740077, KL_s: 0.44114310, reconstruction loss: -34.69637314
# Clusters: 10
# Epoch: [103]  time: 34.2809, ELBO_train: -35.89744234, KL_z: 0.78656153, KL_s: 0.40156265, reconstruction loss: -34.70931817
# Clusters: 10
# Epoch: [104]  time: 34.6056, ELBO_train: -35.75457954, KL_z: 0.78624446, KL_s: 0.29504269, reconstruction loss: -34.67329239
# Clusters: 10
# Epoch: [105]  time: 34.9260, ELBO_train: -35.78632998, KL_z: 0.77689245, KL_s: 0.33067515, reconstruction loss: -34.67876239
# Clusters: 10
# Epoch: [106]  time: 35.2443, ELBO_train: -35.75927043, KL_z: 0.77845601, KL_s: 0.33093367, reconstruction loss: -34.64988075
# Clusters: 10
# Epoch: [107]  time: 35.5577, ELBO_train: -35.65417385, KL_z: 0.77476858, KL_s: 0.28457172, reconstruction loss: -34.59483355
# Clusters: 10
# Epoch: [108]  time: 35.8832, ELBO_train: -35.76865458, KL_z: 0.79927917, KL_s: 0.35209543, reconstruction loss: -34.61727999
# Clusters: 10
# Epoch: [109]  time: 36.2069, ELBO_train: -35.70746851, KL_z: 0.80453592, KL_s: 0.30161691, reconstruction loss: -34.60131568
# Clusters: 10
# Epoch: [110]  time: 36.5267, ELBO_train: -35.75796056, KL_z: 0.82010119, KL_s: 0.34130047, reconstruction loss: -34.59655890
# Clusters: 10
# Epoch: [111]  time: 36.9752, ELBO_train: -35.69784331, KL_z: 0.80631528, KL_s: 0.35318923, reconstruction loss: -34.53833880
# Clusters: 10
# Epoch: [112]  time: 37.4501, ELBO_train: -35.69734359, KL_z: 0.81552839, KL_s: 0.31194481, reconstruction loss: -34.56987038
# Clusters: 10
# Epoch: [113]  time: 37.7782, ELBO_train: -35.60895920, KL_z: 0.82175368, KL_s: 0.28228457, reconstruction loss: -34.50492095
# Clusters: 10
# Epoch: [114]  time: 38.1826, ELBO_train: -35.62324381, KL_z: 0.84163332, KL_s: 0.27537088, reconstruction loss: -34.50623961
# Clusters: 10
# Epoch: [115]  time: 38.5210, ELBO_train: -35.56853104, KL_z: 0.83915668, KL_s: 0.25585447, reconstruction loss: -34.47351988
# Clusters: 10
# Epoch: [116]  time: 38.8543, ELBO_train: -35.59748650, KL_z: 0.83829761, KL_s: 0.27875997, reconstruction loss: -34.48042892
# Clusters: 10
# Epoch: [117]  time: 39.2312, ELBO_train: -35.52176952, KL_z: 0.83409873, KL_s: 0.27140668, reconstruction loss: -34.41626412
# Clusters: 10
# Epoch: [118]  time: 39.6762, ELBO_train: -35.56001449, KL_z: 0.84026292, KL_s: 0.26904209, reconstruction loss: -34.45070948
# Clusters: 10
# Epoch: [119]  time: 40.0398, ELBO_train: -35.52257586, KL_z: 0.84966742, KL_s: 0.27520716, reconstruction loss: -34.39770127
# Clusters: 10
# Epoch: [120]  time: 40.3695, ELBO_train: -35.48654556, KL_z: 0.82742948, KL_s: 0.29046631, reconstruction loss: -34.36864978
# Clusters: 10
# Epoch: [121]  time: 40.7114, ELBO_train: -35.51650143, KL_z: 0.83398335, KL_s: 0.31432893, reconstruction loss: -34.36818915
# Clusters: 10
# Epoch: [122]  time: 41.0539, ELBO_train: -35.50891781, KL_z: 0.84448755, KL_s: 0.30191103, reconstruction loss: -34.36251923
# Clusters: 10
# Epoch: [123]  time: 41.3892, ELBO_train: -35.51662183, KL_z: 0.84196530, KL_s: 0.33630060, reconstruction loss: -34.33835593
# Clusters: 10
# Epoch: [124]  time: 41.7234, ELBO_train: -35.49045825, KL_z: 0.82618941, KL_s: 0.37598258, reconstruction loss: -34.28828627
# Clusters: 10
# Epoch: [125]  time: 42.0540, ELBO_train: -35.47515297, KL_z: 0.84184863, KL_s: 0.35528556, reconstruction loss: -34.27801878
# Clusters: 10
# Epoch: [126]  time: 42.3936, ELBO_train: -35.43036103, KL_z: 0.84678461, KL_s: 0.31941693, reconstruction loss: -34.26415949
# Clusters: 10
# Epoch: [127]  time: 42.7217, ELBO_train: -35.42946315, KL_z: 0.85006906, KL_s: 0.33673900, reconstruction loss: -34.24265508
# Clusters: 10
# Epoch: [128]  time: 43.0565, ELBO_train: -35.41374350, KL_z: 0.86800843, KL_s: 0.30592395, reconstruction loss: -34.23981111
# Clusters: 10
# Epoch: [129]  time: 43.4416, ELBO_train: -35.41260290, KL_z: 0.88668332, KL_s: 0.29835314, reconstruction loss: -34.22756644
# Clusters: 10
# Epoch: [130]  time: 43.8171, ELBO_train: -35.36472344, KL_z: 0.87039812, KL_s: 0.31335359, reconstruction loss: -34.18097173
# Clusters: 10
# Epoch: [131]  time: 44.2119, ELBO_train: -35.40346122, KL_z: 0.90722977, KL_s: 0.29460907, reconstruction loss: -34.20162237
# Clusters: 10
# Epoch: [132]  time: 44.6028, ELBO_train: -35.38497806, KL_z: 0.91620015, KL_s: 0.30119959, reconstruction loss: -34.16757832
# Clusters: 10
# Epoch: [133]  time: 45.0227, ELBO_train: -35.38007069, KL_z: 0.91430488, KL_s: 0.30189505, reconstruction loss: -34.16387076
# Clusters: 10
# Epoch: [134]  time: 45.3726, ELBO_train: -35.38115406, KL_z: 0.91585300, KL_s: 0.31430493, reconstruction loss: -34.15099612
# Clusters: 10
# Epoch: [135]  time: 45.7398, ELBO_train: -35.29921794, KL_z: 0.92182470, KL_s: 0.28497905, reconstruction loss: -34.09241419
# Clusters: 10
# Epoch: [136]  time: 46.0738, ELBO_train: -35.35023808, KL_z: 0.92551776, KL_s: 0.28390637, reconstruction loss: -34.14081395
# Clusters: 10
# Epoch: [137]  time: 46.4097, ELBO_train: -35.31875420, KL_z: 0.93356687, KL_s: 0.30172280, reconstruction loss: -34.08346452
# Clusters: 10
# Epoch: [138]  time: 46.7639, ELBO_train: -35.27866960, KL_z: 0.92890342, KL_s: 0.29030528, reconstruction loss: -34.05946090
# Clusters: 10
# Epoch: [139]  time: 47.1786, ELBO_train: -35.25238395, KL_z: 0.92717838, KL_s: 0.28400330, reconstruction loss: -34.04120226
# Clusters: 10
# Epoch: [140]  time: 47.5649, ELBO_train: -35.26679158, KL_z: 0.93415574, KL_s: 0.30181108, reconstruction loss: -34.03082476
# Clusters: 10
# Epoch: [141]  time: 47.9652, ELBO_train: -35.27567744, KL_z: 0.95481456, KL_s: 0.29649962, reconstruction loss: -34.02436326
# Clusters: 10
# Epoch: [142]  time: 48.3494, ELBO_train: -35.26749706, KL_z: 0.93757604, KL_s: 0.29836541, reconstruction loss: -34.03155562
# Clusters: 10
# Epoch: [143]  time: 48.7349, ELBO_train: -35.25167179, KL_z: 0.95439551, KL_s: 0.30797624, reconstruction loss: -33.98930004
# Clusters: 10
# Epoch: [144]  time: 49.1582, ELBO_train: -35.21020865, KL_z: 0.94732121, KL_s: 0.29452928, reconstruction loss: -33.96835816
# Clusters: 10
# Epoch: [145]  time: 49.5729, ELBO_train: -35.21240640, KL_z: 0.94807654, KL_s: 0.30982464, reconstruction loss: -33.95450522
# Clusters: 10
# Epoch: [146]  time: 49.9758, ELBO_train: -35.19943333, KL_z: 0.95336258, KL_s: 0.33150627, reconstruction loss: -33.91456448
# Clusters: 10
# Epoch: [147]  time: 50.3676, ELBO_train: -35.24894238, KL_z: 0.95630789, KL_s: 0.34955595, reconstruction loss: -33.94307854
# Clusters: 10
# Epoch: [148]  time: 50.8445, ELBO_train: -35.19912696, KL_z: 0.97224785, KL_s: 0.33497870, reconstruction loss: -33.89190041
# Clusters: 10
# Epoch: [149]  time: 51.2215, ELBO_train: -35.24666286, KL_z: 0.98252373, KL_s: 0.35263039, reconstruction loss: -33.91150873
# Clusters: 10
# Epoch: [150]  time: 51.6906, ELBO_train: -35.21640396, KL_z: 1.01067510, KL_s: 0.33169764, reconstruction loss: -33.87403122
# Clusters: 10
# Epoch: [151]  time: 52.1751, ELBO_train: -35.22327089, KL_z: 0.98369259, KL_s: 0.36063664, reconstruction loss: -33.87894166
# Clusters: 10
# Epoch: [152]  time: 52.6552, ELBO_train: -35.13653159, KL_z: 1.00005508, KL_s: 0.32223989, reconstruction loss: -33.81423662
# Clusters: 10
# Epoch: [153]  time: 53.1492, ELBO_train: -35.11929512, KL_z: 0.99687383, KL_s: 0.29162131, reconstruction loss: -33.83079997
# Clusters: 10
# Epoch: [154]  time: 53.6579, ELBO_train: -35.15990424, KL_z: 1.01344185, KL_s: 0.31351550, reconstruction loss: -33.83294690
# Clusters: 10
# Epoch: [155]  time: 54.1168, ELBO_train: -35.11694264, KL_z: 1.00917089, KL_s: 0.30843248, reconstruction loss: -33.79933927
# Clusters: 10
# Epoch: [156]  time: 54.5883, ELBO_train: -35.08381534, KL_z: 0.99993617, KL_s: 0.30794843, reconstruction loss: -33.77593074
# Clusters: 10
# Epoch: [157]  time: 55.0374, ELBO_train: -35.10116124, KL_z: 1.01542416, KL_s: 0.31752883, reconstruction loss: -33.76820825
# Clusters: 10
# Epoch: [158]  time: 55.5031, ELBO_train: -35.11593962, KL_z: 1.01876335, KL_s: 0.34710116, reconstruction loss: -33.75007511
# Clusters: 10
# Epoch: [159]  time: 55.9614, ELBO_train: -35.08490920, KL_z: 1.01678228, KL_s: 0.33140071, reconstruction loss: -33.73672620
# Clusters: 10
# Epoch: [160]  time: 56.4043, ELBO_train: -35.10694027, KL_z: 1.04520573, KL_s: 0.32607266, reconstruction loss: -33.73566188
# Clusters: 10
# Epoch: [161]  time: 56.8551, ELBO_train: -35.08229661, KL_z: 1.04085284, KL_s: 0.30434255, reconstruction loss: -33.73710122
# Clusters: 10
# Epoch: [162]  time: 57.3233, ELBO_train: -35.06964874, KL_z: 1.05061526, KL_s: 0.30517275, reconstruction loss: -33.71386074
# Clusters: 10
# Epoch: [163]  time: 57.8050, ELBO_train: -35.08470058, KL_z: 1.05498149, KL_s: 0.32655482, reconstruction loss: -33.70316427
# Clusters: 10
# Epoch: [164]  time: 58.2961, ELBO_train: -35.07925105, KL_z: 1.05032695, KL_s: 0.35112067, reconstruction loss: -33.67780343
# Clusters: 10
# Epoch: [165]  time: 58.8028, ELBO_train: -35.08162689, KL_z: 1.05050205, KL_s: 0.34547181, reconstruction loss: -33.68565303
# Clusters: 10
# Epoch: [166]  time: 59.4050, ELBO_train: -35.05942106, KL_z: 1.05670264, KL_s: 0.35614948, reconstruction loss: -33.64656895
# Clusters: 10
# Epoch: [167]  time: 59.9203, ELBO_train: -35.04672647, KL_z: 1.04550281, KL_s: 0.34822261, reconstruction loss: -33.65300104
# Clusters: 10
# Epoch: [168]  time: 60.4341, ELBO_train: -35.03742862, KL_z: 1.07375676, KL_s: 0.35215979, reconstruction loss: -33.61151206
# Clusters: 10
# Epoch: [169]  time: 60.9380, ELBO_train: -35.00975561, KL_z: 1.07093281, KL_s: 0.34423666, reconstruction loss: -33.59458613
# Clusters: 10
# Epoch: [170]  time: 61.4436, ELBO_train: -34.97130418, KL_z: 1.07152946, KL_s: 0.33254340, reconstruction loss: -33.56723132
# Clusters: 10
# Epoch: [171]  time: 61.9408, ELBO_train: -34.97921634, KL_z: 1.07450207, KL_s: 0.33880650, reconstruction loss: -33.56590778
# Clusters: 10
# Epoch: [172]  time: 62.3997, ELBO_train: -34.97710156, KL_z: 1.08213194, KL_s: 0.34239805, reconstruction loss: -33.55257157
# Clusters: 10
# Epoch: [173]  time: 62.8007, ELBO_train: -34.98550940, KL_z: 1.09463034, KL_s: 0.32979332, reconstruction loss: -33.56108574
# Clusters: 10
# Epoch: [174]  time: 63.3015, ELBO_train: -34.97571588, KL_z: 1.10109847, KL_s: 0.33700383, reconstruction loss: -33.53761358
# Clusters: 10
# Epoch: [175]  time: 63.7238, ELBO_train: -34.96717715, KL_z: 1.10110106, KL_s: 0.33921565, reconstruction loss: -33.52686044
# Clusters: 10
# Epoch: [176]  time: 64.1078, ELBO_train: -34.96320176, KL_z: 1.11766484, KL_s: 0.34598219, reconstruction loss: -33.49955472
# Clusters: 10
# Epoch: [177]  time: 64.4656, ELBO_train: -34.96791339, KL_z: 1.12984714, KL_s: 0.34697762, reconstruction loss: -33.49108863
# Clusters: 10
# Epoch: [178]  time: 64.8736, ELBO_train: -34.98085070, KL_z: 1.12668721, KL_s: 0.37488451, reconstruction loss: -33.47927898
# Clusters: 10
# Epoch: [179]  time: 65.2403, ELBO_train: -34.97944927, KL_z: 1.13987982, KL_s: 0.37993719, reconstruction loss: -33.45963227
# Clusters: 10
# Epoch: [180]  time: 65.6108, ELBO_train: -34.97415876, KL_z: 1.15099280, KL_s: 0.38564061, reconstruction loss: -33.43752535
# Clusters: 10
# Epoch: [181]  time: 65.9988, ELBO_train: -34.93308830, KL_z: 1.14765926, KL_s: 0.32608481, reconstruction loss: -33.45934422
# Clusters: 10
# Epoch: [182]  time: 66.3743, ELBO_train: -34.89726877, KL_z: 1.13707191, KL_s: 0.32414918, reconstruction loss: -33.43604768
# Clusters: 10
# Epoch: [183]  time: 66.7413, ELBO_train: -34.89893770, KL_z: 1.12959097, KL_s: 0.36370970, reconstruction loss: -33.40563703
# Clusters: 10
# Epoch: [184]  time: 67.1069, ELBO_train: -34.94497633, KL_z: 1.13331649, KL_s: 0.38565031, reconstruction loss: -33.42600954
# Clusters: 10
# Epoch: [185]  time: 67.4545, ELBO_train: -34.88512754, KL_z: 1.15642639, KL_s: 0.34528096, reconstruction loss: -33.38342020
# Clusters: 10
# Epoch: [186]  time: 67.8362, ELBO_train: -34.90637612, KL_z: 1.16467953, KL_s: 0.34874995, reconstruction loss: -33.39294665
# Clusters: 10
# Epoch: [187]  time: 68.2138, ELBO_train: -34.84734511, KL_z: 1.15819543, KL_s: 0.34148129, reconstruction loss: -33.34766839
# Clusters: 10
# Epoch: [188]  time: 68.5686, ELBO_train: -34.84171510, KL_z: 1.14694712, KL_s: 0.36057717, reconstruction loss: -33.33419081
# Clusters: 10
# Epoch: [189]  time: 68.9100, ELBO_train: -34.84720230, KL_z: 1.15725686, KL_s: 0.35323689, reconstruction loss: -33.33670855
# Clusters: 10
# Epoch: [190]  time: 69.2546, ELBO_train: -34.83001852, KL_z: 1.17152118, KL_s: 0.34257538, reconstruction loss: -33.31592196
# Clusters: 10
# Epoch: [191]  time: 69.5994, ELBO_train: -34.85028815, KL_z: 1.18046218, KL_s: 0.33324491, reconstruction loss: -33.33658106
# Clusters: 10
# Epoch: [192]  time: 69.9458, ELBO_train: -34.84457111, KL_z: 1.17958200, KL_s: 0.34350350, reconstruction loss: -33.32148562
# Clusters: 10
# Epoch: [193]  time: 70.2846, ELBO_train: -34.80727601, KL_z: 1.18935872, KL_s: 0.34219825, reconstruction loss: -33.27571904
# Clusters: 10
# Epoch: [194]  time: 70.6409, ELBO_train: -34.82088995, KL_z: 1.20298091, KL_s: 0.34366608, reconstruction loss: -33.27424296
# Clusters: 10
# Epoch: [195]  time: 70.9850, ELBO_train: -34.81106806, KL_z: 1.20913409, KL_s: 0.34963825, reconstruction loss: -33.25229572
# Clusters: 10
# Epoch: [196]  time: 71.3256, ELBO_train: -34.80126905, KL_z: 1.21109670, KL_s: 0.33843230, reconstruction loss: -33.25174005
# Clusters: 10
# Epoch: [197]  time: 71.6634, ELBO_train: -34.79238415, KL_z: 1.21750149, KL_s: 0.33930828, reconstruction loss: -33.23557438
# Clusters: 10
# Epoch: [198]  time: 72.0057, ELBO_train: -34.82107592, KL_z: 1.22512563, KL_s: 0.34253374, reconstruction loss: -33.25341655
# Clusters: 10
# Epoch: [199]  time: 72.3419, ELBO_train: -34.80891466, KL_z: 1.22081212, KL_s: 0.35348014, reconstruction loss: -33.23462240
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = data_processing.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = statistic.samples_concatenation(samples_list)[-1]
    data_test_transformed = data_processing.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = data_processing.discrete_variables_transformation(est_data_test, feat_types_dict)

# %% [markdown]
# ### Visualize the generated samples

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
estimated_values = est_data_test_transformed

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
