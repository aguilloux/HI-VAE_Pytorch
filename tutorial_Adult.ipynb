# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import utils
import time

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "Adult"
m_perc = 10
mask = 1
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data preprocessing

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = utils.read_data(data_file, feat_types_file, miss_file, true_miss_file)

train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# %%
# Adjust batch size if larger than dataset
batch_size = 1000
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 200
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
from utils import print_loss, plot_loss_evolution

start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = np.random.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = utils.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = utils.samples_concatenation(samples_list)
    
    # #Transform discrete variables back to the original values
    data_train_transformed = utils.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = utils.discrete_variables_transformation(est_data_train, feat_types_dict)
    est_data_train_mean_imputed = utils.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = utils.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = utils.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 9
# Epoch: [ 0]  time: 0.2339, ELBO_train: -51.42698625, KL_z: 1.74935692, KL_s: 0.25442430, reconstruction loss: -49.42320503
# Clusters: 6
# Epoch: [ 1]  time: 0.4190, ELBO_train: -33.97348639, KL_z: 3.77403575, KL_s: 0.40190631, reconstruction loss: -29.79754433
# Clusters: 4
# Epoch: [ 2]  time: 0.6068, ELBO_train: -12.97297739, KL_z: 8.32566008, KL_s: 0.47265748, reconstruction loss: -4.17465983
# Clusters: 5
# Epoch: [ 3]  time: 0.7922, ELBO_train: 8.71330091, KL_z: 14.53243362, KL_s: 0.59073502, reconstruction loss: 23.83646955
# Clusters: 5
# Epoch: [ 4]  time: 0.9825, ELBO_train: 26.31361609, KL_z: 20.30673196, KL_s: 0.73902363, reconstruction loss: 47.35937168
# Clusters: 5
# Epoch: [ 5]  time: 1.1710, ELBO_train: 39.19166917, KL_z: 23.67506269, KL_s: 0.88342966, reconstruction loss: 63.75016152
# Clusters: 4
# Epoch: [ 6]  time: 1.3627, ELBO_train: 49.27272650, KL_z: 24.78155562, KL_s: 1.01715738, reconstruction loss: 75.07143949
# Clusters: 4
# Epoch: [ 7]  time: 1.5459, ELBO_train: 57.54283890, KL_z: 24.65483776, KL_s: 1.14143964, reconstruction loss: 83.33911630
# Clusters: 4
# Epoch: [ 8]  time: 1.7303, ELBO_train: 64.68223278, KL_z: 23.96285512, KL_s: 1.25231559, reconstruction loss: 89.89740350
# Clusters: 3
# Epoch: [ 9]  time: 1.9164, ELBO_train: 70.89733241, KL_z: 23.00855064, KL_s: 1.34238718, reconstruction loss: 95.24827024
# Clusters: 3
# Epoch: [10]  time: 2.1050, ELBO_train: 76.45425034, KL_z: 22.00637223, KL_s: 1.41015470, reconstruction loss: 99.87077727
# Clusters: 3
# Epoch: [11]  time: 2.2919, ELBO_train: 81.40147224, KL_z: 21.01652674, KL_s: 1.45960038, reconstruction loss: 103.87759936
# Clusters: 3
# Epoch: [12]  time: 2.4789, ELBO_train: 86.07694127, KL_z: 20.01722182, KL_s: 1.49629400, reconstruction loss: 107.59045709
# Clusters: 3
# Epoch: [13]  time: 2.6683, ELBO_train: 90.06146211, KL_z: 19.09066714, KL_s: 1.52474800, reconstruction loss: 110.67687724
# Clusters: 2
# Epoch: [14]  time: 2.8582, ELBO_train: 93.98567229, KL_z: 18.21728963, KL_s: 1.54824769, reconstruction loss: 113.75120961
# Clusters: 2
# Epoch: [15]  time: 3.0949, ELBO_train: 97.41005619, KL_z: 17.41655753, KL_s: 1.56878570, reconstruction loss: 116.39539942
# Clusters: 2
# Epoch: [16]  time: 3.3268, ELBO_train: 100.74554385, KL_z: 16.66090797, KL_s: 1.58884341, reconstruction loss: 118.99529522
# Clusters: 2
# Epoch: [17]  time: 3.5149, ELBO_train: 103.78886003, KL_z: 15.93448602, KL_s: 1.60838493, reconstruction loss: 121.33173098
# Clusters: 2
# Epoch: [18]  time: 3.7038, ELBO_train: 106.62911665, KL_z: 15.33725020, KL_s: 1.63004650, reconstruction loss: 123.59641334
# Clusters: 2
# Epoch: [19]  time: 3.8919, ELBO_train: 109.33332326, KL_z: 14.67468636, KL_s: 1.65470482, reconstruction loss: 125.66271444
# Clusters: 2
# Epoch: [20]  time: 4.0843, ELBO_train: 111.85428531, KL_z: 14.09811376, KL_s: 1.68259884, reconstruction loss: 127.63499791
# Clusters: 2
# Epoch: [21]  time: 4.2727, ELBO_train: 114.25959308, KL_z: 13.52644565, KL_s: 1.71631836, reconstruction loss: 129.50235709
# Clusters: 2
# Epoch: [22]  time: 4.4660, ELBO_train: 116.48564119, KL_z: 13.02544924, KL_s: 1.75710064, reconstruction loss: 131.26819107
# Clusters: 2
# Epoch: [23]  time: 4.6539, ELBO_train: 118.65642372, KL_z: 12.47837980, KL_s: 1.80280533, reconstruction loss: 132.93760885
# Clusters: 2
# Epoch: [24]  time: 4.8421, ELBO_train: 120.68568508, KL_z: 12.00334769, KL_s: 1.85723713, reconstruction loss: 134.54626991
# Clusters: 2
# Epoch: [25]  time: 5.0314, ELBO_train: 122.71098298, KL_z: 11.48022930, KL_s: 1.91596595, reconstruction loss: 136.10717824
# Clusters: 2
# Epoch: [26]  time: 5.2724, ELBO_train: 124.49427355, KL_z: 11.01061575, KL_s: 1.97708005, reconstruction loss: 137.48196936
# Clusters: 2
# Epoch: [27]  time: 5.4637, ELBO_train: 126.35186298, KL_z: 10.52814916, KL_s: 2.03874315, reconstruction loss: 138.91875529
# Clusters: 2
# Epoch: [28]  time: 5.6512, ELBO_train: 128.06088873, KL_z: 10.12022224, KL_s: 2.09099063, reconstruction loss: 140.27210159
# Clusters: 2
# Epoch: [29]  time: 5.8797, ELBO_train: 129.69449762, KL_z: 9.65051361, KL_s: 2.13375770, reconstruction loss: 141.47876894
# Clusters: 2
# Epoch: [30]  time: 6.0683, ELBO_train: 131.23139895, KL_z: 9.29026556, KL_s: 2.16696033, reconstruction loss: 142.68862484
# Clusters: 2
# Epoch: [31]  time: 6.2675, ELBO_train: 132.76396355, KL_z: 8.85138750, KL_s: 2.19237297, reconstruction loss: 143.80772403
# Clusters: 2
# Epoch: [32]  time: 6.4586, ELBO_train: 134.13585898, KL_z: 8.51846005, KL_s: 2.21001282, reconstruction loss: 144.86433185
# Clusters: 1
# Epoch: [33]  time: 6.6517, ELBO_train: 135.41946646, KL_z: 8.18149502, KL_s: 2.22328778, reconstruction loss: 145.82424927
# Clusters: 1
# Epoch: [34]  time: 6.8421, ELBO_train: 136.71307490, KL_z: 7.86853495, KL_s: 2.23309086, reconstruction loss: 146.81470071
# Clusters: 1
# Epoch: [35]  time: 7.0356, ELBO_train: 137.95443256, KL_z: 7.55496073, KL_s: 2.24167248, reconstruction loss: 147.75106577
# Clusters: 1
# Epoch: [36]  time: 7.2257, ELBO_train: 139.14658062, KL_z: 7.25517515, KL_s: 2.24855901, reconstruction loss: 148.65031478
# Clusters: 1
# Epoch: [37]  time: 7.4341, ELBO_train: 140.24752514, KL_z: 6.96211784, KL_s: 2.25392779, reconstruction loss: 149.46357077
# Clusters: 1
# Epoch: [38]  time: 7.6253, ELBO_train: 141.28332754, KL_z: 6.70498919, KL_s: 2.25811155, reconstruction loss: 150.24642829
# Clusters: 1
# Epoch: [39]  time: 7.8153, ELBO_train: 142.23668788, KL_z: 6.45858031, KL_s: 2.26168984, reconstruction loss: 150.95695803
# Clusters: 1
# Epoch: [40]  time: 8.0173, ELBO_train: 143.15061775, KL_z: 6.21852754, KL_s: 2.26448439, reconstruction loss: 151.63362967
# Clusters: 1
# Epoch: [41]  time: 8.2091, ELBO_train: 144.05406072, KL_z: 6.00012522, KL_s: 2.26631198, reconstruction loss: 152.32049793
# Clusters: 1
# Epoch: [42]  time: 8.4033, ELBO_train: 144.99838961, KL_z: 5.75160865, KL_s: 2.26791537, reconstruction loss: 153.01791363
# Clusters: 1
# Epoch: [43]  time: 8.5922, ELBO_train: 145.76562383, KL_z: 5.55635593, KL_s: 2.26927442, reconstruction loss: 153.59125418
# Clusters: 1
# Epoch: [44]  time: 8.7850, ELBO_train: 146.55936138, KL_z: 5.35134625, KL_s: 2.27057459, reconstruction loss: 154.18128223
# Clusters: 1
# Epoch: [45]  time: 8.9755, ELBO_train: 147.31753129, KL_z: 5.17183548, KL_s: 2.27141096, reconstruction loss: 154.76077773
# Clusters: 1
# Epoch: [46]  time: 9.1705, ELBO_train: 148.05372678, KL_z: 4.97179629, KL_s: 2.27200549, reconstruction loss: 155.29752857
# Clusters: 1
# Epoch: [47]  time: 9.4837, ELBO_train: 148.69658367, KL_z: 4.80226500, KL_s: 2.27276996, reconstruction loss: 155.77161863
# Clusters: 1
# Epoch: [48]  time: 9.8499, ELBO_train: 149.38865486, KL_z: 4.62983458, KL_s: 2.27355947, reconstruction loss: 156.29204890
# Clusters: 1
# Epoch: [49]  time: 10.2106, ELBO_train: 149.99811613, KL_z: 4.47781790, KL_s: 2.27366113, reconstruction loss: 156.74959516
# Clusters: 1
# Epoch: [50]  time: 10.4238, ELBO_train: 150.58368448, KL_z: 4.31226602, KL_s: 2.27406557, reconstruction loss: 157.17001607
# Clusters: 1
# Epoch: [51]  time: 10.6175, ELBO_train: 151.16741885, KL_z: 4.19521427, KL_s: 2.27435314, reconstruction loss: 157.63698626
# Clusters: 1
# Epoch: [52]  time: 10.8143, ELBO_train: 151.73571014, KL_z: 4.02985322, KL_s: 2.27387911, reconstruction loss: 158.03944247
# Clusters: 1
# Epoch: [53]  time: 11.0057, ELBO_train: 152.28920100, KL_z: 3.89341518, KL_s: 2.27331656, reconstruction loss: 158.45593274
# Clusters: 1
# Epoch: [54]  time: 11.2008, ELBO_train: 152.79389895, KL_z: 3.76207617, KL_s: 2.27309212, reconstruction loss: 158.82906724
# Clusters: 1
# Epoch: [55]  time: 11.3954, ELBO_train: 153.24937146, KL_z: 3.65376181, KL_s: 2.27246326, reconstruction loss: 159.17559652
# Clusters: 1
# Epoch: [56]  time: 11.5898, ELBO_train: 153.68935688, KL_z: 3.53802908, KL_s: 2.27185607, reconstruction loss: 159.49924203
# Clusters: 1
# Epoch: [57]  time: 11.7874, ELBO_train: 154.16301551, KL_z: 3.40315590, KL_s: 2.27100781, reconstruction loss: 159.83717923
# Clusters: 1
# Epoch: [58]  time: 11.9798, ELBO_train: 154.54042523, KL_z: 3.33601135, KL_s: 2.27009737, reconstruction loss: 160.14653394
# Clusters: 1
# Epoch: [59]  time: 12.1758, ELBO_train: 154.92012435, KL_z: 3.22695995, KL_s: 2.26866140, reconstruction loss: 160.41574570
# Clusters: 1
# Epoch: [60]  time: 12.3724, ELBO_train: 155.40028557, KL_z: 3.11508428, KL_s: 2.26697491, reconstruction loss: 160.78234476
# Clusters: 2
# Epoch: [61]  time: 12.5675, ELBO_train: 155.70146649, KL_z: 3.03089862, KL_s: 2.26576932, reconstruction loss: 160.99813442
# Clusters: 2
# Epoch: [62]  time: 12.7725, ELBO_train: 156.04605396, KL_z: 2.93473865, KL_s: 2.26440414, reconstruction loss: 161.24519675
# Clusters: 2
# Epoch: [63]  time: 12.9725, ELBO_train: 156.39289328, KL_z: 2.87161899, KL_s: 2.26075481, reconstruction loss: 161.52526707
# Clusters: 2
# Epoch: [64]  time: 13.1672, ELBO_train: 156.69010104, KL_z: 2.77850345, KL_s: 2.25800171, reconstruction loss: 161.72660619
# Clusters: 2
# Epoch: [65]  time: 13.3637, ELBO_train: 156.97568101, KL_z: 2.69765845, KL_s: 2.25480831, reconstruction loss: 161.92814777
# Clusters: 2
# Epoch: [66]  time: 13.5600, ELBO_train: 157.30928802, KL_z: 2.62854941, KL_s: 2.25100440, reconstruction loss: 162.18884184
# Clusters: 2
# Epoch: [67]  time: 13.7566, ELBO_train: 157.58908727, KL_z: 2.56683144, KL_s: 2.24573471, reconstruction loss: 162.40165342
# Clusters: 2
# Epoch: [68]  time: 14.0174, ELBO_train: 157.81372540, KL_z: 2.49531415, KL_s: 2.23912502, reconstruction loss: 162.54816457
# Clusters: 2
# Epoch: [69]  time: 14.2314, ELBO_train: 158.09550359, KL_z: 2.42507486, KL_s: 2.23027358, reconstruction loss: 162.75085203
# Clusters: 2
# Epoch: [70]  time: 14.4287, ELBO_train: 158.34606347, KL_z: 2.37813711, KL_s: 2.21976246, reconstruction loss: 162.94396304
# Clusters: 2
# Epoch: [71]  time: 14.6263, ELBO_train: 158.55852274, KL_z: 2.31160568, KL_s: 2.21335617, reconstruction loss: 163.08348459
# Clusters: 2
# Epoch: [72]  time: 14.8207, ELBO_train: 158.78114495, KL_z: 2.25747420, KL_s: 2.20452001, reconstruction loss: 163.24313916
# Clusters: 2
# Epoch: [73]  time: 15.0186, ELBO_train: 158.99612779, KL_z: 2.21313413, KL_s: 2.19255431, reconstruction loss: 163.40181623
# Clusters: 2
# Epoch: [74]  time: 15.2125, ELBO_train: 159.19754263, KL_z: 2.16842750, KL_s: 2.19283177, reconstruction loss: 163.55880191
# Clusters: 2
# Epoch: [75]  time: 15.4101, ELBO_train: 159.42331754, KL_z: 2.11116007, KL_s: 2.19156432, reconstruction loss: 163.72604193
# Clusters: 2
# Epoch: [76]  time: 15.6042, ELBO_train: 159.61792696, KL_z: 2.06255715, KL_s: 2.18109765, reconstruction loss: 163.86158177
# Clusters: 2
# Epoch: [77]  time: 15.8026, ELBO_train: 159.77901870, KL_z: 2.01614398, KL_s: 2.17648445, reconstruction loss: 163.97164712
# Clusters: 2
# Epoch: [78]  time: 15.9984, ELBO_train: 159.90594189, KL_z: 1.99692475, KL_s: 2.17052489, reconstruction loss: 164.07339153
# Clusters: 2
# Epoch: [79]  time: 16.1966, ELBO_train: 160.07325686, KL_z: 1.94820795, KL_s: 2.16918568, reconstruction loss: 164.19065049
# Clusters: 2
# Epoch: [80]  time: 16.3987, ELBO_train: 160.27250554, KL_z: 1.91501923, KL_s: 2.16502743, reconstruction loss: 164.35255219
# Clusters: 2
# Epoch: [81]  time: 16.5941, ELBO_train: 160.38121444, KL_z: 1.87934042, KL_s: 2.16707704, reconstruction loss: 164.42763190
# Clusters: 2
# Epoch: [82]  time: 16.8065, ELBO_train: 160.54888564, KL_z: 1.84280769, KL_s: 2.16847719, reconstruction loss: 164.56017052
# Clusters: 2
# Epoch: [83]  time: 17.0023, ELBO_train: 160.66779327, KL_z: 1.81158808, KL_s: 2.15950390, reconstruction loss: 164.63888525
# Clusters: 2
# Epoch: [84]  time: 17.1988, ELBO_train: 160.76723480, KL_z: 1.78378494, KL_s: 2.15787556, reconstruction loss: 164.70889530
# Clusters: 2
# Epoch: [85]  time: 17.3947, ELBO_train: 160.87544427, KL_z: 1.74431764, KL_s: 2.15572152, reconstruction loss: 164.77548342
# Clusters: 2
# Epoch: [86]  time: 17.5900, ELBO_train: 161.01245176, KL_z: 1.72827448, KL_s: 2.15824725, reconstruction loss: 164.89897349
# Clusters: 2
# Epoch: [87]  time: 17.7913, ELBO_train: 161.13602682, KL_z: 1.69674364, KL_s: 2.15471629, reconstruction loss: 164.98748675
# Clusters: 2
# Epoch: [88]  time: 17.9915, ELBO_train: 161.20886993, KL_z: 1.67666180, KL_s: 2.15053098, reconstruction loss: 165.03606271
# Clusters: 2
# Epoch: [89]  time: 18.1911, ELBO_train: 161.32604276, KL_z: 1.65340800, KL_s: 2.14541596, reconstruction loss: 165.12486671
# Clusters: 2
# Epoch: [90]  time: 18.4149, ELBO_train: 161.44795344, KL_z: 1.62866840, KL_s: 2.13941520, reconstruction loss: 165.21603705
# Clusters: 2
# Epoch: [91]  time: 18.6106, ELBO_train: 161.54159311, KL_z: 1.60737712, KL_s: 2.14681884, reconstruction loss: 165.29578907
# Clusters: 2
# Epoch: [92]  time: 18.8053, ELBO_train: 161.65199691, KL_z: 1.58186708, KL_s: 2.14089189, reconstruction loss: 165.37475587
# Clusters: 2
# Epoch: [93]  time: 19.0284, ELBO_train: 161.70548131, KL_z: 1.57034973, KL_s: 2.13214648, reconstruction loss: 165.40797752
# Clusters: 2
# Epoch: [94]  time: 19.2259, ELBO_train: 161.74788842, KL_z: 1.54838121, KL_s: 2.13470255, reconstruction loss: 165.43097218
# Clusters: 2
# Epoch: [95]  time: 19.4251, ELBO_train: 161.84558810, KL_z: 1.52952901, KL_s: 2.12979410, reconstruction loss: 165.50491121
# Clusters: 2
# Epoch: [96]  time: 19.6254, ELBO_train: 161.86475842, KL_z: 1.51572300, KL_s: 2.12439181, reconstruction loss: 165.50487323
# Clusters: 2
# Epoch: [97]  time: 19.8289, ELBO_train: 161.94956031, KL_z: 1.50246405, KL_s: 2.13352440, reconstruction loss: 165.58554876
# Clusters: 2
# Epoch: [98]  time: 20.0289, ELBO_train: 162.06161323, KL_z: 1.48238124, KL_s: 2.13861145, reconstruction loss: 165.68260591
# Clusters: 2
# Epoch: [99]  time: 20.2264, ELBO_train: 162.08501845, KL_z: 1.47161235, KL_s: 2.13048195, reconstruction loss: 165.68711275
# Clusters: 2
# Epoch: [100]  time: 20.4278, ELBO_train: 162.15370882, KL_z: 1.45636283, KL_s: 2.12481491, reconstruction loss: 165.73488657
# Clusters: 2
# Epoch: [101]  time: 20.6258, ELBO_train: 162.26170701, KL_z: 1.44261587, KL_s: 2.12980877, reconstruction loss: 165.83413166
# Clusters: 2
# Epoch: [102]  time: 20.8282, ELBO_train: 162.27554615, KL_z: 1.43323687, KL_s: 2.11818353, reconstruction loss: 165.82696655
# Clusters: 2
# Epoch: [103]  time: 21.0357, ELBO_train: 162.32512723, KL_z: 1.42341965, KL_s: 2.10459708, reconstruction loss: 165.85314397
# Clusters: 2
# Epoch: [104]  time: 21.2378, ELBO_train: 162.35525102, KL_z: 1.41518040, KL_s: 2.10199777, reconstruction loss: 165.87242919
# Clusters: 2
# Epoch: [105]  time: 21.4417, ELBO_train: 162.44799922, KL_z: 1.39773601, KL_s: 2.12485589, reconstruction loss: 165.97059112
# Clusters: 2
# Epoch: [106]  time: 21.6427, ELBO_train: 162.49813080, KL_z: 1.39224581, KL_s: 2.11504724, reconstruction loss: 166.00542385
# Clusters: 2
# Epoch: [107]  time: 21.8451, ELBO_train: 162.55401024, KL_z: 1.38483611, KL_s: 2.08889425, reconstruction loss: 166.02774060
# Clusters: 2
# Epoch: [108]  time: 22.0474, ELBO_train: 162.48216306, KL_z: 1.37979702, KL_s: 2.07427860, reconstruction loss: 165.93623869
# Clusters: 2
# Epoch: [109]  time: 22.2481, ELBO_train: 162.58602318, KL_z: 1.36715089, KL_s: 2.08561246, reconstruction loss: 166.03878654
# Clusters: 2
# Epoch: [110]  time: 22.4495, ELBO_train: 162.61410170, KL_z: 1.36043647, KL_s: 2.09354667, reconstruction loss: 166.06808485
# Clusters: 2
# Epoch: [111]  time: 22.6514, ELBO_train: 162.63160353, KL_z: 1.35021478, KL_s: 2.07525006, reconstruction loss: 166.05706838
# Clusters: 2
# Epoch: [112]  time: 22.8502, ELBO_train: 162.74383428, KL_z: 1.34965039, KL_s: 2.08104947, reconstruction loss: 166.17453414
# Clusters: 2
# Epoch: [113]  time: 23.0544, ELBO_train: 162.77296272, KL_z: 1.33508427, KL_s: 2.07667786, reconstruction loss: 166.18472485
# Clusters: 2
# Epoch: [114]  time: 23.2547, ELBO_train: 162.79986748, KL_z: 1.33451454, KL_s: 2.07278799, reconstruction loss: 166.20717001
# Clusters: 2
# Epoch: [115]  time: 23.4557, ELBO_train: 162.78894923, KL_z: 1.33505672, KL_s: 2.07251844, reconstruction loss: 166.19652440
# Clusters: 2
# Epoch: [116]  time: 23.6575, ELBO_train: 162.88744002, KL_z: 1.32441016, KL_s: 2.05648351, reconstruction loss: 166.26833369
# Clusters: 2
# Epoch: [117]  time: 23.8518, ELBO_train: 162.88506787, KL_z: 1.31637295, KL_s: 2.04137384, reconstruction loss: 166.24281466
# Clusters: 2
# Epoch: [118]  time: 24.0554, ELBO_train: 162.89023590, KL_z: 1.31939130, KL_s: 2.02353932, reconstruction loss: 166.23316652
# Clusters: 2
# Epoch: [119]  time: 24.2525, ELBO_train: 162.90918380, KL_z: 1.32564291, KL_s: 1.99646546, reconstruction loss: 166.23129216
# Clusters: 2
# Epoch: [120]  time: 24.4571, ELBO_train: 162.99263587, KL_z: 1.31256488, KL_s: 2.00709110, reconstruction loss: 166.31229186
# Clusters: 2
# Epoch: [121]  time: 24.6587, ELBO_train: 163.00769278, KL_z: 1.30296223, KL_s: 1.99342624, reconstruction loss: 166.30408124
# Clusters: 2
# Epoch: [122]  time: 24.8607, ELBO_train: 163.02202724, KL_z: 1.30348928, KL_s: 1.98511037, reconstruction loss: 166.31062689
# Clusters: 2
# Epoch: [123]  time: 25.1489, ELBO_train: 163.00303063, KL_z: 1.30270103, KL_s: 1.97939917, reconstruction loss: 166.28513083
# Clusters: 2
# Epoch: [124]  time: 25.4420, ELBO_train: 163.06046647, KL_z: 1.29669850, KL_s: 1.94878858, reconstruction loss: 166.30595356
# Clusters: 2
# Epoch: [125]  time: 25.6796, ELBO_train: 163.09204688, KL_z: 1.30119960, KL_s: 1.92711631, reconstruction loss: 166.32036280
# Clusters: 2
# Epoch: [126]  time: 25.9314, ELBO_train: 163.08240802, KL_z: 1.29615755, KL_s: 1.91886004, reconstruction loss: 166.29742561
# Clusters: 3
# Epoch: [127]  time: 26.1652, ELBO_train: 163.17217665, KL_z: 1.28637213, KL_s: 1.94974210, reconstruction loss: 166.40829089
# Clusters: 3
# Epoch: [128]  time: 26.4492, ELBO_train: 163.16907677, KL_z: 1.29078286, KL_s: 1.95210360, reconstruction loss: 166.41196323
# Clusters: 3
# Epoch: [129]  time: 26.6704, ELBO_train: 163.21236185, KL_z: 1.28417789, KL_s: 1.96741834, reconstruction loss: 166.46395808
# Clusters: 4
# Epoch: [130]  time: 26.8910, ELBO_train: 163.22888418, KL_z: 1.28582275, KL_s: 1.95885083, reconstruction loss: 166.47355776
# Clusters: 3
# Epoch: [131]  time: 27.1394, ELBO_train: 163.28088907, KL_z: 1.27365950, KL_s: 1.95016859, reconstruction loss: 166.50471716
# Clusters: 4
# Epoch: [132]  time: 27.3391, ELBO_train: 163.25460639, KL_z: 1.27484477, KL_s: 1.97430136, reconstruction loss: 166.50375252
# Clusters: 4
# Epoch: [133]  time: 27.5427, ELBO_train: 163.25770451, KL_z: 1.27327325, KL_s: 1.97013183, reconstruction loss: 166.50110960
# Clusters: 4
# Epoch: [134]  time: 27.7652, ELBO_train: 163.25618509, KL_z: 1.26846281, KL_s: 1.95706042, reconstruction loss: 166.48170833
# Clusters: 4
# Epoch: [135]  time: 27.9897, ELBO_train: 163.31972738, KL_z: 1.27048858, KL_s: 1.95395488, reconstruction loss: 166.54417084
# Clusters: 4
# Epoch: [136]  time: 28.1893, ELBO_train: 163.28837057, KL_z: 1.27829169, KL_s: 1.93975864, reconstruction loss: 166.50642090
# Clusters: 4
# Epoch: [137]  time: 28.3909, ELBO_train: 163.32863324, KL_z: 1.27543658, KL_s: 1.92469995, reconstruction loss: 166.52876976
# Clusters: 4
# Epoch: [138]  time: 28.5940, ELBO_train: 163.37253864, KL_z: 1.26695096, KL_s: 1.89515362, reconstruction loss: 166.53464321
# Clusters: 5
# Epoch: [139]  time: 28.7972, ELBO_train: 163.40472999, KL_z: 1.26650716, KL_s: 1.86343492, reconstruction loss: 166.53467207
# Clusters: 5
# Epoch: [140]  time: 28.9969, ELBO_train: 163.41266280, KL_z: 1.26981832, KL_s: 1.84382862, reconstruction loss: 166.52630973
# Clusters: 6
# Epoch: [141]  time: 29.2051, ELBO_train: 163.32964442, KL_z: 1.29248814, KL_s: 1.80509027, reconstruction loss: 166.42722283
# Clusters: 6
# Epoch: [142]  time: 29.4032, ELBO_train: 163.41407482, KL_z: 1.28157539, KL_s: 1.78071053, reconstruction loss: 166.47636074
# Clusters: 6
# Epoch: [143]  time: 29.6176, ELBO_train: 163.46505444, KL_z: 1.29329520, KL_s: 1.76537941, reconstruction loss: 166.52372905
# Clusters: 6
# Epoch: [144]  time: 29.8180, ELBO_train: 163.51344769, KL_z: 1.28456833, KL_s: 1.77106938, reconstruction loss: 166.56908540
# Clusters: 6
# Epoch: [145]  time: 30.0240, ELBO_train: 163.47279123, KL_z: 1.30221496, KL_s: 1.72407474, reconstruction loss: 166.49908093
# Clusters: 6
# Epoch: [146]  time: 30.2257, ELBO_train: 163.55510418, KL_z: 1.28966916, KL_s: 1.72787990, reconstruction loss: 166.57265324
# Clusters: 6
# Epoch: [147]  time: 30.4302, ELBO_train: 163.53934185, KL_z: 1.29837059, KL_s: 1.71057672, reconstruction loss: 166.54828916
# Clusters: 6
# Epoch: [148]  time: 30.6339, ELBO_train: 163.63717123, KL_z: 1.29279736, KL_s: 1.69363532, reconstruction loss: 166.62360392
# Clusters: 6
# Epoch: [149]  time: 30.8382, ELBO_train: 163.64659295, KL_z: 1.29235115, KL_s: 1.70352169, reconstruction loss: 166.64246578
# Clusters: 6
# Epoch: [150]  time: 31.0421, ELBO_train: 163.61943582, KL_z: 1.27879642, KL_s: 1.70789877, reconstruction loss: 166.60613101
# Clusters: 6
# Epoch: [151]  time: 31.2443, ELBO_train: 163.62905649, KL_z: 1.28314551, KL_s: 1.69407507, reconstruction loss: 166.60627708
# Clusters: 6
# Epoch: [152]  time: 31.4581, ELBO_train: 163.69352018, KL_z: 1.27989268, KL_s: 1.65888636, reconstruction loss: 166.63229923
# Clusters: 6
# Epoch: [153]  time: 31.6652, ELBO_train: 163.73175049, KL_z: 1.28587524, KL_s: 1.62083808, reconstruction loss: 166.63846381
# Clusters: 6
# Epoch: [154]  time: 31.8686, ELBO_train: 163.74812904, KL_z: 1.29723881, KL_s: 1.57191546, reconstruction loss: 166.61728331
# Clusters: 6
# Epoch: [155]  time: 32.0716, ELBO_train: 163.75152177, KL_z: 1.30337523, KL_s: 1.55468009, reconstruction loss: 166.60957709
# Clusters: 6
# Epoch: [156]  time: 32.2781, ELBO_train: 163.82308549, KL_z: 1.29527778, KL_s: 1.55125905, reconstruction loss: 166.66962232
# Clusters: 7
# Epoch: [157]  time: 32.4835, ELBO_train: 163.84680587, KL_z: 1.29443277, KL_s: 1.54216251, reconstruction loss: 166.68340115
# Clusters: 7
# Epoch: [158]  time: 32.6895, ELBO_train: 163.83262693, KL_z: 1.29918923, KL_s: 1.53471272, reconstruction loss: 166.66652888
# Clusters: 7
# Epoch: [159]  time: 32.8930, ELBO_train: 163.90709510, KL_z: 1.30050708, KL_s: 1.51927155, reconstruction loss: 166.72687373
# Clusters: 7
# Epoch: [160]  time: 33.0962, ELBO_train: 163.92597433, KL_z: 1.30348155, KL_s: 1.49558292, reconstruction loss: 166.72503880
# Clusters: 7
# Epoch: [161]  time: 33.3021, ELBO_train: 163.93684798, KL_z: 1.29893915, KL_s: 1.48943175, reconstruction loss: 166.72521887
# Clusters: 7
# Epoch: [162]  time: 33.5058, ELBO_train: 163.93678342, KL_z: 1.30032152, KL_s: 1.49519157, reconstruction loss: 166.73229652
# Clusters: 7
# Epoch: [163]  time: 33.7994, ELBO_train: 163.93886273, KL_z: 1.29381064, KL_s: 1.49129371, reconstruction loss: 166.72396708
# Clusters: 7
# Epoch: [164]  time: 34.0036, ELBO_train: 163.93221166, KL_z: 1.29877562, KL_s: 1.48613460, reconstruction loss: 166.71712188
# Clusters: 7
# Epoch: [165]  time: 34.2026, ELBO_train: 163.99867425, KL_z: 1.29864950, KL_s: 1.47772662, reconstruction loss: 166.77505037
# Clusters: 7
# Epoch: [166]  time: 34.4083, ELBO_train: 164.00060800, KL_z: 1.30358789, KL_s: 1.46639466, reconstruction loss: 166.77059056
# Clusters: 7
# Epoch: [167]  time: 34.6178, ELBO_train: 164.04871427, KL_z: 1.30091085, KL_s: 1.46664372, reconstruction loss: 166.81626884
# Clusters: 7
# Epoch: [168]  time: 34.8261, ELBO_train: 164.05825336, KL_z: 1.29756153, KL_s: 1.44208816, reconstruction loss: 166.79790305
# Clusters: 7
# Epoch: [169]  time: 35.0339, ELBO_train: 164.09723781, KL_z: 1.30501272, KL_s: 1.42593189, reconstruction loss: 166.82818242
# Clusters: 7
# Epoch: [170]  time: 35.2475, ELBO_train: 164.13310066, KL_z: 1.30644823, KL_s: 1.38809332, reconstruction loss: 166.82764221
# Clusters: 7
# Epoch: [171]  time: 35.4504, ELBO_train: 164.13180249, KL_z: 1.30770252, KL_s: 1.35102541, reconstruction loss: 166.79053042
# Clusters: 7
# Epoch: [172]  time: 35.6570, ELBO_train: 164.16351964, KL_z: 1.30387373, KL_s: 1.33695828, reconstruction loss: 166.80435165
# Clusters: 7
# Epoch: [173]  time: 35.8574, ELBO_train: 164.17888817, KL_z: 1.31294071, KL_s: 1.31753323, reconstruction loss: 166.80936211
# Clusters: 7
# Epoch: [174]  time: 36.0604, ELBO_train: 164.26119526, KL_z: 1.31826570, KL_s: 1.29932306, reconstruction loss: 166.87878402
# Clusters: 8
# Epoch: [175]  time: 36.2707, ELBO_train: 164.24351032, KL_z: 1.31133645, KL_s: 1.29527037, reconstruction loss: 166.85011714
# Clusters: 8
# Epoch: [176]  time: 36.4840, ELBO_train: 164.28065902, KL_z: 1.32141905, KL_s: 1.27142842, reconstruction loss: 166.87350649
# Clusters: 8
# Epoch: [177]  time: 36.6901, ELBO_train: 164.32732274, KL_z: 1.33114920, KL_s: 1.24541589, reconstruction loss: 166.90388783
# Clusters: 8
# Epoch: [178]  time: 36.8940, ELBO_train: 164.32762263, KL_z: 1.33147141, KL_s: 1.23752449, reconstruction loss: 166.89661853
# Clusters: 8
# Epoch: [179]  time: 37.0993, ELBO_train: 164.33743814, KL_z: 1.32965066, KL_s: 1.24191106, reconstruction loss: 166.90899987
# Clusters: 8
# Epoch: [180]  time: 37.3022, ELBO_train: 164.36787121, KL_z: 1.31508307, KL_s: 1.27150903, reconstruction loss: 166.95446331
# Clusters: 8
# Epoch: [181]  time: 37.5035, ELBO_train: 164.35444230, KL_z: 1.32774559, KL_s: 1.26760156, reconstruction loss: 166.94978946
# Clusters: 8
# Epoch: [182]  time: 37.7143, ELBO_train: 164.34860640, KL_z: 1.33117762, KL_s: 1.26267516, reconstruction loss: 166.94245918
# Clusters: 8
# Epoch: [183]  time: 37.9189, ELBO_train: 164.34645844, KL_z: 1.32576661, KL_s: 1.25966036, reconstruction loss: 166.93188541
# Clusters: 8
# Epoch: [184]  time: 38.1215, ELBO_train: 164.36551490, KL_z: 1.30968547, KL_s: 1.25080184, reconstruction loss: 166.92600222
# Clusters: 8
# Epoch: [185]  time: 38.3346, ELBO_train: 164.35992960, KL_z: 1.32162970, KL_s: 1.25458096, reconstruction loss: 166.93614025
# Clusters: 8
# Epoch: [186]  time: 38.5342, ELBO_train: 164.39512047, KL_z: 1.31644342, KL_s: 1.25810791, reconstruction loss: 166.96967180
# Clusters: 8
# Epoch: [187]  time: 38.7355, ELBO_train: 164.39738112, KL_z: 1.32404638, KL_s: 1.24241271, reconstruction loss: 166.96384022
# Clusters: 8
# Epoch: [188]  time: 38.9354, ELBO_train: 164.40365014, KL_z: 1.32984514, KL_s: 1.23283476, reconstruction loss: 166.96633004
# Clusters: 8
# Epoch: [189]  time: 39.1385, ELBO_train: 164.44854267, KL_z: 1.32859658, KL_s: 1.21964788, reconstruction loss: 166.99678713
# Clusters: 8
# Epoch: [190]  time: 39.3431, ELBO_train: 164.44644752, KL_z: 1.33320690, KL_s: 1.19559106, reconstruction loss: 166.97524548
# Clusters: 8
# Epoch: [191]  time: 39.5472, ELBO_train: 164.47118612, KL_z: 1.34477907, KL_s: 1.16579662, reconstruction loss: 166.98176181
# Clusters: 8
# Epoch: [192]  time: 39.7566, ELBO_train: 164.47928385, KL_z: 1.34640836, KL_s: 1.14541631, reconstruction loss: 166.97110852
# Clusters: 8
# Epoch: [193]  time: 39.9634, ELBO_train: 164.45022466, KL_z: 1.34319878, KL_s: 1.14594306, reconstruction loss: 166.93936649
# Clusters: 8
# Epoch: [194]  time: 40.1628, ELBO_train: 164.49336888, KL_z: 1.35654867, KL_s: 1.13590351, reconstruction loss: 166.98582106
# Clusters: 8
# Epoch: [195]  time: 40.3767, ELBO_train: 164.45196064, KL_z: 1.34765467, KL_s: 1.12882440, reconstruction loss: 166.92843971
# Clusters: 8
# Epoch: [196]  time: 40.5832, ELBO_train: 164.47669103, KL_z: 1.34827737, KL_s: 1.13569917, reconstruction loss: 166.96066756
# Clusters: 8
# Epoch: [197]  time: 40.7866, ELBO_train: 164.50653252, KL_z: 1.34633929, KL_s: 1.13291656, reconstruction loss: 166.98578838
# Clusters: 8
# Epoch: [198]  time: 40.9934, ELBO_train: 164.48819733, KL_z: 1.34435996, KL_s: 1.11011864, reconstruction loss: 166.94267593
# Clusters: 8
# Epoch: [199]  time: 41.2003, ELBO_train: 164.55826569, KL_z: 1.33789837, KL_s: 1.11858288, reconstruction loss: 167.01474694
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = utils.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = utils.samples_concatenation(samples_list)[-1]
    data_test_transformed = utils.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = utils.discrete_variables_transformation(est_data_test, feat_types_dict)

# %%
from utils import plot_true_vs_estimation
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
estimated_values = est_data_test_transformed

# Call plotting function
plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
