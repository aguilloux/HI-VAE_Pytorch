# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
from utils import data_processing, visualization, statistic
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "Adult"
m_perc = 10
mask = 1
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data loading and Feature analysis

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = data_processing.read_data(data_file, feat_types_file, miss_file, true_miss_file)

# Feature analysis
data_transformed = data_processing.discrete_variables_transformation(data, feat_types_dict)
features_df = pd.DataFrame(data_transformed, columns=["feat_" + str(i+1) for i in range(data_transformed.shape[1])])

visualization.plot_data(features_df, feat_types_dict)

# %% [markdown]
# ### Experiment setting

# %%
# Train-test split
train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# Adjust batch size if larger than dataset
batch_size = 1000
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 200
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = np.random.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = data_processing.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = statistic.samples_concatenation(samples_list)
    
    # #Transform discrete variables back to the original values
    data_train_transformed = data_processing.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = data_processing.discrete_variables_transformation(est_data_train, feat_types_dict)
    est_data_train_mean_imputed = statistic.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = statistic.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = statistic.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    visualization.print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

visualization.plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
visualization.plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
visualization.plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 10
# Epoch: [ 0]  time: 0.3621, ELBO_train: -57.82342471, KL_z: 1.77881055, KL_s: 0.08717617, reconstruction loss: -55.95743799
# Clusters: 7
# Epoch: [ 1]  time: 0.5483, ELBO_train: -40.07253632, KL_z: 4.97243768, KL_s: 0.17125535, reconstruction loss: -34.92884330
# Clusters: 6
# Epoch: [ 2]  time: 0.7418, ELBO_train: -16.32725980, KL_z: 11.30838732, KL_s: 0.30105516, reconstruction loss: -4.71781732
# Clusters: 5
# Epoch: [ 3]  time: 0.9331, ELBO_train: 6.80888062, KL_z: 18.44648699, KL_s: 0.39050764, reconstruction loss: 25.64587525
# Clusters: 5
# Epoch: [ 4]  time: 1.1211, ELBO_train: 24.35732467, KL_z: 23.03420749, KL_s: 0.45178677, reconstruction loss: 47.84331894
# Clusters: 4
# Epoch: [ 5]  time: 1.3150, ELBO_train: 37.31731598, KL_z: 24.72498842, KL_s: 0.55694500, reconstruction loss: 62.59924940
# Clusters: 4
# Epoch: [ 6]  time: 1.5322, ELBO_train: 47.56459984, KL_z: 25.05069527, KL_s: 0.73950688, reconstruction loss: 73.35480199
# Clusters: 4
# Epoch: [ 7]  time: 1.7218, ELBO_train: 56.02690638, KL_z: 24.71910543, KL_s: 0.95767410, reconstruction loss: 81.70368591
# Clusters: 3
# Epoch: [ 8]  time: 1.9084, ELBO_train: 63.28710028, KL_z: 23.94077785, KL_s: 1.22757363, reconstruction loss: 88.45545176
# Clusters: 3
# Epoch: [ 9]  time: 2.1153, ELBO_train: 69.85554857, KL_z: 22.96619004, KL_s: 1.54383694, reconstruction loss: 94.36557555
# Clusters: 3
# Epoch: [10]  time: 2.3275, ELBO_train: 75.50830342, KL_z: 21.83422250, KL_s: 1.83813358, reconstruction loss: 99.18065951
# Clusters: 3
# Epoch: [11]  time: 2.5116, ELBO_train: 80.83768082, KL_z: 20.68737235, KL_s: 2.02728052, reconstruction loss: 103.55233369
# Clusters: 3
# Epoch: [12]  time: 2.6979, ELBO_train: 85.45166896, KL_z: 19.66063463, KL_s: 2.12440698, reconstruction loss: 107.23671057
# Clusters: 3
# Epoch: [13]  time: 2.8847, ELBO_train: 89.72116588, KL_z: 18.68463604, KL_s: 2.17775103, reconstruction loss: 110.58355295
# Clusters: 3
# Epoch: [14]  time: 3.0737, ELBO_train: 93.51156176, KL_z: 17.84534696, KL_s: 2.21012361, reconstruction loss: 113.56703234
# Clusters: 3
# Epoch: [15]  time: 3.2596, ELBO_train: 97.04138125, KL_z: 16.99694597, KL_s: 2.23057279, reconstruction loss: 116.26890001
# Clusters: 3
# Epoch: [16]  time: 3.4542, ELBO_train: 100.22270232, KL_z: 16.29837506, KL_s: 2.24475108, reconstruction loss: 118.76582845
# Clusters: 3
# Epoch: [17]  time: 3.6446, ELBO_train: 103.21223010, KL_z: 15.62286751, KL_s: 2.25472553, reconstruction loss: 121.08982314
# Clusters: 3
# Epoch: [18]  time: 3.8410, ELBO_train: 106.00385549, KL_z: 14.95768782, KL_s: 2.26245916, reconstruction loss: 123.22400246
# Clusters: 3
# Epoch: [19]  time: 4.0372, ELBO_train: 108.69458565, KL_z: 14.37260151, KL_s: 2.26826117, reconstruction loss: 125.33544833
# Clusters: 3
# Epoch: [20]  time: 4.2413, ELBO_train: 111.05670166, KL_z: 13.82389762, KL_s: 2.27279272, reconstruction loss: 127.15339199
# Clusters: 1
# Epoch: [96]  time: 19.7528, ELBO_train: 161.14042429, KL_z: 1.81147797, KL_s: 2.29767795, reconstruction loss: 165.24958020
# Clusters: 1
# Epoch: [97]  time: 19.9451, ELBO_train: 161.25308404, KL_z: 1.79895844, KL_s: 2.29784936, reconstruction loss: 165.34989184
# Clusters: 1
# Epoch: [98]  time: 20.1484, ELBO_train: 161.30258003, KL_z: 1.78244380, KL_s: 2.29790013, reconstruction loss: 165.38292395
# Clusters: 1
# Epoch: [99]  time: 20.3418, ELBO_train: 161.34613917, KL_z: 1.77510596, KL_s: 2.29779717, reconstruction loss: 165.41904230
# Clusters: 1
# Epoch: [100]  time: 20.5438, ELBO_train: 161.44955034, KL_z: 1.75465072, KL_s: 2.29791015, reconstruction loss: 165.50211120
# Clusters: 1
# Epoch: [101]  time: 20.7416, ELBO_train: 161.50547321, KL_z: 1.73692407, KL_s: 2.29780436, reconstruction loss: 165.54020164
# Clusters: 1
# Epoch: [102]  time: 20.9382, ELBO_train: 161.52958855, KL_z: 1.72864758, KL_s: 2.29765106, reconstruction loss: 165.55588719
# Clusters: 1
# Epoch: [103]  time: 21.1373, ELBO_train: 161.59186789, KL_z: 1.72223051, KL_s: 2.29749562, reconstruction loss: 165.61159402
# Clusters: 1
# Epoch: [104]  time: 21.3285, ELBO_train: 161.62405219, KL_z: 1.71275201, KL_s: 2.29733745, reconstruction loss: 165.63414166
# Clusters: 1
# Epoch: [105]  time: 21.5222, ELBO_train: 161.66355250, KL_z: 1.70192128, KL_s: 2.29712620, reconstruction loss: 165.66259998
# Clusters: 1
# Epoch: [106]  time: 21.7189, ELBO_train: 161.72533475, KL_z: 1.69316955, KL_s: 2.29690975, reconstruction loss: 165.71541406
# Clusters: 1
# Epoch: [107]  time: 21.9183, ELBO_train: 161.69327604, KL_z: 1.67774328, KL_s: 2.29666686, reconstruction loss: 165.66768618
# Clusters: 1
# Epoch: [108]  time: 22.1196, ELBO_train: 161.80654731, KL_z: 1.66952956, KL_s: 2.29641836, reconstruction loss: 165.77249523
# Clusters: 1
# Epoch: [109]  time: 22.3148, ELBO_train: 161.82565132, KL_z: 1.66497709, KL_s: 2.29613955, reconstruction loss: 165.78676796
# Clusters: 1
# Epoch: [110]  time: 22.5143, ELBO_train: 161.85309542, KL_z: 1.64840240, KL_s: 2.29576306, reconstruction loss: 165.79726088
# Clusters: 1
# Epoch: [111]  time: 22.7087, ELBO_train: 161.87183615, KL_z: 1.64705674, KL_s: 2.29539732, reconstruction loss: 165.81429020
# Clusters: 1
# Epoch: [112]  time: 22.9099, ELBO_train: 161.94933613, KL_z: 1.64307491, KL_s: 2.29500382, reconstruction loss: 165.88741485
# Clusters: 1
# Epoch: [113]  time: 23.1070, ELBO_train: 161.94837541, KL_z: 1.63587688, KL_s: 2.29451853, reconstruction loss: 165.87877081
# Clusters: 1
# Clusters: 3
# Epoch: [152]  time: 31.5717, ELBO_train: 162.40640670, KL_z: 1.59705972, KL_s: 2.22660056, reconstruction loss: 166.23006697
# Clusters: 3
# Epoch: [153]  time: 31.8013, ELBO_train: 162.33102534, KL_z: 1.58878721, KL_s: 2.19382847, reconstruction loss: 166.11364102
# Clusters: 3
# Epoch: [154]  time: 32.1070, ELBO_train: 162.22063739, KL_z: 1.60409487, KL_s: 2.15520249, reconstruction loss: 165.97993475
# Clusters: 2
# Epoch: [155]  time: 32.3360, ELBO_train: 162.30027067, KL_z: 1.61107500, KL_s: 2.19276250, reconstruction loss: 166.10410817
# Clusters: 2
# Epoch: [156]  time: 32.5508, ELBO_train: 162.35691657, KL_z: 1.62249420, KL_s: 2.20639749, reconstruction loss: 166.18580826
# Clusters: 3
# Epoch: [157]  time: 32.8641, ELBO_train: 162.33666229, KL_z: 1.62572357, KL_s: 2.19743859, reconstruction loss: 166.15982445
# Clusters: 2
# Epoch: [158]  time: 33.1311, ELBO_train: 162.31985826, KL_z: 1.63566186, KL_s: 2.18095752, reconstruction loss: 166.13647764
# Clusters: 2
# Epoch: [159]  time: 33.3913, ELBO_train: 162.36062329, KL_z: 1.62284268, KL_s: 2.20214738, reconstruction loss: 166.18561335
# Clusters: 3
# Epoch: [160]  time: 33.6233, ELBO_train: 162.44010984, KL_z: 1.62486660, KL_s: 2.24273044, reconstruction loss: 166.30770689
# Clusters: 3
# Epoch: [161]  time: 33.8317, ELBO_train: 162.44684660, KL_z: 1.62898429, KL_s: 2.24648376, reconstruction loss: 166.32231464
# Clusters: 3
# Epoch: [162]  time: 34.0496, ELBO_train: 162.45805300, KL_z: 1.63311305, KL_s: 2.24364698, reconstruction loss: 166.33481304
# Clusters: 3
# Epoch: [163]  time: 34.2589, ELBO_train: 162.47783661, KL_z: 1.62728595, KL_s: 2.24051561, reconstruction loss: 166.34563817
# Clusters: 3
# Epoch: [164]  time: 34.4604, ELBO_train: 162.41085111, KL_z: 1.63226947, KL_s: 2.24349424, reconstruction loss: 166.28661482
# Clusters: 4
# Epoch: [165]  time: 34.6640, ELBO_train: 162.49381373, KL_z: 1.63849798, KL_s: 2.24319864, reconstruction loss: 166.37551035
# Clusters: 4
# Epoch: [166]  time: 34.8751, ELBO_train: 162.48715973, KL_z: 1.63753812, KL_s: 2.24303154, reconstruction loss: 166.36772939
# Clusters: 4
# Epoch: [167]  time: 35.0956, ELBO_train: 162.48765329, KL_z: 1.64134899, KL_s: 2.24655028, reconstruction loss: 166.37555256
# Clusters: 4
# Epoch: [168]  time: 35.3065, ELBO_train: 162.46447695, KL_z: 1.64848273, KL_s: 2.24745328, reconstruction loss: 166.36041296
# Clusters: 4
# Epoch: [169]  time: 35.5108, ELBO_train: 162.52502383, KL_z: 1.63970023, KL_s: 2.24933257, reconstruction loss: 166.41405663
# Clusters: 4
# Epoch: [170]  time: 35.7149, ELBO_train: 162.49032065, KL_z: 1.64744983, KL_s: 2.25309068, reconstruction loss: 166.39086115
# Clusters: 4
# Epoch: [171]  time: 35.9333, ELBO_train: 162.51177979, KL_z: 1.65512499, KL_s: 2.25189603, reconstruction loss: 166.41880081
# Clusters: 4
# Epoch: [172]  time: 36.1432, ELBO_train: 162.50854551, KL_z: 1.65373702, KL_s: 2.25075404, reconstruction loss: 166.41303657
# Clusters: 4
# Epoch: [173]  time: 36.3559, ELBO_train: 162.54898658, KL_z: 1.65673642, KL_s: 2.25045776, reconstruction loss: 166.45618077
# Clusters: 4
# Epoch: [174]  time: 36.6697, ELBO_train: 162.48891801, KL_z: 1.65979118, KL_s: 2.25008494, reconstruction loss: 166.39879413
# Clusters: 4
# Epoch: [175]  time: 36.9681, ELBO_train: 162.48014127, KL_z: 1.66198637, KL_s: 2.24660245, reconstruction loss: 166.38873009
# Clusters: 4
# Epoch: [176]  time: 37.2328, ELBO_train: 162.49923647, KL_z: 1.66990340, KL_s: 2.23872279, reconstruction loss: 166.40786266
# Clusters: 4
# Epoch: [177]  time: 37.4976, ELBO_train: 162.53564218, KL_z: 1.66819874, KL_s: 2.23441181, reconstruction loss: 166.43825273
# Clusters: 4
# Epoch: [178]  time: 37.7440, ELBO_train: 162.52671403, KL_z: 1.66659425, KL_s: 2.23307958, reconstruction loss: 166.42638786
# Clusters: 4
# Epoch: [179]  time: 37.9942, ELBO_train: 162.56023231, KL_z: 1.66083324, KL_s: 2.23748689, reconstruction loss: 166.45855244
# Clusters: 4
# Epoch: [180]  time: 38.3715, ELBO_train: 162.56238732, KL_z: 1.66460935, KL_s: 2.24208107, reconstruction loss: 166.46907774
# Clusters: 4
# Epoch: [181]  time: 38.6230, ELBO_train: 162.52518874, KL_z: 1.68047249, KL_s: 2.24390929, reconstruction loss: 166.44957051
# Clusters: 4
# Epoch: [182]  time: 38.8756, ELBO_train: 162.52116629, KL_z: 1.67826627, KL_s: 2.24581748, reconstruction loss: 166.44525004
# Clusters: 4
# Epoch: [183]  time: 39.1076, ELBO_train: 162.57065641, KL_z: 1.67841953, KL_s: 2.24729851, reconstruction loss: 166.49637444
# Clusters: 4
# Epoch: [184]  time: 39.3687, ELBO_train: 162.57951883, KL_z: 1.68246369, KL_s: 2.25432155, reconstruction loss: 166.51630407
# Clusters: 4
# Epoch: [185]  time: 39.7033, ELBO_train: 162.57134071, KL_z: 1.68777536, KL_s: 2.25632868, reconstruction loss: 166.51544475
# Clusters: 4
# Epoch: [186]  time: 39.9834, ELBO_train: 162.54797070, KL_z: 1.69427102, KL_s: 2.25658460, reconstruction loss: 166.49882632
# Clusters: 4
# Epoch: [187]  time: 40.2909, ELBO_train: 162.51956764, KL_z: 1.69364150, KL_s: 2.25701441, reconstruction loss: 166.47022355
# Clusters: 4
# Epoch: [188]  time: 40.5997, ELBO_train: 162.55252134, KL_z: 1.69614148, KL_s: 2.25576797, reconstruction loss: 166.50443079
# Clusters: 4
# Epoch: [189]  time: 40.8804, ELBO_train: 162.54493655, KL_z: 1.70168881, KL_s: 2.25639285, reconstruction loss: 166.50301821
# Clusters: 4
# Epoch: [190]  time: 41.1900, ELBO_train: 162.57758273, KL_z: 1.69924074, KL_s: 2.25793220, reconstruction loss: 166.53475567
# Clusters: 4
# Epoch: [191]  time: 41.4750, ELBO_train: 162.57765961, KL_z: 1.71024367, KL_s: 2.25633066, reconstruction loss: 166.54423394
# Clusters: 4
# Epoch: [192]  time: 41.7451, ELBO_train: 162.60399510, KL_z: 1.71019606, KL_s: 2.25369434, reconstruction loss: 166.56788551
# Clusters: 4
# Epoch: [193]  time: 42.0096, ELBO_train: 162.58426608, KL_z: 1.70803041, KL_s: 2.25371447, reconstruction loss: 166.54601095
# Clusters: 4
# Epoch: [194]  time: 42.2774, ELBO_train: 162.61043783, KL_z: 1.71345491, KL_s: 2.25925949, reconstruction loss: 166.58315223
# Clusters: 4
# Epoch: [195]  time: 42.5591, ELBO_train: 162.57891963, KL_z: 1.71154467, KL_s: 2.26362192, reconstruction loss: 166.55408622
# Clusters: 4
# Epoch: [196]  time: 42.8288, ELBO_train: 162.54533797, KL_z: 1.71760814, KL_s: 2.26321969, reconstruction loss: 166.52616579
# Clusters: 4
# Epoch: [197]  time: 43.1828, ELBO_train: 162.54731809, KL_z: 1.73012080, KL_s: 2.26211617, reconstruction loss: 166.53955505
# Clusters: 4
# Epoch: [198]  time: 43.4959, ELBO_train: 162.57217349, KL_z: 1.74033227, KL_s: 2.26189888, reconstruction loss: 166.57440463
# Clusters: 4
# Epoch: [199]  time: 43.8483, ELBO_train: 162.57504859, KL_z: 1.73339762, KL_s: 2.26120724, reconstruction loss: 166.56965345
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = data_processing.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = statistic.samples_concatenation(samples_list)[-1]
    data_test_transformed = data_processing.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = data_processing.discrete_variables_transformation(est_data_test, feat_types_dict)

# %% [markdown]
# ### Visualize the generated samples

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
estimated_values = est_data_test_transformed

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
