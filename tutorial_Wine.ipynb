# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
from utils import data_processing, visualization, statistic
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "Wine"
m_perc = 10
mask = 1
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data loading and Feature analysis

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = data_processing.read_data(data_file, feat_types_file, miss_file, true_miss_file)

# Feature analysis
data_transformed = data_processing.discrete_variables_transformation(data, feat_types_dict)
features_df = pd.DataFrame(data_transformed, columns=["feat_" + str(i+1) for i in range(data_transformed.shape[1])])

visualization.plot_data(features_df, feat_types_dict)

# %% [markdown]
# ### Experiment setting

# %%
# Train-test split
train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# Adjust batch size if larger than dataset
batch_size = 1000
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 200
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = np.random.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = data_processing.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = statistic.samples_concatenation(samples_list)
    
    # #Transform discrete variables back to the original values
    data_train_transformed = data_processing.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = data_processing.discrete_variables_transformation(est_data_train, feat_types_dict)
    est_data_train_mean_imputed = statistic.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = statistic.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = statistic.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    visualization.print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

visualization.plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
visualization.plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
visualization.plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 10
# Epoch: [ 0]  time: 0.0815, ELBO_train: -14.64008007, KL_z: 1.67356887, KL_s: 0.15499167, reconstruction loss: -12.81151953
# Clusters: 10
# Epoch: [ 1]  time: 0.1370, ELBO_train: -14.31814938, KL_z: 1.48154862, KL_s: 0.14657097, reconstruction loss: -12.69002979
# Clusters: 10
# Epoch: [ 2]  time: 0.1905, ELBO_train: -14.06638393, KL_z: 1.32344339, KL_s: 0.13948073, reconstruction loss: -12.60345981
# Clusters: 10
# Epoch: [ 3]  time: 0.2417, ELBO_train: -13.74918995, KL_z: 1.18729515, KL_s: 0.13355870, reconstruction loss: -12.42833610
# Clusters: 10
# Epoch: [ 4]  time: 0.2947, ELBO_train: -13.60089378, KL_z: 1.07490652, KL_s: 0.12779207, reconstruction loss: -12.39819520
# Clusters: 10
# Epoch: [ 5]  time: 0.3501, ELBO_train: -13.31998043, KL_z: 0.98395290, KL_s: 0.12316198, reconstruction loss: -12.21286554
# Clusters: 10
# Epoch: [ 6]  time: 0.4018, ELBO_train: -13.16540165, KL_z: 0.90907979, KL_s: 0.11924658, reconstruction loss: -12.13707528
# Clusters: 10
# Epoch: [ 7]  time: 0.4559, ELBO_train: -13.00044594, KL_z: 0.85060657, KL_s: 0.11584520, reconstruction loss: -12.03399416
# Clusters: 10
# Epoch: [ 8]  time: 0.5108, ELBO_train: -12.87674789, KL_z: 0.80336274, KL_s: 0.11251421, reconstruction loss: -11.96087095
# Clusters: 10
# Epoch: [ 9]  time: 0.5603, ELBO_train: -12.73207741, KL_z: 0.76778445, KL_s: 0.11090999, reconstruction loss: -11.85338297
# Clusters: 10
# Epoch: [10]  time: 0.6144, ELBO_train: -12.54847641, KL_z: 0.74008465, KL_s: 0.10884886, reconstruction loss: -11.69954290
# Clusters: 10
# Epoch: [11]  time: 0.6642, ELBO_train: -12.46258316, KL_z: 0.72085665, KL_s: 0.10735211, reconstruction loss: -11.63437439
# Clusters: 10
# Epoch: [12]  time: 0.7175, ELBO_train: -12.40810013, KL_z: 0.70808413, KL_s: 0.10634494, reconstruction loss: -11.59367106
# Clusters: 10
# Epoch: [13]  time: 0.7714, ELBO_train: -12.21603470, KL_z: 0.70116946, KL_s: 0.10566993, reconstruction loss: -11.40919532
# Clusters: 10
# Epoch: [14]  time: 0.8252, ELBO_train: -12.14446507, KL_z: 0.69889821, KL_s: 0.10504432, reconstruction loss: -11.34052254
# Clusters: 10
# Epoch: [15]  time: 0.8792, ELBO_train: -11.98210030, KL_z: 0.70190976, KL_s: 0.10469165, reconstruction loss: -11.17549889
# Clusters: 10
# Epoch: [16]  time: 0.9372, ELBO_train: -11.90757408, KL_z: 0.71109396, KL_s: 0.10470939, reconstruction loss: -11.09177073
# Clusters: 10
# Epoch: [17]  time: 0.9894, ELBO_train: -11.75569038, KL_z: 0.72177902, KL_s: 0.10481591, reconstruction loss: -10.92909545
# Clusters: 10
# Epoch: [18]  time: 1.0395, ELBO_train: -11.62514973, KL_z: 0.73793809, KL_s: 0.10530086, reconstruction loss: -10.78191078
# Clusters: 10
# Epoch: [19]  time: 1.0918, ELBO_train: -11.45546455, KL_z: 0.75847102, KL_s: 0.10547142, reconstruction loss: -10.59152211
# Clusters: 10
# Epoch: [20]  time: 1.1444, ELBO_train: -11.36230450, KL_z: 0.78015621, KL_s: 0.10592322, reconstruction loss: -10.47622507
# Clusters: 10
# Epoch: [21]  time: 1.1955, ELBO_train: -11.28020000, KL_z: 0.80221587, KL_s: 0.10697231, reconstruction loss: -10.37101182
# Clusters: 10
# Epoch: [22]  time: 1.2450, ELBO_train: -11.16546860, KL_z: 0.83212737, KL_s: 0.10764804, reconstruction loss: -10.22569319
# Clusters: 10
# Epoch: [23]  time: 1.3053, ELBO_train: -11.08428288, KL_z: 0.85815955, KL_s: 0.10857177, reconstruction loss: -10.11755155
# Clusters: 10
# Epoch: [24]  time: 1.3558, ELBO_train: -10.91100864, KL_z: 0.89099796, KL_s: 0.11002612, reconstruction loss: -9.90998456
# Clusters: 10
# Epoch: [25]  time: 1.4106, ELBO_train: -10.80053654, KL_z: 0.92362790, KL_s: 0.11130629, reconstruction loss: -9.76560235
# Clusters: 10
# Epoch: [26]  time: 1.4620, ELBO_train: -10.63852825, KL_z: 0.95564080, KL_s: 0.11288967, reconstruction loss: -9.56999778
# Clusters: 10
# Epoch: [27]  time: 1.5155, ELBO_train: -10.54815521, KL_z: 0.98932470, KL_s: 0.11440325, reconstruction loss: -9.44442726
# Clusters: 10
# Epoch: [28]  time: 1.5628, ELBO_train: -10.41334438, KL_z: 1.02264783, KL_s: 0.11583643, reconstruction loss: -9.27486012
# Clusters: 10
# Epoch: [29]  time: 1.6128, ELBO_train: -10.24907799, KL_z: 1.05752959, KL_s: 0.11735749, reconstruction loss: -9.07419090
# Clusters: 10
# Epoch: [30]  time: 1.6586, ELBO_train: -10.16450348, KL_z: 1.08114414, KL_s: 0.11895485, reconstruction loss: -8.96440449
# Clusters: 10
# Epoch: [31]  time: 1.7064, ELBO_train: -10.04964180, KL_z: 1.10239036, KL_s: 0.12074747, reconstruction loss: -8.82650397
# Clusters: 10
# Epoch: [32]  time: 1.7713, ELBO_train: -9.87123661, KL_z: 1.12714624, KL_s: 0.12239375, reconstruction loss: -8.62169662
# Clusters: 10
# Epoch: [33]  time: 1.8283, ELBO_train: -9.69836082, KL_z: 1.14757738, KL_s: 0.12449236, reconstruction loss: -8.42629108
# Clusters: 10
# Epoch: [34]  time: 1.8769, ELBO_train: -9.69026489, KL_z: 1.17100694, KL_s: 0.12711143, reconstruction loss: -8.39214652
# Clusters: 10
# Epoch: [35]  time: 1.9437, ELBO_train: -9.55124073, KL_z: 1.18897576, KL_s: 0.12940454, reconstruction loss: -8.23286042
# Clusters: 10
# Epoch: [36]  time: 1.9941, ELBO_train: -9.36062183, KL_z: 1.20740511, KL_s: 0.13150659, reconstruction loss: -8.02171013
# Clusters: 10
# Epoch: [37]  time: 2.0478, ELBO_train: -9.28179588, KL_z: 1.22667468, KL_s: 0.13401952, reconstruction loss: -7.92110169
# Clusters: 10
# Epoch: [38]  time: 2.1018, ELBO_train: -9.19361057, KL_z: 1.24394891, KL_s: 0.13618245, reconstruction loss: -7.81347921
# Clusters: 10
# Epoch: [39]  time: 2.1611, ELBO_train: -9.10149097, KL_z: 1.26078732, KL_s: 0.13836503, reconstruction loss: -7.70233862
# Clusters: 10
# Epoch: [40]  time: 2.2164, ELBO_train: -8.94549961, KL_z: 1.27682884, KL_s: 0.14042568, reconstruction loss: -7.52824509
# Clusters: 10
# Epoch: [41]  time: 2.2788, ELBO_train: -8.79501915, KL_z: 1.29584763, KL_s: 0.14306703, reconstruction loss: -7.35610449
# Clusters: 10
# Epoch: [42]  time: 2.3293, ELBO_train: -8.70853939, KL_z: 1.30952406, KL_s: 0.14540777, reconstruction loss: -7.25360756
# Clusters: 9
# Epoch: [43]  time: 2.3786, ELBO_train: -8.59474182, KL_z: 1.31299479, KL_s: 0.14719310, reconstruction loss: -7.13455393
# Clusters: 10
# Epoch: [44]  time: 2.4357, ELBO_train: -8.39766502, KL_z: 1.32130315, KL_s: 0.15001302, reconstruction loss: -6.92634885
# Clusters: 10
# Epoch: [45]  time: 2.4829, ELBO_train: -8.35925102, KL_z: 1.32063749, KL_s: 0.15206852, reconstruction loss: -6.88654501
# Clusters: 10
# Epoch: [46]  time: 2.5346, ELBO_train: -8.26006145, KL_z: 1.32848859, KL_s: 0.15390997, reconstruction loss: -6.77766290
# Clusters: 10
# Epoch: [47]  time: 2.5848, ELBO_train: -8.25091248, KL_z: 1.32881145, KL_s: 0.15524988, reconstruction loss: -6.76685114
# Clusters: 10
# Epoch: [48]  time: 2.6298, ELBO_train: -8.13079443, KL_z: 1.34606688, KL_s: 0.15778055, reconstruction loss: -6.62694700
# Clusters: 10
# Epoch: [49]  time: 2.6745, ELBO_train: -7.94343662, KL_z: 1.36815503, KL_s: 0.16003084, reconstruction loss: -6.41525075
# Clusters: 10
# Epoch: [50]  time: 2.7176, ELBO_train: -7.96741343, KL_z: 1.37772329, KL_s: 0.16181798, reconstruction loss: -6.42787216
# Clusters: 10
# Epoch: [51]  time: 2.7685, ELBO_train: -7.81669197, KL_z: 1.37984910, KL_s: 0.16389318, reconstruction loss: -6.27294970
# Clusters: 10
# Epoch: [52]  time: 2.8166, ELBO_train: -7.75051050, KL_z: 1.38884423, KL_s: 0.16618347, reconstruction loss: -6.19548280
# Clusters: 10
# Epoch: [53]  time: 2.8690, ELBO_train: -7.61844578, KL_z: 1.39221737, KL_s: 0.16838980, reconstruction loss: -6.05783861
# Clusters: 10
# Epoch: [54]  time: 2.9172, ELBO_train: -7.54774294, KL_z: 1.39149067, KL_s: 0.17070322, reconstruction loss: -5.98554904
# Clusters: 10
# Epoch: [55]  time: 2.9606, ELBO_train: -7.44644127, KL_z: 1.39810116, KL_s: 0.17287564, reconstruction loss: -5.87546446
# Clusters: 10
# Epoch: [56]  time: 3.0101, ELBO_train: -7.40462551, KL_z: 1.40088222, KL_s: 0.17515159, reconstruction loss: -5.82859170
# Clusters: 10
# Epoch: [57]  time: 3.0619, ELBO_train: -7.27295580, KL_z: 1.40862360, KL_s: 0.17721190, reconstruction loss: -5.68712029
# Clusters: 10
# Epoch: [58]  time: 3.1357, ELBO_train: -7.23508415, KL_z: 1.41246815, KL_s: 0.18011694, reconstruction loss: -5.64249907
# Clusters: 9
# Epoch: [59]  time: 3.1807, ELBO_train: -7.14148188, KL_z: 1.41095660, KL_s: 0.18224297, reconstruction loss: -5.54828231
# Clusters: 9
# Epoch: [60]  time: 3.2246, ELBO_train: -7.04748907, KL_z: 1.40991662, KL_s: 0.18355079, reconstruction loss: -5.45402167
# Clusters: 9
# Epoch: [61]  time: 3.2719, ELBO_train: -6.97345238, KL_z: 1.42821136, KL_s: 0.18528590, reconstruction loss: -5.35995512
# Clusters: 9
# Epoch: [62]  time: 3.3150, ELBO_train: -6.89924335, KL_z: 1.42311661, KL_s: 0.18595586, reconstruction loss: -5.29017088
# Clusters: 9
# Epoch: [63]  time: 3.3729, ELBO_train: -6.87428179, KL_z: 1.42227218, KL_s: 0.18767715, reconstruction loss: -5.26433246
# Clusters: 9
# Epoch: [64]  time: 3.4211, ELBO_train: -6.79271908, KL_z: 1.42305968, KL_s: 0.18965168, reconstruction loss: -5.18000772
# Clusters: 9
# Epoch: [65]  time: 3.4731, ELBO_train: -6.76388597, KL_z: 1.42002366, KL_s: 0.19074383, reconstruction loss: -5.15311849
# Clusters: 9
# Epoch: [66]  time: 3.5200, ELBO_train: -6.66116838, KL_z: 1.43820717, KL_s: 0.19199615, reconstruction loss: -5.03096507
# Clusters: 9
# Epoch: [67]  time: 3.5670, ELBO_train: -6.62747602, KL_z: 1.42752838, KL_s: 0.19268146, reconstruction loss: -5.00726619
# Clusters: 9
# Epoch: [68]  time: 3.6139, ELBO_train: -6.51684828, KL_z: 1.42960100, KL_s: 0.19378033, reconstruction loss: -4.89346695
# Clusters: 9
# Epoch: [69]  time: 3.6572, ELBO_train: -6.43015709, KL_z: 1.42050304, KL_s: 0.19386253, reconstruction loss: -4.81579151
# Clusters: 9
# Epoch: [70]  time: 3.7038, ELBO_train: -6.45484800, KL_z: 1.42547548, KL_s: 0.19496036, reconstruction loss: -4.83441217
# Clusters: 9
# Epoch: [71]  time: 3.7469, ELBO_train: -6.35415154, KL_z: 1.42400725, KL_s: 0.19587488, reconstruction loss: -4.73426940
# Clusters: 10
# Epoch: [72]  time: 3.7972, ELBO_train: -6.32562113, KL_z: 1.42821052, KL_s: 0.19668241, reconstruction loss: -4.70072820
# Clusters: 9
# Epoch: [73]  time: 3.8455, ELBO_train: -6.34295321, KL_z: 1.43526254, KL_s: 0.19847541, reconstruction loss: -4.70921526
# Clusters: 10
# Epoch: [74]  time: 3.8938, ELBO_train: -6.23589954, KL_z: 1.44042003, KL_s: 0.20081191, reconstruction loss: -4.59466760
# Clusters: 10
# Epoch: [75]  time: 3.9392, ELBO_train: -6.18677492, KL_z: 1.44079971, KL_s: 0.20208201, reconstruction loss: -4.54389319
# Clusters: 10
# Epoch: [76]  time: 3.9851, ELBO_train: -6.13003826, KL_z: 1.44256847, KL_s: 0.20380421, reconstruction loss: -4.48366559
# Clusters: 9
# Epoch: [77]  time: 4.0342, ELBO_train: -6.10593452, KL_z: 1.42784302, KL_s: 0.20558548, reconstruction loss: -4.47250602
# Clusters: 10
# Epoch: [78]  time: 4.0819, ELBO_train: -6.09273052, KL_z: 1.42469847, KL_s: 0.20639215, reconstruction loss: -4.46163990
# Clusters: 10
# Epoch: [79]  time: 4.1289, ELBO_train: -6.01175919, KL_z: 1.42325509, KL_s: 0.20756230, reconstruction loss: -4.38094180
# Clusters: 10
# Epoch: [80]  time: 4.1762, ELBO_train: -6.02568245, KL_z: 1.42797697, KL_s: 0.20815964, reconstruction loss: -4.38954585
# Clusters: 10
# Epoch: [81]  time: 4.2221, ELBO_train: -5.97440662, KL_z: 1.42366931, KL_s: 0.21056094, reconstruction loss: -4.34017637
# Clusters: 10
# Epoch: [82]  time: 4.2692, ELBO_train: -5.89566393, KL_z: 1.42855754, KL_s: 0.21167188, reconstruction loss: -4.25543451
# Clusters: 10
# Epoch: [83]  time: 4.3151, ELBO_train: -5.83095255, KL_z: 1.43049586, KL_s: 0.21393809, reconstruction loss: -4.18651860
# Clusters: 10
# Epoch: [84]  time: 4.3602, ELBO_train: -5.85882435, KL_z: 1.42853401, KL_s: 0.21495996, reconstruction loss: -4.21533039
# Clusters: 10
# Epoch: [85]  time: 4.4064, ELBO_train: -5.80860777, KL_z: 1.41705644, KL_s: 0.21583610, reconstruction loss: -4.17571523
# Clusters: 10
# Epoch: [86]  time: 4.4526, ELBO_train: -5.77280416, KL_z: 1.41570179, KL_s: 0.21709685, reconstruction loss: -4.14000552
# Clusters: 10
# Epoch: [87]  time: 4.5001, ELBO_train: -5.68664141, KL_z: 1.40954466, KL_s: 0.21958990, reconstruction loss: -4.05750685
# Clusters: 10
# Epoch: [88]  time: 4.5476, ELBO_train: -5.66592960, KL_z: 1.41098452, KL_s: 0.22150521, reconstruction loss: -4.03343987
# Clusters: 10
# Epoch: [89]  time: 4.5965, ELBO_train: -5.66324568, KL_z: 1.39565504, KL_s: 0.22294879, reconstruction loss: -4.04464185
# Clusters: 10
# Epoch: [90]  time: 4.6453, ELBO_train: -5.57862959, KL_z: 1.39401343, KL_s: 0.22500782, reconstruction loss: -3.95960834
# Clusters: 10
# Epoch: [91]  time: 4.6960, ELBO_train: -5.63514519, KL_z: 1.40031068, KL_s: 0.22522702, reconstruction loss: -4.00960748
# Clusters: 10
# Epoch: [92]  time: 4.7469, ELBO_train: -5.61591291, KL_z: 1.39690278, KL_s: 0.22481046, reconstruction loss: -3.99419968
# Clusters: 10
# Epoch: [93]  time: 4.7933, ELBO_train: -5.56874580, KL_z: 1.40124218, KL_s: 0.22562675, reconstruction loss: -3.94187686
# Clusters: 10
# Epoch: [94]  time: 4.8449, ELBO_train: -5.54457893, KL_z: 1.40362413, KL_s: 0.22642031, reconstruction loss: -3.91453450
# Clusters: 10
# Epoch: [95]  time: 4.8905, ELBO_train: -5.46081266, KL_z: 1.40062826, KL_s: 0.22682314, reconstruction loss: -3.83336127
# Clusters: 10
# Epoch: [96]  time: 4.9375, ELBO_train: -5.45975475, KL_z: 1.39258029, KL_s: 0.22555475, reconstruction loss: -3.84161971
# Clusters: 10
# Epoch: [97]  time: 4.9852, ELBO_train: -5.46985750, KL_z: 1.39164643, KL_s: 0.22601380, reconstruction loss: -3.85219727
# Clusters: 10
# Epoch: [98]  time: 5.0319, ELBO_train: -5.37067251, KL_z: 1.37955990, KL_s: 0.22624855, reconstruction loss: -3.76486406
# Clusters: 10
# Epoch: [99]  time: 5.0788, ELBO_train: -5.36337023, KL_z: 1.38792496, KL_s: 0.22710252, reconstruction loss: -3.74834275
# Clusters: 10
# Epoch: [100]  time: 5.1227, ELBO_train: -5.37229061, KL_z: 1.38765118, KL_s: 0.22451406, reconstruction loss: -3.76012537
# Clusters: 10
# Epoch: [101]  time: 5.1691, ELBO_train: -5.35716639, KL_z: 1.38294170, KL_s: 0.22151666, reconstruction loss: -3.75270803
# Clusters: 10
# Epoch: [102]  time: 5.2135, ELBO_train: -5.36948452, KL_z: 1.38952518, KL_s: 0.21808167, reconstruction loss: -3.76187768
# Clusters: 10
# Epoch: [103]  time: 5.2624, ELBO_train: -5.34084816, KL_z: 1.39890237, KL_s: 0.21677976, reconstruction loss: -3.72516603
# Clusters: 10
# Epoch: [104]  time: 5.3098, ELBO_train: -5.34206285, KL_z: 1.40910308, KL_s: 0.21312761, reconstruction loss: -3.71983216
# Clusters: 10
# Epoch: [105]  time: 5.3569, ELBO_train: -5.22020102, KL_z: 1.40864799, KL_s: 0.21277795, reconstruction loss: -3.59877508
# Clusters: 10
# Epoch: [106]  time: 5.4039, ELBO_train: -5.20638971, KL_z: 1.40027990, KL_s: 0.21124091, reconstruction loss: -3.59486890
# Clusters: 10
# Epoch: [107]  time: 5.4518, ELBO_train: -5.28372078, KL_z: 1.40368989, KL_s: 0.20870423, reconstruction loss: -3.67132666
# Clusters: 10
# Epoch: [108]  time: 5.4987, ELBO_train: -5.26953564, KL_z: 1.40334995, KL_s: 0.20731211, reconstruction loss: -3.65887358
# Clusters: 10
# Epoch: [109]  time: 5.5441, ELBO_train: -5.21838179, KL_z: 1.41332066, KL_s: 0.20608487, reconstruction loss: -3.59897625
# Clusters: 10
# Epoch: [110]  time: 5.5925, ELBO_train: -5.24521437, KL_z: 1.41329367, KL_s: 0.20474868, reconstruction loss: -3.62717202
# Clusters: 10
# Epoch: [111]  time: 5.6427, ELBO_train: -5.17885342, KL_z: 1.40958102, KL_s: 0.20371261, reconstruction loss: -3.56555979
# Clusters: 10
# Epoch: [112]  time: 5.6864, ELBO_train: -5.15435991, KL_z: 1.39797626, KL_s: 0.20352006, reconstruction loss: -3.55286360
# Clusters: 10
# Epoch: [113]  time: 5.7341, ELBO_train: -5.15569010, KL_z: 1.39775052, KL_s: 0.20443535, reconstruction loss: -3.55350423
# Clusters: 10
# Epoch: [114]  time: 5.7810, ELBO_train: -5.12946196, KL_z: 1.39109848, KL_s: 0.20397506, reconstruction loss: -3.53438842
# Clusters: 10
# Epoch: [115]  time: 5.8279, ELBO_train: -5.07866373, KL_z: 1.39006538, KL_s: 0.20352206, reconstruction loss: -3.48507628
# Clusters: 10
# Epoch: [116]  time: 5.8753, ELBO_train: -5.10659971, KL_z: 1.38468716, KL_s: 0.20355854, reconstruction loss: -3.51835401
# Clusters: 10
# Epoch: [117]  time: 5.9212, ELBO_train: -5.09233923, KL_z: 1.39496789, KL_s: 0.20466094, reconstruction loss: -3.49271040
# Clusters: 10
# Epoch: [118]  time: 5.9695, ELBO_train: -5.05434275, KL_z: 1.37465851, KL_s: 0.20590062, reconstruction loss: -3.47378361
# Clusters: 10
# Epoch: [119]  time: 6.0138, ELBO_train: -5.06943893, KL_z: 1.37339582, KL_s: 0.20702248, reconstruction loss: -3.48902063
# Clusters: 10
# Epoch: [120]  time: 6.0592, ELBO_train: -5.07101641, KL_z: 1.38556821, KL_s: 0.20689864, reconstruction loss: -3.47854955
# Clusters: 10
# Epoch: [121]  time: 6.1162, ELBO_train: -5.05730543, KL_z: 1.39187477, KL_s: 0.20517316, reconstruction loss: -3.46025751
# Clusters: 10
# Epoch: [122]  time: 6.1768, ELBO_train: -5.03326702, KL_z: 1.38745532, KL_s: 0.20390234, reconstruction loss: -3.44190936
# Clusters: 10
# Epoch: [123]  time: 6.2314, ELBO_train: -4.99339304, KL_z: 1.39839964, KL_s: 0.20294957, reconstruction loss: -3.39204383
# Clusters: 10
# Epoch: [124]  time: 6.2824, ELBO_train: -5.05575752, KL_z: 1.39715955, KL_s: 0.20091224, reconstruction loss: -3.45768573
# Clusters: 10
# Epoch: [125]  time: 6.3333, ELBO_train: -5.00897465, KL_z: 1.39920321, KL_s: 0.20014157, reconstruction loss: -3.40962987
# Clusters: 10
# Epoch: [126]  time: 6.3814, ELBO_train: -4.95183229, KL_z: 1.39866903, KL_s: 0.20072522, reconstruction loss: -3.35243804
# Clusters: 10
# Epoch: [127]  time: 6.4309, ELBO_train: -4.99330912, KL_z: 1.39897134, KL_s: 0.20176334, reconstruction loss: -3.39257443
# Clusters: 10
# Epoch: [128]  time: 6.4775, ELBO_train: -4.96688833, KL_z: 1.38131526, KL_s: 0.20336504, reconstruction loss: -3.38220804
# Clusters: 10
# Epoch: [129]  time: 6.5263, ELBO_train: -4.92581959, KL_z: 1.38151205, KL_s: 0.20373273, reconstruction loss: -3.34057481
# Clusters: 10
# Epoch: [130]  time: 6.5757, ELBO_train: -4.98909874, KL_z: 1.38744488, KL_s: 0.20369482, reconstruction loss: -3.39795904
# Clusters: 10
# Epoch: [131]  time: 6.6259, ELBO_train: -4.94258232, KL_z: 1.37133405, KL_s: 0.20327783, reconstruction loss: -3.36797044
# Clusters: 10
# Epoch: [132]  time: 6.6748, ELBO_train: -4.92475348, KL_z: 1.36514180, KL_s: 0.20353251, reconstruction loss: -3.35607917
# Clusters: 10
# Epoch: [133]  time: 6.7296, ELBO_train: -4.81947174, KL_z: 1.36281753, KL_s: 0.20250287, reconstruction loss: -3.25415134
# Clusters: 10
# Epoch: [134]  time: 6.7851, ELBO_train: -4.89445581, KL_z: 1.36378498, KL_s: 0.20126982, reconstruction loss: -3.32940102
# Clusters: 10
# Epoch: [135]  time: 6.8446, ELBO_train: -4.86897755, KL_z: 1.36827052, KL_s: 0.20017810, reconstruction loss: -3.30052893
# Clusters: 10
# Epoch: [136]  time: 6.8996, ELBO_train: -4.83300495, KL_z: 1.35952482, KL_s: 0.19896059, reconstruction loss: -3.27451954
# Clusters: 10
# Epoch: [137]  time: 6.9512, ELBO_train: -4.84662209, KL_z: 1.35567482, KL_s: 0.19771771, reconstruction loss: -3.29322956
# Clusters: 10
# Epoch: [138]  time: 7.0060, ELBO_train: -4.87897615, KL_z: 1.35916820, KL_s: 0.19622416, reconstruction loss: -3.32358379
# Clusters: 10
# Epoch: [139]  time: 7.0640, ELBO_train: -4.87656231, KL_z: 1.37548394, KL_s: 0.19596686, reconstruction loss: -3.30511150
# Clusters: 10
# Epoch: [140]  time: 7.1216, ELBO_train: -4.79783506, KL_z: 1.36842089, KL_s: 0.19602933, reconstruction loss: -3.23338485
# Clusters: 10
# Epoch: [141]  time: 7.1755, ELBO_train: -4.81466265, KL_z: 1.37271316, KL_s: 0.19665709, reconstruction loss: -3.24529240
# Clusters: 10
# Epoch: [142]  time: 7.2280, ELBO_train: -4.74450560, KL_z: 1.37461154, KL_s: 0.19597278, reconstruction loss: -3.17392128
# Clusters: 10
# Epoch: [143]  time: 7.2848, ELBO_train: -4.80953007, KL_z: 1.36499791, KL_s: 0.19529300, reconstruction loss: -3.24923916
# Clusters: 10
# Epoch: [144]  time: 7.3400, ELBO_train: -4.84005594, KL_z: 1.36835961, KL_s: 0.19407048, reconstruction loss: -3.27762585
# Clusters: 10
# Epoch: [145]  time: 7.3941, ELBO_train: -4.80411654, KL_z: 1.37741771, KL_s: 0.19403987, reconstruction loss: -3.23265896
# Clusters: 10
# Epoch: [146]  time: 7.4512, ELBO_train: -4.83832617, KL_z: 1.37629066, KL_s: 0.19398537, reconstruction loss: -3.26805015
# Clusters: 10
# Epoch: [147]  time: 7.5157, ELBO_train: -4.81540604, KL_z: 1.37831500, KL_s: 0.19376435, reconstruction loss: -3.24332669
# Clusters: 10
# Epoch: [148]  time: 7.5735, ELBO_train: -4.74661751, KL_z: 1.37951231, KL_s: 0.19333568, reconstruction loss: -3.17376952
# Clusters: 10
# Epoch: [149]  time: 7.6362, ELBO_train: -4.80199947, KL_z: 1.36920257, KL_s: 0.19359479, reconstruction loss: -3.23920212
# Clusters: 10
# Epoch: [150]  time: 7.6901, ELBO_train: -4.80275888, KL_z: 1.37386866, KL_s: 0.19347062, reconstruction loss: -3.23541961
# Clusters: 10
# Epoch: [151]  time: 7.7506, ELBO_train: -4.76492920, KL_z: 1.37267356, KL_s: 0.19246373, reconstruction loss: -3.19979191
# Clusters: 10
# Epoch: [152]  time: 7.8005, ELBO_train: -4.76906433, KL_z: 1.38571179, KL_s: 0.19116697, reconstruction loss: -3.19218557
# Clusters: 10
# Epoch: [153]  time: 7.8562, ELBO_train: -4.73877764, KL_z: 1.38238149, KL_s: 0.19064345, reconstruction loss: -3.16575270
# Clusters: 10
# Epoch: [154]  time: 7.9071, ELBO_train: -4.75897903, KL_z: 1.39081168, KL_s: 0.19067330, reconstruction loss: -3.17749405
# Clusters: 10
# Epoch: [155]  time: 7.9701, ELBO_train: -4.71055975, KL_z: 1.38059719, KL_s: 0.19094028, reconstruction loss: -3.13902228
# Clusters: 10
# Epoch: [156]  time: 8.0944, ELBO_train: -4.71904917, KL_z: 1.36819286, KL_s: 0.19103079, reconstruction loss: -3.15982552
# Clusters: 10
# Epoch: [157]  time: 8.1536, ELBO_train: -4.73885307, KL_z: 1.37017081, KL_s: 0.19168911, reconstruction loss: -3.17699316
# Clusters: 10
# Epoch: [158]  time: 8.2126, ELBO_train: -4.73633871, KL_z: 1.37842216, KL_s: 0.19202132, reconstruction loss: -3.16589522
# Clusters: 10
# Epoch: [159]  time: 8.2712, ELBO_train: -4.77481394, KL_z: 1.39417863, KL_s: 0.19177327, reconstruction loss: -3.18886204
# Clusters: 10
# Epoch: [160]  time: 8.3216, ELBO_train: -4.70086479, KL_z: 1.38566854, KL_s: 0.19279971, reconstruction loss: -3.12239654
# Clusters: 10
# Epoch: [161]  time: 8.3769, ELBO_train: -4.72451344, KL_z: 1.39454229, KL_s: 0.19330444, reconstruction loss: -3.13666670
# Clusters: 10
# Epoch: [162]  time: 8.4347, ELBO_train: -4.68716555, KL_z: 1.38534348, KL_s: 0.19470739, reconstruction loss: -3.10711467
# Clusters: 10
# Epoch: [163]  time: 8.4928, ELBO_train: -4.72882013, KL_z: 1.37356641, KL_s: 0.19644589, reconstruction loss: -3.15880783
# Clusters: 10
# Epoch: [164]  time: 8.5536, ELBO_train: -4.67094173, KL_z: 1.36666956, KL_s: 0.19785547, reconstruction loss: -3.10641670
# Clusters: 10
# Epoch: [165]  time: 8.6123, ELBO_train: -4.73658428, KL_z: 1.37329354, KL_s: 0.19839964, reconstruction loss: -3.16489110
# Clusters: 10
# Epoch: [166]  time: 8.6675, ELBO_train: -4.66539555, KL_z: 1.37126350, KL_s: 0.19879627, reconstruction loss: -3.09533577
# Clusters: 10
# Epoch: [167]  time: 8.7235, ELBO_train: -4.65397844, KL_z: 1.37258081, KL_s: 0.20062222, reconstruction loss: -3.08077540
# Clusters: 10
# Epoch: [168]  time: 8.7768, ELBO_train: -4.66943159, KL_z: 1.35724161, KL_s: 0.20111022, reconstruction loss: -3.11107976
# Clusters: 10
# Epoch: [169]  time: 8.8382, ELBO_train: -4.59905844, KL_z: 1.35737524, KL_s: 0.20099974, reconstruction loss: -3.04068346
# Clusters: 10
# Epoch: [170]  time: 8.8930, ELBO_train: -4.66336832, KL_z: 1.34747901, KL_s: 0.20010276, reconstruction loss: -3.11578655
# Clusters: 10
# Epoch: [171]  time: 8.9473, ELBO_train: -4.61456032, KL_z: 1.34830487, KL_s: 0.20013113, reconstruction loss: -3.06612432
# Clusters: 10
# Epoch: [172]  time: 9.0025, ELBO_train: -4.68139362, KL_z: 1.34923742, KL_s: 0.20096245, reconstruction loss: -3.13119376
# Clusters: 10
# Epoch: [173]  time: 9.0644, ELBO_train: -4.63665009, KL_z: 1.35379162, KL_s: 0.20156236, reconstruction loss: -3.08129611
# Clusters: 10
# Epoch: [174]  time: 9.1335, ELBO_train: -4.62854023, KL_z: 1.35299270, KL_s: 0.20209727, reconstruction loss: -3.07345026
# Clusters: 10
# Epoch: [175]  time: 9.1897, ELBO_train: -4.63343925, KL_z: 1.35389044, KL_s: 0.20085716, reconstruction loss: -3.07869165
# Clusters: 10
# Epoch: [176]  time: 9.2498, ELBO_train: -4.66661539, KL_z: 1.36361368, KL_s: 0.19945488, reconstruction loss: -3.10354683
# Clusters: 10
# Epoch: [177]  time: 9.3069, ELBO_train: -4.55603809, KL_z: 1.36874259, KL_s: 0.19791555, reconstruction loss: -2.98937995
# Clusters: 10
# Epoch: [178]  time: 9.3662, ELBO_train: -4.60896502, KL_z: 1.35079250, KL_s: 0.19622316, reconstruction loss: -3.06194935
# Clusters: 10
# Epoch: [179]  time: 9.4216, ELBO_train: -4.56636543, KL_z: 1.34905560, KL_s: 0.19641871, reconstruction loss: -3.02089112
# Clusters: 10
# Epoch: [180]  time: 9.4767, ELBO_train: -4.63540411, KL_z: 1.36195276, KL_s: 0.19775190, reconstruction loss: -3.07569945
# Clusters: 10
# Epoch: [181]  time: 9.5318, ELBO_train: -4.60991774, KL_z: 1.35507610, KL_s: 0.19849858, reconstruction loss: -3.05634305
# Clusters: 10
# Epoch: [182]  time: 9.5893, ELBO_train: -4.59297342, KL_z: 1.35149608, KL_s: 0.19916873, reconstruction loss: -3.04230862
# Clusters: 10
# Epoch: [183]  time: 9.6460, ELBO_train: -4.60552053, KL_z: 1.35236943, KL_s: 0.19956069, reconstruction loss: -3.05359042
# Clusters: 10
# Epoch: [184]  time: 9.6989, ELBO_train: -4.62627726, KL_z: 1.36978168, KL_s: 0.20062132, reconstruction loss: -3.05587425
# Clusters: 10
# Epoch: [185]  time: 9.7551, ELBO_train: -4.64652023, KL_z: 1.35379918, KL_s: 0.20244474, reconstruction loss: -3.09027631
# Clusters: 10
# Epoch: [186]  time: 9.8097, ELBO_train: -4.55722113, KL_z: 1.34168751, KL_s: 0.20336151, reconstruction loss: -3.01217210
# Clusters: 10
# Epoch: [187]  time: 9.8662, ELBO_train: -4.52131739, KL_z: 1.35354521, KL_s: 0.20395732, reconstruction loss: -2.96381485
# Clusters: 10
# Epoch: [188]  time: 9.9220, ELBO_train: -4.59999962, KL_z: 1.36080763, KL_s: 0.20479751, reconstruction loss: -3.03439448
# Clusters: 10
# Epoch: [189]  time: 9.9778, ELBO_train: -4.53842478, KL_z: 1.35055237, KL_s: 0.20610108, reconstruction loss: -2.98177133
# Clusters: 10
# Epoch: [190]  time: 10.0366, ELBO_train: -4.65221186, KL_z: 1.35290129, KL_s: 0.20527534, reconstruction loss: -3.09403522
# Clusters: 10
# Epoch: [191]  time: 10.0935, ELBO_train: -4.52839842, KL_z: 1.34684403, KL_s: 0.20553102, reconstruction loss: -2.97602336
# Clusters: 10
# Epoch: [192]  time: 10.1449, ELBO_train: -4.50928926, KL_z: 1.35222769, KL_s: 0.20540662, reconstruction loss: -2.95165496
# Clusters: 10
# Epoch: [193]  time: 10.2018, ELBO_train: -4.55851326, KL_z: 1.36177034, KL_s: 0.20788388, reconstruction loss: -2.98885903
# Clusters: 10
# Epoch: [194]  time: 10.2562, ELBO_train: -4.57864981, KL_z: 1.34972198, KL_s: 0.21122785, reconstruction loss: -3.01769998
# Clusters: 10
# Epoch: [195]  time: 10.3073, ELBO_train: -4.51618490, KL_z: 1.33668294, KL_s: 0.21313777, reconstruction loss: -2.96636419
# Clusters: 10
# Epoch: [196]  time: 10.3584, ELBO_train: -4.56237154, KL_z: 1.33589096, KL_s: 0.21392899, reconstruction loss: -3.01255159
# Clusters: 10
# Epoch: [197]  time: 10.4120, ELBO_train: -4.56579247, KL_z: 1.34309819, KL_s: 0.21563172, reconstruction loss: -3.00706255
# Clusters: 10
# Epoch: [198]  time: 10.4681, ELBO_train: -4.53117695, KL_z: 1.33314590, KL_s: 0.21846013, reconstruction loss: -2.97957091
# Clusters: 10
# Epoch: [199]  time: 10.5221, ELBO_train: -4.52022924, KL_z: 1.31799471, KL_s: 0.22099299, reconstruction loss: -2.98124154
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = data_processing.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = statistic.samples_concatenation(samples_list)[-1]
    data_test_transformed = data_processing.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = data_processing.discrete_variables_transformation(est_data_test, feat_types_dict)

# %% [markdown]
# ### Visualize the generated samples

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
estimated_values = est_data_test_transformed

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
