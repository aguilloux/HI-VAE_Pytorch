# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import utils
import time

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "Wine"
# dataset_name = "Adult"
# dataset_name = "Breast"
m_perc = 10
mask = 1
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data preprocessing

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = utils.read_data(data_file, feat_types_file, miss_file, true_miss_file)

train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# %%
# Adjust batch size if larger than dataset
batch_size = 1000
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 2000
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
from utils import print_loss, plot_loss_evolution

start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = np.random.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = utils.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = utils.samples_concatenation(samples_list)
    
    # #Transform discrete variables back to the original values
    data_train_transformed = utils.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = utils.discrete_variables_transformation(est_data_train, feat_types_dict)
    est_data_train_mean_imputed = utils.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = utils.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = utils.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 10
# Epoch: [ 0]  time: 0.0597, ELBO_train: -14.11609783, KL_z: 1.56512995, KL_s: 0.11846900, reconstruction loss: -12.43249888
# Clusters: 10
# Epoch: [ 1]  time: 0.1012, ELBO_train: -13.71747494, KL_z: 1.43040514, KL_s: 0.11221061, reconstruction loss: -12.17485919
# Clusters: 10
# Epoch: [ 2]  time: 0.1491, ELBO_train: -13.34104195, KL_z: 1.32335558, KL_s: 0.10714049, reconstruction loss: -11.91054587
# Clusters: 10
# Epoch: [ 3]  time: 0.1978, ELBO_train: -13.09542370, KL_z: 1.22376745, KL_s: 0.10268950, reconstruction loss: -11.76896675
# Clusters: 10
# Epoch: [ 4]  time: 0.2464, ELBO_train: -12.73967285, KL_z: 1.14727345, KL_s: 0.09937711, reconstruction loss: -11.49302230
# Clusters: 10
# Epoch: [ 5]  time: 0.2955, ELBO_train: -12.49746838, KL_z: 1.08038759, KL_s: 0.09634557, reconstruction loss: -11.32073522
# Clusters: 10
# Epoch: [ 6]  time: 0.3586, ELBO_train: -12.23950787, KL_z: 1.03134058, KL_s: 0.09428968, reconstruction loss: -11.11387761
# Clusters: 10
# Epoch: [ 7]  time: 0.4124, ELBO_train: -12.06491642, KL_z: 0.98599772, KL_s: 0.09265904, reconstruction loss: -10.98625965
# Clusters: 10
# Epoch: [ 8]  time: 0.4679, ELBO_train: -11.84767494, KL_z: 0.95286093, KL_s: 0.09127016, reconstruction loss: -10.80354385
# Clusters: 10
# Epoch: [ 9]  time: 0.5695, ELBO_train: -11.63500271, KL_z: 0.92890780, KL_s: 0.09067903, reconstruction loss: -10.61541588
# Clusters: 10
# Epoch: [10]  time: 0.6331, ELBO_train: -11.39838352, KL_z: 0.90763857, KL_s: 0.09032030, reconstruction loss: -10.40042465
# Clusters: 10
# Epoch: [11]  time: 0.6847, ELBO_train: -11.28755951, KL_z: 0.89362700, KL_s: 0.09017649, reconstruction loss: -10.30375602
# Clusters: 10
# Epoch: [12]  time: 0.7374, ELBO_train: -11.00130157, KL_z: 0.88755534, KL_s: 0.09055429, reconstruction loss: -10.02319195
# Clusters: 10
# Epoch: [13]  time: 0.7877, ELBO_train: -10.86436119, KL_z: 0.88274971, KL_s: 0.09070935, reconstruction loss: -9.89090213
# Clusters: 10
# Epoch: [14]  time: 0.8365, ELBO_train: -10.66361847, KL_z: 0.88204007, KL_s: 0.09102154, reconstruction loss: -9.69055686
# Clusters: 10
# Epoch: [15]  time: 0.8844, ELBO_train: -10.53383427, KL_z: 0.88910632, KL_s: 0.09153924, reconstruction loss: -9.55318871
# Clusters: 10
# Epoch: [16]  time: 0.9450, ELBO_train: -10.29382248, KL_z: 0.89362494, KL_s: 0.09225063, reconstruction loss: -9.30794691
# Clusters: 10
# Epoch: [17]  time: 0.9972, ELBO_train: -10.18840828, KL_z: 0.90182265, KL_s: 0.09267001, reconstruction loss: -9.19391562
# Clusters: 10
# Epoch: [18]  time: 1.0721, ELBO_train: -10.01680069, KL_z: 0.91647284, KL_s: 0.09381604, reconstruction loss: -9.00651181
# Clusters: 10
# Epoch: [19]  time: 1.1253, ELBO_train: -9.80966549, KL_z: 0.92965854, KL_s: 0.09487081, reconstruction loss: -8.78513614
# Clusters: 10
# Epoch: [20]  time: 1.1840, ELBO_train: -9.66197319, KL_z: 0.95047309, KL_s: 0.09598165, reconstruction loss: -8.61551845
# Clusters: 10
# Epoch: [21]  time: 1.2446, ELBO_train: -9.50791836, KL_z: 0.96457374, KL_s: 0.09646349, reconstruction loss: -8.44688113
# Clusters: 10
# Epoch: [22]  time: 1.2950, ELBO_train: -9.31423836, KL_z: 0.97698022, KL_s: 0.09767036, reconstruction loss: -8.23958777
# Clusters: 10
# Epoch: [23]  time: 1.3396, ELBO_train: -9.22121410, KL_z: 0.99397365, KL_s: 0.09867077, reconstruction loss: -8.12856969
# Clusters: 10
# Epoch: [24]  time: 1.3856, ELBO_train: -9.09413185, KL_z: 1.01335735, KL_s: 0.09971395, reconstruction loss: -7.98106055
# Clusters: 10
# Epoch: [25]  time: 1.4418, ELBO_train: -8.90608864, KL_z: 1.03485553, KL_s: 0.10093188, reconstruction loss: -7.77030122
# Clusters: 10
# Epoch: [26]  time: 1.4883, ELBO_train: -8.82093792, KL_z: 1.05217237, KL_s: 0.10229201, reconstruction loss: -7.66647353
# Clusters: 10
# Epoch: [27]  time: 1.5415, ELBO_train: -8.60653000, KL_z: 1.07051854, KL_s: 0.10323815, reconstruction loss: -7.43277330
# Clusters: 10
# Epoch: [28]  time: 1.5853, ELBO_train: -8.50606461, KL_z: 1.08378642, KL_s: 0.10470433, reconstruction loss: -7.31757386
# Clusters: 10
# Epoch: [29]  time: 1.6527, ELBO_train: -8.33935699, KL_z: 1.09524429, KL_s: 0.10625706, reconstruction loss: -7.13785565
# Clusters: 10
# Epoch: [30]  time: 1.7040, ELBO_train: -8.25103874, KL_z: 1.10624883, KL_s: 0.10775685, reconstruction loss: -7.03703306
# Clusters: 10
# Epoch: [31]  time: 1.7650, ELBO_train: -8.04868917, KL_z: 1.11495314, KL_s: 0.10901465, reconstruction loss: -6.82472138
# Clusters: 10
# Epoch: [32]  time: 1.8294, ELBO_train: -8.02981901, KL_z: 1.12481844, KL_s: 0.11007333, reconstruction loss: -6.79492724
# Clusters: 10
# Epoch: [33]  time: 1.8795, ELBO_train: -7.87357426, KL_z: 1.13531265, KL_s: 0.11098242, reconstruction loss: -6.62727919
# Clusters: 10
# Epoch: [34]  time: 1.9314, ELBO_train: -7.76063032, KL_z: 1.14571655, KL_s: 0.11221147, reconstruction loss: -6.50270231
# Clusters: 10
# Epoch: [35]  time: 1.9822, ELBO_train: -7.67095585, KL_z: 1.15249302, KL_s: 0.11370602, reconstruction loss: -6.40475681
# Clusters: 10
# Epoch: [36]  time: 2.0371, ELBO_train: -7.55204105, KL_z: 1.16343877, KL_s: 0.11525083, reconstruction loss: -6.27335145
# Clusters: 10
# Epoch: [37]  time: 2.0935, ELBO_train: -7.46106272, KL_z: 1.17166421, KL_s: 0.11629100, reconstruction loss: -6.17310750
# Clusters: 10
# Epoch: [38]  time: 2.1506, ELBO_train: -7.34603786, KL_z: 1.17771587, KL_s: 0.11799531, reconstruction loss: -6.05032668
# Clusters: 10
# Epoch: [39]  time: 2.2064, ELBO_train: -7.25756063, KL_z: 1.17688637, KL_s: 0.11884246, reconstruction loss: -5.96183181
# Clusters: 10
# Epoch: [40]  time: 2.2645, ELBO_train: -7.20351534, KL_z: 1.17427101, KL_s: 0.11992593, reconstruction loss: -5.90931840
# Clusters: 10
# Epoch: [41]  time: 2.3178, ELBO_train: -7.01365461, KL_z: 1.17894192, KL_s: 0.12164922, reconstruction loss: -5.71306348
# Clusters: 10
# Epoch: [42]  time: 2.3775, ELBO_train: -7.01633701, KL_z: 1.18243330, KL_s: 0.12281737, reconstruction loss: -5.71108634
# Clusters: 10
# Epoch: [43]  time: 2.4387, ELBO_train: -6.91981916, KL_z: 1.18480771, KL_s: 0.12394648, reconstruction loss: -5.61106498
# Clusters: 10
# Epoch: [44]  time: 2.4907, ELBO_train: -6.87448845, KL_z: 1.18824043, KL_s: 0.12535601, reconstruction loss: -5.56089201
# Clusters: 10
# Epoch: [45]  time: 2.5433, ELBO_train: -6.77354813, KL_z: 1.19089229, KL_s: 0.12639022, reconstruction loss: -5.45626562
# Clusters: 10
# Epoch: [46]  time: 2.5967, ELBO_train: -6.71418371, KL_z: 1.19467371, KL_s: 0.12728715, reconstruction loss: -5.39222286
# Clusters: 10
# Epoch: [47]  time: 2.6414, ELBO_train: -6.65337658, KL_z: 1.19924953, KL_s: 0.12828360, reconstruction loss: -5.32584345
# Clusters: 10
# Epoch: [48]  time: 2.6873, ELBO_train: -6.53176517, KL_z: 1.19766104, KL_s: 0.12925391, reconstruction loss: -5.20485022
# Clusters: 10
# Epoch: [49]  time: 2.7327, ELBO_train: -6.48662310, KL_z: 1.20587418, KL_s: 0.13074546, reconstruction loss: -5.15000346
# Clusters: 10
# Epoch: [50]  time: 2.7786, ELBO_train: -6.36531639, KL_z: 1.21102931, KL_s: 0.13194594, reconstruction loss: -5.02234113
# Clusters: 10
# Epoch: [51]  time: 2.8265, ELBO_train: -6.34102650, KL_z: 1.20730789, KL_s: 0.13341880, reconstruction loss: -5.00029981
# Clusters: 10
# Epoch: [52]  time: 2.8707, ELBO_train: -6.30345030, KL_z: 1.20723352, KL_s: 0.13468361, reconstruction loss: -4.96153316
# Clusters: 10
# Epoch: [53]  time: 2.9207, ELBO_train: -6.20279007, KL_z: 1.20913100, KL_s: 0.13642683, reconstruction loss: -4.85723224
# Clusters: 10
# Epoch: [54]  time: 2.9692, ELBO_train: -6.17928972, KL_z: 1.20976436, KL_s: 0.13788886, reconstruction loss: -4.83163650
# Clusters: 10
# Epoch: [55]  time: 3.0233, ELBO_train: -6.12760878, KL_z: 1.21608918, KL_s: 0.13966670, reconstruction loss: -4.77185290
# Clusters: 10
# Epoch: [56]  time: 3.0749, ELBO_train: -6.08805990, KL_z: 1.22472038, KL_s: 0.14145608, reconstruction loss: -4.72188344
# Clusters: 10
# Epoch: [57]  time: 3.1279, ELBO_train: -6.04821100, KL_z: 1.23109236, KL_s: 0.14349833, reconstruction loss: -4.67362032
# Clusters: 10
# Epoch: [58]  time: 3.1820, ELBO_train: -5.98042469, KL_z: 1.22886252, KL_s: 0.14512734, reconstruction loss: -4.60643482
# Clusters: 10
# Epoch: [59]  time: 3.2354, ELBO_train: -5.99152241, KL_z: 1.23861675, KL_s: 0.14677997, reconstruction loss: -4.60612569
# Clusters: 10
# Epoch: [60]  time: 3.2833, ELBO_train: -5.91406822, KL_z: 1.23729641, KL_s: 0.14863324, reconstruction loss: -4.52813857
# Clusters: 10
# Epoch: [61]  time: 3.3637, ELBO_train: -5.84559641, KL_z: 1.24271317, KL_s: 0.15001335, reconstruction loss: -4.45286989
# Clusters: 10
# Epoch: [62]  time: 3.4182, ELBO_train: -5.80061951, KL_z: 1.24734840, KL_s: 0.15104046, reconstruction loss: -4.40223064
# Clusters: 10
# Epoch: [63]  time: 3.4672, ELBO_train: -5.77398129, KL_z: 1.25030963, KL_s: 0.15246692, reconstruction loss: -4.37120473
# Clusters: 10
# Epoch: [64]  time: 3.5218, ELBO_train: -5.77214088, KL_z: 1.25522666, KL_s: 0.15349278, reconstruction loss: -4.36342144
# Clusters: 10
# Epoch: [65]  time: 3.5846, ELBO_train: -5.63263111, KL_z: 1.25663457, KL_s: 0.15489411, reconstruction loss: -4.22110243
# Clusters: 10
# Epoch: [66]  time: 3.6324, ELBO_train: -5.67357655, KL_z: 1.26015911, KL_s: 0.15618148, reconstruction loss: -4.25723596
# Clusters: 10
# Epoch: [67]  time: 3.6810, ELBO_train: -5.61981163, KL_z: 1.25990760, KL_s: 0.15809131, reconstruction loss: -4.20181272
# Clusters: 10
# Epoch: [68]  time: 3.7304, ELBO_train: -5.62348709, KL_z: 1.25896819, KL_s: 0.15948930, reconstruction loss: -4.20502961
# Clusters: 10
# Epoch: [69]  time: 3.7769, ELBO_train: -5.53209057, KL_z: 1.26233547, KL_s: 0.16099095, reconstruction loss: -4.10876415
# Clusters: 10
# Epoch: [70]  time: 3.8248, ELBO_train: -5.53670378, KL_z: 1.26256766, KL_s: 0.16277108, reconstruction loss: -4.11136503
# Clusters: 10
# Epoch: [71]  time: 3.8728, ELBO_train: -5.47474031, KL_z: 1.25718124, KL_s: 0.16376166, reconstruction loss: -4.05379741
# Clusters: 10
# Epoch: [72]  time: 3.9182, ELBO_train: -5.44457302, KL_z: 1.26575370, KL_s: 0.16521311, reconstruction loss: -4.01360621
# Clusters: 10
# Epoch: [73]  time: 3.9653, ELBO_train: -5.42269163, KL_z: 1.27172449, KL_s: 0.16774220, reconstruction loss: -3.98322494
# Clusters: 10
# Epoch: [74]  time: 4.0191, ELBO_train: -5.41305199, KL_z: 1.26872244, KL_s: 0.16959233, reconstruction loss: -3.97473722
# Clusters: 10
# Epoch: [75]  time: 4.0764, ELBO_train: -5.36684341, KL_z: 1.25856512, KL_s: 0.17087741, reconstruction loss: -3.93740089
# Clusters: 10
# Epoch: [76]  time: 4.1264, ELBO_train: -5.31730881, KL_z: 1.26246567, KL_s: 0.17215290, reconstruction loss: -3.88269024
# Clusters: 10
# Epoch: [77]  time: 4.1729, ELBO_train: -5.32545681, KL_z: 1.26013737, KL_s: 0.17424288, reconstruction loss: -3.89107656
# Clusters: 10
# Epoch: [78]  time: 4.2218, ELBO_train: -5.34731789, KL_z: 1.26929717, KL_s: 0.17552667, reconstruction loss: -3.90249405
# Clusters: 10
# Epoch: [79]  time: 4.2711, ELBO_train: -5.28509903, KL_z: 1.27096105, KL_s: 0.17644658, reconstruction loss: -3.83769140
# Clusters: 10
# Epoch: [80]  time: 4.3197, ELBO_train: -5.23451910, KL_z: 1.28360898, KL_s: 0.17746949, reconstruction loss: -3.77344062
# Clusters: 10
# Epoch: [81]  time: 4.3621, ELBO_train: -5.28813534, KL_z: 1.28075557, KL_s: 0.17811108, reconstruction loss: -3.82926869
# Clusters: 10
# Epoch: [82]  time: 4.4100, ELBO_train: -5.22443495, KL_z: 1.27598102, KL_s: 0.17853494, reconstruction loss: -3.76991899
# Clusters: 10
# Epoch: [83]  time: 4.4569, ELBO_train: -5.20992441, KL_z: 1.28312776, KL_s: 0.17960286, reconstruction loss: -3.74719379
# Clusters: 10
# Epoch: [84]  time: 4.5086, ELBO_train: -5.21894302, KL_z: 1.28463833, KL_s: 0.17951918, reconstruction loss: -3.75478551
# Clusters: 10
# Epoch: [85]  time: 4.5521, ELBO_train: -5.19051619, KL_z: 1.28869655, KL_s: 0.18038030, reconstruction loss: -3.72143934
# Clusters: 10
# Epoch: [86]  time: 4.6169, ELBO_train: -5.19707632, KL_z: 1.28592765, KL_s: 0.18162599, reconstruction loss: -3.72952268
# Clusters: 10
# Epoch: [87]  time: 4.6611, ELBO_train: -5.10919180, KL_z: 1.29100535, KL_s: 0.18312230, reconstruction loss: -3.63506415
# Clusters: 10
# Epoch: [88]  time: 4.7073, ELBO_train: -5.16948433, KL_z: 1.29982526, KL_s: 0.18420544, reconstruction loss: -3.68545363
# Clusters: 10
# Epoch: [89]  time: 4.8003, ELBO_train: -5.11772356, KL_z: 1.29361708, KL_s: 0.18528147, reconstruction loss: -3.63882501
# Clusters: 10
# Epoch: [90]  time: 4.8481, ELBO_train: -5.08822861, KL_z: 1.28805108, KL_s: 0.18821778, reconstruction loss: -3.61195974
# Clusters: 10
# Epoch: [91]  time: 4.8935, ELBO_train: -5.07585783, KL_z: 1.29124854, KL_s: 0.19081149, reconstruction loss: -3.59379780
# Clusters: 10
# Epoch: [92]  time: 4.9395, ELBO_train: -5.07002316, KL_z: 1.29641657, KL_s: 0.19425845, reconstruction loss: -3.57934813
# Clusters: 10
# Epoch: [93]  time: 4.9909, ELBO_train: -5.04131355, KL_z: 1.29833748, KL_s: 0.19722633, reconstruction loss: -3.54574974
# Clusters: 10
# Epoch: [94]  time: 5.0373, ELBO_train: -5.09920206, KL_z: 1.30720561, KL_s: 0.19831586, reconstruction loss: -3.59368060
# Clusters: 10
# Epoch: [95]  time: 5.0850, ELBO_train: -4.99386206, KL_z: 1.29296381, KL_s: 0.19900303, reconstruction loss: -3.50189521
# Clusters: 10
# Epoch: [96]  time: 5.1312, ELBO_train: -4.96568985, KL_z: 1.30234115, KL_s: 0.20025434, reconstruction loss: -3.46309435
# Clusters: 10
# Epoch: [97]  time: 5.1785, ELBO_train: -5.03104172, KL_z: 1.30088122, KL_s: 0.20162659, reconstruction loss: -3.52853391
# Clusters: 10
# Epoch: [98]  time: 5.2256, ELBO_train: -4.97588654, KL_z: 1.29756660, KL_s: 0.20272779, reconstruction loss: -3.47559214
# Clusters: 10
# Epoch: [99]  time: 5.2693, ELBO_train: -4.96556530, KL_z: 1.30150199, KL_s: 0.20525155, reconstruction loss: -3.45881176
# Clusters: 10
# Epoch: [100]  time: 5.3163, ELBO_train: -5.00854864, KL_z: 1.30004389, KL_s: 0.20639610, reconstruction loss: -3.50210865
# Clusters: 10
# Epoch: [101]  time: 5.3640, ELBO_train: -4.95532789, KL_z: 1.31168747, KL_s: 0.20747271, reconstruction loss: -3.43616772
# Clusters: 10
# Epoch: [102]  time: 5.4138, ELBO_train: -4.96013203, KL_z: 1.31240206, KL_s: 0.20927048, reconstruction loss: -3.43845949
# Clusters: 10
# Epoch: [103]  time: 5.4602, ELBO_train: -4.94106331, KL_z: 1.30326807, KL_s: 0.20971889, reconstruction loss: -3.42807634
# Clusters: 10
# Epoch: [104]  time: 5.5069, ELBO_train: -4.93558321, KL_z: 1.29895964, KL_s: 0.20960746, reconstruction loss: -3.42701612
# Clusters: 10
# Epoch: [105]  time: 5.5530, ELBO_train: -4.94448709, KL_z: 1.31183784, KL_s: 0.20856519, reconstruction loss: -3.42408407
# Clusters: 10
# Epoch: [106]  time: 5.5993, ELBO_train: -4.93261480, KL_z: 1.32994225, KL_s: 0.20698981, reconstruction loss: -3.39568274
# Clusters: 10
# Epoch: [107]  time: 5.6464, ELBO_train: -4.90884466, KL_z: 1.34342439, KL_s: 0.20787296, reconstruction loss: -3.35754731
# Clusters: 10
# Epoch: [108]  time: 5.6918, ELBO_train: -4.92148380, KL_z: 1.34314089, KL_s: 0.20867939, reconstruction loss: -3.36966352
# Clusters: 10
# Epoch: [109]  time: 5.7366, ELBO_train: -4.91409674, KL_z: 1.33229935, KL_s: 0.20966320, reconstruction loss: -3.37213418
# Clusters: 10
# Epoch: [110]  time: 5.7842, ELBO_train: -4.90951347, KL_z: 1.32440410, KL_s: 0.21144605, reconstruction loss: -3.37366333
# Clusters: 10
# Epoch: [111]  time: 5.8290, ELBO_train: -4.80945024, KL_z: 1.31563287, KL_s: 0.21360054, reconstruction loss: -3.28021684
# Clusters: 10
# Epoch: [112]  time: 5.8789, ELBO_train: -4.88368530, KL_z: 1.31328149, KL_s: 0.21677637, reconstruction loss: -3.35362744
# Clusters: 10
# Epoch: [113]  time: 5.9251, ELBO_train: -4.84156122, KL_z: 1.31766026, KL_s: 0.21673441, reconstruction loss: -3.30716655
# Clusters: 10
# Epoch: [114]  time: 5.9687, ELBO_train: -4.87676249, KL_z: 1.32044103, KL_s: 0.21715002, reconstruction loss: -3.33917143
# Clusters: 10
# Epoch: [115]  time: 6.0152, ELBO_train: -4.86876583, KL_z: 1.33191707, KL_s: 0.21798010, reconstruction loss: -3.31886866
# Clusters: 10
# Epoch: [116]  time: 6.0601, ELBO_train: -4.83365412, KL_z: 1.32623978, KL_s: 0.21825118, reconstruction loss: -3.28916316
# Clusters: 10
# Epoch: [117]  time: 6.1054, ELBO_train: -4.82109442, KL_z: 1.33129113, KL_s: 0.21863093, reconstruction loss: -3.27117236
# Clusters: 10
# Epoch: [118]  time: 6.1532, ELBO_train: -4.75157690, KL_z: 1.33318374, KL_s: 0.21893206, reconstruction loss: -3.19946110
# Clusters: 10
# Epoch: [119]  time: 6.1999, ELBO_train: -4.80914307, KL_z: 1.32877421, KL_s: 0.21677852, reconstruction loss: -3.26359034
# Clusters: 10
# Epoch: [120]  time: 6.2470, ELBO_train: -4.80907602, KL_z: 1.32990353, KL_s: 0.21652975, reconstruction loss: -3.26264274
# Clusters: 10
# Epoch: [121]  time: 6.2967, ELBO_train: -4.81700878, KL_z: 1.33088672, KL_s: 0.21588178, reconstruction loss: -3.27024028
# Clusters: 10
# Epoch: [122]  time: 6.3421, ELBO_train: -4.75747108, KL_z: 1.33836491, KL_s: 0.21582723, reconstruction loss: -3.20327895
# Clusters: 10
# Epoch: [123]  time: 6.3874, ELBO_train: -4.80801468, KL_z: 1.33993225, KL_s: 0.21362786, reconstruction loss: -3.25445457
# Clusters: 10
# Epoch: [124]  time: 6.4329, ELBO_train: -4.78422403, KL_z: 1.35043511, KL_s: 0.21217513, reconstruction loss: -3.22161379
# Clusters: 10
# Epoch: [125]  time: 6.4778, ELBO_train: -4.76359758, KL_z: 1.34395888, KL_s: 0.21183262, reconstruction loss: -3.20780609
# Clusters: 10
# Epoch: [126]  time: 6.5536, ELBO_train: -4.77852402, KL_z: 1.34081998, KL_s: 0.21438198, reconstruction loss: -3.22332206
# Clusters: 10
# Epoch: [127]  time: 6.6019, ELBO_train: -4.74336958, KL_z: 1.34928620, KL_s: 0.21743035, reconstruction loss: -3.17665303
# Clusters: 10
# Epoch: [128]  time: 6.6515, ELBO_train: -4.73901415, KL_z: 1.34303348, KL_s: 0.21853213, reconstruction loss: -3.17744853
# Clusters: 10
# Epoch: [129]  time: 6.7015, ELBO_train: -4.76493616, KL_z: 1.33913770, KL_s: 0.21998949, reconstruction loss: -3.20580897
# Clusters: 10
# Epoch: [130]  time: 6.7483, ELBO_train: -4.70518389, KL_z: 1.33542285, KL_s: 0.22246976, reconstruction loss: -3.14729128
# Clusters: 10
# Epoch: [131]  time: 6.7988, ELBO_train: -4.68818779, KL_z: 1.34081526, KL_s: 0.22481394, reconstruction loss: -3.12255859
# Clusters: 10
# Epoch: [132]  time: 6.8452, ELBO_train: -4.73613758, KL_z: 1.33178446, KL_s: 0.22607908, reconstruction loss: -3.17827404
# Clusters: 10
# Epoch: [133]  time: 6.8898, ELBO_train: -4.76010437, KL_z: 1.35136492, KL_s: 0.22582355, reconstruction loss: -3.18291590
# Clusters: 10
# Epoch: [134]  time: 6.9395, ELBO_train: -4.77667847, KL_z: 1.34497061, KL_s: 0.22638521, reconstruction loss: -3.20532265
# Clusters: 10
# Epoch: [135]  time: 6.9859, ELBO_train: -4.72125406, KL_z: 1.34581459, KL_s: 0.22758455, reconstruction loss: -3.14785492
# Clusters: 10
# Epoch: [136]  time: 7.0328, ELBO_train: -4.73399925, KL_z: 1.35965483, KL_s: 0.22790694, reconstruction loss: -3.14643748
# Clusters: 10
# Epoch: [137]  time: 7.0789, ELBO_train: -4.66331215, KL_z: 1.35331864, KL_s: 0.22860775, reconstruction loss: -3.08138576
# Clusters: 10
# Epoch: [138]  time: 7.1240, ELBO_train: -4.70184078, KL_z: 1.35731559, KL_s: 0.22793241, reconstruction loss: -3.11659279
# Clusters: 10
# Epoch: [139]  time: 7.1718, ELBO_train: -4.68899517, KL_z: 1.35822546, KL_s: 0.23027987, reconstruction loss: -3.10048983
# Clusters: 10
# Epoch: [140]  time: 7.2182, ELBO_train: -4.72227287, KL_z: 1.36549878, KL_s: 0.23282394, reconstruction loss: -3.12395015
# Clusters: 10
# Epoch: [141]  time: 7.2663, ELBO_train: -4.68611889, KL_z: 1.35538244, KL_s: 0.23584390, reconstruction loss: -3.09489255
# Clusters: 10
# Epoch: [142]  time: 7.3177, ELBO_train: -4.71718540, KL_z: 1.35616603, KL_s: 0.23829575, reconstruction loss: -3.12272363
# Clusters: 10
# Epoch: [143]  time: 7.3650, ELBO_train: -4.68290434, KL_z: 1.35193405, KL_s: 0.23981347, reconstruction loss: -3.09115682
# Clusters: 10
# Epoch: [144]  time: 7.4325, ELBO_train: -4.66409225, KL_z: 1.33949924, KL_s: 0.24057226, reconstruction loss: -3.08402076
# Clusters: 10
# Epoch: [145]  time: 7.4893, ELBO_train: -4.66755209, KL_z: 1.35306134, KL_s: 0.24035234, reconstruction loss: -3.07413840
# Clusters: 10
# Epoch: [146]  time: 7.5391, ELBO_train: -4.67798204, KL_z: 1.34591825, KL_s: 0.23935375, reconstruction loss: -3.09271004
# Clusters: 10
# Epoch: [147]  time: 7.5949, ELBO_train: -4.67548065, KL_z: 1.34934945, KL_s: 0.23860226, reconstruction loss: -3.08752894
# Clusters: 10
# Epoch: [148]  time: 7.6587, ELBO_train: -4.67492466, KL_z: 1.36376438, KL_s: 0.23869801, reconstruction loss: -3.07246227
# Clusters: 10
# Epoch: [149]  time: 7.7162, ELBO_train: -4.68015814, KL_z: 1.36771164, KL_s: 0.23902297, reconstruction loss: -3.07342353
# Clusters: 10
# Epoch: [150]  time: 7.7687, ELBO_train: -4.68553171, KL_z: 1.36672401, KL_s: 0.23831053, reconstruction loss: -3.08049717
# Clusters: 10
# Epoch: [151]  time: 7.8165, ELBO_train: -4.68995552, KL_z: 1.36927924, KL_s: 0.23639598, reconstruction loss: -3.08428030
# Clusters: 10
# Epoch: [152]  time: 7.8636, ELBO_train: -4.64999275, KL_z: 1.36419215, KL_s: 0.23594079, reconstruction loss: -3.04985981
# Clusters: 10
# Epoch: [153]  time: 7.9126, ELBO_train: -4.66277294, KL_z: 1.36008174, KL_s: 0.23484712, reconstruction loss: -3.06784408
# Clusters: 10
# Epoch: [154]  time: 7.9613, ELBO_train: -4.65061035, KL_z: 1.36722782, KL_s: 0.23460259, reconstruction loss: -3.04877994
# Clusters: 10
# Epoch: [155]  time: 8.0064, ELBO_train: -4.62105684, KL_z: 1.37266638, KL_s: 0.23354554, reconstruction loss: -3.01484492
# Clusters: 10
# Epoch: [156]  time: 8.0533, ELBO_train: -4.63685026, KL_z: 1.37264590, KL_s: 0.23428941, reconstruction loss: -3.02991495
# Clusters: 10
# Epoch: [157]  time: 8.1012, ELBO_train: -4.62880335, KL_z: 1.35354929, KL_s: 0.23448663, reconstruction loss: -3.04076743
# Clusters: 10
# Epoch: [158]  time: 8.1589, ELBO_train: -4.57036562, KL_z: 1.34651642, KL_s: 0.23690147, reconstruction loss: -2.98694773
# Clusters: 10
# Epoch: [159]  time: 8.2221, ELBO_train: -4.62692795, KL_z: 1.34951878, KL_s: 0.23836856, reconstruction loss: -3.03904061
# Clusters: 10
# Epoch: [160]  time: 8.2720, ELBO_train: -4.61133184, KL_z: 1.35023715, KL_s: 0.23844709, reconstruction loss: -3.02264760
# Clusters: 10
# Epoch: [161]  time: 8.3209, ELBO_train: -4.61394014, KL_z: 1.36002264, KL_s: 0.24019756, reconstruction loss: -3.01371994
# Clusters: 10
# Epoch: [162]  time: 8.3705, ELBO_train: -4.61317520, KL_z: 1.36279321, KL_s: 0.24317737, reconstruction loss: -3.00720463
# Clusters: 10
# Epoch: [163]  time: 8.4197, ELBO_train: -4.58428154, KL_z: 1.35501268, KL_s: 0.24635797, reconstruction loss: -2.98291090
# Clusters: 10
# Epoch: [164]  time: 8.4674, ELBO_train: -4.64361143, KL_z: 1.35813282, KL_s: 0.24800172, reconstruction loss: -3.03747690
# Clusters: 10
# Epoch: [165]  time: 8.5148, ELBO_train: -4.59799004, KL_z: 1.35180278, KL_s: 0.24746218, reconstruction loss: -2.99872508
# Clusters: 10
# Epoch: [166]  time: 8.5631, ELBO_train: -4.56218433, KL_z: 1.36476352, KL_s: 0.24555211, reconstruction loss: -2.95186870
# Clusters: 10
# Epoch: [167]  time: 8.6089, ELBO_train: -4.64111090, KL_z: 1.36566117, KL_s: 0.24541368, reconstruction loss: -3.03003604
# Clusters: 10
# Epoch: [168]  time: 8.6542, ELBO_train: -4.54016304, KL_z: 1.37167199, KL_s: 0.24691496, reconstruction loss: -2.92157609
# Clusters: 10
# Epoch: [169]  time: 8.7066, ELBO_train: -4.64782009, KL_z: 1.37788985, KL_s: 0.24643331, reconstruction loss: -3.02349694
# Clusters: 10
# Epoch: [170]  time: 8.7577, ELBO_train: -4.55999575, KL_z: 1.37206495, KL_s: 0.24670925, reconstruction loss: -2.94122155
# Clusters: 10
# Epoch: [171]  time: 8.8058, ELBO_train: -4.56855288, KL_z: 1.36503789, KL_s: 0.24648790, reconstruction loss: -2.95702708
# Clusters: 10
# Epoch: [172]  time: 8.8537, ELBO_train: -4.58298368, KL_z: 1.37677593, KL_s: 0.25030322, reconstruction loss: -2.95590453
# Clusters: 10
# Epoch: [173]  time: 8.8994, ELBO_train: -4.56721907, KL_z: 1.35534182, KL_s: 0.25590906, reconstruction loss: -2.95596819
# Clusters: 10
# Epoch: [174]  time: 8.9484, ELBO_train: -4.56567717, KL_z: 1.34692092, KL_s: 0.26006656, reconstruction loss: -2.95868969
# Clusters: 10
# Epoch: [175]  time: 8.9953, ELBO_train: -4.52985096, KL_z: 1.34312980, KL_s: 0.26209922, reconstruction loss: -2.92462194
# Clusters: 10
# Epoch: [176]  time: 9.0458, ELBO_train: -4.54029818, KL_z: 1.32524447, KL_s: 0.26543617, reconstruction loss: -2.94961753
# Clusters: 10
# Epoch: [177]  time: 9.0984, ELBO_train: -4.57384958, KL_z: 1.33530445, KL_s: 0.26710768, reconstruction loss: -2.97143745
# Clusters: 10
# Epoch: [178]  time: 9.1444, ELBO_train: -4.57835636, KL_z: 1.34381275, KL_s: 0.26753955, reconstruction loss: -2.96700406
# Clusters: 10
# Epoch: [179]  time: 9.1931, ELBO_train: -4.49599476, KL_z: 1.34091136, KL_s: 0.26692867, reconstruction loss: -2.88815472
# Clusters: 10
# Epoch: [180]  time: 9.2435, ELBO_train: -4.55010014, KL_z: 1.35534122, KL_s: 0.26711335, reconstruction loss: -2.92764556
# Clusters: 10
# Epoch: [181]  time: 9.2916, ELBO_train: -4.53122740, KL_z: 1.36110921, KL_s: 0.26833854, reconstruction loss: -2.90177965
# Clusters: 10
# Epoch: [182]  time: 9.3383, ELBO_train: -4.52349672, KL_z: 1.34768381, KL_s: 0.26823578, reconstruction loss: -2.90757713
# Clusters: 10
# Epoch: [183]  time: 9.3900, ELBO_train: -4.52801714, KL_z: 1.33087106, KL_s: 0.26744542, reconstruction loss: -2.92970066
# Clusters: 10
# Epoch: [184]  time: 9.4340, ELBO_train: -4.49780521, KL_z: 1.34082839, KL_s: 0.26874428, reconstruction loss: -2.88823254
# Clusters: 10
# Epoch: [185]  time: 9.4777, ELBO_train: -4.54899597, KL_z: 1.32220514, KL_s: 0.26871095, reconstruction loss: -2.95807989
# Clusters: 10
# Epoch: [186]  time: 9.5236, ELBO_train: -4.52295418, KL_z: 1.32662790, KL_s: 0.26932764, reconstruction loss: -2.92699864
# Clusters: 10
# Epoch: [187]  time: 9.5693, ELBO_train: -4.54259949, KL_z: 1.34305425, KL_s: 0.26786342, reconstruction loss: -2.93168182
# Clusters: 10
# Epoch: [188]  time: 9.6200, ELBO_train: -4.52913074, KL_z: 1.34383371, KL_s: 0.26791987, reconstruction loss: -2.91737716
# Clusters: 10
# Epoch: [189]  time: 9.6661, ELBO_train: -4.47286129, KL_z: 1.33361344, KL_s: 0.26918035, reconstruction loss: -2.87006750
# Clusters: 10
# Epoch: [190]  time: 9.7130, ELBO_train: -4.52247829, KL_z: 1.35225761, KL_s: 0.27067227, reconstruction loss: -2.89954841
# Clusters: 10
# Epoch: [191]  time: 9.7592, ELBO_train: -4.50077772, KL_z: 1.33546185, KL_s: 0.27143669, reconstruction loss: -2.89387918
# Clusters: 10
# Epoch: [192]  time: 9.8028, ELBO_train: -4.49059591, KL_z: 1.34011919, KL_s: 0.27061720, reconstruction loss: -2.87985952
# Clusters: 10
# Epoch: [193]  time: 9.8494, ELBO_train: -4.50494318, KL_z: 1.34844706, KL_s: 0.27014089, reconstruction loss: -2.88635523
# Clusters: 10
# Epoch: [194]  time: 9.8941, ELBO_train: -4.55530205, KL_z: 1.35412371, KL_s: 0.26995397, reconstruction loss: -2.93122437
# Clusters: 10
# Epoch: [195]  time: 9.9374, ELBO_train: -4.55920486, KL_z: 1.35169549, KL_s: 0.26948433, reconstruction loss: -2.93802505
# Clusters: 10
# Epoch: [196]  time: 9.9815, ELBO_train: -4.46345873, KL_z: 1.34049547, KL_s: 0.26958880, reconstruction loss: -2.85337446
# Clusters: 10
# Epoch: [197]  time: 10.0261, ELBO_train: -4.45810165, KL_z: 1.32780087, KL_s: 0.26884274, reconstruction loss: -2.86145804
# Clusters: 10
# Epoch: [198]  time: 10.0845, ELBO_train: -4.46969891, KL_z: 1.33869815, KL_s: 0.26906691, reconstruction loss: -2.86193385
# Clusters: 10
# Epoch: [199]  time: 10.1682, ELBO_train: -4.47533302, KL_z: 1.33761272, KL_s: 0.26850705, reconstruction loss: -2.86921325
# Clusters: 10
# Epoch: [200]  time: 10.2196, ELBO_train: -4.47374687, KL_z: 1.34512599, KL_s: 0.26752219, reconstruction loss: -2.86109869
# Clusters: 10
# Epoch: [201]  time: 10.2660, ELBO_train: -4.46366758, KL_z: 1.33699543, KL_s: 0.26606703, reconstruction loss: -2.86060512
# Clusters: 10
# Epoch: [202]  time: 10.3096, ELBO_train: -4.52444210, KL_z: 1.34949872, KL_s: 0.26487527, reconstruction loss: -2.91006811
# Clusters: 10
# Epoch: [203]  time: 10.3575, ELBO_train: -4.47734451, KL_z: 1.35274913, KL_s: 0.26431723, reconstruction loss: -2.86027815
# Clusters: 10
# Epoch: [204]  time: 10.4043, ELBO_train: -4.40852547, KL_z: 1.34582691, KL_s: 0.26327839, reconstruction loss: -2.79942017
# Clusters: 10
# Epoch: [205]  time: 10.4548, ELBO_train: -4.45405912, KL_z: 1.34707723, KL_s: 0.26229181, reconstruction loss: -2.84469008
# Clusters: 10
# Epoch: [206]  time: 10.5060, ELBO_train: -4.44192600, KL_z: 1.34406903, KL_s: 0.26076651, reconstruction loss: -2.83709047
# Clusters: 10
# Epoch: [207]  time: 10.5548, ELBO_train: -4.51598301, KL_z: 1.34976175, KL_s: 0.26055002, reconstruction loss: -2.90567124
# Clusters: 10
# Epoch: [208]  time: 10.6022, ELBO_train: -4.46799822, KL_z: 1.33278806, KL_s: 0.26037731, reconstruction loss: -2.87483284
# Clusters: 10
# Epoch: [209]  time: 10.6528, ELBO_train: -4.47051783, KL_z: 1.35549910, KL_s: 0.26100283, reconstruction loss: -2.85401590
# Clusters: 10
# Epoch: [210]  time: 10.7065, ELBO_train: -4.46868181, KL_z: 1.37147102, KL_s: 0.26191311, reconstruction loss: -2.83529768
# Clusters: 10
# Epoch: [211]  time: 10.7602, ELBO_train: -4.45910349, KL_z: 1.36275842, KL_s: 0.26338654, reconstruction loss: -2.83295853
# Clusters: 10
# Epoch: [212]  time: 10.8146, ELBO_train: -4.46306629, KL_z: 1.35631850, KL_s: 0.26494365, reconstruction loss: -2.84180415
# Clusters: 10
# Epoch: [213]  time: 10.8682, ELBO_train: -4.47576475, KL_z: 1.34848659, KL_s: 0.26530275, reconstruction loss: -2.86197541
# Clusters: 10
# Epoch: [214]  time: 10.9184, ELBO_train: -4.46400270, KL_z: 1.33602886, KL_s: 0.26759725, reconstruction loss: -2.86037660
# Clusters: 10
# Epoch: [215]  time: 10.9683, ELBO_train: -4.40250492, KL_z: 1.33694811, KL_s: 0.26893678, reconstruction loss: -2.79662004
# Clusters: 10
# Epoch: [216]  time: 11.0187, ELBO_train: -4.42720213, KL_z: 1.31814644, KL_s: 0.26953897, reconstruction loss: -2.83951671
# Clusters: 10
# Epoch: [217]  time: 11.0681, ELBO_train: -4.42580881, KL_z: 1.32978201, KL_s: 0.26938424, reconstruction loss: -2.82664256
# Clusters: 10
# Epoch: [218]  time: 11.1147, ELBO_train: -4.44241877, KL_z: 1.33804832, KL_s: 0.26916757, reconstruction loss: -2.83520288
# Clusters: 10
# Epoch: [219]  time: 11.1594, ELBO_train: -4.44427214, KL_z: 1.34974084, KL_s: 0.27050381, reconstruction loss: -2.82402749
# Clusters: 10
# Epoch: [220]  time: 11.2030, ELBO_train: -4.46461554, KL_z: 1.35192871, KL_s: 0.27101283, reconstruction loss: -2.84167399
# Clusters: 10
# Epoch: [221]  time: 11.2524, ELBO_train: -4.50767088, KL_z: 1.36103525, KL_s: 0.27159104, reconstruction loss: -2.87504458
# Clusters: 10
# Epoch: [222]  time: 11.2970, ELBO_train: -4.46726608, KL_z: 1.35998013, KL_s: 0.27109909, reconstruction loss: -2.83618686
# Clusters: 10
# Epoch: [223]  time: 11.3419, ELBO_train: -4.46538763, KL_z: 1.35216892, KL_s: 0.27223563, reconstruction loss: -2.84098308
# Clusters: 10
# Epoch: [224]  time: 11.3872, ELBO_train: -4.42562675, KL_z: 1.35534928, KL_s: 0.27395682, reconstruction loss: -2.79632065
# Clusters: 10
# Epoch: [225]  time: 11.4646, ELBO_train: -4.40617905, KL_z: 1.35071218, KL_s: 0.27690969, reconstruction loss: -2.77855718
# Clusters: 10
# Epoch: [226]  time: 11.5183, ELBO_train: -4.44490538, KL_z: 1.35138435, KL_s: 0.28071246, reconstruction loss: -2.81280856
# Clusters: 10
# Epoch: [227]  time: 11.5651, ELBO_train: -4.38747520, KL_z: 1.33117909, KL_s: 0.28218946, reconstruction loss: -2.77410665
# Clusters: 10
# Epoch: [228]  time: 11.6102, ELBO_train: -4.42381210, KL_z: 1.31674490, KL_s: 0.28445125, reconstruction loss: -2.82261596
# Clusters: 10
# Epoch: [229]  time: 11.6577, ELBO_train: -4.46026630, KL_z: 1.34995646, KL_s: 0.28605318, reconstruction loss: -2.82425666
# Clusters: 10
# Epoch: [230]  time: 11.7057, ELBO_train: -4.38583975, KL_z: 1.33082542, KL_s: 0.28806996, reconstruction loss: -2.76694436
# Clusters: 10
# Epoch: [231]  time: 11.7545, ELBO_train: -4.42685747, KL_z: 1.35704334, KL_s: 0.29031053, reconstruction loss: -2.77950361
# Clusters: 10
# Epoch: [232]  time: 11.8011, ELBO_train: -4.45878735, KL_z: 1.33295133, KL_s: 0.29097490, reconstruction loss: -2.83486111
# Clusters: 10
# Epoch: [233]  time: 11.8487, ELBO_train: -4.39808617, KL_z: 1.32474403, KL_s: 0.29188266, reconstruction loss: -2.78145947
# Clusters: 10
# Epoch: [234]  time: 11.8932, ELBO_train: -4.40629301, KL_z: 1.33918264, KL_s: 0.29273443, reconstruction loss: -2.77437594
# Clusters: 10
# Epoch: [235]  time: 11.9451, ELBO_train: -4.36608496, KL_z: 1.33411674, KL_s: 0.29294205, reconstruction loss: -2.73902617
# Clusters: 10
# Epoch: [236]  time: 11.9919, ELBO_train: -4.41155310, KL_z: 1.34011996, KL_s: 0.29371619, reconstruction loss: -2.77771695
# Clusters: 10
# Epoch: [237]  time: 12.0368, ELBO_train: -4.40181971, KL_z: 1.31920273, KL_s: 0.29387279, reconstruction loss: -2.78874419
# Clusters: 10
# Epoch: [238]  time: 12.0822, ELBO_train: -4.43404627, KL_z: 1.32727201, KL_s: 0.29310584, reconstruction loss: -2.81366842
# Clusters: 10
# Epoch: [239]  time: 12.1329, ELBO_train: -4.41992979, KL_z: 1.33683426, KL_s: 0.29286942, reconstruction loss: -2.79022610
# Clusters: 10
# Epoch: [240]  time: 12.2184, ELBO_train: -4.40612402, KL_z: 1.33606999, KL_s: 0.29048185, reconstruction loss: -2.77957218
# Clusters: 10
# Epoch: [241]  time: 12.2687, ELBO_train: -4.41388893, KL_z: 1.34435670, KL_s: 0.29068775, reconstruction loss: -2.77884448
# Clusters: 10
# Epoch: [242]  time: 12.3165, ELBO_train: -4.38185539, KL_z: 1.34068830, KL_s: 0.28904543, reconstruction loss: -2.75212166
# Clusters: 10
# Epoch: [243]  time: 12.3629, ELBO_train: -4.38448639, KL_z: 1.34200466, KL_s: 0.29052801, reconstruction loss: -2.75195372
# Clusters: 10
# Epoch: [244]  time: 12.4080, ELBO_train: -4.40947657, KL_z: 1.32953637, KL_s: 0.29069872, reconstruction loss: -2.78924148
# Clusters: 10
# Epoch: [245]  time: 12.4543, ELBO_train: -4.38024750, KL_z: 1.33329556, KL_s: 0.29119492, reconstruction loss: -2.75575702
# Clusters: 10
# Epoch: [246]  time: 12.5046, ELBO_train: -4.34545107, KL_z: 1.32527666, KL_s: 0.29358296, reconstruction loss: -2.72659144
# Clusters: 10
# Epoch: [247]  time: 12.5523, ELBO_train: -4.40877161, KL_z: 1.33112082, KL_s: 0.29464159, reconstruction loss: -2.78300920
# Clusters: 10
# Epoch: [248]  time: 12.5981, ELBO_train: -4.36462755, KL_z: 1.32281573, KL_s: 0.29614148, reconstruction loss: -2.74567034
# Clusters: 10
# Epoch: [249]  time: 12.6491, ELBO_train: -4.37718811, KL_z: 1.33150949, KL_s: 0.29801137, reconstruction loss: -2.74766724
# Clusters: 10
# Epoch: [250]  time: 12.7028, ELBO_train: -4.38024607, KL_z: 1.31400228, KL_s: 0.29883628, reconstruction loss: -2.76740751
# Clusters: 10
# Epoch: [251]  time: 12.7530, ELBO_train: -4.37497120, KL_z: 1.31488335, KL_s: 0.29925358, reconstruction loss: -2.76083426
# Clusters: 10
# Epoch: [252]  time: 12.8019, ELBO_train: -4.33605080, KL_z: 1.32000222, KL_s: 0.30040438, reconstruction loss: -2.71564419
# Clusters: 10
# Epoch: [253]  time: 12.8528, ELBO_train: -4.39487410, KL_z: 1.32574286, KL_s: 0.30048625, reconstruction loss: -2.76864498
# Clusters: 10
# Epoch: [254]  time: 12.9108, ELBO_train: -4.39965286, KL_z: 1.32845595, KL_s: 0.30259087, reconstruction loss: -2.76860604
# Clusters: 10
# Epoch: [255]  time: 12.9646, ELBO_train: -4.37919931, KL_z: 1.32176175, KL_s: 0.30402229, reconstruction loss: -2.75341527
# Clusters: 10
# Epoch: [256]  time: 13.0226, ELBO_train: -4.36040792, KL_z: 1.31309762, KL_s: 0.30450454, reconstruction loss: -2.74280577
# Clusters: 10
# Epoch: [257]  time: 13.1069, ELBO_train: -4.34542074, KL_z: 1.32767322, KL_s: 0.30519156, reconstruction loss: -2.71255596
# Clusters: 10
# Epoch: [258]  time: 13.1609, ELBO_train: -4.36560278, KL_z: 1.31075220, KL_s: 0.30555377, reconstruction loss: -2.74929681
# Clusters: 10
# Epoch: [259]  time: 13.2082, ELBO_train: -4.39777126, KL_z: 1.31985209, KL_s: 0.30568907, reconstruction loss: -2.77223010
# Clusters: 10
# Epoch: [260]  time: 13.2585, ELBO_train: -4.39437943, KL_z: 1.32923310, KL_s: 0.30652978, reconstruction loss: -2.75861654
# Clusters: 10
# Epoch: [261]  time: 13.3084, ELBO_train: -4.37752895, KL_z: 1.32240136, KL_s: 0.30704496, reconstruction loss: -2.74808264
# Clusters: 10
# Epoch: [262]  time: 13.3582, ELBO_train: -4.38242254, KL_z: 1.32057242, KL_s: 0.30790341, reconstruction loss: -2.75394671
# Clusters: 10
# Epoch: [263]  time: 13.4111, ELBO_train: -4.29982443, KL_z: 1.31993923, KL_s: 0.31011100, reconstruction loss: -2.66977420
# Clusters: 10
# Epoch: [264]  time: 13.4665, ELBO_train: -4.32991877, KL_z: 1.32158256, KL_s: 0.31217725, reconstruction loss: -2.69615896
# Clusters: 10
# Epoch: [265]  time: 13.5245, ELBO_train: -4.37420549, KL_z: 1.33334417, KL_s: 0.31276491, reconstruction loss: -2.72809641
# Clusters: 10
# Epoch: [266]  time: 13.5837, ELBO_train: -4.29026728, KL_z: 1.32551520, KL_s: 0.31282601, reconstruction loss: -2.65192606
# Clusters: 10
# Epoch: [267]  time: 13.6525, ELBO_train: -4.36562738, KL_z: 1.32302499, KL_s: 0.31204298, reconstruction loss: -2.73055942
# Clusters: 10
# Epoch: [268]  time: 13.7156, ELBO_train: -4.32268829, KL_z: 1.30889120, KL_s: 0.31346221, reconstruction loss: -2.70033488
# Clusters: 10
# Epoch: [269]  time: 13.7873, ELBO_train: -4.32449131, KL_z: 1.30872483, KL_s: 0.31319516, reconstruction loss: -2.70257132
# Clusters: 10
# Epoch: [270]  time: 13.8393, ELBO_train: -4.32936573, KL_z: 1.31379220, KL_s: 0.31404934, reconstruction loss: -2.70152419
# Clusters: 10
# Epoch: [271]  time: 13.9071, ELBO_train: -4.32966290, KL_z: 1.29958942, KL_s: 0.31439657, reconstruction loss: -2.71567690
# Clusters: 10
# Epoch: [272]  time: 13.9710, ELBO_train: -4.32273474, KL_z: 1.30986412, KL_s: 0.31346703, reconstruction loss: -2.69940360
# Clusters: 10
# Epoch: [273]  time: 14.0326, ELBO_train: -4.30944214, KL_z: 1.30222638, KL_s: 0.31378720, reconstruction loss: -2.69342856
# Clusters: 10
# Epoch: [274]  time: 14.0862, ELBO_train: -4.28428936, KL_z: 1.29872460, KL_s: 0.31342301, reconstruction loss: -2.67214174
# Clusters: 10
# Epoch: [275]  time: 14.1372, ELBO_train: -4.30749712, KL_z: 1.29844134, KL_s: 0.31467729, reconstruction loss: -2.69437850
# Clusters: 10
# Epoch: [276]  time: 14.1880, ELBO_train: -4.34397459, KL_z: 1.30325069, KL_s: 0.31591797, reconstruction loss: -2.72480593
# Clusters: 10
# Epoch: [277]  time: 14.2360, ELBO_train: -4.35173225, KL_z: 1.33123689, KL_s: 0.31744103, reconstruction loss: -2.70305433
# Clusters: 10
# Epoch: [278]  time: 14.2824, ELBO_train: -4.30078096, KL_z: 1.32429290, KL_s: 0.31743722, reconstruction loss: -2.65905085
# Clusters: 10
# Epoch: [279]  time: 14.3335, ELBO_train: -4.27499628, KL_z: 1.31864109, KL_s: 0.31810393, reconstruction loss: -2.63825126
# Clusters: 10
# Epoch: [280]  time: 14.3932, ELBO_train: -4.33094807, KL_z: 1.30904913, KL_s: 0.31986337, reconstruction loss: -2.70203557
# Clusters: 10
# Epoch: [281]  time: 14.4445, ELBO_train: -4.32573738, KL_z: 1.30652089, KL_s: 0.31980367, reconstruction loss: -2.69941282
# Clusters: 10
# Epoch: [282]  time: 14.4924, ELBO_train: -4.33297720, KL_z: 1.31622148, KL_s: 0.31995032, reconstruction loss: -2.69680541
# Clusters: 10
# Epoch: [283]  time: 14.5379, ELBO_train: -4.32650394, KL_z: 1.32451594, KL_s: 0.32062724, reconstruction loss: -2.68136077
# Clusters: 10
# Epoch: [284]  time: 14.5833, ELBO_train: -4.31894140, KL_z: 1.31261806, KL_s: 0.32275772, reconstruction loss: -2.68356562
# Clusters: 10
# Epoch: [285]  time: 14.6344, ELBO_train: -4.34655237, KL_z: 1.31102479, KL_s: 0.32484040, reconstruction loss: -2.71068718
# Clusters: 10
# Epoch: [286]  time: 14.6868, ELBO_train: -4.30382185, KL_z: 1.30871751, KL_s: 0.32727995, reconstruction loss: -2.66782439
# Clusters: 10
# Epoch: [287]  time: 14.7509, ELBO_train: -4.30639553, KL_z: 1.30717456, KL_s: 0.32748926, reconstruction loss: -2.67173171
# Clusters: 10
# Epoch: [288]  time: 14.8068, ELBO_train: -4.32186670, KL_z: 1.31773508, KL_s: 0.32699080, reconstruction loss: -2.67714083
# Clusters: 10
# Epoch: [289]  time: 14.8629, ELBO_train: -4.31902857, KL_z: 1.31543427, KL_s: 0.32833688, reconstruction loss: -2.67525742
# Clusters: 10
# Epoch: [290]  time: 14.9438, ELBO_train: -4.28403158, KL_z: 1.30552826, KL_s: 0.32822177, reconstruction loss: -2.65028155
# Clusters: 10
# Epoch: [291]  time: 14.9930, ELBO_train: -4.30212440, KL_z: 1.30114055, KL_s: 0.33281214, reconstruction loss: -2.66817172
# Clusters: 10
# Epoch: [292]  time: 15.0486, ELBO_train: -4.25960560, KL_z: 1.28948407, KL_s: 0.33517516, reconstruction loss: -2.63494637
# Clusters: 10
# Epoch: [293]  time: 15.1002, ELBO_train: -4.27063270, KL_z: 1.29987202, KL_s: 0.34072554, reconstruction loss: -2.63003514
# Clusters: 10
# Epoch: [294]  time: 15.1512, ELBO_train: -4.30556641, KL_z: 1.29434357, KL_s: 0.34533908, reconstruction loss: -2.66588376
# Clusters: 10
# Epoch: [295]  time: 15.2040, ELBO_train: -4.31662502, KL_z: 1.29094975, KL_s: 0.34927611, reconstruction loss: -2.67639916
# Clusters: 10
# Epoch: [296]  time: 15.2597, ELBO_train: -4.29347000, KL_z: 1.29064662, KL_s: 0.35012119, reconstruction loss: -2.65270219
# Clusters: 10
# Epoch: [297]  time: 15.3183, ELBO_train: -4.26696901, KL_z: 1.28809316, KL_s: 0.35172515, reconstruction loss: -2.62715070
# Clusters: 10
# Epoch: [298]  time: 15.3744, ELBO_train: -4.23681087, KL_z: 1.28518128, KL_s: 0.35120695, reconstruction loss: -2.60042264
# Clusters: 10
# Epoch: [299]  time: 15.4357, ELBO_train: -4.25313540, KL_z: 1.28893158, KL_s: 0.35267940, reconstruction loss: -2.61152442
# Clusters: 10
# Epoch: [300]  time: 15.4913, ELBO_train: -4.29463940, KL_z: 1.29103191, KL_s: 0.35212672, reconstruction loss: -2.65148077
# Clusters: 10
# Epoch: [301]  time: 15.5490, ELBO_train: -4.27515182, KL_z: 1.27135739, KL_s: 0.35355992, reconstruction loss: -2.65023451
# Clusters: 10
# Epoch: [302]  time: 15.6008, ELBO_train: -4.25402832, KL_z: 1.28304336, KL_s: 0.35443239, reconstruction loss: -2.61655257
# Clusters: 10
# Epoch: [303]  time: 15.6572, ELBO_train: -4.28035412, KL_z: 1.29527678, KL_s: 0.35477791, reconstruction loss: -2.63029943
# Clusters: 10
# Epoch: [304]  time: 15.7070, ELBO_train: -4.27759924, KL_z: 1.29073911, KL_s: 0.35648379, reconstruction loss: -2.63037634
# Clusters: 10
# Epoch: [305]  time: 15.7602, ELBO_train: -4.27114429, KL_z: 1.28092599, KL_s: 0.35808697, reconstruction loss: -2.63213134
# Clusters: 10
# Epoch: [306]  time: 15.8165, ELBO_train: -4.30091581, KL_z: 1.27403877, KL_s: 0.36149304, reconstruction loss: -2.66538401
# Clusters: 10
# Epoch: [307]  time: 15.8686, ELBO_train: -4.26385117, KL_z: 1.28678668, KL_s: 0.36229379, reconstruction loss: -2.61477070
# Clusters: 10
# Epoch: [308]  time: 15.9230, ELBO_train: -4.26873522, KL_z: 1.29854429, KL_s: 0.36419172, reconstruction loss: -2.60599921
# Clusters: 10
# Epoch: [309]  time: 15.9728, ELBO_train: -4.24495649, KL_z: 1.29082191, KL_s: 0.36448359, reconstruction loss: -2.58965099
# Clusters: 10
# Epoch: [310]  time: 16.0245, ELBO_train: -4.27092528, KL_z: 1.29250474, KL_s: 0.36640201, reconstruction loss: -2.61201854
# Clusters: 10
# Epoch: [311]  time: 16.0745, ELBO_train: -4.24826469, KL_z: 1.29492033, KL_s: 0.36932349, reconstruction loss: -2.58402088
# Clusters: 10
# Epoch: [312]  time: 16.1253, ELBO_train: -4.28806734, KL_z: 1.29784203, KL_s: 0.37112155, reconstruction loss: -2.61910377
# Clusters: 10
# Epoch: [313]  time: 16.1788, ELBO_train: -4.26473875, KL_z: 1.29189012, KL_s: 0.37148955, reconstruction loss: -2.60135908
# Clusters: 10
# Epoch: [314]  time: 16.2297, ELBO_train: -4.22928619, KL_z: 1.26917603, KL_s: 0.37171905, reconstruction loss: -2.58839111
# Clusters: 10
# Epoch: [315]  time: 16.2810, ELBO_train: -4.24036379, KL_z: 1.27815161, KL_s: 0.37153895, reconstruction loss: -2.59067323
# Clusters: 10
# Epoch: [316]  time: 16.3303, ELBO_train: -4.27055349, KL_z: 1.28690403, KL_s: 0.37210639, reconstruction loss: -2.61154308
# Clusters: 10
# Epoch: [317]  time: 16.3786, ELBO_train: -4.28590469, KL_z: 1.29289360, KL_s: 0.37185335, reconstruction loss: -2.62115774
# Clusters: 10
# Epoch: [318]  time: 16.4285, ELBO_train: -4.28295698, KL_z: 1.28187220, KL_s: 0.37190208, reconstruction loss: -2.62918270
# Clusters: 10
# Epoch: [319]  time: 16.4850, ELBO_train: -4.20535154, KL_z: 1.26681838, KL_s: 0.37278595, reconstruction loss: -2.56574721
# Clusters: 10
# Epoch: [320]  time: 16.5361, ELBO_train: -4.24630151, KL_z: 1.27315798, KL_s: 0.37343326, reconstruction loss: -2.59971027
# Clusters: 10
# Epoch: [321]  time: 16.5875, ELBO_train: -4.26889048, KL_z: 1.28046670, KL_s: 0.37322347, reconstruction loss: -2.61520030
# Clusters: 10
# Epoch: [322]  time: 16.6384, ELBO_train: -4.23262510, KL_z: 1.28072152, KL_s: 0.37512727, reconstruction loss: -2.57677631
# Clusters: 10
# Epoch: [323]  time: 16.6897, ELBO_train: -4.24628077, KL_z: 1.28947313, KL_s: 0.37573731, reconstruction loss: -2.58107033
# Clusters: 10
# Epoch: [324]  time: 16.7406, ELBO_train: -4.23586369, KL_z: 1.28323071, KL_s: 0.37608809, reconstruction loss: -2.57654488
# Clusters: 10
# Epoch: [325]  time: 16.7894, ELBO_train: -4.23585911, KL_z: 1.27457767, KL_s: 0.37636175, reconstruction loss: -2.58491969
# Clusters: 10
# Epoch: [326]  time: 16.8397, ELBO_train: -4.20859032, KL_z: 1.25147946, KL_s: 0.37775362, reconstruction loss: -2.57935724
# Clusters: 10
# Epoch: [327]  time: 16.8921, ELBO_train: -4.22963419, KL_z: 1.26733930, KL_s: 0.37839527, reconstruction loss: -2.58389962
# Clusters: 10
# Epoch: [328]  time: 16.9425, ELBO_train: -4.19399414, KL_z: 1.26779306, KL_s: 0.37707810, reconstruction loss: -2.54912298
# Clusters: 10
# Epoch: [329]  time: 16.9945, ELBO_train: -4.20841579, KL_z: 1.25732801, KL_s: 0.37696340, reconstruction loss: -2.57412438
# Clusters: 10
# Epoch: [330]  time: 17.0465, ELBO_train: -4.21481829, KL_z: 1.26560349, KL_s: 0.37724583, reconstruction loss: -2.57196896
# Clusters: 10
# Epoch: [331]  time: 17.0983, ELBO_train: -4.21593494, KL_z: 1.27183607, KL_s: 0.37750795, reconstruction loss: -2.56659093
# Clusters: 10
# Epoch: [332]  time: 17.1535, ELBO_train: -4.26112261, KL_z: 1.28316607, KL_s: 0.37739556, reconstruction loss: -2.60056098
# Clusters: 10
# Epoch: [333]  time: 17.2038, ELBO_train: -4.22826214, KL_z: 1.28403223, KL_s: 0.37707345, reconstruction loss: -2.56715646
# Clusters: 10
# Epoch: [334]  time: 17.2578, ELBO_train: -4.19741774, KL_z: 1.27048550, KL_s: 0.37655325, reconstruction loss: -2.55037899
# Clusters: 10
# Epoch: [335]  time: 17.3183, ELBO_train: -4.23156300, KL_z: 1.27527063, KL_s: 0.37694707, reconstruction loss: -2.57934530
# Clusters: 10
# Epoch: [336]  time: 17.4005, ELBO_train: -4.22641854, KL_z: 1.27663181, KL_s: 0.37782497, reconstruction loss: -2.57196176
# Clusters: 10
# Epoch: [337]  time: 17.4497, ELBO_train: -4.27307148, KL_z: 1.27629933, KL_s: 0.37716775, reconstruction loss: -2.61960440
# Clusters: 10
# Epoch: [338]  time: 17.4996, ELBO_train: -4.21832614, KL_z: 1.28621528, KL_s: 0.37764685, reconstruction loss: -2.55446401
# Clusters: 10
# Epoch: [339]  time: 17.5487, ELBO_train: -4.22011709, KL_z: 1.29437501, KL_s: 0.37867362, reconstruction loss: -2.54706845
# Clusters: 10
# Epoch: [340]  time: 17.6006, ELBO_train: -4.24524965, KL_z: 1.28554482, KL_s: 0.37884095, reconstruction loss: -2.58086388
# Clusters: 10
# Epoch: [341]  time: 17.6532, ELBO_train: -4.25692072, KL_z: 1.29377315, KL_s: 0.37814555, reconstruction loss: -2.58500202
# Clusters: 10
# Epoch: [342]  time: 17.7035, ELBO_train: -4.20440407, KL_z: 1.27928221, KL_s: 0.37820065, reconstruction loss: -2.54692121
# Clusters: 10
# Epoch: [343]  time: 17.7548, ELBO_train: -4.22675891, KL_z: 1.29464960, KL_s: 0.37746255, reconstruction loss: -2.55464675
# Clusters: 10
# Epoch: [344]  time: 17.8116, ELBO_train: -4.22909336, KL_z: 1.27499769, KL_s: 0.37856579, reconstruction loss: -2.57552989
# Clusters: 10
# Epoch: [345]  time: 17.8613, ELBO_train: -4.22791233, KL_z: 1.28607073, KL_s: 0.37856312, reconstruction loss: -2.56327848
# Clusters: 10
# Epoch: [346]  time: 17.9109, ELBO_train: -4.20676556, KL_z: 1.27132912, KL_s: 0.37894902, reconstruction loss: -2.55648742
# Clusters: 10
# Epoch: [347]  time: 17.9630, ELBO_train: -4.21051979, KL_z: 1.28627126, KL_s: 0.38125751, reconstruction loss: -2.54299102
# Clusters: 10
# Epoch: [348]  time: 18.0147, ELBO_train: -4.23996820, KL_z: 1.27910397, KL_s: 0.38144796, reconstruction loss: -2.57941628
# Clusters: 10
# Epoch: [349]  time: 18.0656, ELBO_train: -4.16732397, KL_z: 1.27750232, KL_s: 0.38158824, reconstruction loss: -2.50823340
# Clusters: 10
# Epoch: [350]  time: 18.1147, ELBO_train: -4.20475407, KL_z: 1.26714158, KL_s: 0.38197477, reconstruction loss: -2.55563772
# Clusters: 10
# Epoch: [351]  time: 18.1629, ELBO_train: -4.24700956, KL_z: 1.26343429, KL_s: 0.38177869, reconstruction loss: -2.60179658
# Clusters: 10
# Epoch: [352]  time: 18.2284, ELBO_train: -4.18920584, KL_z: 1.27187567, KL_s: 0.38170192, reconstruction loss: -2.53562825
# Clusters: 10
# Epoch: [353]  time: 18.2752, ELBO_train: -4.19078140, KL_z: 1.27526596, KL_s: 0.38378055, reconstruction loss: -2.53173490
# Clusters: 10
# ...
# Clusters: 10
# Epoch: [1884]  time: 78.6461, ELBO_train: -3.65219750, KL_z: 0.71039224, KL_s: 0.77621098, reconstruction loss: -2.16559429
# Clusters: 10
# Epoch: [1885]  time: 78.6837, ELBO_train: -3.67946153, KL_z: 0.71184494, KL_s: 0.77675409, reconstruction loss: -2.19086249
# Clusters: 10
# Epoch: [1886]  time: 78.7212, ELBO_train: -3.60538602, KL_z: 0.71043427, KL_s: 0.77673995, reconstruction loss: -2.11821179
# Clusters: 10
# Epoch: [1887]  time: 78.7589, ELBO_train: -3.63742099, KL_z: 0.71168467, KL_s: 0.77583690, reconstruction loss: -2.14989942
# Clusters: 10
# Epoch: [1888]  time: 78.7962, ELBO_train: -3.63881955, KL_z: 0.71942375, KL_s: 0.77819345, reconstruction loss: -2.14120235
# Clusters: 10
# Epoch: [1889]  time: 78.8353, ELBO_train: -3.66707087, KL_z: 0.72075433, KL_s: 0.77815962, reconstruction loss: -2.16815692
# Clusters: 10
# Epoch: [1890]  time: 78.8736, ELBO_train: -3.62341762, KL_z: 0.70805576, KL_s: 0.77885482, reconstruction loss: -2.13650703
# Clusters: 10
# Epoch: [1891]  time: 78.9105, ELBO_train: -3.61566176, KL_z: 0.71597400, KL_s: 0.77966788, reconstruction loss: -2.12001989
# Clusters: 10
# Epoch: [1892]  time: 78.9485, ELBO_train: -3.59601326, KL_z: 0.71608877, KL_s: 0.77944422, reconstruction loss: -2.10048027
# Clusters: 10
# Epoch: [1893]  time: 78.9857, ELBO_train: -3.59574809, KL_z: 0.70571611, KL_s: 0.77880821, reconstruction loss: -2.11122377
# Clusters: 10
# Epoch: [1894]  time: 79.0235, ELBO_train: -3.63079557, KL_z: 0.70628293, KL_s: 0.77543032, reconstruction loss: -2.14908233
# Clusters: 10
# Epoch: [1895]  time: 79.0628, ELBO_train: -3.62479510, KL_z: 0.71272240, KL_s: 0.77571180, reconstruction loss: -2.13636091
# Clusters: 10
# Epoch: [1896]  time: 79.1007, ELBO_train: -3.66343751, KL_z: 0.71389258, KL_s: 0.77598400, reconstruction loss: -2.17356093
# Clusters: 10
# Epoch: [1897]  time: 79.1388, ELBO_train: -3.64659657, KL_z: 0.71285408, KL_s: 0.77646143, reconstruction loss: -2.15728106
# Clusters: 10
# Epoch: [1898]  time: 79.1769, ELBO_train: -3.61715050, KL_z: 0.70936774, KL_s: 0.77662206, reconstruction loss: -2.13116070
# Clusters: 10
# Epoch: [1899]  time: 79.2141, ELBO_train: -3.65838652, KL_z: 0.71791400, KL_s: 0.77464616, reconstruction loss: -2.16582636
# Clusters: 10
# Epoch: [1900]  time: 79.2517, ELBO_train: -3.63571219, KL_z: 0.70694950, KL_s: 0.77603061, reconstruction loss: -2.15273209
# Clusters: 10
# Epoch: [1901]  time: 79.2915, ELBO_train: -3.63800530, KL_z: 0.71077958, KL_s: 0.77701275, reconstruction loss: -2.15021297
# Clusters: 10
# Epoch: [1902]  time: 79.3287, ELBO_train: -3.63451467, KL_z: 0.71900730, KL_s: 0.77830627, reconstruction loss: -2.13720109
# Clusters: 10
# Epoch: [1903]  time: 79.3667, ELBO_train: -3.64679880, KL_z: 0.71376125, KL_s: 0.77822247, reconstruction loss: -2.15481509
# Clusters: 10
# Epoch: [1904]  time: 79.4042, ELBO_train: -3.63525672, KL_z: 0.70694871, KL_s: 0.77885046, reconstruction loss: -2.14945755
# Clusters: 10
# Epoch: [1905]  time: 79.4417, ELBO_train: -3.63898201, KL_z: 0.71054479, KL_s: 0.77666554, reconstruction loss: -2.15177168
# Clusters: 10
# Epoch: [1906]  time: 79.4784, ELBO_train: -3.67060604, KL_z: 0.71380202, KL_s: 0.77849891, reconstruction loss: -2.17830511
# Clusters: 10
# Epoch: [1907]  time: 79.5179, ELBO_train: -3.65347843, KL_z: 0.71280956, KL_s: 0.77773123, reconstruction loss: -2.16293764
# Clusters: 10
# Epoch: [1908]  time: 79.5558, ELBO_train: -3.70137086, KL_z: 0.72035710, KL_s: 0.77688410, reconstruction loss: -2.20412966
# Clusters: 10
# Epoch: [1909]  time: 79.5937, ELBO_train: -3.63489203, KL_z: 0.72461506, KL_s: 0.77779310, reconstruction loss: -2.13248388
# Clusters: 10
# Epoch: [1910]  time: 79.6315, ELBO_train: -3.64730668, KL_z: 0.72619921, KL_s: 0.77953792, reconstruction loss: -2.14156955
# Clusters: 10
# Epoch: [1911]  time: 79.6690, ELBO_train: -3.64654756, KL_z: 0.72209340, KL_s: 0.77747619, reconstruction loss: -2.14697796
# Clusters: 10
# Epoch: [1912]  time: 79.7064, ELBO_train: -3.67777171, KL_z: 0.71898414, KL_s: 0.77544730, reconstruction loss: -2.18334028
# Clusters: 10
# Epoch: [1913]  time: 79.7499, ELBO_train: -3.63049259, KL_z: 0.71591483, KL_s: 0.77667761, reconstruction loss: -2.13790015
# Clusters: 10
# Epoch: [1914]  time: 79.7878, ELBO_train: -3.61607180, KL_z: 0.70888457, KL_s: 0.77485147, reconstruction loss: -2.13233576
# Clusters: 10
# Epoch: [1915]  time: 79.8247, ELBO_train: -3.63918662, KL_z: 0.71512887, KL_s: 0.77787008, reconstruction loss: -2.14618766
# Clusters: 10
# Epoch: [1916]  time: 79.8621, ELBO_train: -3.65586910, KL_z: 0.71088876, KL_s: 0.77799096, reconstruction loss: -2.16698939
# Clusters: 10
# Epoch: [1917]  time: 79.8996, ELBO_train: -3.65464602, KL_z: 0.71183426, KL_s: 0.77769492, reconstruction loss: -2.16511683
# Clusters: 10
# Epoch: [1918]  time: 79.9376, ELBO_train: -3.62584171, KL_z: 0.71111680, KL_s: 0.77745008, reconstruction loss: -2.13727483
# Clusters: 10
# Epoch: [1919]  time: 79.9776, ELBO_train: -3.64049244, KL_z: 0.71388558, KL_s: 0.77653949, reconstruction loss: -2.15006737
# Clusters: 10
# Epoch: [1920]  time: 80.0152, ELBO_train: -3.60052781, KL_z: 0.71399740, KL_s: 0.77708523, reconstruction loss: -2.10944518
# Clusters: 10
# Epoch: [1921]  time: 80.0530, ELBO_train: -3.63365669, KL_z: 0.71290787, KL_s: 0.77607815, reconstruction loss: -2.14467067
# Clusters: 10
# Epoch: [1922]  time: 80.0899, ELBO_train: -3.63551226, KL_z: 0.71349722, KL_s: 0.77265007, reconstruction loss: -2.14936496
# Clusters: 10
# Epoch: [1923]  time: 80.1269, ELBO_train: -3.62696295, KL_z: 0.69743255, KL_s: 0.77729571, reconstruction loss: -2.15223469
# Clusters: 10
# Epoch: [1924]  time: 80.1633, ELBO_train: -3.61433735, KL_z: 0.70108442, KL_s: 0.77914877, reconstruction loss: -2.13410416
# Clusters: 10
# Epoch: [1925]  time: 80.2021, ELBO_train: -3.66383095, KL_z: 0.71709096, KL_s: 0.77779062, reconstruction loss: -2.16894937
# Clusters: 10
# Epoch: [1926]  time: 80.2408, ELBO_train: -3.63836203, KL_z: 0.71220363, KL_s: 0.77732570, reconstruction loss: -2.14883269
# Clusters: 10
# Epoch: [1927]  time: 80.2786, ELBO_train: -3.64490271, KL_z: 0.72079096, KL_s: 0.77741899, reconstruction loss: -2.14669275
# Clusters: 10
# Epoch: [1928]  time: 80.3163, ELBO_train: -3.63843327, KL_z: 0.71239262, KL_s: 0.77733951, reconstruction loss: -2.14870114
# Clusters: 10
# Epoch: [1929]  time: 80.3538, ELBO_train: -3.64820113, KL_z: 0.71729120, KL_s: 0.77606750, reconstruction loss: -2.15484244
# Clusters: 10
# Epoch: [1930]  time: 80.3914, ELBO_train: -3.65542684, KL_z: 0.71498189, KL_s: 0.77671328, reconstruction loss: -2.16373167
# Clusters: 10
# Epoch: [1931]  time: 80.4303, ELBO_train: -3.59393616, KL_z: 0.70399758, KL_s: 0.77422981, reconstruction loss: -2.11570877
# Clusters: 10
# Epoch: [1932]  time: 80.4678, ELBO_train: -3.59855065, KL_z: 0.71085168, KL_s: 0.77672155, reconstruction loss: -2.11097742
# Clusters: 10
# Epoch: [1933]  time: 80.5058, ELBO_train: -3.63520370, KL_z: 0.71263256, KL_s: 0.77693048, reconstruction loss: -2.14564066
# Clusters: 10
# Epoch: [1934]  time: 80.5435, ELBO_train: -3.58185387, KL_z: 0.70409436, KL_s: 0.77365701, reconstruction loss: -2.10410249
# Clusters: 10
# Epoch: [1935]  time: 80.5817, ELBO_train: -3.56741467, KL_z: 0.69873395, KL_s: 0.77726905, reconstruction loss: -2.09141166
# Clusters: 10
# Epoch: [1936]  time: 80.6189, ELBO_train: -3.63248963, KL_z: 0.69848208, KL_s: 0.77711942, reconstruction loss: -2.15688813
# Clusters: 10
# Epoch: [1937]  time: 80.6590, ELBO_train: -3.61130776, KL_z: 0.70001870, KL_s: 0.77420874, reconstruction loss: -2.13708032
# Clusters: 10
# Epoch: [1938]  time: 80.6972, ELBO_train: -3.62783813, KL_z: 0.70832793, KL_s: 0.77719486, reconstruction loss: -2.14231535
# Clusters: 10
# Epoch: [1939]  time: 80.7345, ELBO_train: -3.65433135, KL_z: 0.70411501, KL_s: 0.77565665, reconstruction loss: -2.17455969
# Clusters: 10
# Epoch: [1940]  time: 80.7723, ELBO_train: -3.60100813, KL_z: 0.70765589, KL_s: 0.77653735, reconstruction loss: -2.11681489
# Clusters: 10
# Epoch: [1941]  time: 80.8095, ELBO_train: -3.61890330, KL_z: 0.70858495, KL_s: 0.78036568, reconstruction loss: -2.12995267
# Clusters: 10
# Epoch: [1942]  time: 80.8459, ELBO_train: -3.58904638, KL_z: 0.70040046, KL_s: 0.77747269, reconstruction loss: -2.11117324
# Clusters: 10
# Epoch: [1943]  time: 80.8849, ELBO_train: -3.63107190, KL_z: 0.70400177, KL_s: 0.77786717, reconstruction loss: -2.14920295
# Clusters: 10
# Epoch: [1944]  time: 80.9233, ELBO_train: -3.64067140, KL_z: 0.70995356, KL_s: 0.77562408, reconstruction loss: -2.15509375
# Clusters: 10
# Epoch: [1945]  time: 80.9609, ELBO_train: -3.63218560, KL_z: 0.71225388, KL_s: 0.77676239, reconstruction loss: -2.14316933
# Clusters: 10
# Epoch: [1946]  time: 80.9980, ELBO_train: -3.63327637, KL_z: 0.70664746, KL_s: 0.77626705, reconstruction loss: -2.15036186
# Clusters: 10
# Epoch: [1947]  time: 81.0353, ELBO_train: -3.63963451, KL_z: 0.71634991, KL_s: 0.77613146, reconstruction loss: -2.14715314
# Clusters: 10
# Epoch: [1948]  time: 81.0730, ELBO_train: -3.67694025, KL_z: 0.71418016, KL_s: 0.77549350, reconstruction loss: -2.18726659
# Clusters: 10
# Epoch: [1949]  time: 81.1351, ELBO_train: -3.60564628, KL_z: 0.70161225, KL_s: 0.77603984, reconstruction loss: -2.12799419
# Clusters: 10
# Epoch: [1950]  time: 81.1726, ELBO_train: -3.64120550, KL_z: 0.70608171, KL_s: 0.77426562, reconstruction loss: -2.16085817
# Clusters: 10
# Epoch: [1951]  time: 81.2103, ELBO_train: -3.65318365, KL_z: 0.71199387, KL_s: 0.77691715, reconstruction loss: -2.16427263
# Clusters: 10
# Epoch: [1952]  time: 81.2477, ELBO_train: -3.64224548, KL_z: 0.71203152, KL_s: 0.77416816, reconstruction loss: -2.15604581
# Clusters: 10
# Epoch: [1953]  time: 81.2849, ELBO_train: -3.63171873, KL_z: 0.71163285, KL_s: 0.77826862, reconstruction loss: -2.14181726
# Clusters: 10
# Epoch: [1954]  time: 81.3231, ELBO_train: -3.59779730, KL_z: 0.70207475, KL_s: 0.77880554, reconstruction loss: -2.11691700
# Clusters: 10
# Epoch: [1955]  time: 81.3652, ELBO_train: -3.67411141, KL_z: 0.71186839, KL_s: 0.78125501, reconstruction loss: -2.18098801
# Clusters: 10
# Epoch: [1956]  time: 81.4028, ELBO_train: -3.60953774, KL_z: 0.70723979, KL_s: 0.77901602, reconstruction loss: -2.12328193
# Clusters: 10
# Epoch: [1957]  time: 81.4401, ELBO_train: -3.61647115, KL_z: 0.70375922, KL_s: 0.77973804, reconstruction loss: -2.13297389
# Clusters: 10
# Epoch: [1958]  time: 81.4772, ELBO_train: -3.63378539, KL_z: 0.71246558, KL_s: 0.78116963, reconstruction loss: -2.14015018
# Clusters: 10
# Epoch: [1959]  time: 81.5143, ELBO_train: -3.62097287, KL_z: 0.69913093, KL_s: 0.78239157, reconstruction loss: -2.13945037
# Clusters: 10
# Epoch: [1960]  time: 81.5520, ELBO_train: -3.68798604, KL_z: 0.70880042, KL_s: 0.78221383, reconstruction loss: -2.19697179
# Clusters: 10
# Epoch: [1961]  time: 81.5904, ELBO_train: -3.59727077, KL_z: 0.70337721, KL_s: 0.78037875, reconstruction loss: -2.11351482
# Clusters: 10
# Epoch: [1962]  time: 81.6275, ELBO_train: -3.60937386, KL_z: 0.70868628, KL_s: 0.78156886, reconstruction loss: -2.11911871
# Clusters: 10
# Epoch: [1963]  time: 81.6652, ELBO_train: -3.60606318, KL_z: 0.69814519, KL_s: 0.78304763, reconstruction loss: -2.12487036
# Clusters: 10
# Epoch: [1964]  time: 81.7031, ELBO_train: -3.63049784, KL_z: 0.71060215, KL_s: 0.78286538, reconstruction loss: -2.13703030
# Clusters: 10
# Epoch: [1965]  time: 81.7408, ELBO_train: -3.64247732, KL_z: 0.71074582, KL_s: 0.78276498, reconstruction loss: -2.14896652
# Clusters: 10
# Epoch: [1966]  time: 81.7790, ELBO_train: -3.60128117, KL_z: 0.69750367, KL_s: 0.78092368, reconstruction loss: -2.12285382
# Clusters: 10
# Epoch: [1967]  time: 81.8177, ELBO_train: -3.67050257, KL_z: 0.71021800, KL_s: 0.77977419, reconstruction loss: -2.18051038
# Clusters: 10
# Epoch: [1968]  time: 81.8560, ELBO_train: -3.66279936, KL_z: 0.71424153, KL_s: 0.78141792, reconstruction loss: -2.16713991
# Clusters: 10
# Epoch: [1969]  time: 81.8939, ELBO_train: -3.67461724, KL_z: 0.71754124, KL_s: 0.78190744, reconstruction loss: -2.17516856
# Clusters: 10
# Epoch: [1970]  time: 81.9323, ELBO_train: -3.65438080, KL_z: 0.71524739, KL_s: 0.77924082, reconstruction loss: -2.15989258
# Clusters: 10
# Epoch: [1971]  time: 81.9693, ELBO_train: -3.63118010, KL_z: 0.70977616, KL_s: 0.78197153, reconstruction loss: -2.13943241
# Clusters: 10
# Epoch: [1972]  time: 82.0069, ELBO_train: -3.58716216, KL_z: 0.69740571, KL_s: 0.78169382, reconstruction loss: -2.10806264
# Clusters: 10
# Epoch: [1973]  time: 82.0463, ELBO_train: -3.64757023, KL_z: 0.70754240, KL_s: 0.78128998, reconstruction loss: -2.15873785
# Clusters: 10
# Epoch: [1974]  time: 82.0846, ELBO_train: -3.63779435, KL_z: 0.70229590, KL_s: 0.78356142, reconstruction loss: -2.15193703
# Clusters: 10
# Epoch: [1975]  time: 82.1233, ELBO_train: -3.62751927, KL_z: 0.70397968, KL_s: 0.78228114, reconstruction loss: -2.14125845
# Clusters: 10
# Epoch: [1976]  time: 82.1604, ELBO_train: -3.62439599, KL_z: 0.70078702, KL_s: 0.78267803, reconstruction loss: -2.14093094
# Clusters: 10
# Epoch: [1977]  time: 82.1985, ELBO_train: -3.59658818, KL_z: 0.70334845, KL_s: 0.78013918, reconstruction loss: -2.11310055
# Clusters: 10
# Epoch: [1978]  time: 82.2362, ELBO_train: -3.62117848, KL_z: 0.70621052, KL_s: 0.77851279, reconstruction loss: -2.13645518
# Clusters: 10
# Epoch: [1979]  time: 82.2759, ELBO_train: -3.60855918, KL_z: 0.70762111, KL_s: 0.78249667, reconstruction loss: -2.11844140
# Clusters: 10
# Epoch: [1980]  time: 82.3132, ELBO_train: -3.65107379, KL_z: 0.70726202, KL_s: 0.78047836, reconstruction loss: -2.16333342
# Clusters: 10
# Epoch: [1981]  time: 82.3500, ELBO_train: -3.66266146, KL_z: 0.70812013, KL_s: 0.78067234, reconstruction loss: -2.17386899
# Clusters: 10
# Epoch: [1982]  time: 82.3882, ELBO_train: -3.63022628, KL_z: 0.70187519, KL_s: 0.78040764, reconstruction loss: -2.14794345
# Clusters: 10
# Epoch: [1983]  time: 82.4255, ELBO_train: -3.58982558, KL_z: 0.70212455, KL_s: 0.78207784, reconstruction loss: -2.10562320
# Clusters: 10
# Epoch: [1984]  time: 82.4633, ELBO_train: -3.62284231, KL_z: 0.70409960, KL_s: 0.78191526, reconstruction loss: -2.13682746
# Clusters: 10
# Epoch: [1985]  time: 82.5030, ELBO_train: -3.64993019, KL_z: 0.71035942, KL_s: 0.78125341, reconstruction loss: -2.15831736
# Clusters: 10
# Epoch: [1986]  time: 82.5404, ELBO_train: -3.62500820, KL_z: 0.69216070, KL_s: 0.78346345, reconstruction loss: -2.14938405
# Clusters: 10
# Epoch: [1987]  time: 82.5782, ELBO_train: -3.58425426, KL_z: 0.69899801, KL_s: 0.78144710, reconstruction loss: -2.10380915
# Clusters: 10
# Epoch: [1988]  time: 82.6161, ELBO_train: -3.63926282, KL_z: 0.69435561, KL_s: 0.78084512, reconstruction loss: -2.16406209
# Clusters: 10
# Epoch: [1989]  time: 82.6531, ELBO_train: -3.68798914, KL_z: 0.70000007, KL_s: 0.77958455, reconstruction loss: -2.20840452
# Clusters: 10
# Epoch: [1990]  time: 82.6916, ELBO_train: -3.64221697, KL_z: 0.70184042, KL_s: 0.78185511, reconstruction loss: -2.15852144
# Clusters: 10
# Epoch: [1991]  time: 82.7323, ELBO_train: -3.62603521, KL_z: 0.70611612, KL_s: 0.78140471, reconstruction loss: -2.13851439
# Clusters: 10
# Epoch: [1992]  time: 82.7704, ELBO_train: -3.67823343, KL_z: 0.71385970, KL_s: 0.77963386, reconstruction loss: -2.18473988
# Clusters: 10
# Epoch: [1993]  time: 82.8077, ELBO_train: -3.61745353, KL_z: 0.71456003, KL_s: 0.78018227, reconstruction loss: -2.12271123
# Clusters: 10
# Epoch: [1994]  time: 82.8462, ELBO_train: -3.59023499, KL_z: 0.70617307, KL_s: 0.77838781, reconstruction loss: -2.10567411
# Clusters: 10
# Epoch: [1995]  time: 82.8837, ELBO_train: -3.65966644, KL_z: 0.71144819, KL_s: 0.77986190, reconstruction loss: -2.16835635
# Clusters: 10
# Epoch: [1996]  time: 82.9208, ELBO_train: -3.61621642, KL_z: 0.70257137, KL_s: 0.78030214, reconstruction loss: -2.13334291
# Clusters: 10
# Epoch: [1997]  time: 82.9638, ELBO_train: -3.67466002, KL_z: 0.70658925, KL_s: 0.77856491, reconstruction loss: -2.18950586
# Clusters: 10
# Epoch: [1998]  time: 83.0016, ELBO_train: -3.62756004, KL_z: 0.70075510, KL_s: 0.78406205, reconstruction loss: -2.14274290
# Clusters: 10
# Epoch: [1999]  time: 83.0392, ELBO_train: -3.68502107, KL_z: 0.71050076, KL_s: 0.78309906, reconstruction loss: -2.19142125
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = utils.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = utils.samples_concatenation(samples_list)[-1]
    data_test_transformed = utils.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = utils.discrete_variables_transformation(est_data_test, feat_types_dict)

# %%
from utils import plot_true_vs_estimation
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
estimated_values = est_data_test_transformed

# Call plotting function
plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
