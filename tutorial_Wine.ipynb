# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
from utils import data_processing, visualization, statistic
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "Wine"
m_perc = 10
mask = 1
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data loading and Feature analysis

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = data_processing.read_data(data_file, feat_types_file, miss_file, true_miss_file)

# Feature analysis
data_transformed = data_processing.discrete_variables_transformation(data, feat_types_dict)
features_df = pd.DataFrame(data_transformed, columns=["feat_" + str(i+1) for i in range(data_transformed.shape[1])])

visualization.plot_data(features_df, feat_types_dict)

# %% [markdown]
# ### Experiment setting

# %%
# Train-test split
train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# Adjust batch size if larger than dataset
batch_size = 1000
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 200
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = np.random.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = data_processing.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau, n_generated_sample=1)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = statistic.samples_concatenation(samples_list)
    
    # Transform discrete variables back to the original values
    data_train_transformed = data_processing.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = data_processing.discrete_variables_transformation(est_data_train[0], feat_types_dict)
    est_data_train_mean_imputed = statistic.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = statistic.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = statistic.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    visualization.print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

visualization.plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
visualization.plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
visualization.plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 10
# Epoch: [ 0]  time: 0.2019, ELBO_train: -14.36839809, KL_z: 1.65317068, KL_s: 0.21149325, reconstruction loss: -12.50373416
# Clusters: 10
# Epoch: [ 1]  time: 0.2390, ELBO_train: -14.02346516, KL_z: 1.47294767, KL_s: 0.20276465, reconstruction loss: -12.34775283
# Clusters: 10
# Epoch: [ 2]  time: 0.2764, ELBO_train: -13.69468498, KL_z: 1.32850246, KL_s: 0.19384651, reconstruction loss: -12.17233601
# Clusters: 10
# Epoch: [ 3]  time: 0.3122, ELBO_train: -13.39487972, KL_z: 1.20067284, KL_s: 0.18655758, reconstruction loss: -12.00764930
# Clusters: 10
# Epoch: [ 4]  time: 0.3496, ELBO_train: -13.11828957, KL_z: 1.08929505, KL_s: 0.17943106, reconstruction loss: -11.84956346
# Clusters: 10
# Epoch: [ 5]  time: 0.3856, ELBO_train: -12.97092857, KL_z: 0.99984896, KL_s: 0.17282109, reconstruction loss: -11.79825852
# Clusters: 10
# Epoch: [ 6]  time: 0.4224, ELBO_train: -12.79370899, KL_z: 0.93054037, KL_s: 0.16752744, reconstruction loss: -11.69564118
# Clusters: 10
# Epoch: [ 7]  time: 0.4590, ELBO_train: -12.61781292, KL_z: 0.87137836, KL_s: 0.16267824, reconstruction loss: -11.58375632
# Clusters: 10
# Epoch: [ 8]  time: 0.4938, ELBO_train: -12.47769470, KL_z: 0.82283751, KL_s: 0.15888824, reconstruction loss: -11.49596895
# Clusters: 10
# Epoch: [ 9]  time: 0.5468, ELBO_train: -12.39127007, KL_z: 0.78741791, KL_s: 0.15481844, reconstruction loss: -11.44903371
# Clusters: 10
# Epoch: [10]  time: 0.5865, ELBO_train: -12.21094856, KL_z: 0.76332250, KL_s: 0.15183783, reconstruction loss: -11.29578824
# Clusters: 10
# Epoch: [11]  time: 0.6260, ELBO_train: -12.08008385, KL_z: 0.74777814, KL_s: 0.14921060, reconstruction loss: -11.18309511
# Clusters: 10
# Epoch: [12]  time: 0.6616, ELBO_train: -12.02871647, KL_z: 0.73326807, KL_s: 0.14687457, reconstruction loss: -11.14857383
# Clusters: 10
# Epoch: [13]  time: 0.6964, ELBO_train: -11.91097126, KL_z: 0.73425343, KL_s: 0.14517360, reconstruction loss: -11.03154423
# Clusters: 10
# Epoch: [14]  time: 0.7350, ELBO_train: -11.78238220, KL_z: 0.73051918, KL_s: 0.14301267, reconstruction loss: -10.90885036
# Clusters: 10
# Epoch: [15]  time: 0.7697, ELBO_train: -11.66314564, KL_z: 0.73740242, KL_s: 0.14083347, reconstruction loss: -10.78490975
# Clusters: 10
# Epoch: [16]  time: 0.8052, ELBO_train: -11.54009380, KL_z: 0.74846263, KL_s: 0.13918991, reconstruction loss: -10.65244126
# Clusters: 10
# Epoch: [17]  time: 0.8398, ELBO_train: -11.45818748, KL_z: 0.76443830, KL_s: 0.13777399, reconstruction loss: -10.55597520
# Clusters: 10
# Epoch: [18]  time: 0.8803, ELBO_train: -11.33667336, KL_z: 0.78398794, KL_s: 0.13643522, reconstruction loss: -10.41625019
# Clusters: 10
# Epoch: [19]  time: 0.9141, ELBO_train: -11.18421040, KL_z: 0.80727829, KL_s: 0.13517408, reconstruction loss: -10.24175802
# Clusters: 10
# Epoch: [20]  time: 0.9483, ELBO_train: -11.06672440, KL_z: 0.83493006, KL_s: 0.13470330, reconstruction loss: -10.09709103
# Clusters: 10
# Epoch: [21]  time: 0.9823, ELBO_train: -10.96420479, KL_z: 0.86484573, KL_s: 0.13367009, reconstruction loss: -9.96568897
# Clusters: 10
# Epoch: [22]  time: 1.0159, ELBO_train: -10.75482635, KL_z: 0.89722188, KL_s: 0.13283982, reconstruction loss: -9.72476466
# Clusters: 10
# Epoch: [23]  time: 1.0502, ELBO_train: -10.64035797, KL_z: 0.92972653, KL_s: 0.13235550, reconstruction loss: -9.57827594
# Clusters: 10
# Epoch: [24]  time: 1.0845, ELBO_train: -10.46215553, KL_z: 0.96727377, KL_s: 0.13200212, reconstruction loss: -9.36287965
# Clusters: 10
# Epoch: [25]  time: 1.1198, ELBO_train: -10.31430988, KL_z: 0.99984208, KL_s: 0.13139391, reconstruction loss: -9.18307389
# Clusters: 10
# Epoch: [26]  time: 1.1564, ELBO_train: -10.19926586, KL_z: 1.03840392, KL_s: 0.13112283, reconstruction loss: -9.02973912
# Clusters: 10
# Epoch: [27]  time: 1.1909, ELBO_train: -10.06592045, KL_z: 1.07711585, KL_s: 0.13117528, reconstruction loss: -8.85762932
# Clusters: 10
# Epoch: [28]  time: 1.2254, ELBO_train: -9.87646389, KL_z: 1.11687741, KL_s: 0.13140903, reconstruction loss: -8.62817745
# Clusters: 10
# Epoch: [29]  time: 1.2627, ELBO_train: -9.65834522, KL_z: 1.15223873, KL_s: 0.13169403, reconstruction loss: -8.37441247
# Clusters: 10
# Epoch: [30]  time: 1.2966, ELBO_train: -9.54045887, KL_z: 1.19318066, KL_s: 0.13184099, reconstruction loss: -8.21543722
# Clusters: 10
# Epoch: [31]  time: 1.3294, ELBO_train: -9.30533314, KL_z: 1.22591681, KL_s: 0.13205056, reconstruction loss: -7.94736576
# Clusters: 10
# Epoch: [32]  time: 1.3637, ELBO_train: -9.19626827, KL_z: 1.25916820, KL_s: 0.13247108, reconstruction loss: -7.80462899
# Clusters: 10
# Epoch: [33]  time: 1.3996, ELBO_train: -8.97421207, KL_z: 1.28339930, KL_s: 0.13284235, reconstruction loss: -7.55797043
# Clusters: 10
# Epoch: [34]  time: 1.4343, ELBO_train: -8.85959015, KL_z: 1.31182935, KL_s: 0.13322821, reconstruction loss: -7.41453259
# Clusters: 10
# Epoch: [35]  time: 1.4810, ELBO_train: -8.69608765, KL_z: 1.33636906, KL_s: 0.13403234, reconstruction loss: -7.22568624
# Clusters: 10
# Epoch: [36]  time: 1.5192, ELBO_train: -8.53360004, KL_z: 1.35933971, KL_s: 0.13492045, reconstruction loss: -7.03933988
# Clusters: 10
# Epoch: [37]  time: 1.5540, ELBO_train: -8.36948624, KL_z: 1.38276200, KL_s: 0.13553524, reconstruction loss: -6.85118899
# Clusters: 10
# Epoch: [38]  time: 1.5898, ELBO_train: -8.24157104, KL_z: 1.39788132, KL_s: 0.13587055, reconstruction loss: -6.70781918
# Clusters: 10
# Epoch: [39]  time: 1.6264, ELBO_train: -8.11797171, KL_z: 1.41447060, KL_s: 0.13665380, reconstruction loss: -6.56684730
# Clusters: 10
# Epoch: [40]  time: 1.6614, ELBO_train: -8.01431847, KL_z: 1.43272505, KL_s: 0.13717713, reconstruction loss: -6.44441628
# Clusters: 10
# Epoch: [41]  time: 1.6962, ELBO_train: -7.84752064, KL_z: 1.44846504, KL_s: 0.13803835, reconstruction loss: -6.26101725
# Clusters: 10
# Epoch: [42]  time: 1.7305, ELBO_train: -7.73712120, KL_z: 1.46428015, KL_s: 0.13923221, reconstruction loss: -6.13360884
# Clusters: 10
# Epoch: [43]  time: 1.7658, ELBO_train: -7.66098423, KL_z: 1.47611775, KL_s: 0.13982272, reconstruction loss: -6.04504375
# Clusters: 10
# Epoch: [44]  time: 1.8007, ELBO_train: -7.48481426, KL_z: 1.48476725, KL_s: 0.14080801, reconstruction loss: -5.85923901
# Clusters: 10
# Epoch: [45]  time: 1.8459, ELBO_train: -7.34908829, KL_z: 1.49250948, KL_s: 0.14179840, reconstruction loss: -5.71478040
# Clusters: 10
# Epoch: [46]  time: 1.8826, ELBO_train: -7.21157131, KL_z: 1.49110866, KL_s: 0.14256568, reconstruction loss: -5.57789698
# Clusters: 10
# Epoch: [47]  time: 1.9274, ELBO_train: -7.24336243, KL_z: 1.49405365, KL_s: 0.14268303, reconstruction loss: -5.60662575
# Clusters: 10
# Epoch: [48]  time: 1.9710, ELBO_train: -7.07463017, KL_z: 1.49223373, KL_s: 0.14318662, reconstruction loss: -5.43920982
# Clusters: 10
# Epoch: [49]  time: 2.0141, ELBO_train: -6.98370867, KL_z: 1.49712842, KL_s: 0.14358311, reconstruction loss: -5.34299715
# Clusters: 10
# Epoch: [50]  time: 2.0532, ELBO_train: -6.87233629, KL_z: 1.49767439, KL_s: 0.14452844, reconstruction loss: -5.23013346
# Clusters: 10
# Epoch: [51]  time: 2.0899, ELBO_train: -6.77127371, KL_z: 1.49254172, KL_s: 0.14465165, reconstruction loss: -5.13408034
# Clusters: 10
# Epoch: [52]  time: 2.1252, ELBO_train: -6.68372335, KL_z: 1.48807321, KL_s: 0.14551659, reconstruction loss: -5.05013356
# Clusters: 10
# Epoch: [53]  time: 2.1587, ELBO_train: -6.63571873, KL_z: 1.48381085, KL_s: 0.14621406, reconstruction loss: -5.00569382
# Clusters: 10
# Epoch: [54]  time: 2.1924, ELBO_train: -6.53195066, KL_z: 1.48470392, KL_s: 0.14669442, reconstruction loss: -4.90055232
# Clusters: 10
# Epoch: [55]  time: 2.2271, ELBO_train: -6.45306292, KL_z: 1.47946949, KL_s: 0.14709415, reconstruction loss: -4.82649927
# Clusters: 10
# Epoch: [56]  time: 2.2613, ELBO_train: -6.39123783, KL_z: 1.47753551, KL_s: 0.14826627, reconstruction loss: -4.76543605
# Clusters: 10
# Epoch: [57]  time: 2.2941, ELBO_train: -6.32342739, KL_z: 1.47483091, KL_s: 0.14900703, reconstruction loss: -4.69958944
# Clusters: 10
# Epoch: [58]  time: 2.3279, ELBO_train: -6.26092634, KL_z: 1.46726081, KL_s: 0.14940820, reconstruction loss: -4.64425733
# Clusters: 10
# Epoch: [59]  time: 2.3627, ELBO_train: -6.22810030, KL_z: 1.47394226, KL_s: 0.15019903, reconstruction loss: -4.60395901
# Clusters: 10
# Epoch: [60]  time: 2.3977, ELBO_train: -6.12413578, KL_z: 1.46786051, KL_s: 0.15182862, reconstruction loss: -4.50444665
# Clusters: 10
# Epoch: [61]  time: 2.4340, ELBO_train: -6.07755880, KL_z: 1.46898961, KL_s: 0.15230069, reconstruction loss: -4.45626850
# Clusters: 10
# Epoch: [62]  time: 2.4684, ELBO_train: -6.02351952, KL_z: 1.47267003, KL_s: 0.15248218, reconstruction loss: -4.39836731
# Clusters: 10
# Epoch: [63]  time: 2.5024, ELBO_train: -5.95624905, KL_z: 1.46991267, KL_s: 0.15337152, reconstruction loss: -4.33296485
# Clusters: 10
# Epoch: [64]  time: 2.5375, ELBO_train: -5.90850706, KL_z: 1.46387658, KL_s: 0.15440950, reconstruction loss: -4.29022098
# Clusters: 10
# Epoch: [65]  time: 2.5720, ELBO_train: -5.92409229, KL_z: 1.45990469, KL_s: 0.15496249, reconstruction loss: -4.30922511
# Clusters: 10
# Epoch: [66]  time: 2.6065, ELBO_train: -5.83944330, KL_z: 1.45439291, KL_s: 0.15523634, reconstruction loss: -4.22981405
# Clusters: 10
# Epoch: [67]  time: 2.6429, ELBO_train: -5.78042116, KL_z: 1.45635121, KL_s: 0.15507646, reconstruction loss: -4.16899350
# Clusters: 10
# Epoch: [68]  time: 2.6794, ELBO_train: -5.68038998, KL_z: 1.45587623, KL_s: 0.15462475, reconstruction loss: -4.06988900
# Clusters: 10
# Epoch: [69]  time: 2.7149, ELBO_train: -5.69190359, KL_z: 1.45473125, KL_s: 0.15487313, reconstruction loss: -4.08229921
# Clusters: 10
# Epoch: [70]  time: 2.7508, ELBO_train: -5.62473288, KL_z: 1.44579391, KL_s: 0.15575261, reconstruction loss: -4.02318635
# Clusters: 10
# Epoch: [71]  time: 2.7873, ELBO_train: -5.63634377, KL_z: 1.43903294, KL_s: 0.15649962, reconstruction loss: -4.04081120
# Clusters: 10
# Epoch: [72]  time: 2.8239, ELBO_train: -5.61653442, KL_z: 1.43732760, KL_s: 0.15823765, reconstruction loss: -4.02096918
# Clusters: 10
# Epoch: [73]  time: 2.8586, ELBO_train: -5.58161488, KL_z: 1.43738484, KL_s: 0.16002483, reconstruction loss: -3.98420520
# Clusters: 10
# Epoch: [74]  time: 2.8928, ELBO_train: -5.49734173, KL_z: 1.43638108, KL_s: 0.16266017, reconstruction loss: -3.89830048
# Clusters: 10
# Epoch: [75]  time: 2.9266, ELBO_train: -5.46164513, KL_z: 1.44682772, KL_s: 0.16338234, reconstruction loss: -3.85143507
# Clusters: 10
# Epoch: [76]  time: 2.9609, ELBO_train: -5.46173849, KL_z: 1.44877853, KL_s: 0.16439586, reconstruction loss: -3.84856410
# Clusters: 10
# Epoch: [77]  time: 2.9960, ELBO_train: -5.43500118, KL_z: 1.45674913, KL_s: 0.16539106, reconstruction loss: -3.81286099
# Clusters: 10
# Epoch: [78]  time: 3.0294, ELBO_train: -5.35593367, KL_z: 1.44805238, KL_s: 0.16625113, reconstruction loss: -3.74163015
# Clusters: 10
# Epoch: [79]  time: 3.0621, ELBO_train: -5.37102947, KL_z: 1.43531034, KL_s: 0.16764932, reconstruction loss: -3.76806982
# Clusters: 10
# Epoch: [80]  time: 3.0961, ELBO_train: -5.31587791, KL_z: 1.42882159, KL_s: 0.16881895, reconstruction loss: -3.71823738
# Clusters: 10
# Epoch: [81]  time: 3.1289, ELBO_train: -5.30133266, KL_z: 1.42066722, KL_s: 0.16990352, reconstruction loss: -3.71076193
# Clusters: 10
# Epoch: [82]  time: 3.1613, ELBO_train: -5.27911568, KL_z: 1.42453263, KL_s: 0.17097487, reconstruction loss: -3.68360817
# Clusters: 10
# Epoch: [83]  time: 3.1943, ELBO_train: -5.26215506, KL_z: 1.41624815, KL_s: 0.17276449, reconstruction loss: -3.67314241
# Clusters: 10
# Epoch: [84]  time: 3.2283, ELBO_train: -5.21546926, KL_z: 1.41818199, KL_s: 0.17407365, reconstruction loss: -3.62321362
# Clusters: 10
# Epoch: [85]  time: 3.2625, ELBO_train: -5.22573795, KL_z: 1.41176050, KL_s: 0.17509456, reconstruction loss: -3.63888290
# Clusters: 10
# Epoch: [86]  time: 3.2959, ELBO_train: -5.18724051, KL_z: 1.41886084, KL_s: 0.17734890, reconstruction loss: -3.59103076
# Clusters: 10
# Epoch: [87]  time: 3.3292, ELBO_train: -5.14224672, KL_z: 1.42396078, KL_s: 0.17857690, reconstruction loss: -3.53970904
# Clusters: 10
# Epoch: [88]  time: 3.3629, ELBO_train: -5.13688450, KL_z: 1.41555781, KL_s: 0.18017683, reconstruction loss: -3.54114985
# Clusters: 10
# Epoch: [89]  time: 3.3998, ELBO_train: -5.15125761, KL_z: 1.40957122, KL_s: 0.18189063, reconstruction loss: -3.55979576
# Clusters: 10
# Epoch: [90]  time: 3.4445, ELBO_train: -5.16592226, KL_z: 1.41631372, KL_s: 0.18388686, reconstruction loss: -3.56572168
# Clusters: 10
# Epoch: [91]  time: 3.4821, ELBO_train: -5.10752239, KL_z: 1.42689135, KL_s: 0.18538241, reconstruction loss: -3.49524863
# Clusters: 10
# Epoch: [92]  time: 3.5150, ELBO_train: -5.16964073, KL_z: 1.42332659, KL_s: 0.18678198, reconstruction loss: -3.55953217
# Clusters: 10
# Epoch: [93]  time: 3.5487, ELBO_train: -5.08118181, KL_z: 1.41971242, KL_s: 0.18659401, reconstruction loss: -3.47487538
# Clusters: 10
# Epoch: [94]  time: 3.5822, ELBO_train: -5.09639921, KL_z: 1.42743390, KL_s: 0.18615079, reconstruction loss: -3.48281453
# Clusters: 10
# Epoch: [95]  time: 3.6189, ELBO_train: -5.03715620, KL_z: 1.42630055, KL_s: 0.18645530, reconstruction loss: -3.42440035
# Clusters: 10
# Epoch: [96]  time: 3.6540, ELBO_train: -5.08139973, KL_z: 1.41154242, KL_s: 0.18823137, reconstruction loss: -3.48162594
# Clusters: 10
# Epoch: [97]  time: 3.6882, ELBO_train: -4.98421803, KL_z: 1.40671272, KL_s: 0.19089870, reconstruction loss: -3.38660660
# Clusters: 10
# Epoch: [98]  time: 3.7220, ELBO_train: -5.00309916, KL_z: 1.41220000, KL_s: 0.19517632, reconstruction loss: -3.39572284
# Clusters: 10
# Epoch: [99]  time: 3.7562, ELBO_train: -5.07207365, KL_z: 1.41170762, KL_s: 0.19919262, reconstruction loss: -3.46117342
# Clusters: 10
# Epoch: [100]  time: 3.7892, ELBO_train: -5.00854273, KL_z: 1.42204936, KL_s: 0.19840622, reconstruction loss: -3.38808715
# Clusters: 10
# Epoch: [101]  time: 3.8225, ELBO_train: -4.97870226, KL_z: 1.42695351, KL_s: 0.19753904, reconstruction loss: -3.35420971
# Clusters: 10
# Epoch: [102]  time: 3.8570, ELBO_train: -4.99034376, KL_z: 1.42720497, KL_s: 0.19554729, reconstruction loss: -3.36759150
# Clusters: 10
# Epoch: [103]  time: 3.8916, ELBO_train: -4.96545219, KL_z: 1.42731259, KL_s: 0.19325385, reconstruction loss: -3.34488575
# Clusters: 10
# Epoch: [104]  time: 3.9261, ELBO_train: -5.01819963, KL_z: 1.42629535, KL_s: 0.18909202, reconstruction loss: -3.40281227
# Clusters: 10
# Epoch: [105]  time: 3.9599, ELBO_train: -4.95320473, KL_z: 1.42833045, KL_s: 0.18762140, reconstruction loss: -3.33725288
# Clusters: 10
# Epoch: [106]  time: 3.9940, ELBO_train: -4.93744555, KL_z: 1.43051040, KL_s: 0.18743267, reconstruction loss: -3.31950247
# Clusters: 10
# Epoch: [107]  time: 4.0280, ELBO_train: -4.91833267, KL_z: 1.43154657, KL_s: 0.18732781, reconstruction loss: -3.29945829
# Clusters: 10
# Epoch: [108]  time: 4.0616, ELBO_train: -4.88275499, KL_z: 1.41845245, KL_s: 0.19151111, reconstruction loss: -3.27279143
# Clusters: 10
# Epoch: [109]  time: 4.0951, ELBO_train: -4.83322067, KL_z: 1.39469280, KL_s: 0.19676023, reconstruction loss: -3.24176764
# Clusters: 10
# Epoch: [110]  time: 4.1279, ELBO_train: -4.91710081, KL_z: 1.39424868, KL_s: 0.20142255, reconstruction loss: -3.32142959
# Clusters: 10
# Epoch: [111]  time: 4.1602, ELBO_train: -4.94302044, KL_z: 1.40369890, KL_s: 0.20759354, reconstruction loss: -3.33172801
# Clusters: 10
# Epoch: [112]  time: 4.1930, ELBO_train: -4.78645124, KL_z: 1.40194337, KL_s: 0.21102657, reconstruction loss: -3.17348130
# Clusters: 10
# Epoch: [113]  time: 4.2260, ELBO_train: -4.88944273, KL_z: 1.40610895, KL_s: 0.21119523, reconstruction loss: -3.27213855
# Clusters: 10
# Epoch: [114]  time: 4.2584, ELBO_train: -4.87125559, KL_z: 1.41103415, KL_s: 0.21063833, reconstruction loss: -3.24958310
# Clusters: 10
# Epoch: [115]  time: 4.2925, ELBO_train: -4.83659296, KL_z: 1.40421736, KL_s: 0.21004629, reconstruction loss: -3.22232931
# Clusters: 10
# Epoch: [116]  time: 4.3258, ELBO_train: -4.85756607, KL_z: 1.40442834, KL_s: 0.20815363, reconstruction loss: -3.24498410
# Clusters: 10
# Epoch: [117]  time: 4.3585, ELBO_train: -4.85823154, KL_z: 1.41460772, KL_s: 0.20533094, reconstruction loss: -3.23829288
# Clusters: 10
# Epoch: [118]  time: 4.3912, ELBO_train: -4.80979643, KL_z: 1.41140878, KL_s: 0.20351377, reconstruction loss: -3.19487388
# Clusters: 10
# Epoch: [119]  time: 4.4236, ELBO_train: -4.84215088, KL_z: 1.41678705, KL_s: 0.20306964, reconstruction loss: -3.22229419
# Clusters: 10
# Epoch: [120]  time: 4.4574, ELBO_train: -4.77918129, KL_z: 1.41936607, KL_s: 0.20293274, reconstruction loss: -3.15688248
# Clusters: 10
# Epoch: [121]  time: 4.4907, ELBO_train: -4.76197357, KL_z: 1.40896683, KL_s: 0.20219455, reconstruction loss: -3.15081220
# Clusters: 10
# Epoch: [122]  time: 4.5250, ELBO_train: -4.77597675, KL_z: 1.40319293, KL_s: 0.20148845, reconstruction loss: -3.17129538
# Clusters: 10
# Epoch: [123]  time: 4.5580, ELBO_train: -4.70827255, KL_z: 1.39881177, KL_s: 0.20198841, reconstruction loss: -3.10747237
# Clusters: 10
# Epoch: [124]  time: 4.5911, ELBO_train: -4.81182270, KL_z: 1.39775236, KL_s: 0.20296764, reconstruction loss: -3.21110270
# Clusters: 10
# Epoch: [125]  time: 4.6252, ELBO_train: -4.78276844, KL_z: 1.40134132, KL_s: 0.20469451, reconstruction loss: -3.17673261
# Clusters: 10
# Epoch: [126]  time: 4.6585, ELBO_train: -4.78301868, KL_z: 1.39299734, KL_s: 0.20855207, reconstruction loss: -3.18146927
# Clusters: 10
# Epoch: [127]  time: 4.6918, ELBO_train: -4.75889807, KL_z: 1.39879165, KL_s: 0.21082497, reconstruction loss: -3.14928145
# Clusters: 10
# Epoch: [128]  time: 4.7246, ELBO_train: -4.72760420, KL_z: 1.40658898, KL_s: 0.21381474, reconstruction loss: -3.10720048
# Clusters: 10
# Epoch: [129]  time: 4.7590, ELBO_train: -4.77215528, KL_z: 1.40523155, KL_s: 0.21609159, reconstruction loss: -3.15083215
# Clusters: 10
# Epoch: [130]  time: 4.7934, ELBO_train: -4.77068148, KL_z: 1.40215328, KL_s: 0.21644874, reconstruction loss: -3.15207946
# Clusters: 10
# Epoch: [131]  time: 4.8280, ELBO_train: -4.78506870, KL_z: 1.40997601, KL_s: 0.21901751, reconstruction loss: -3.15607519
# Clusters: 10
# Epoch: [132]  time: 4.8604, ELBO_train: -4.73154650, KL_z: 1.41439610, KL_s: 0.22076974, reconstruction loss: -3.09638066
# Clusters: 10
# Epoch: [133]  time: 4.8930, ELBO_train: -4.70877457, KL_z: 1.39993191, KL_s: 0.22131939, reconstruction loss: -3.08752327
# Clusters: 10
# Epoch: [134]  time: 4.9265, ELBO_train: -4.69339638, KL_z: 1.40173867, KL_s: 0.22007303, reconstruction loss: -3.07158468
# Clusters: 10
# Epoch: [135]  time: 4.9597, ELBO_train: -4.70639372, KL_z: 1.39287834, KL_s: 0.22172513, reconstruction loss: -3.09179025
# Clusters: 10
# Epoch: [136]  time: 4.9932, ELBO_train: -4.67995253, KL_z: 1.38209345, KL_s: 0.22397542, reconstruction loss: -3.07388365
# Clusters: 10
# Epoch: [137]  time: 5.0268, ELBO_train: -4.75347643, KL_z: 1.38399923, KL_s: 0.22431850, reconstruction loss: -3.14515870
# Clusters: 10
# Epoch: [138]  time: 5.0610, ELBO_train: -4.74649839, KL_z: 1.38675032, KL_s: 0.22384753, reconstruction loss: -3.13590055
# Clusters: 10
# Epoch: [139]  time: 5.0952, ELBO_train: -4.66484060, KL_z: 1.38075759, KL_s: 0.22444310, reconstruction loss: -3.05963991
# Clusters: 10
# Epoch: [140]  time: 5.1294, ELBO_train: -4.63292770, KL_z: 1.38896761, KL_s: 0.22409601, reconstruction loss: -3.01986408
# Clusters: 10
# Epoch: [141]  time: 5.1633, ELBO_train: -4.73159685, KL_z: 1.39903204, KL_s: 0.22405190, reconstruction loss: -3.10851290
# Clusters: 10
# Epoch: [142]  time: 5.1974, ELBO_train: -4.69210653, KL_z: 1.38874135, KL_s: 0.22340722, reconstruction loss: -3.07995796
# Clusters: 10
# Epoch: [143]  time: 5.2311, ELBO_train: -4.65125914, KL_z: 1.38752847, KL_s: 0.22206025, reconstruction loss: -3.04167042
# Clusters: 10
# Epoch: [144]  time: 5.2649, ELBO_train: -4.67522354, KL_z: 1.39829261, KL_s: 0.22117319, reconstruction loss: -3.05575774
# Clusters: 10
# Epoch: [145]  time: 5.2988, ELBO_train: -4.66728449, KL_z: 1.39182384, KL_s: 0.22031794, reconstruction loss: -3.05514271
# Clusters: 10
# Epoch: [146]  time: 5.3342, ELBO_train: -4.68382111, KL_z: 1.40400753, KL_s: 0.21933756, reconstruction loss: -3.06047602
# Clusters: 10
# Epoch: [147]  time: 5.3683, ELBO_train: -4.69830399, KL_z: 1.40722373, KL_s: 0.21897097, reconstruction loss: -3.07210929
# Clusters: 10
# Epoch: [148]  time: 5.4037, ELBO_train: -4.67308407, KL_z: 1.41175368, KL_s: 0.21924324, reconstruction loss: -3.04208715
# Clusters: 10
# Epoch: [149]  time: 5.4421, ELBO_train: -4.68351612, KL_z: 1.40500994, KL_s: 0.22148695, reconstruction loss: -3.05701923
# Clusters: 10
# Epoch: [150]  time: 5.4759, ELBO_train: -4.70436134, KL_z: 1.39783671, KL_s: 0.22300973, reconstruction loss: -3.08351490
# Clusters: 10
# Epoch: [151]  time: 5.5208, ELBO_train: -4.69629574, KL_z: 1.38844907, KL_s: 0.22306714, reconstruction loss: -3.08477952
# Clusters: 10
# Epoch: [152]  time: 5.5701, ELBO_train: -4.61075964, KL_z: 1.38499122, KL_s: 0.22272801, reconstruction loss: -3.00304041
# Clusters: 10
# Epoch: [153]  time: 5.6171, ELBO_train: -4.61569157, KL_z: 1.40436859, KL_s: 0.22177458, reconstruction loss: -2.98954840
# Clusters: 10
# Epoch: [154]  time: 5.6569, ELBO_train: -4.64879370, KL_z: 1.39143131, KL_s: 0.22179980, reconstruction loss: -3.03556259
# Clusters: 10
# Epoch: [155]  time: 5.6928, ELBO_train: -4.65583496, KL_z: 1.38295479, KL_s: 0.22283859, reconstruction loss: -3.05004158
# Clusters: 10
# Epoch: [156]  time: 5.7280, ELBO_train: -4.59989223, KL_z: 1.39110281, KL_s: 0.22330656, reconstruction loss: -2.98548286
# Clusters: 10
# Epoch: [157]  time: 5.7651, ELBO_train: -4.65569925, KL_z: 1.39080384, KL_s: 0.22270660, reconstruction loss: -3.04218881
# Clusters: 10
# Epoch: [158]  time: 5.8087, ELBO_train: -4.59800596, KL_z: 1.38777905, KL_s: 0.22320614, reconstruction loss: -2.98702078
# Clusters: 10
# Epoch: [159]  time: 5.8466, ELBO_train: -4.60195036, KL_z: 1.38934586, KL_s: 0.22302203, reconstruction loss: -2.98958247
# Clusters: 10
# Epoch: [160]  time: 5.8851, ELBO_train: -4.63841314, KL_z: 1.39040794, KL_s: 0.22216845, reconstruction loss: -3.02583675
# Clusters: 10
# Epoch: [161]  time: 5.9218, ELBO_train: -4.61705742, KL_z: 1.39106698, KL_s: 0.22207417, reconstruction loss: -3.00391626
# Clusters: 10
# Epoch: [162]  time: 5.9587, ELBO_train: -4.60597878, KL_z: 1.38989108, KL_s: 0.22262840, reconstruction loss: -2.99345930
# Clusters: 10
# Epoch: [163]  time: 5.9941, ELBO_train: -4.63529520, KL_z: 1.39264274, KL_s: 0.22286162, reconstruction loss: -3.01979084
# Clusters: 10
# Epoch: [164]  time: 6.0289, ELBO_train: -4.57762661, KL_z: 1.39226272, KL_s: 0.22337694, reconstruction loss: -2.96198695
# Clusters: 10
# Epoch: [165]  time: 6.0656, ELBO_train: -4.64004688, KL_z: 1.39143083, KL_s: 0.22380362, reconstruction loss: -3.02481244
# Clusters: 10
# Epoch: [166]  time: 6.1004, ELBO_train: -4.58124809, KL_z: 1.38709059, KL_s: 0.22429924, reconstruction loss: -2.96985826
# Clusters: 10
# Epoch: [167]  time: 6.1346, ELBO_train: -4.59871655, KL_z: 1.38087227, KL_s: 0.22300272, reconstruction loss: -2.99484155
# Clusters: 10
# Epoch: [168]  time: 6.1686, ELBO_train: -4.60063496, KL_z: 1.39410522, KL_s: 0.22372632, reconstruction loss: -2.98280342
# Clusters: 10
# Epoch: [169]  time: 6.2033, ELBO_train: -4.60026865, KL_z: 1.39056871, KL_s: 0.22358770, reconstruction loss: -2.98611224
# Clusters: 10
# Epoch: [170]  time: 6.2381, ELBO_train: -4.66201077, KL_z: 1.40074723, KL_s: 0.22465887, reconstruction loss: -3.03660467
# Clusters: 10
# Epoch: [171]  time: 6.2730, ELBO_train: -4.60855312, KL_z: 1.41252935, KL_s: 0.22481818, reconstruction loss: -2.97120559
# Clusters: 10
# Epoch: [172]  time: 6.3074, ELBO_train: -4.58804131, KL_z: 1.40269284, KL_s: 0.22438006, reconstruction loss: -2.96096840
# Clusters: 10
# Epoch: [173]  time: 6.3414, ELBO_train: -4.60887470, KL_z: 1.39976633, KL_s: 0.22448978, reconstruction loss: -2.98461859
# Clusters: 10
# Epoch: [174]  time: 6.3762, ELBO_train: -4.56956968, KL_z: 1.40250485, KL_s: 0.22430377, reconstruction loss: -2.94276106
# Clusters: 10
# Epoch: [175]  time: 6.4107, ELBO_train: -4.55210342, KL_z: 1.39630175, KL_s: 0.22450109, reconstruction loss: -2.93130059
# Clusters: 10
# Epoch: [176]  time: 6.4446, ELBO_train: -4.55871563, KL_z: 1.38797402, KL_s: 0.22539172, reconstruction loss: -2.94534988
# Clusters: 10
# Epoch: [177]  time: 6.4791, ELBO_train: -4.59358644, KL_z: 1.37380140, KL_s: 0.22579656, reconstruction loss: -2.99398849
# Clusters: 10
# Epoch: [178]  time: 6.5153, ELBO_train: -4.64316349, KL_z: 1.38043177, KL_s: 0.22648926, reconstruction loss: -3.03624246
# Clusters: 10
# Epoch: [179]  time: 6.5496, ELBO_train: -4.59452620, KL_z: 1.39751699, KL_s: 0.22547998, reconstruction loss: -2.97152922
# Clusters: 10
# Epoch: [180]  time: 6.5843, ELBO_train: -4.58277473, KL_z: 1.41046710, KL_s: 0.22533746, reconstruction loss: -2.94697018
# Clusters: 10
# Epoch: [181]  time: 6.6198, ELBO_train: -4.55617142, KL_z: 1.41471949, KL_s: 0.22404833, reconstruction loss: -2.91740360
# Clusters: 10
# Epoch: [182]  time: 6.6547, ELBO_train: -4.51377974, KL_z: 1.40421956, KL_s: 0.22182312, reconstruction loss: -2.88773706
# Clusters: 10
# Epoch: [183]  time: 6.6894, ELBO_train: -4.59440460, KL_z: 1.39462652, KL_s: 0.22154155, reconstruction loss: -2.97823653
# Clusters: 10
# Epoch: [184]  time: 6.8287, ELBO_train: -4.57846127, KL_z: 1.38079102, KL_s: 0.22117887, reconstruction loss: -2.97649138
# Clusters: 10
# Epoch: [185]  time: 6.8978, ELBO_train: -4.53177605, KL_z: 1.38839290, KL_s: 0.22088337, reconstruction loss: -2.92249978
# Clusters: 10
# Epoch: [186]  time: 6.9370, ELBO_train: -4.61237154, KL_z: 1.40942981, KL_s: 0.22057590, reconstruction loss: -2.98236582
# Clusters: 10
# Epoch: [187]  time: 6.9725, ELBO_train: -4.56182623, KL_z: 1.40168502, KL_s: 0.22157044, reconstruction loss: -2.93857076
# Clusters: 10
# Epoch: [188]  time: 7.0090, ELBO_train: -4.56978159, KL_z: 1.41199617, KL_s: 0.22284698, reconstruction loss: -2.93493843
# Clusters: 10
# Epoch: [189]  time: 7.0453, ELBO_train: -4.57440224, KL_z: 1.38722410, KL_s: 0.22416039, reconstruction loss: -2.96301775
# Clusters: 10
# Epoch: [190]  time: 7.0895, ELBO_train: -4.47164173, KL_z: 1.38844185, KL_s: 0.22764196, reconstruction loss: -2.85555792
# Clusters: 10
# Epoch: [191]  time: 7.1380, ELBO_train: -4.53622618, KL_z: 1.38540831, KL_s: 0.22898316, reconstruction loss: -2.92183471
# Clusters: 10
# Epoch: [192]  time: 7.1811, ELBO_train: -4.54405413, KL_z: 1.37313697, KL_s: 0.22947526, reconstruction loss: -2.94144189
# Clusters: 10
# Epoch: [193]  time: 7.2177, ELBO_train: -4.49696703, KL_z: 1.37217090, KL_s: 0.23169107, reconstruction loss: -2.89310505
# Clusters: 10
# Epoch: [194]  time: 7.2565, ELBO_train: -4.51965542, KL_z: 1.38176885, KL_s: 0.23549600, reconstruction loss: -2.90239058
# Clusters: 10
# Epoch: [195]  time: 7.2977, ELBO_train: -4.54642458, KL_z: 1.38732688, KL_s: 0.23916578, reconstruction loss: -2.91993191
# Clusters: 10
# Epoch: [196]  time: 7.3344, ELBO_train: -4.55192184, KL_z: 1.39458404, KL_s: 0.24106917, reconstruction loss: -2.91626863
# Clusters: 10
# Epoch: [197]  time: 7.3746, ELBO_train: -4.53420477, KL_z: 1.38166873, KL_s: 0.24151845, reconstruction loss: -2.91101758
# Clusters: 10
# Epoch: [198]  time: 7.4127, ELBO_train: -4.54208899, KL_z: 1.38354144, KL_s: 0.24178042, reconstruction loss: -2.91676712
# Clusters: 10
# Epoch: [199]  time: 7.4484, ELBO_train: -4.55139561, KL_z: 1.39551888, KL_s: 0.24170127, reconstruction loss: -2.91417546
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

# Number of samples generated by one input data
n_generated_sample = 10

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = data_processing.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3, n_generated_sample=n_generated_sample)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = statistic.samples_concatenation(samples_list)[-1]
    data_test_transformed = data_processing.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = []
    for j in range(n_generated_sample):
        est_data_test_transformed.append(data_processing.discrete_variables_transformation(est_data_test[i], feat_types_dict).unsqueeze(0))
    
    est_data_test_transformed = torch.cat(est_data_test_transformed, dim=0)

# %% [markdown]
# ### Visualize the generated samples

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
# Take first generated sample
idx = 0
estimated_values = est_data_test_transformed[idx]

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
# Take second generated sample
idx = 1
estimated_values = est_data_test_transformed[idx]

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
