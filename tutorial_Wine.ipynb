# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
from utils import data_processing, visualization, statistic
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "Wine"
m_perc = 10
mask = 1
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data loading and Feature analysis

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = data_processing.read_data(data_file, feat_types_file, miss_file, true_miss_file)

# Feature analysis
data_transformed = data_processing.discrete_variables_transformation(data, feat_types_dict)

visualization.plot_data(data_transformed, feat_types_dict)

# %% [markdown]
# ### Experiment setting

# %%
# Train-test split
train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# Adjust batch size if larger than dataset
batch_size = 1000
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 200
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = np.random.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = data_processing.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau, n_generated_sample=1)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = statistic.samples_concatenation(samples_list)
    
    # Transform discrete variables back to the original values
    data_train_transformed = data_processing.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = data_processing.discrete_variables_transformation(est_data_train[0], feat_types_dict)
    est_data_train_mean_imputed = statistic.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = statistic.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = statistic.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    visualization.print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

visualization.plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
visualization.plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
visualization.plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 10
# Epoch: [ 0]  time: 0.2265, ELBO_train: -18.20938568, KL_z: 1.82931809, KL_s: 0.14208913, reconstruction loss: -16.23797846
# Clusters: 10
# Epoch: [ 1]  time: 0.3464, ELBO_train: -17.81891289, KL_z: 1.64328074, KL_s: 0.13734684, reconstruction loss: -16.03828530
# Clusters: 10
# Epoch: [ 2]  time: 0.4706, ELBO_train: -17.54247818, KL_z: 1.48624113, KL_s: 0.13361063, reconstruction loss: -15.92262642
# Clusters: 10
# Epoch: [ 3]  time: 0.5976, ELBO_train: -17.23974342, KL_z: 1.34346678, KL_s: 0.12980628, reconstruction loss: -15.76647036
# Clusters: 10
# Epoch: [ 4]  time: 0.7181, ELBO_train: -16.96669502, KL_z: 1.23249469, KL_s: 0.12584190, reconstruction loss: -15.60835843
# Clusters: 10
# Epoch: [ 5]  time: 0.8406, ELBO_train: -16.79784317, KL_z: 1.13557677, KL_s: 0.12262893, reconstruction loss: -15.53963747
# Clusters: 10
# Epoch: [ 6]  time: 1.0003, ELBO_train: -16.56105843, KL_z: 1.05421662, KL_s: 0.11936717, reconstruction loss: -15.38747463
# Clusters: 10
# Epoch: [ 7]  time: 1.1219, ELBO_train: -16.36146049, KL_z: 0.99540616, KL_s: 0.11653366, reconstruction loss: -15.24952067
# Clusters: 10
# Epoch: [ 8]  time: 1.2482, ELBO_train: -16.08722744, KL_z: 0.94270018, KL_s: 0.11436453, reconstruction loss: -15.03016273
# Clusters: 10
# Epoch: [ 9]  time: 1.3796, ELBO_train: -16.01754742, KL_z: 0.90571072, KL_s: 0.11210675, reconstruction loss: -14.99972994
# Clusters: 10
# Epoch: [10]  time: 1.5103, ELBO_train: -15.87071438, KL_z: 0.88110603, KL_s: 0.11088843, reconstruction loss: -14.87871991
# Clusters: 10
# Epoch: [11]  time: 1.6361, ELBO_train: -15.63653202, KL_z: 0.85847998, KL_s: 0.10999408, reconstruction loss: -14.66805797
# Clusters: 10
# Epoch: [12]  time: 1.7682, ELBO_train: -15.52226944, KL_z: 0.85032306, KL_s: 0.10923018, reconstruction loss: -14.56271620
# Clusters: 10
# Epoch: [13]  time: 1.9015, ELBO_train: -15.39267120, KL_z: 0.85225500, KL_s: 0.10882831, reconstruction loss: -14.43158790
# Clusters: 10
# Epoch: [14]  time: 2.0282, ELBO_train: -15.23707600, KL_z: 0.86151428, KL_s: 0.10914369, reconstruction loss: -14.26641803
# Clusters: 10
# Epoch: [15]  time: 2.1529, ELBO_train: -15.06150494, KL_z: 0.87422719, KL_s: 0.10938168, reconstruction loss: -14.07789607
# Clusters: 10
# Epoch: [16]  time: 2.2791, ELBO_train: -15.00266018, KL_z: 0.88798027, KL_s: 0.11012731, reconstruction loss: -14.00455260
# Clusters: 10
# Epoch: [17]  time: 2.4011, ELBO_train: -14.82977962, KL_z: 0.91117979, KL_s: 0.11124763, reconstruction loss: -13.80735220
# Clusters: 10
# Epoch: [18]  time: 2.5363, ELBO_train: -14.66770153, KL_z: 0.94129984, KL_s: 0.11243052, reconstruction loss: -13.61397116
# Clusters: 10
# Epoch: [19]  time: 2.7970, ELBO_train: -14.50459080, KL_z: 0.97356131, KL_s: 0.11372881, reconstruction loss: -13.41730068
# Clusters: 10
# Epoch: [20]  time: 2.9226, ELBO_train: -14.38592186, KL_z: 1.00984304, KL_s: 0.11532888, reconstruction loss: -13.26074994
# Clusters: 10
# Epoch: [21]  time: 3.0550, ELBO_train: -14.18553619, KL_z: 1.04815934, KL_s: 0.11705599, reconstruction loss: -13.02032087
# Clusters: 9
# Epoch: [22]  time: 3.1832, ELBO_train: -14.05482559, KL_z: 1.08321044, KL_s: 0.11882300, reconstruction loss: -12.85279214
# Clusters: 9
# Epoch: [23]  time: 3.3116, ELBO_train: -13.88785839, KL_z: 1.11893928, KL_s: 0.12055378, reconstruction loss: -12.64836533
# Clusters: 9
# Epoch: [24]  time: 3.4405, ELBO_train: -13.65465908, KL_z: 1.15578313, KL_s: 0.12229705, reconstruction loss: -12.37657890
# Clusters: 9
# Epoch: [25]  time: 3.5678, ELBO_train: -13.52623596, KL_z: 1.19255843, KL_s: 0.12401004, reconstruction loss: -12.20966749
# Clusters: 9
# Epoch: [26]  time: 3.6975, ELBO_train: -13.34062748, KL_z: 1.23125403, KL_s: 0.12559128, reconstruction loss: -11.98378217
# Clusters: 9
# Epoch: [27]  time: 3.8234, ELBO_train: -13.17766800, KL_z: 1.26541564, KL_s: 0.12764125, reconstruction loss: -11.78461111
# Clusters: 9
# Epoch: [28]  time: 3.9565, ELBO_train: -13.07239647, KL_z: 1.30258391, KL_s: 0.12991128, reconstruction loss: -11.63990128
# Clusters: 9
# Epoch: [29]  time: 4.0857, ELBO_train: -12.95355511, KL_z: 1.33362656, KL_s: 0.13196635, reconstruction loss: -11.48796220
# Clusters: 9
# Epoch: [30]  time: 4.2268, ELBO_train: -12.74514103, KL_z: 1.37097259, KL_s: 0.13362718, reconstruction loss: -11.24054127
# Clusters: 9
# Epoch: [31]  time: 4.3600, ELBO_train: -12.57921104, KL_z: 1.41191320, KL_s: 0.13529277, reconstruction loss: -11.03200507
# Clusters: 9
# Epoch: [32]  time: 4.4927, ELBO_train: -12.45958271, KL_z: 1.44779663, KL_s: 0.13689432, reconstruction loss: -10.87489176
# Clusters: 9
# Epoch: [33]  time: 4.6281, ELBO_train: -12.32565384, KL_z: 1.48450701, KL_s: 0.13888693, reconstruction loss: -10.70225990
# Clusters: 9
# Epoch: [34]  time: 4.8313, ELBO_train: -12.17552834, KL_z: 1.51004066, KL_s: 0.14019217, reconstruction loss: -10.52529550
# Clusters: 9
# Epoch: [35]  time: 4.9783, ELBO_train: -11.93234138, KL_z: 1.53520267, KL_s: 0.14180055, reconstruction loss: -10.25533817
# Clusters: 9
# Epoch: [36]  time: 5.1105, ELBO_train: -11.81787777, KL_z: 1.55350461, KL_s: 0.14333997, reconstruction loss: -10.12103319
# Clusters: 9
# Epoch: [37]  time: 5.2538, ELBO_train: -11.70515442, KL_z: 1.56642895, KL_s: 0.14387403, reconstruction loss: -9.99485145
# Clusters: 9
# Epoch: [38]  time: 5.3863, ELBO_train: -11.57689209, KL_z: 1.58147690, KL_s: 0.14459291, reconstruction loss: -9.85082228
# Clusters: 9
# Epoch: [39]  time: 5.5135, ELBO_train: -11.49444466, KL_z: 1.59281480, KL_s: 0.14577727, reconstruction loss: -9.75585258
# Clusters: 9
# Epoch: [40]  time: 5.6653, ELBO_train: -11.30777225, KL_z: 1.60483394, KL_s: 0.14644980, reconstruction loss: -9.55648851
# Clusters: 9
# Epoch: [41]  time: 5.8074, ELBO_train: -11.13940067, KL_z: 1.62703137, KL_s: 0.14690008, reconstruction loss: -9.36546922
# Clusters: 9
# Epoch: [42]  time: 5.9485, ELBO_train: -11.10852699, KL_z: 1.63713915, KL_s: 0.14715552, reconstruction loss: -9.32423232
# Clusters: 9
# Epoch: [43]  time: 6.0902, ELBO_train: -10.97451591, KL_z: 1.65284493, KL_s: 0.14797029, reconstruction loss: -9.17370069
# Clusters: 9
# Epoch: [44]  time: 6.2473, ELBO_train: -10.85262146, KL_z: 1.66575985, KL_s: 0.14921460, reconstruction loss: -9.03764701
# Clusters: 9
# Epoch: [45]  time: 6.3793, ELBO_train: -10.78334198, KL_z: 1.67637155, KL_s: 0.14977160, reconstruction loss: -8.95719883
# Clusters: 9
# Epoch: [46]  time: 6.5155, ELBO_train: -10.66186829, KL_z: 1.68320289, KL_s: 0.15008807, reconstruction loss: -8.82857733
# Clusters: 9
# Epoch: [47]  time: 6.6567, ELBO_train: -10.61572132, KL_z: 1.69446924, KL_s: 0.15103793, reconstruction loss: -8.77021415
# Clusters: 9
# Epoch: [48]  time: 6.7935, ELBO_train: -10.51635303, KL_z: 1.70563653, KL_s: 0.15172877, reconstruction loss: -8.65898774
# Clusters: 9
# Epoch: [49]  time: 6.9290, ELBO_train: -10.34920845, KL_z: 1.70303516, KL_s: 0.15271978, reconstruction loss: -8.49345350
# Clusters: 9
# Epoch: [50]  time: 7.1515, ELBO_train: -10.27284069, KL_z: 1.70769365, KL_s: 0.15287604, reconstruction loss: -8.41227100
# Clusters: 9
# Epoch: [51]  time: 7.2843, ELBO_train: -10.19926968, KL_z: 1.69086502, KL_s: 0.15334187, reconstruction loss: -8.35506279
# Clusters: 9
# Epoch: [52]  time: 7.4177, ELBO_train: -10.17999096, KL_z: 1.67982094, KL_s: 0.15412807, reconstruction loss: -8.34604194
# Clusters: 9
# Epoch: [53]  time: 7.5956, ELBO_train: -10.02758865, KL_z: 1.68226140, KL_s: 0.15531573, reconstruction loss: -8.19001153
# Clusters: 9
# Epoch: [54]  time: 7.7537, ELBO_train: -9.98077831, KL_z: 1.68764663, KL_s: 0.15576568, reconstruction loss: -8.13736601
# Clusters: 9
# Epoch: [55]  time: 7.8980, ELBO_train: -9.98418121, KL_z: 1.70351698, KL_s: 0.15685434, reconstruction loss: -8.12380989
# Clusters: 10
# Epoch: [56]  time: 8.0341, ELBO_train: -9.83779335, KL_z: 1.70575361, KL_s: 0.15752721, reconstruction loss: -7.97451253
# Clusters: 10
# Epoch: [57]  time: 8.1657, ELBO_train: -9.82485161, KL_z: 1.70865233, KL_s: 0.15799723, reconstruction loss: -7.95820205
# Clusters: 10
# Epoch: [58]  time: 8.2980, ELBO_train: -9.76824360, KL_z: 1.71470540, KL_s: 0.15783057, reconstruction loss: -7.89570763
# Clusters: 10
# Epoch: [59]  time: 8.4308, ELBO_train: -9.69922218, KL_z: 1.71185534, KL_s: 0.15779138, reconstruction loss: -7.82957547
# Clusters: 10
# Epoch: [60]  time: 8.6028, ELBO_train: -9.59402981, KL_z: 1.71422625, KL_s: 0.15793638, reconstruction loss: -7.72186718
# Clusters: 10
# Epoch: [61]  time: 8.7854, ELBO_train: -9.48237896, KL_z: 1.70614848, KL_s: 0.15832720, reconstruction loss: -7.61790328
# Clusters: 10
# Epoch: [62]  time: 8.9346, ELBO_train: -9.46468697, KL_z: 1.68834963, KL_s: 0.15900364, reconstruction loss: -7.61733370
# Clusters: 10
# Epoch: [63]  time: 9.0698, ELBO_train: -9.46404457, KL_z: 1.68130877, KL_s: 0.15992475, reconstruction loss: -7.62281106
# Clusters: 10
# Epoch: [64]  time: 9.2185, ELBO_train: -9.40044785, KL_z: 1.68432460, KL_s: 0.16016974, reconstruction loss: -7.55595350
# Clusters: 10
# Epoch: [65]  time: 9.4193, ELBO_train: -9.30323048, KL_z: 1.69089334, KL_s: 0.16127949, reconstruction loss: -7.45105765
# Clusters: 10
# Epoch: [66]  time: 9.5602, ELBO_train: -9.27758560, KL_z: 1.68279810, KL_s: 0.16067085, reconstruction loss: -7.43411665
# Clusters: 10
# Epoch: [67]  time: 9.7003, ELBO_train: -9.20336838, KL_z: 1.67852371, KL_s: 0.16172752, reconstruction loss: -7.36311715
# Clusters: 10
# Epoch: [68]  time: 9.8456, ELBO_train: -9.23282757, KL_z: 1.67069609, KL_s: 0.16221776, reconstruction loss: -7.39991372
# Clusters: 10
# Epoch: [69]  time: 9.9840, ELBO_train: -9.11571007, KL_z: 1.67333186, KL_s: 0.16242547, reconstruction loss: -7.27995274
# Clusters: 10
# Epoch: [70]  time: 10.1692, ELBO_train: -9.10397663, KL_z: 1.66488280, KL_s: 0.16285300, reconstruction loss: -7.27624083
# Clusters: 10
# Epoch: [71]  time: 10.3542, ELBO_train: -9.11173058, KL_z: 1.66382418, KL_s: 0.16222878, reconstruction loss: -7.28567762
# Clusters: 10
# Epoch: [72]  time: 10.5147, ELBO_train: -9.03104019, KL_z: 1.65914192, KL_s: 0.16223698, reconstruction loss: -7.20966129
# Clusters: 10
# Epoch: [73]  time: 10.6530, ELBO_train: -9.05001144, KL_z: 1.66762872, KL_s: 0.16190019, reconstruction loss: -7.22048254
# Clusters: 10
# Epoch: [74]  time: 10.8743, ELBO_train: -8.95761871, KL_z: 1.66650262, KL_s: 0.16240067, reconstruction loss: -7.12871542
# Clusters: 10
# Epoch: [75]  time: 11.0124, ELBO_train: -8.92729626, KL_z: 1.66559622, KL_s: 0.16342859, reconstruction loss: -7.09827144
# Clusters: 10
# Epoch: [76]  time: 11.1837, ELBO_train: -8.91495724, KL_z: 1.66086659, KL_s: 0.16367068, reconstruction loss: -7.09041996
# Clusters: 10
# Epoch: [77]  time: 11.3250, ELBO_train: -8.84233112, KL_z: 1.65832062, KL_s: 0.16456361, reconstruction loss: -7.01944690
# Clusters: 10
# Epoch: [78]  time: 11.4679, ELBO_train: -8.77092838, KL_z: 1.64733288, KL_s: 0.16595874, reconstruction loss: -6.95763676
# Clusters: 10
# Epoch: [79]  time: 11.6052, ELBO_train: -8.83444080, KL_z: 1.63238852, KL_s: 0.16715078, reconstruction loss: -7.03490150
# Clusters: 10
# Epoch: [80]  time: 11.7403, ELBO_train: -8.82435303, KL_z: 1.64004281, KL_s: 0.16903214, reconstruction loss: -7.01527808
# Clusters: 10
# Epoch: [81]  time: 11.9944, ELBO_train: -8.78924351, KL_z: 1.64170721, KL_s: 0.17058263, reconstruction loss: -6.97695367
# Clusters: 10
# Epoch: [82]  time: 12.1354, ELBO_train: -8.71454067, KL_z: 1.64008496, KL_s: 0.17067509, reconstruction loss: -6.90378063
# Clusters: 10
# Epoch: [83]  time: 12.2795, ELBO_train: -8.76208630, KL_z: 1.65351803, KL_s: 0.17067699, reconstruction loss: -6.93789127
# Clusters: 10
# Epoch: [84]  time: 12.4193, ELBO_train: -8.69281902, KL_z: 1.64957714, KL_s: 0.17184696, reconstruction loss: -6.87139492
# Clusters: 10
# Epoch: [85]  time: 12.5584, ELBO_train: -8.67801743, KL_z: 1.63633807, KL_s: 0.17315726, reconstruction loss: -6.86852210
# Clusters: 10
# Epoch: [86]  time: 12.7039, ELBO_train: -8.67967014, KL_z: 1.63627882, KL_s: 0.17352605, reconstruction loss: -6.86986527
# Clusters: 10
# Epoch: [87]  time: 12.8499, ELBO_train: -8.60827141, KL_z: 1.63178813, KL_s: 0.17423716, reconstruction loss: -6.80224612
# Clusters: 10
# Epoch: [88]  time: 12.9898, ELBO_train: -8.62454662, KL_z: 1.62335985, KL_s: 0.17411394, reconstruction loss: -6.82707283
# Clusters: 10
# Epoch: [89]  time: 13.1287, ELBO_train: -8.56010361, KL_z: 1.62039208, KL_s: 0.17424984, reconstruction loss: -6.76546168
# Clusters: 10
# Epoch: [90]  time: 13.2716, ELBO_train: -8.62322369, KL_z: 1.61845167, KL_s: 0.17419930, reconstruction loss: -6.83057272
# Clusters: 10
# Epoch: [91]  time: 13.4141, ELBO_train: -8.56438560, KL_z: 1.62384846, KL_s: 0.17349191, reconstruction loss: -6.76704524
# Clusters: 10
# Epoch: [92]  time: 13.5718, ELBO_train: -8.50916252, KL_z: 1.62579393, KL_s: 0.17359037, reconstruction loss: -6.70977821
# Clusters: 10
# Epoch: [93]  time: 13.7265, ELBO_train: -8.56882420, KL_z: 1.62316999, KL_s: 0.17456675, reconstruction loss: -6.77108746
# Clusters: 10
# Epoch: [94]  time: 13.8848, ELBO_train: -8.48607597, KL_z: 1.63105922, KL_s: 0.17689447, reconstruction loss: -6.67812228
# Clusters: 10
# Epoch: [95]  time: 14.0284, ELBO_train: -8.50477886, KL_z: 1.62913327, KL_s: 0.17880697, reconstruction loss: -6.69683862
# Clusters: 10
# Epoch: [96]  time: 14.2433, ELBO_train: -8.56975498, KL_z: 1.61881175, KL_s: 0.17986298, reconstruction loss: -6.77108026
# Clusters: 10
# Epoch: [97]  time: 14.3771, ELBO_train: -8.45516777, KL_z: 1.61872904, KL_s: 0.18225780, reconstruction loss: -6.65418093
# Clusters: 10
# Epoch: [98]  time: 14.5178, ELBO_train: -8.44677200, KL_z: 1.61813405, KL_s: 0.18485827, reconstruction loss: -6.64377968
# Clusters: 10
# Epoch: [99]  time: 14.6577, ELBO_train: -8.45233269, KL_z: 1.60379775, KL_s: 0.18894563, reconstruction loss: -6.65958931
# Clusters: 10
# Epoch: [100]  time: 14.8008, ELBO_train: -8.44928627, KL_z: 1.60378351, KL_s: 0.19294744, reconstruction loss: -6.65255532
# Clusters: 10
# Epoch: [101]  time: 14.9424, ELBO_train: -8.42322311, KL_z: 1.61266403, KL_s: 0.19283867, reconstruction loss: -6.61772041
# Clusters: 10
# Epoch: [102]  time: 15.0823, ELBO_train: -8.45672474, KL_z: 1.62463305, KL_s: 0.19042950, reconstruction loss: -6.64166219
# Clusters: 10
# Epoch: [103]  time: 15.2237, ELBO_train: -8.40935745, KL_z: 1.61934211, KL_s: 0.18704185, reconstruction loss: -6.60297348
# Clusters: 10
# Epoch: [104]  time: 15.3668, ELBO_train: -8.37912827, KL_z: 1.61690660, KL_s: 0.18470001, reconstruction loss: -6.57752166
# Clusters: 10
# Epoch: [105]  time: 15.5087, ELBO_train: -8.38271160, KL_z: 1.61688867, KL_s: 0.17940788, reconstruction loss: -6.58641505
# Clusters: 10
# Epoch: [106]  time: 15.6490, ELBO_train: -8.39450989, KL_z: 1.62477808, KL_s: 0.17603827, reconstruction loss: -6.59369354
# Clusters: 10
# Epoch: [107]  time: 15.7915, ELBO_train: -8.40650501, KL_z: 1.63079045, KL_s: 0.17270274, reconstruction loss: -6.60301182
# Clusters: 10
# Epoch: [108]  time: 15.9336, ELBO_train: -8.38423977, KL_z: 1.64169714, KL_s: 0.17038031, reconstruction loss: -6.57216232
# Clusters: 10
# Epoch: [109]  time: 16.0722, ELBO_train: -8.36344337, KL_z: 1.64445250, KL_s: 0.16743846, reconstruction loss: -6.55155241
# Clusters: 10
# Epoch: [110]  time: 16.2166, ELBO_train: -8.38343544, KL_z: 1.62619808, KL_s: 0.17052975, reconstruction loss: -6.58670762
# Clusters: 10
# Epoch: [111]  time: 16.3584, ELBO_train: -8.30694675, KL_z: 1.63247058, KL_s: 0.17464385, reconstruction loss: -6.49983232
# Clusters: 10
# Epoch: [112]  time: 16.5711, ELBO_train: -8.29147053, KL_z: 1.62284350, KL_s: 0.17878995, reconstruction loss: -6.48983707
# Clusters: 10
# Epoch: [113]  time: 16.7090, ELBO_train: -8.28697729, KL_z: 1.62916813, KL_s: 0.18232327, reconstruction loss: -6.47548590
# Clusters: 10
# Epoch: [114]  time: 16.8506, ELBO_train: -8.26109524, KL_z: 1.61002271, KL_s: 0.18361716, reconstruction loss: -6.46745536
# Clusters: 10
# Epoch: [115]  time: 16.9908, ELBO_train: -8.28392086, KL_z: 1.61209133, KL_s: 0.18262835, reconstruction loss: -6.48920119
# Clusters: 10
# Epoch: [116]  time: 17.1293, ELBO_train: -8.30244751, KL_z: 1.61017818, KL_s: 0.18062906, reconstruction loss: -6.51164026
# Clusters: 10
# Epoch: [117]  time: 17.2712, ELBO_train: -8.30802441, KL_z: 1.62104642, KL_s: 0.18048701, reconstruction loss: -6.50649097
# Clusters: 10
# Epoch: [118]  time: 17.4472, ELBO_train: -8.25299511, KL_z: 1.62790332, KL_s: 0.18006115, reconstruction loss: -6.44503064
# Clusters: 10
# Epoch: [119]  time: 17.5908, ELBO_train: -8.22403049, KL_z: 1.62502487, KL_s: 0.17988672, reconstruction loss: -6.41911891
# Clusters: 10
# Epoch: [120]  time: 17.7314, ELBO_train: -8.20930777, KL_z: 1.61972876, KL_s: 0.18065901, reconstruction loss: -6.40892000
# Clusters: 10
# Epoch: [121]  time: 17.8723, ELBO_train: -8.28553886, KL_z: 1.61918764, KL_s: 0.17982922, reconstruction loss: -6.48652201
# Clusters: 10
# Epoch: [122]  time: 18.0080, ELBO_train: -8.23906841, KL_z: 1.62438531, KL_s: 0.17890544, reconstruction loss: -6.43577766
# Clusters: 10
# Epoch: [123]  time: 18.1430, ELBO_train: -8.28433590, KL_z: 1.63683872, KL_s: 0.17769613, reconstruction loss: -6.46980104
# Clusters: 10
# Epoch: [124]  time: 18.2740, ELBO_train: -8.23623905, KL_z: 1.64217322, KL_s: 0.17722440, reconstruction loss: -6.41684144
# Clusters: 10
# Epoch: [125]  time: 18.4078, ELBO_train: -8.16836119, KL_z: 1.63194847, KL_s: 0.17868309, reconstruction loss: -6.35772963
# Clusters: 10
# Epoch: [126]  time: 18.5425, ELBO_train: -8.18704739, KL_z: 1.63137426, KL_s: 0.18108687, reconstruction loss: -6.37458625
# Clusters: 10
# Epoch: [127]  time: 18.6718, ELBO_train: -8.21143093, KL_z: 1.62809589, KL_s: 0.18241010, reconstruction loss: -6.40092494
# Clusters: 10
# Epoch: [128]  time: 18.8670, ELBO_train: -8.15594730, KL_z: 1.62002685, KL_s: 0.18423047, reconstruction loss: -6.35168998
# Clusters: 10
# Epoch: [129]  time: 19.0048, ELBO_train: -8.15154438, KL_z: 1.60720546, KL_s: 0.18686471, reconstruction loss: -6.35747421
# Clusters: 10
# Epoch: [130]  time: 19.1381, ELBO_train: -8.12759676, KL_z: 1.60455472, KL_s: 0.18966136, reconstruction loss: -6.33338068
# Clusters: 10
# Epoch: [131]  time: 19.2695, ELBO_train: -8.16747541, KL_z: 1.60749838, KL_s: 0.19034214, reconstruction loss: -6.36963489
# Clusters: 10
# Epoch: [132]  time: 19.4048, ELBO_train: -8.16567860, KL_z: 1.61517150, KL_s: 0.19100823, reconstruction loss: -6.35949886
# Clusters: 10
# Epoch: [133]  time: 19.5331, ELBO_train: -8.17558317, KL_z: 1.63304524, KL_s: 0.19061933, reconstruction loss: -6.35191860
# Clusters: 10
# Epoch: [134]  time: 19.6644, ELBO_train: -8.20496063, KL_z: 1.64166429, KL_s: 0.19033232, reconstruction loss: -6.37296402
# Clusters: 10
# Epoch: [135]  time: 19.7972, ELBO_train: -8.07751675, KL_z: 1.65438631, KL_s: 0.19091892, reconstruction loss: -6.23221152
# Clusters: 10
# Epoch: [136]  time: 19.9346, ELBO_train: -8.14829025, KL_z: 1.64098296, KL_s: 0.18980331, reconstruction loss: -6.31750398
# Clusters: 10
# Epoch: [137]  time: 20.0690, ELBO_train: -8.11597586, KL_z: 1.62899466, KL_s: 0.19038711, reconstruction loss: -6.29659410
# Clusters: 10
# Epoch: [138]  time: 20.1993, ELBO_train: -8.11672506, KL_z: 1.62034631, KL_s: 0.19008040, reconstruction loss: -6.30629835
# Clusters: 10
# Epoch: [139]  time: 20.3318, ELBO_train: -8.12771149, KL_z: 1.62090909, KL_s: 0.19032793, reconstruction loss: -6.31647446
# Clusters: 10
# Epoch: [140]  time: 20.4652, ELBO_train: -8.04614067, KL_z: 1.62193167, KL_s: 0.18968577, reconstruction loss: -6.23452322
# Clusters: 10
# Epoch: [141]  time: 20.6036, ELBO_train: -8.14744339, KL_z: 1.61806726, KL_s: 0.18814936, reconstruction loss: -6.34122677
# Clusters: 10
# Epoch: [142]  time: 20.7346, ELBO_train: -8.12434435, KL_z: 1.62262261, KL_s: 0.18765349, reconstruction loss: -6.31406825
# Clusters: 10
# Epoch: [143]  time: 20.9305, ELBO_train: -8.04765892, KL_z: 1.64424372, KL_s: 0.18794918, reconstruction loss: -6.21546602
# Clusters: 10
# Epoch: [144]  time: 21.0634, ELBO_train: -8.05647278, KL_z: 1.62873847, KL_s: 0.18721037, reconstruction loss: -6.24052393
# Clusters: 10
# Epoch: [145]  time: 21.1922, ELBO_train: -8.10252810, KL_z: 1.64840801, KL_s: 0.18621812, reconstruction loss: -6.26790197
# Clusters: 10
# Epoch: [146]  time: 21.3296, ELBO_train: -8.10490847, KL_z: 1.63895447, KL_s: 0.18497448, reconstruction loss: -6.28097951
# Clusters: 10
# Epoch: [147]  time: 21.4675, ELBO_train: -8.07716551, KL_z: 1.64237583, KL_s: 0.18423162, reconstruction loss: -6.25055807
# Clusters: 10
# Epoch: [148]  time: 21.6050, ELBO_train: -8.11203995, KL_z: 1.64618320, KL_s: 0.18469934, reconstruction loss: -6.28115740
# Clusters: 10
# Epoch: [149]  time: 21.7388, ELBO_train: -8.10407772, KL_z: 1.65485480, KL_s: 0.18575082, reconstruction loss: -6.26347210
# Clusters: 10
# Epoch: [150]  time: 21.8742, ELBO_train: -8.06129055, KL_z: 1.64982994, KL_s: 0.18596931, reconstruction loss: -6.22549131
# Clusters: 10
# Epoch: [151]  time: 22.0040, ELBO_train: -8.01079216, KL_z: 1.65219393, KL_s: 0.18654547, reconstruction loss: -6.17205276
# Clusters: 10
# Epoch: [152]  time: 22.1412, ELBO_train: -8.07547197, KL_z: 1.64051964, KL_s: 0.18665586, reconstruction loss: -6.24829648
# Clusters: 10
# Epoch: [153]  time: 22.2806, ELBO_train: -8.05151424, KL_z: 1.63107958, KL_s: 0.18723063, reconstruction loss: -6.23320403
# Clusters: 10
# Epoch: [154]  time: 22.4140, ELBO_train: -8.02668009, KL_z: 1.64898670, KL_s: 0.18911309, reconstruction loss: -6.18858030
# Clusters: 10
# Epoch: [155]  time: 22.5473, ELBO_train: -8.03763361, KL_z: 1.65114188, KL_s: 0.18962774, reconstruction loss: -6.19686399
# Clusters: 10
# Epoch: [156]  time: 22.6783, ELBO_train: -8.05413399, KL_z: 1.64565699, KL_s: 0.19185505, reconstruction loss: -6.21662195
# Clusters: 10
# Epoch: [157]  time: 22.8137, ELBO_train: -8.01599798, KL_z: 1.64709091, KL_s: 0.19283390, reconstruction loss: -6.17607317
# Clusters: 10
# Epoch: [158]  time: 22.9502, ELBO_train: -8.05096579, KL_z: 1.65288563, KL_s: 0.19263401, reconstruction loss: -6.20544615
# Clusters: 10
# Epoch: [159]  time: 23.1484, ELBO_train: -8.07603569, KL_z: 1.64070971, KL_s: 0.19311204, reconstruction loss: -6.24221394
# Clusters: 10
# Epoch: [160]  time: 23.2884, ELBO_train: -8.05142536, KL_z: 1.65106702, KL_s: 0.19413285, reconstruction loss: -6.20622549
# Clusters: 10
# Epoch: [161]  time: 23.4184, ELBO_train: -8.04604626, KL_z: 1.64944174, KL_s: 0.19380064, reconstruction loss: -6.20280387
# Clusters: 10
# Epoch: [162]  time: 23.5506, ELBO_train: -8.02568016, KL_z: 1.66017582, KL_s: 0.19490685, reconstruction loss: -6.17059748
# Clusters: 10
# Epoch: [163]  time: 23.6843, ELBO_train: -8.01940937, KL_z: 1.64345489, KL_s: 0.19583960, reconstruction loss: -6.18011489
# Clusters: 10
# Epoch: [164]  time: 23.8197, ELBO_train: -7.99236965, KL_z: 1.64983826, KL_s: 0.19768233, reconstruction loss: -6.14484906
# Clusters: 10
# Epoch: [165]  time: 23.9563, ELBO_train: -8.00790052, KL_z: 1.64542768, KL_s: 0.20119610, reconstruction loss: -6.16127675
# Clusters: 10
# Epoch: [166]  time: 24.0891, ELBO_train: -7.99912186, KL_z: 1.64549439, KL_s: 0.20372710, reconstruction loss: -6.14990036
# Clusters: 10
# Epoch: [167]  time: 24.2173, ELBO_train: -8.02031803, KL_z: 1.65930722, KL_s: 0.20509634, reconstruction loss: -6.15591447
# Clusters: 10
# Epoch: [168]  time: 24.3541, ELBO_train: -7.98744431, KL_z: 1.63828256, KL_s: 0.20762367, reconstruction loss: -6.14153807
# Clusters: 10
# Epoch: [169]  time: 24.4862, ELBO_train: -7.99004431, KL_z: 1.63844323, KL_s: 0.21013064, reconstruction loss: -6.14147043
# Clusters: 10
# Epoch: [170]  time: 24.6165, ELBO_train: -8.00736561, KL_z: 1.65117705, KL_s: 0.21064935, reconstruction loss: -6.14553921
# Clusters: 10
# Epoch: [171]  time: 24.7504, ELBO_train: -7.98335381, KL_z: 1.64170930, KL_s: 0.21146784, reconstruction loss: -6.13017666
# Clusters: 10
# Epoch: [172]  time: 24.8851, ELBO_train: -7.96338949, KL_z: 1.64112391, KL_s: 0.21091337, reconstruction loss: -6.11135221
# Clusters: 10
# Epoch: [173]  time: 25.0170, ELBO_train: -7.92443981, KL_z: 1.64327185, KL_s: 0.21050754, reconstruction loss: -6.07066042
# Clusters: 10
# Epoch: [174]  time: 25.2121, ELBO_train: -7.95118771, KL_z: 1.65977232, KL_s: 0.20980339, reconstruction loss: -6.08161199
# Clusters: 10
# Epoch: [175]  time: 25.3456, ELBO_train: -7.96946106, KL_z: 1.64843135, KL_s: 0.20934935, reconstruction loss: -6.11168036
# Clusters: 10
# Epoch: [176]  time: 25.4786, ELBO_train: -7.92482204, KL_z: 1.63094559, KL_s: 0.21186557, reconstruction loss: -6.08201089
# Clusters: 10
# Epoch: [177]  time: 25.6136, ELBO_train: -7.90691710, KL_z: 1.62482374, KL_s: 0.21524072, reconstruction loss: -6.06685264
# Clusters: 10
# Epoch: [178]  time: 25.7491, ELBO_train: -7.96028128, KL_z: 1.62139199, KL_s: 0.21863270, reconstruction loss: -6.12025659
# Clusters: 10
# Epoch: [179]  time: 25.8794, ELBO_train: -7.99919233, KL_z: 1.64129755, KL_s: 0.22080178, reconstruction loss: -6.13709300
# Clusters: 10
# Epoch: [180]  time: 26.0173, ELBO_train: -7.94334183, KL_z: 1.64949961, KL_s: 0.22303510, reconstruction loss: -6.07080712
# Clusters: 10
# Epoch: [181]  time: 26.1540, ELBO_train: -7.93977966, KL_z: 1.64489560, KL_s: 0.22369075, reconstruction loss: -6.07119331
# Clusters: 10
# Epoch: [182]  time: 26.2910, ELBO_train: -7.91134539, KL_z: 1.65171158, KL_s: 0.22351584, reconstruction loss: -6.03611796
# Clusters: 10
# Epoch: [183]  time: 26.4220, ELBO_train: -7.99167595, KL_z: 1.64446535, KL_s: 0.22428432, reconstruction loss: -6.12292628
# Clusters: 10
# Epoch: [184]  time: 26.5535, ELBO_train: -7.95973005, KL_z: 1.66019289, KL_s: 0.22338343, reconstruction loss: -6.07615373
# Clusters: 10
# Epoch: [185]  time: 26.6834, ELBO_train: -8.01255054, KL_z: 1.65616293, KL_s: 0.22457743, reconstruction loss: -6.13181019
# Clusters: 10
# Epoch: [186]  time: 26.8192, ELBO_train: -7.96561756, KL_z: 1.66374509, KL_s: 0.22549825, reconstruction loss: -6.07637422
# Clusters: 10
# Epoch: [187]  time: 26.9525, ELBO_train: -7.91376572, KL_z: 1.65989466, KL_s: 0.22688341, reconstruction loss: -6.02698765
# Clusters: 10
# Epoch: [188]  time: 27.0840, ELBO_train: -7.89149475, KL_z: 1.65957775, KL_s: 0.22785206, reconstruction loss: -6.00406494
# Clusters: 10
# Epoch: [189]  time: 27.2244, ELBO_train: -7.82043734, KL_z: 1.64307227, KL_s: 0.22756786, reconstruction loss: -5.94979720
# Clusters: 10
# Epoch: [190]  time: 27.4249, ELBO_train: -7.87579775, KL_z: 1.63718572, KL_s: 0.22729435, reconstruction loss: -6.01131768
# Clusters: 10
# Epoch: [191]  time: 27.5612, ELBO_train: -7.93963261, KL_z: 1.63482182, KL_s: 0.22758236, reconstruction loss: -6.07722843
# Clusters: 10
# Epoch: [192]  time: 27.6948, ELBO_train: -7.90714064, KL_z: 1.62968357, KL_s: 0.22792454, reconstruction loss: -6.04953253
# Clusters: 10
# Epoch: [193]  time: 27.8299, ELBO_train: -7.94440479, KL_z: 1.64599257, KL_s: 0.22961411, reconstruction loss: -6.06879811
# Clusters: 10
# Epoch: [194]  time: 27.9639, ELBO_train: -7.95110483, KL_z: 1.64864821, KL_s: 0.23190842, reconstruction loss: -6.07054820
# Clusters: 10
# Epoch: [195]  time: 28.0925, ELBO_train: -7.89042664, KL_z: 1.65351503, KL_s: 0.23469496, reconstruction loss: -6.00221665
# Clusters: 10
# Epoch: [196]  time: 28.2238, ELBO_train: -7.89972830, KL_z: 1.63619208, KL_s: 0.23760514, reconstruction loss: -6.02593107
# Clusters: 10
# Epoch: [197]  time: 28.3557, ELBO_train: -7.90650463, KL_z: 1.63121696, KL_s: 0.24007063, reconstruction loss: -6.03521705
# Clusters: 10
# Epoch: [198]  time: 28.4914, ELBO_train: -7.90238295, KL_z: 1.64427943, KL_s: 0.24228563, reconstruction loss: -6.01581788
# Clusters: 10
# Epoch: [199]  time: 28.6290, ELBO_train: -7.93406143, KL_z: 1.62009234, KL_s: 0.24366808, reconstruction loss: -6.07030101
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

# Number of samples generated by one input data
n_generated_sample = 10

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = data_processing.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3, n_generated_sample=n_generated_sample)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = statistic.samples_concatenation(samples_list)[-1]
    data_test_transformed = data_processing.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = []
    for j in range(n_generated_sample):
        est_data_test_transformed.append(data_processing.discrete_variables_transformation(est_data_test[i], feat_types_dict).unsqueeze(0))
    
    est_data_test_transformed = torch.cat(est_data_test_transformed, dim=0)

# %% [markdown]
# ### Visualize the generated samples

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
# Take first generated sample
idx = 0
estimated_values = est_data_test_transformed[idx]

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)

# %%
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
# Take second generated sample
idx = 1
estimated_values = est_data_test_transformed[idx]

# Call plotting function
visualization.plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
