# %% [markdown]
# # Generation and post-analysis in metabric dataset

# %% [markdown]
# #### Associated publication
# Reference: https://www.nejm.org/doi/full/10.1056/NEJM199709113371101

# %%
import pandas as pd
import torch

from utils import data_processing, visualization

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## 1. Original data loading, analysis and visualization

# %% [markdown]
# ### 1.1. Experiment setting - links to data

# %%
dataset_name = "SAS_2"
data_file_control= "./dataset/" + dataset_name + "/data_control.csv"
feat_types_file_control = "./dataset/" + dataset_name + "/data_types_control.csv"
data_file_treated= "./dataset/" + dataset_name + "/data_treated.csv"
feat_types_file_treated= "./dataset/" + dataset_name + "/data_types_treated.csv"

# If the dataset has no missing data, leave the "miss_file" variable empty
m_perc = 10
mask = 1
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### 1.2. Loading, feature analysis, and visualization of original data: control vs treated group

# %%
control_fnames = ['time', 'censor'] + pd.read_csv(feat_types_file_control)["name"].to_list()[1:]
control = pd.read_csv(data_file_control, header=None, names=control_fnames)
print(control.head())
# Out:
#     time  censor  SEX   AGE  RACCAT  PRBEV  PROXAL  B_METACT  B_LDHNM  \
# 0   15.0     0.0    1  22.0       1      1       1         2    399.0
# 1  233.0     1.0    1  20.0       1      1       1         2    340.0
# 2  882.0     1.0    1  32.0       1      1       1         1    168.0
# 3   51.0     1.0    1  48.0       1      0       1         2     82.0
# 4  110.0     1.0    0  37.0       1      0       1         2    460.0
#
#    BECOGICD  DIAGTYPE  PRADJYN  LIVERMET  KRAS
# 0       1.0         0        0         1     0
# 1       0.0         1        0         1     2
# 2       0.0         0        0         1     2
# 3       1.0         1        0         1     1
# 4       2.0         0        0         1     1

# %%
# Load and transform control data
df_init_control_encoded, feat_types_dict, miss_mask_control, true_miss_mask_control, _ = data_processing.read_data(data_file_control, feat_types_file_control, miss_file, true_miss_file)
data_init_control_encoded = torch.from_numpy(df_init_control_encoded.values)
data_init_control = data_processing.discrete_variables_transformation(data_init_control_encoded, feat_types_dict)

# Load and transform treated data
df_init_treated_encoded, _, _, _, _ = data_processing.read_data(data_file_treated, feat_types_file_treated, miss_file, true_miss_file)
data_init_treated_encoded = torch.from_numpy(df_init_treated_encoded.values)
data_init_treated = data_processing.discrete_variables_transformation(data_init_treated_encoded, feat_types_dict)

# %%
# Format data in dataframe
df_init_treated = pd.DataFrame(data_init_treated.numpy(), columns=control_fnames)
df_init_control = pd.DataFrame(data_init_control.numpy(), columns=control_fnames)

# Update dataframe
df_init_treated["treatment"] = 1
df_init_control["treatment"] = 0
df_init = pd.concat([df_init_control, df_init_treated], ignore_index=True)

# %% [markdown]
# ## 2. Training and generation from the generative model

# %% [markdown]
# Possible generative models: HI-VAE (our), survival_gan, survival_ctgan, survival_nflow, survae (synthcity)

# %%
from execute import surv_hivae, surv_gan, surv_vae
generators_dict = {"HI-VAE_weibull" : surv_hivae,
                    "HI-VAE_piecewise" : surv_hivae,
                    "Surv-GAN" : surv_gan,
                    "Surv-VAE" : surv_vae}
# Out:
# [KeOps] Warning : omp.h header is not in the path, disabling OpenMP. To fix this, you can set the environment
#                   variable OMP_PATH to the location of the header before importing keopscore or pykeops,
#                   e.g. using os.environ: import os; os.environ['OMP_PATH'] = '/path/to/omp/header'
# [KeOps] Warning : Cuda libraries were not detected on the system or could not be loaded ; using cpu only mode

# %%
# the datasets used for training is data_init_control
import json
import os
name_config = "SAS_1"
best_param_files = [f for f in os.listdir("optuna_results") if (f.endswith('.json') & (name_config in f))]

generators_sel = ["HI-VAE_weibull", "HI-VAE_piecewise", "Surv-GAN", "Surv-VAE"]

best_params_dict = {}
for generator_name in generators_sel:
    best_param_file = [item for item in best_param_files if generator_name in item][0]
    with open("optuna_results/" + best_param_file, "r") as f:
        best_params_dict[generator_name] = json.load(f)

n_generated_dataset = 100
data_gen_control_dict = {}
for generator_name in generators_sel:
    print("=" * 100)
    print("Generate data by " + generator_name)
    best_params = best_params_dict[generator_name]
    if generator_name in ["HI-VAE_weibull", "HI-VAE_piecewise"]:
            feat_types_dict_ext = feat_types_dict.copy()
            for i in range(len(feat_types_dict)):
                if feat_types_dict_ext[i]['name'] == "survcens":
                    if generator_name in["HI-VAE_weibull"]:
                        feat_types_dict_ext[i]["type"] = 'surv_weibull'
                    else:
                        feat_types_dict_ext[i]["type"] = 'surv_piecewise'
    if generator_name in ["HI-VAE_weibull", "HI-VAE_piecewise"]:
        data_gen_control_dict[generator_name] = generators_dict[generator_name].run(df_init_control_encoded, miss_mask_control, true_miss_mask_control, feat_types_dict_ext, n_generated_dataset, params=best_params)
    else:
        data_gen_control_dict[generator_name] = generators_dict[generator_name].run(data_init_control, columns=control_fnames, target_column="censor", time_to_event_column="time", n_generated_dataset=n_generated_dataset, params=best_params)
# Out:
# ====================================================================================================
# Generate data by HI-VAE_weibull
# Epoch: [ 0]  time: 0.1521, ELBO_train: -21.01763725, KL_z: 1.45798655, KL_s: 0.08884025, reconstruction loss: -19.47081045
# Epoch: [100]  time: 1.5857, ELBO_train: -16.62239901, KL_z: 0.47585003, KL_s: 0.01825730, reconstruction loss: -16.12829169
# Epoch: [200]  time: 2.9285, ELBO_train: -16.44681231, KL_z: 0.55861859, KL_s: 0.01438387, reconstruction loss: -15.87380985
# Epoch: [300]  time: 4.2358, ELBO_train: -16.37281609, KL_z: 0.67311255, KL_s: 0.01498810, reconstruction loss: -15.68471543
# Epoch: [400]  time: 5.6005, ELBO_train: -16.38257281, KL_z: 0.77773468, KL_s: 0.01518623, reconstruction loss: -15.58965190
# Epoch: [500]  time: 6.9508, ELBO_train: -16.51070658, KL_z: 0.89542152, KL_s: 0.01629178, reconstruction loss: -15.59899328
# Epoch: [600]  time: 8.2712, ELBO_train: -16.30082067, KL_z: 0.96772065, KL_s: 0.01645708, reconstruction loss: -15.31664294
# Epoch: [700]  time: 9.5905, ELBO_train: -16.09237385, KL_z: 1.03618312, KL_s: 0.01487724, reconstruction loss: -15.04131349
# Epoch: [800]  time: 11.0775, ELBO_train: -16.41190910, KL_z: 1.10830180, KL_s: 0.01944741, reconstruction loss: -15.28415990
# Epoch: [900]  time: 12.7409, ELBO_train: -16.14746380, KL_z: 1.13967109, KL_s: 0.02004941, reconstruction loss: -14.98774330
# Training finished.
# ====================================================================================================
# Generate data by HI-VAE_piecewise
# Epoch: [ 0]  time: 0.0186, ELBO_train: -20.59206263, KL_z: 0.74976104, KL_s: 0.04399725, reconstruction loss: -19.79830434
# Epoch: [100]  time: 1.4631, ELBO_train: -17.05145200, KL_z: 0.33062935, KL_s: 0.02014315, reconstruction loss: -16.70067950
# Epoch: [200]  time: 2.7419, ELBO_train: -16.51580747, KL_z: 0.52589536, KL_s: 0.01858195, reconstruction loss: -15.97133017
# Epoch: [300]  time: 4.0234, ELBO_train: -16.34271749, KL_z: 0.66230134, KL_s: 0.02401574, reconstruction loss: -15.65640040
# Epoch: [400]  time: 5.3143, ELBO_train: -16.35653941, KL_z: 0.69621330, KL_s: 0.02260395, reconstruction loss: -15.63772215
# Epoch: [500]  time: 6.6090, ELBO_train: -16.33834457, KL_z: 0.77030164, KL_s: 0.02566497, reconstruction loss: -15.54237797
# Epoch: [600]  time: 8.0294, ELBO_train: -16.14965979, KL_z: 0.76729608, KL_s: 0.02647595, reconstruction loss: -15.35588777
# Epoch: [700]  time: 9.3255, ELBO_train: -16.23010890, KL_z: 0.82954413, KL_s: 0.02598957, reconstruction loss: -15.37457520
# Epoch: [800]  time: 10.6272, ELBO_train: -16.24854120, KL_z: 0.86907305, KL_s: 0.03049866, reconstruction loss: -15.34896948
# Epoch: [900]  time: 11.9330, ELBO_train: -16.18427690, KL_z: 0.89413702, KL_s: 0.02914949, reconstruction loss: -15.26099038
# Training finished.
# ====================================================================================================
# Generate data by Surv-GAN
# [2025-06-19T21:22:14.299670+0200][3117][CRITICAL] Error importing TabularGoggle: No module named 'dgl'
# [2025-06-19T21:22:14.301145+0200][3117][CRITICAL] module disabled: /opt/anaconda3/envs/hivae/lib/python3.13/site-packages/synthcity/plugins/generic/plugin_goggle.py
# [2025-06-19T21:22:15.229667+0200][3117][CRITICAL] load failed: No module named 'pytorch_lightning'
# [2025-06-19T21:22:15.230233+0200][3117][CRITICAL] load failed: module 'synthcity.plugins.privacy.plugin_decaf' has no attribute 'plugin'
# [2025-06-19T21:22:15.230415+0200][3117][CRITICAL] module plugin_decaf load failed
# [2025-06-19T21:22:15.449141+0200][3117][CRITICAL] module disabled: /opt/anaconda3/envs/hivae/lib/python3.13/site-packages/synthcity/plugins/generic/plugin_goggle.py
# [2025-06-19T21:22:15.450001+0200][3117][CRITICAL] load failed: module 'synthcity.plugins.privacy.plugin_decaf' has no attribute 'plugin'
# [2025-06-19T21:22:15.450250+0200][3117][CRITICAL] load failed: module 'synthcity.plugins.privacy.plugin_decaf' has no attribute 'plugin'
# [2025-06-19T21:22:15.450456+0200][3117][CRITICAL] module plugin_decaf load failed
#  13%|█▎        | 1299/10000 [00:21<02:22, 61.22it/s]
# [2025-06-19T21:22:47.022854+0200][3117][CRITICAL] module disabled: /opt/anaconda3/envs/hivae/lib/python3.13/site-packages/synthcity/plugins/generic/plugin_goggle.py
# [2025-06-19T21:22:47.023491+0200][3117][CRITICAL] load failed: module 'synthcity.plugins.privacy.plugin_decaf' has no attribute 'plugin'
# [2025-06-19T21:22:47.023737+0200][3117][CRITICAL] load failed: module 'synthcity.plugins.privacy.plugin_decaf' has no attribute 'plugin'
# [2025-06-19T21:22:47.023947+0200][3117][CRITICAL] module plugin_decaf load failed
# [2025-06-19T21:22:47.047182+0200][3117][CRITICAL] module disabled: /opt/anaconda3/envs/hivae/lib/python3.13/site-packages/synthcity/plugins/generic/plugin_goggle.py
# [2025-06-19T21:22:47.047596+0200][3117][CRITICAL] load failed: module 'synthcity.plugins.privacy.plugin_decaf' has no attribute 'plugin'
# [2025-06-19T21:22:47.047821+0200][3117][CRITICAL] load failed: module 'synthcity.plugins.privacy.plugin_decaf' has no attribute 'plugin'
# [2025-06-19T21:22:47.047991+0200][3117][CRITICAL] module plugin_decaf load failed
# ====================================================================================================
# Generate data by Surv-VAE
# 100%|██████████| 100/100 [00:01<00:00, 50.58it/s]

# %%
# Convert generated data into dataframe
df_gen_control_dict = {}
df_syn_dict = {}
for generator_name in generators_sel:
    list_df_gen_control = []
    data_syn = []
    for j in range(n_generated_dataset):
        df_gen_control_j = pd.DataFrame(data_gen_control_dict[generator_name][j].numpy(), columns=control_fnames)
        df_gen_control_j['treatment'] = 0
        list_df_gen_control.append(df_gen_control_j)
        data_syn.append(pd.concat([df_init_treated, df_gen_control_j], ignore_index=True))
        
    df_gen_control_dict[generator_name] = list_df_gen_control
    df_syn_dict[generator_name] = data_syn

# %% [markdown]
# ### 3. Compare generation performance

# %% [markdown]
# #### 3.1. General metrics

# %%
from utils.metrics import general_metrics
general_scores = []
for generator_name in generators_sel:
    general_scores.append(general_metrics(df_init_control, df_gen_control_dict[generator_name], generator_name))
general_scores_df = pd.concat(general_scores)

# %%
general_scores_bis = []
generators_sel_bis = ["HI-VAE_weibull", "Surv-GAN", "Surv-VAE"]
generator_name_bis = ["Our Model", "Surv-GAN", "Surv-VAE"]
for i in range(len(generators_sel_bis)):
    general_scores_bis.append(general_metrics(df_init_control, df_gen_control_dict[generators_sel_bis[i]], generator_name_bis[i]))
general_scores_df_bis = pd.concat(general_scores_bis)

# %% [markdown]
# ##### 3.1.1. Data resemblance

# %%
from utils.visualization import visualize_general_perf
visualize_general_perf(general_scores_df, metrics=[['J-S distance', "min"], ['KS test', "max"]])

# %%
visualize_general_perf(general_scores_df_bis, metrics=[['J-S distance', "min"], ['Survival curves distance', "min"], ['K-map score', "max"]])
visualize_general_perf(general_scores_df_bis, metrics=[['Survival curves distance', "min"]])
visualize_general_perf(general_scores_df_bis, metrics=[['NNDR', "max"]])

# %% [markdown]
# ##### 3.1.2. Utility

# %%
visualize_general_perf(general_scores_df, metrics=[['Survival curves distance', "min"], ['Detection XGB', "min"]])

# %% [markdown]
# #### 3.1.3. Privacy

# %%
visualize_general_perf(general_scores_df, metrics=[['NNDR', "min"], ['K-map score', "max"]])

# %% [markdown]
# #### Replicability metrics

# %%
from utils.metrics import replicability_ext
replicability_scores = []
for generator_name in generators_sel:
    replicability_scores.append(replicability_ext(df_init, df_syn_dict[generator_name], generator_name))
replicability_scores_df = pd.concat(replicability_scores, ignore_index=True)

# %%
from utils.visualization import visualize_replicability_perf
visualize_replicability_perf(replicability_scores_df)

# %%
replicability_scores_df
# Out:
#            Generator  Nb generated datasets  Estimate agreement  \
# 0     HI-VAE_weibull                     20            1.000000
# 1     HI-VAE_weibull                     40            1.000000
# 2     HI-VAE_weibull                     60            1.000000
# 3     HI-VAE_weibull                     80            1.000000
# 4     HI-VAE_weibull                    100            1.000000
# 5   HI-VAE_piecewise                     20            0.800000
# 6   HI-VAE_piecewise                     40            0.850000
# 7   HI-VAE_piecewise                     60            0.866667
# 8   HI-VAE_piecewise                     80            0.887500
# 9   HI-VAE_piecewise                    100            0.870000
# 10          Surv-GAN                     20            0.000000
# 11          Surv-GAN                     40            0.000000
# 12          Surv-GAN                     60            0.000000
# 13          Surv-GAN                     80            0.000000
# 14          Surv-GAN                    100            0.000000
# 15          Surv-VAE                     20            0.000000
# 16          Surv-VAE                     40            0.000000
# 17          Surv-VAE                     60            0.000000
# 18          Surv-VAE                     80            0.000000
# 19          Surv-VAE                    100            0.000000
#
#     Decision agreement  Standardized difference  CI overlap
# 0               0.9000                      1.0    0.859574
# 1               0.8750                      1.0    0.864488
# 2               0.9000                      1.0    0.870244
# 3               0.9125                      1.0    0.864896
# 4               0.8900                      1.0    0.858904
# 5               1.0000                      1.0    0.635754
# 6               1.0000                      1.0    0.660254
# 7               1.0000                      1.0    0.660304
# 8               1.0000                      1.0    0.666213
# 9               0.9900                      1.0    0.661576
# 10              0.0000                      0.0    0.043229
# 11              0.0000                      0.0    0.035828
# 12              0.0000                      0.0    0.049992
# 13              0.0000                      0.0    0.046036
# 14              0.0000                      0.0    0.044050
# 15              0.0000                      0.0    0.008827
# 16              0.0000                      0.0    0.004414
# 17              0.0000                      0.0    0.002942
# 18              0.0000                      0.0    0.002207
# 19              0.0000                      0.0    0.001765

# %%
from utils.metrics import fit_cox_model
import numpy as np
columns = ['time', 'censor', 'treatment']
coef_init, _, ci_init, se_init = fit_cox_model(df_init, columns)
# Compute midpoints and widths
midpoints = [(ci_init[1] + ci_init[0]) / 2]
errors = [(ci_init[1] - ci_init[0]) / 2]
label = ["Init"]
colors = ['green', 'blue', 'orange', 'cyan']

colors_ = ['red']
for i , generator in enumerate(generators_sel):
    data_syn_ = df_syn_dict[generator]
    results = [fit_cox_model(data, columns) for data in data_syn_]
    coef_syn, _, _, se_syn = zip(*results)
    for n in range(10):
        coef_syn_, se_syn_ = np.array(coef_syn)[n][0], np.array(se_syn)[n][0]
        ci_syn = (coef_syn_ - 1.96 * se_syn_, coef_syn_ + 1.96 * se_syn_)
        midpoints.append((ci_syn[1] + ci_syn[0]) / 2)
        errors.append((ci_syn[1] - ci_syn[0]) / 2)
        label.append(generator + " " + str(n + 1))
        colors_.append(colors[i])

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8, 12))

# Plot as horizontal error bars
for i, (mid, err) in enumerate(zip(midpoints, errors)):
    ax.errorbar(x=mid, y=i, xerr=err, fmt='o', capsize=5, color=colors_[i])

plt.yticks(range(len(midpoints)), label)
plt.xlabel("Value")
plt.title("Interval Comparison")
plt.grid(True)
plt.tight_layout()
plt.show()
