# %%
import torch
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import utils
import time

# %% [markdown]
# ### Experiment setting

# %%
dataset_name = "defaultCredit"
# dataset_name = "Wine"
# dataset_name = "Adult"
# dataset_name = "Breast"
m_perc = 10
mask = 1
data_file= "dataset/" + dataset_name + "/data.csv"
feat_types_file = "dataset/" + dataset_name + "/data_types.csv"
miss_file = "dataset/" + dataset_name + "/Missing{}_{}.csv".format(m_perc, mask)
true_miss_file = None

# %% [markdown]
# ### Data preprocessing

# %%
# Load training data
data, feat_types_dict, miss_mask, true_miss_mask, n_samples = utils.read_data(data_file, feat_types_file, miss_file, true_miss_file)

train_test_share = .8
n_samples = data.shape[0]
n_train_samples = int(train_test_share * n_samples)
train_index = np.random.choice(n_samples, n_train_samples, replace=False)
test_index = [i for i in np.arange(n_samples) if i not in train_index]

data_train = data[train_index]
miss_mask_train = miss_mask[train_index]
true_miss_mask_train = true_miss_mask[train_index]

data_test = data[test_index]
miss_mask_test = miss_mask[test_index]
true_miss_mask_test = true_miss_mask[test_index]

# %%
# Adjust batch size if larger than dataset
batch_size = 1000
batch_size = min(batch_size, n_train_samples)

# Number of batches
n_train_samples = data_train.shape[0]
n_batches_train = int(np.floor(n_train_samples / batch_size))
n_train_samples = n_batches_train * batch_size

# Compute real missing mask
miss_mask_train = torch.multiply(miss_mask_train, true_miss_mask_train)

# %% [markdown]
# ### Model loading

# %%
import importlib
import os 

# model_name="HIVAE_factorized"
model_name="HIVAE_inputDropout"
dim_latent_z = 10
dim_latent_y = 5
dim_latent_s = 10
epochs = 200
lr = 1e-3
save_file= "{}_{}_missing_{}_{}_z{}_y{}_s{}_batch_{}".format(model_name, dataset_name, m_perc, mask, dim_latent_z, dim_latent_y, dim_latent_s, batch_size)
# Create directories for saving models
save_dir = f'./saved_networks/{save_file}/'
os.makedirs(save_dir, exist_ok=True)
network_file = os.path.join(save_dir, f'{save_file}.pth')

# Create PyTorch HVAE model
model_loading = getattr(importlib.import_module("src"), model_name)
vae_model = model_loading(input_dim=data_train.shape[1], 
                          z_dim=dim_latent_z, 
                          y_dim=dim_latent_y, 
                          s_dim=dim_latent_s, 
                          y_dim_partition=None, 
                          feat_types_file=feat_types_file)

optimizer = optim.Adam(vae_model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
from utils import print_loss, plot_loss_evolution

start_time = time.time()
loss_train, error_observed_train, error_missing_train = [], [], []

for epoch in range(epochs):
    avg_loss, avg_KL_s, avg_KL_z = 0.0, 0.0, 0.0
    samples_list, p_params_list, q_params_list, log_p_x_total, log_p_x_missing_total = [], [], [], [], []
    tau = max(1.0 - 0.01 * epoch, 1e-3)

    # Shuffle training data
    perm = np.random.permutation(data_train.shape[0])
    data_train = data_train[perm]
    miss_mask_train = miss_mask_train[perm]
    true_miss_mask_train = true_miss_mask_train[perm]

    for i in range(n_batches_train):
        # Get batch data
        data_list, miss_list = utils.next_batch(data_train, feat_types_dict, miss_mask_train, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]


        # Compute loss
        optimizer.zero_grad()
        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau)
        vae_res["neg_ELBO_loss"].backward()
        optimizer.step()

        with torch.no_grad():

            avg_loss += vae_res["neg_ELBO_loss"].item() / n_batches_train
            avg_KL_s += torch.mean(vae_res["KL_s"]).item() / n_batches_train
            avg_KL_z += torch.mean(vae_res["KL_z"]).item() / n_batches_train

        # Save the generated samlpes and estimated parameters !
        samples_list.append(vae_res["samples"])
        p_params_list.append(vae_res["p_params"])
        q_params_list.append(vae_res["q_params"])
        log_p_x_total.append(vae_res["log_p_x"])
        log_p_x_missing_total.append(vae_res["log_p_x_missing"])


    #Concatenate samples in arrays
    s_total, z_total, y_total, est_data_train = utils.samples_concatenation(samples_list)
    
    # #Transform discrete variables back to the original values
    data_train_transformed = utils.discrete_variables_transformation(data_train[: n_train_samples], feat_types_dict)
    est_data_train_transformed = utils.discrete_variables_transformation(est_data_train, feat_types_dict)
    est_data_train_mean_imputed = utils.mean_imputation(data_train_transformed, miss_mask_train[: n_train_samples], feat_types_dict)

    # Compute errors
    error_observed_samples, error_missing_samples = utils.error_computation(data_train_transformed, est_data_train_transformed, feat_types_dict, miss_mask[:n_train_samples])
    
    # # #Create global dictionary of the distribution parameters
    q_params_complete = utils.q_distribution_params_concatenation(q_params_list)
    
    #Number of clusters created
    cluster_index = torch.argmax(q_params_complete['s'], 1)
    cluster = torch.unique(cluster_index)
    print('Clusters: ' + str(len(cluster)))

    # Save average loss and error
    loss_train.append(avg_loss)
    error_observed_train.append(torch.mean(error_observed_samples))
    error_missing_train.append(torch.mean(error_missing_samples))

    print_loss(epoch, start_time, -avg_loss, avg_KL_s, avg_KL_z)

print("Training finished.")

torch.save(vae_model.state_dict(), network_file)

plot_loss_evolution(-np.array(loss_train), title = "HI_VAE loss over epoch",
                                xlabel = "Epoch", ylabel = "ELBO")
plot_loss_evolution(np.array(error_observed_train), title = "Error on observed data",
                                xlabel = "Epoch", ylabel = "AvgErr")
plot_loss_evolution(np.array(error_missing_train), title = "Error on missing data",
                                xlabel = "Epoch", ylabel = "AvgErr")
# Out:
# Clusters: 9
# Epoch: [ 0]  time: 0.4036, ELBO_train: -156.74047089, KL_z: 1.13620245, KL_s: 0.16091786, reconstruction loss: -155.44335057
# Clusters: 4
# Epoch: [ 1]  time: 0.7537, ELBO_train: -149.23919042, KL_z: 1.84950401, KL_s: 0.43113329, reconstruction loss: -146.95855312
# Clusters: 3
# Epoch: [ 2]  time: 1.1228, ELBO_train: -142.12174225, KL_z: 4.13685237, KL_s: 0.71899911, reconstruction loss: -137.26589076
# Clusters: 3
# Epoch: [ 3]  time: 1.4702, ELBO_train: -135.02731578, KL_z: 6.80853820, KL_s: 0.91412391, reconstruction loss: -127.30465366
# Clusters: 3
# Epoch: [41]  time: 14.5392, ELBO_train: -71.21569856, KL_z: 4.38275425, KL_s: 1.77911326, reconstruction loss: -65.05383105
# Clusters: 3
# Epoch: [42]  time: 14.8881, ELBO_train: -70.70616976, KL_z: 4.28358767, KL_s: 1.77893341, reconstruction loss: -64.64364868
# Clusters: 3
# Epoch: [43]  time: 15.2361, ELBO_train: -70.20324198, KL_z: 4.22319845, KL_s: 1.77708017, reconstruction loss: -64.20296336
# Clusters: 3
# Epoch: [44]  time: 15.5806, ELBO_train: -69.72997411, KL_z: 4.14411463, KL_s: 1.78012168, reconstruction loss: -63.80573779
# Clusters: 3
# Epoch: [45]  time: 15.9280, ELBO_train: -69.23475552, KL_z: 4.05041088, KL_s: 1.78665871, reconstruction loss: -63.39768593
# Clusters: 3
# Epoch: [46]  time: 16.2766, ELBO_train: -68.79849625, KL_z: 3.98731589, KL_s: 1.79236169, reconstruction loss: -63.01881866
# Clusters: 3
# Epoch: [47]  time: 16.6255, ELBO_train: -68.35894712, KL_z: 3.92541679, KL_s: 1.78760167, reconstruction loss: -62.64592866
# Clusters: 3
# Epoch: [48]  time: 16.9749, ELBO_train: -67.95663389, KL_z: 3.85531144, KL_s: 1.78705800, reconstruction loss: -62.31426445
# Clusters: 2
# Epoch: [49]  time: 17.3247, ELBO_train: -67.52443409, KL_z: 3.79348230, KL_s: 1.79017572, reconstruction loss: -61.94077607
# Clusters: 2
# Epoch: [50]  time: 17.6744, ELBO_train: -67.11063385, KL_z: 3.71604139, KL_s: 1.79618913, reconstruction loss: -61.59840333
# Clusters: 2
# Epoch: [51]  time: 18.0216, ELBO_train: -66.75453409, KL_z: 3.66014834, KL_s: 1.79131313, reconstruction loss: -61.30307262
# Clusters: 2
# Epoch: [52]  time: 18.3711, ELBO_train: -66.40699164, KL_z: 3.62877785, KL_s: 1.79229608, reconstruction loss: -60.98591771
# Clusters: 2
# Epoch: [53]  time: 18.7210, ELBO_train: -66.03532314, KL_z: 3.55915959, KL_s: 1.79084032, reconstruction loss: -60.68532324
# Clusters: 2
# Epoch: [54]  time: 19.0720, ELBO_train: -65.65859890, KL_z: 3.47995214, KL_s: 1.79568077, reconstruction loss: -60.38296599
# Clusters: 2
# Epoch: [55]  time: 19.4220, ELBO_train: -65.34180641, KL_z: 3.44012759, KL_s: 1.79823059, reconstruction loss: -60.10344823
# Clusters: 2
# Epoch: [56]  time: 19.7739, ELBO_train: -65.03027328, KL_z: 3.40259824, KL_s: 1.79359130, reconstruction loss: -59.83408374
# Clusters: 2
# Epoch: [57]  time: 20.1232, ELBO_train: -64.71338669, KL_z: 3.35157654, KL_s: 1.79522769, reconstruction loss: -59.56658247
# Clusters: 2
# Epoch: [58]  time: 20.4882, ELBO_train: -64.43038082, KL_z: 3.30238087, KL_s: 1.80072069, reconstruction loss: -59.32727926
# Clusters: 2
# Clusters: 4
# Epoch: [78]  time: 27.5335, ELBO_train: -60.08447425, KL_z: 2.60691977, KL_s: 1.69660018, reconstruction loss: -55.78095430
# Clusters: 4
# Epoch: [79]  time: 27.8873, ELBO_train: -59.93760649, KL_z: 2.58097825, KL_s: 1.68806155, reconstruction loss: -55.66856669
# Clusters: 4
# Epoch: [80]  time: 28.2425, ELBO_train: -59.79463832, KL_z: 2.55927837, KL_s: 1.69924403, reconstruction loss: -55.53611592
# Clusters: 4
# Epoch: [81]  time: 28.6011, ELBO_train: -59.64601183, KL_z: 2.52854433, KL_s: 1.70512425, reconstruction loss: -55.41234325
# Clusters: 4
# Epoch: [82]  time: 28.9536, ELBO_train: -59.51942396, KL_z: 2.51735040, KL_s: 1.70007035, reconstruction loss: -55.30200322
# Clusters: 4
# Epoch: [83]  time: 29.3547, ELBO_train: -59.40275065, KL_z: 2.48590076, KL_s: 1.68474784, reconstruction loss: -55.23210206
# Clusters: 4
# Epoch: [84]  time: 29.7167, ELBO_train: -59.28832626, KL_z: 2.48044627, KL_s: 1.68392544, reconstruction loss: -55.12395455
# Clusters: 4
# Epoch: [85]  time: 30.0769, ELBO_train: -59.15485414, KL_z: 2.46793514, KL_s: 1.69737094, reconstruction loss: -54.98954806
# Clusters: 4
# Epoch: [86]  time: 30.4346, ELBO_train: -59.05899556, KL_z: 2.44496522, KL_s: 1.69379523, reconstruction loss: -54.92023511
# Clusters: 5
# Epoch: [87]  time: 30.7919, ELBO_train: -58.93086131, KL_z: 2.42296968, KL_s: 1.69724077, reconstruction loss: -54.81065087
# Clusters: 4
# Epoch: [88]  time: 31.1454, ELBO_train: -58.83454625, KL_z: 2.40117316, KL_s: 1.71173843, reconstruction loss: -54.72163466
# Clusters: 5
# Epoch: [89]  time: 31.5041, ELBO_train: -58.73313665, KL_z: 2.39437712, KL_s: 1.69915625, reconstruction loss: -54.63960328
# Clusters: 5
# Epoch: [90]  time: 31.8693, ELBO_train: -58.66002989, KL_z: 2.39226157, KL_s: 1.70173973, reconstruction loss: -54.56602859
# Clusters: 4
# Epoch: [91]  time: 32.2197, ELBO_train: -58.53913625, KL_z: 2.36332199, KL_s: 1.70435988, reconstruction loss: -54.47145438
# Clusters: 4
# Epoch: [92]  time: 32.5761, ELBO_train: -58.48394299, KL_z: 2.34121349, KL_s: 1.70098947, reconstruction loss: -54.44174002
# Clusters: 4
# Epoch: [93]  time: 32.9336, ELBO_train: -58.37840668, KL_z: 2.35999556, KL_s: 1.69518038, reconstruction loss: -54.32323074
# Clusters: 4
# Epoch: [94]  time: 33.2892, ELBO_train: -58.29697943, KL_z: 2.33869787, KL_s: 1.69000839, reconstruction loss: -54.26827316
# Clusters: 4
# Epoch: [95]  time: 33.6520, ELBO_train: -58.22313261, KL_z: 2.33242971, KL_s: 1.67505134, reconstruction loss: -54.21565156
# Clusters: 4
# Epoch: [96]  time: 34.0036, ELBO_train: -58.16529687, KL_z: 2.33037074, KL_s: 1.68663724, reconstruction loss: -54.14828889
# Clusters: 4
# Epoch: [97]  time: 34.3621, ELBO_train: -58.06302245, KL_z: 2.31133473, KL_s: 1.69613198, reconstruction loss: -54.05555574
# Clusters: 4
# Epoch: [98]  time: 34.7233, ELBO_train: -58.03151464, KL_z: 2.29797691, KL_s: 1.70827410, reconstruction loss: -54.02526363
# Clusters: 4
# Epoch: [99]  time: 35.0822, ELBO_train: -57.99000565, KL_z: 2.31284488, KL_s: 1.69780644, reconstruction loss: -53.97935433
# Clusters: 5
# Epoch: [100]  time: 35.4420, ELBO_train: -57.91723982, KL_z: 2.30156583, KL_s: 1.66855312, reconstruction loss: -53.94712088
# Clusters: 4
# Epoch: [101]  time: 35.8135, ELBO_train: -57.87245750, KL_z: 2.30658222, KL_s: 1.63117796, reconstruction loss: -53.93469732
# Clusters: 4
# Epoch: [102]  time: 36.1833, ELBO_train: -57.81259346, KL_z: 2.29179293, KL_s: 1.68536801, reconstruction loss: -53.83543252
# Clusters: 4
# Epoch: [103]  time: 36.5471, ELBO_train: -57.73055506, KL_z: 2.28151277, KL_s: 1.65876544, reconstruction loss: -53.79027686
# Clusters: 4
# Epoch: [104]  time: 36.9080, ELBO_train: -57.69554615, KL_z: 2.26814664, KL_s: 1.67090454, reconstruction loss: -53.75649496
# Clusters: 4
# Epoch: [105]  time: 37.2724, ELBO_train: -57.62271976, KL_z: 2.26180443, KL_s: 1.68775582, reconstruction loss: -53.67315951
# Clusters: 4
# Epoch: [106]  time: 37.6521, ELBO_train: -57.60140419, KL_z: 2.27178816, KL_s: 1.65907233, reconstruction loss: -53.67054370
# Clusters: 4
# Epoch: [107]  time: 38.0088, ELBO_train: -57.54462481, KL_z: 2.28184391, KL_s: 1.61399114, reconstruction loss: -53.64878975
# Clusters: 4
# Epoch: [108]  time: 38.3640, ELBO_train: -57.52548663, KL_z: 2.31874748, KL_s: 1.54824579, reconstruction loss: -53.65849336
# Clusters: 4
# Epoch: [109]  time: 38.7237, ELBO_train: -57.47853216, KL_z: 2.33357884, KL_s: 1.53815222, reconstruction loss: -53.60680109
# Clusters: 4
# Epoch: [110]  time: 39.0838, ELBO_train: -57.45048412, KL_z: 2.36598126, KL_s: 1.48409202, reconstruction loss: -53.60041084
# Clusters: 5
# Epoch: [111]  time: 39.4425, ELBO_train: -57.37769127, KL_z: 2.35046600, KL_s: 1.45005420, reconstruction loss: -53.57717107
# Clusters: 5
# Epoch: [112]  time: 39.8002, ELBO_train: -57.32036575, KL_z: 2.34279242, KL_s: 1.44593467, reconstruction loss: -53.53163865
# Clusters: 5
# Epoch: [113]  time: 40.1554, ELBO_train: -57.25421095, KL_z: 2.32535489, KL_s: 1.42084305, reconstruction loss: -53.50801301
# Clusters: 5
# Epoch: [114]  time: 40.5722, ELBO_train: -57.18790642, KL_z: 2.30873782, KL_s: 1.42037605, reconstruction loss: -53.45879255
# Clusters: 10
# Epoch: [171]  time: 61.9621, ELBO_train: -55.51533858, KL_z: 2.15588161, KL_s: 0.80716925, reconstruction loss: -52.55228771
# Clusters: 10
# Epoch: [172]  time: 62.3376, ELBO_train: -55.47408597, KL_z: 2.14325210, KL_s: 0.80188739, reconstruction loss: -52.52894647
# Clusters: 10
# Epoch: [173]  time: 62.7104, ELBO_train: -55.50907962, KL_z: 2.15858411, KL_s: 0.79063147, reconstruction loss: -52.55986403
# Clusters: 9
# Epoch: [174]  time: 63.0803, ELBO_train: -55.48979807, KL_z: 2.16976375, KL_s: 0.79229080, reconstruction loss: -52.52774351
# Clusters: 9
# Epoch: [175]  time: 63.4584, ELBO_train: -55.47155746, KL_z: 2.16683227, KL_s: 0.78195676, reconstruction loss: -52.52276843
# Clusters: 10
# Epoch: [176]  time: 63.8302, ELBO_train: -55.42377186, KL_z: 2.14995109, KL_s: 0.77138762, reconstruction loss: -52.50243315
# Clusters: 10
# Epoch: [177]  time: 64.2025, ELBO_train: -55.41081127, KL_z: 2.16285961, KL_s: 0.76877585, reconstruction loss: -52.47917581
# Clusters: 10
# Epoch: [178]  time: 64.5721, ELBO_train: -55.40591478, KL_z: 2.15060228, KL_s: 0.76097775, reconstruction loss: -52.49433475
# Clusters: 10
# Epoch: [179]  time: 64.9396, ELBO_train: -55.37825378, KL_z: 2.15644449, KL_s: 0.75155680, reconstruction loss: -52.47025248
# Clusters: 10
# Epoch: [180]  time: 65.3131, ELBO_train: -55.38916302, KL_z: 2.14516369, KL_s: 0.75293626, reconstruction loss: -52.49106307
# Clusters: 10
# Epoch: [181]  time: 65.6897, ELBO_train: -55.37160969, KL_z: 2.14687957, KL_s: 0.74191188, reconstruction loss: -52.48281823
# Clusters: 10
# Epoch: [182]  time: 66.0581, ELBO_train: -55.34093475, KL_z: 2.13390901, KL_s: 0.74453715, reconstruction loss: -52.46248859
# Clusters: 10
# Epoch: [183]  time: 66.4268, ELBO_train: -55.33553696, KL_z: 2.12869337, KL_s: 0.74321354, reconstruction loss: -52.46363005
# Clusters: 10
# Epoch: [184]  time: 66.7992, ELBO_train: -55.33044434, KL_z: 2.13403697, KL_s: 0.73663871, reconstruction loss: -52.45976866
# Clusters: 10
# Epoch: [185]  time: 67.1727, ELBO_train: -55.29404958, KL_z: 2.11721361, KL_s: 0.73359631, reconstruction loss: -52.44323966
# Clusters: 10
# Epoch: [186]  time: 67.5403, ELBO_train: -55.27661880, KL_z: 2.11691014, KL_s: 0.72213424, reconstruction loss: -52.43757442
# Clusters: 10
# Epoch: [187]  time: 67.9130, ELBO_train: -55.27547137, KL_z: 2.12008696, KL_s: 0.70623486, reconstruction loss: -52.44914955
# Clusters: 10
# Epoch: [188]  time: 68.2870, ELBO_train: -55.25545279, KL_z: 2.11291534, KL_s: 0.70207690, reconstruction loss: -52.44046056
# Clusters: 10
# Epoch: [189]  time: 68.6572, ELBO_train: -55.23265441, KL_z: 2.11724603, KL_s: 0.69358194, reconstruction loss: -52.42182644
# Clusters: 10
# Epoch: [190]  time: 69.0284, ELBO_train: -55.23556566, KL_z: 2.11498163, KL_s: 0.68916046, reconstruction loss: -52.43142357
# Clusters: 10
# Epoch: [191]  time: 69.4062, ELBO_train: -55.24437809, KL_z: 2.13258187, KL_s: 0.68428881, reconstruction loss: -52.42750741
# Clusters: 10
# Epoch: [192]  time: 69.7741, ELBO_train: -55.20946360, KL_z: 2.11701569, KL_s: 0.69443915, reconstruction loss: -52.39800876
# Clusters: 10
# Epoch: [193]  time: 70.1421, ELBO_train: -55.20140076, KL_z: 2.10521998, KL_s: 0.70681866, reconstruction loss: -52.38936212
# Clusters: 10
# Epoch: [194]  time: 70.5124, ELBO_train: -55.20400620, KL_z: 2.10098897, KL_s: 0.71496154, reconstruction loss: -52.38805568
# Clusters: 10
# Epoch: [195]  time: 70.8835, ELBO_train: -55.17988920, KL_z: 2.09858811, KL_s: 0.70568336, reconstruction loss: -52.37561773
# Clusters: 10
# Epoch: [196]  time: 71.2597, ELBO_train: -55.16595650, KL_z: 2.08798405, KL_s: 0.70859973, reconstruction loss: -52.36937272
# Clusters: 10
# Epoch: [197]  time: 71.6333, ELBO_train: -55.18224780, KL_z: 2.08441349, KL_s: 0.70765514, reconstruction loss: -52.39017917
# Clusters: 10
# Epoch: [198]  time: 72.0058, ELBO_train: -55.14148378, KL_z: 2.07808885, KL_s: 0.70014970, reconstruction loss: -52.36324524
# Clusters: 10
# Epoch: [199]  time: 72.3761, ELBO_train: -55.17401584, KL_z: 2.08600687, KL_s: 0.70399712, reconstruction loss: -52.38401185
# Training finished.

# %% [markdown]
# ### Test model

# %%
n_test_samples = data_test.shape[0]
# Adjust batch size if larger than dataset
batch_size = n_test_samples

# Number of batches
n_batches_test = int(np.floor(n_test_samples / batch_size))

# Compute real missing mask
miss_mask_test = torch.multiply(miss_mask_test, true_miss_mask_test)

with torch.no_grad(): 
    
    error_mode_global = 0.0
    avg_loss = 0.0
    samples_list = []
    
    for i in range(n_batches_test):
        data_list, miss_list = utils.next_batch(data_test, feat_types_dict, miss_mask_test, batch_size, i)

        # Mask unknown data (set unobserved values to zero)
        data_list_observed = [data * miss_list[:, i].view(batch_size, 1) for i, data in enumerate(data_list)]

        vae_res = vae_model.forward(data_list_observed, data_list, miss_list, tau=1e-3)
        samples_list.append(vae_res["samples"])
    
    
    #Concatenate samples in arrays
    est_data_test = utils.samples_concatenation(samples_list)[-1]
    data_test_transformed = utils.discrete_variables_transformation(data_test, feat_types_dict)
    est_data_test_transformed = utils.discrete_variables_transformation(est_data_test, feat_types_dict)

# %%
from utils import plot_true_vs_estimation
# Example Usage
torch.manual_seed(42)

true_values = data_test_transformed
estimated_values = est_data_test_transformed

# Call plotting function
plot_true_vs_estimation(true_values, estimated_values, miss_mask_test, feat_types_dict, num_sel_samples=50)
